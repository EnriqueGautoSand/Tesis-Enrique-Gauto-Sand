# %%
# !pip install keras-tuner==1.4.7
# !pip install pandas==2.1.4
# !pip install numpy==1.26.4
# !pip install tensorflow==2.15.0
# Out:
# Collecting keras-tuner==1.4.7
#   Downloading keras_tuner-1.4.7-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (from keras-tuner==1.4.7) (3.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras-tuner==1.4.7) (24.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from keras-tuner==1.4.7) (2.32.3)
# Collecting kt-legacy (from keras-tuner==1.4.7)
#   Downloading kt_legacy-1.0.5-py3-none-any.whl.metadata (221 bytes)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras->keras-tuner==1.4.7) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras->keras-tuner==1.4.7) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras->keras-tuner==1.4.7) (13.9.3)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras->keras-tuner==1.4.7) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras->keras-tuner==1.4.7) (3.11.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras->keras-tuner==1.4.7) (0.13.0)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.10/dist-packages (from keras->keras-tuner==1.4.7) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner==1.4.7) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner==1.4.7) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner==1.4.7) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner==1.4.7) (2024.8.30)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from optree->keras->keras-tuner==1.4.7) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras->keras-tuner==1.4.7) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras->keras-tuner==1.4.7) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras->keras-tuner==1.4.7) (0.1.2)
# Downloading keras_tuner-1.4.7-py3-none-any.whl (129 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.1/129.1 kB 5.2 MB/s eta 0:00:00
# Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Installing collected packages: kt-legacy, keras-tuner
# Successfully installed keras-tuner-1.4.7 kt-legacy-1.0.5
# Collecting pandas==2.1.4
#   Downloading pandas-2.1.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas==2.1.4) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas==2.1.4) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas==2.1.4) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas==2.1.4) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas==2.1.4) (1.16.0)
# Downloading pandas-2.1.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 34.8 MB/s eta 0:00:00
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.1.4 which is incompatible.
# Successfully installed pandas-2.1.4
# Requirement already satisfied: numpy==1.26.4 in /usr/local/lib/python3.10/dist-packages (1.26.4)
# Collecting tensorflow==2.15.0
#   Downloading tensorflow-2.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.4 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (18.1.1)
# Collecting ml-dtypes~=0.2.0 (from tensorflow==2.15.0)
#   Downloading ml_dtypes-0.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (1.26.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (4.12.2)
# Collecting wrapt<1.15,>=1.11.0 (from tensorflow==2.15.0)
#   Downloading wrapt-1.14.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (0.37.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (1.64.1)
# Collecting tensorboard<2.16,>=2.15 (from tensorflow==2.15.0)
#   Downloading tensorboard-2.15.2-py3-none-any.whl.metadata (1.7 kB)
# Collecting tensorflow-estimator<2.16,>=2.15.0 (from tensorflow==2.15.0)
#   Downloading tensorflow_estimator-2.15.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting keras<2.16,>=2.15.0 (from tensorflow==2.15.0)
#   Downloading keras-2.15.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow==2.15.0) (0.44.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (1.2.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.7)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.0.6)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.0.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.2.2)
# Downloading tensorflow-2.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (475.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 475.2/475.2 MB 3.6 MB/s eta 0:00:00
# Downloading keras-2.15.0-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 66.1 MB/s eta 0:00:00
# Downloading ml_dtypes-0.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 52.2 MB/s eta 0:00:00
# Downloading tensorboard-2.15.2-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 90.0 MB/s eta 0:00:00
# Downloading tensorflow_estimator-2.15.0-py2.py3-none-any.whl (441 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.0/442.0 kB 32.8 MB/s eta 0:00:00
# Downloading wrapt-1.14.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 7.7 MB/s eta 0:00:00
# Installing collected packages: wrapt, tensorflow-estimator, ml-dtypes, keras, tensorboard, tensorflow
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.16.0
#     Uninstalling wrapt-1.16.0:
#       Successfully uninstalled wrapt-1.16.0
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml-dtypes 0.4.1
#     Uninstalling ml-dtypes-0.4.1:
#       Successfully uninstalled ml-dtypes-0.4.1
#   Attempting uninstall: keras
#     Found existing installation: keras 3.4.1
#     Uninstalling keras-3.4.1:
#       Successfully uninstalled keras-3.4.1
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.17.0
#     Uninstalling tensorboard-2.17.0:
#       Successfully uninstalled tensorboard-2.17.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.17.0
#     Uninstalling tensorflow-2.17.0:
#       Successfully uninstalled tensorflow-2.17.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorstore 0.1.67 requires ml-dtypes>=0.3.1, but you have ml-dtypes 0.2.0 which is incompatible.
# tf-keras 2.17.0 requires tensorflow<2.18,>=2.17, but you have tensorflow 2.15.0 which is incompatible.
# Successfully installed keras-2.15.0 ml-dtypes-0.2.0 tensorboard-2.15.2 tensorflow-2.15.0 tensorflow-estimator-2.15.0 wrapt-1.14.1

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras #desde tensorflow 2 se importa keras,  como paquete integrado de tensorflow
import pandas as pd
import numpy as np
from math import sqrt
from numpy import concatenate
from matplotlib import pyplot
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM, GRU
import tensorflow as tf
from datetime import datetime
from keras.models import Sequential
from keras.layers import Dense,Flatten,LSTM,RepeatVector,TimeDistributed#, GRUCellV2
from copy import deepcopy

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Reading the data set, parsing the dates and inferring the date format to date time. We also fill the Nan’s with 0.
#agrego index_col=0 para solucionar Unnamed: 0 porque https://stackoverflow.com/questions/43983622/remove-unnamed-columns-in-pandas-dataframe
dataset = read_csv("/content/drive/MyDrive/a Tesis de Grado/Tesis Versiones/tesis 2024/GA4/editorial unam/preprocesamiento/outlier/salidaCSV/salidaKNN2024EditorialUniversitariaGA4.csv", index_col=0)
#dataset.fillna(0, inplace=True)//pasar nans a ceros
#revisar lo que hago en el otro dataset
print(dataset.size)
print(dataset.columns)

print(dataset.shape)
print(dataset)
dataset.head()
# Out:
# 21534
# Index(['Número de vistas de página', 'Usuarios nuevos', 'Usuarios',
#        'Número de sesiones por usuario', 'Sesiones', 'Argentina',
#        'Otros Paises', 'mobile', 'desktop', 'tablet',
#        'Categoría de dispositivo promedio', 'Categoría de dispositivo std',
#        'Windows', 'Android', 'Linux', 'Macintosh',
#        'Sistema operativo (not set)', 'iOS', 'Windows Phone', 'Chrome OS',
#        'Tizen', 'Sistema operativo promedio', 'Sistema operativo std',
#        'Organic Search', 'Social', 'Direct', 'Referral',
#        'Agrupación de canales predeterminada promedio',
#        'Agrupación de canales predeterminada std', 'mediana_de_medianas',
#        'lag_90', 'lag_180', 'lag_270', 'lag_360', 'mediana Dispositivos',
#        'mediana Sistema operativo',
#        'mediana Agrupación de canales predeterminada'],
#       dtype='object')
# (582, 37)
#      Número de vistas de página  Usuarios nuevos  Usuarios  \
# 0                          71.0             39.0      39.0
# 1                         279.0            142.0     147.0
# 2                         207.0            103.0     117.0
# 3                         110.0             77.0      81.0
# 4                          80.0             53.0      57.0
# ..                          ...              ...       ...
# 579                        82.0             25.0      28.0
# 580                        19.0              8.0       9.0
# 581                        48.0             13.0      18.0
# 582                       140.0             18.0      23.0
# 583                        55.0             27.0      30.0
#
#      Número de sesiones por usuario  Sesiones  Argentina  Otros Paises  \
# 0                          1.205128      47.0       70.0           1.0
# 1                          1.156463     170.0      222.0          57.0
# 2                          1.230769     144.0      174.0          33.0
# 3                          1.074074      87.0       86.0          24.0
# 4                          1.052632      60.0       60.0          20.0
# ..                              ...       ...        ...           ...
# 579                        1.153846      30.0       74.0           8.0
# 580                        1.125000       9.0       15.0           4.0
# 581                        1.375000      22.0       44.0           4.0
# 582                        1.318182      29.0       31.0         109.0
# 583                        1.066667      32.0       36.0          19.0
#
#      mobile  desktop  tablet  ...  \
# 0      37.0     34.0     0.0  ...
# 1     155.0    124.0     0.0  ...
# 2     124.0     81.0     2.0  ...
# 3      72.0     37.0     1.0  ...
# 4      48.0     30.0     2.0  ...
# ..      ...      ...     ...  ...
# 579    14.0     68.0     0.0  ...
# 580    17.0      2.0     0.0  ...
# 581    12.0     36.0     0.0  ...
# 582    14.0    126.0     0.0  ...
# 583    12.0     41.0     2.0  ...
#
#      Agrupación de canales predeterminada promedio  \
# 0                                            17.75
# 1                                            69.75
# 2                                            51.75
# 3                                            27.50
# 4                                            20.00
# ..                                             ...
# 579                                          20.50
# 580                                           4.75
# 581                                          12.00
# 582                                          35.00
# 583                                          13.75
#
#      Agrupación de canales predeterminada std  mediana_de_medianas     lag_90  \
# 0                                   17.210098           106.905607  124.82723
# 1                                   54.061886           106.905607  124.82723
# 2                                   42.310608           106.905607  124.82723
# 3                                    8.500000           106.905607  124.82723
# 4                                    8.154754           106.905607  124.82723
# ..                                        ...                  ...        ...
# 579                                 26.612967            63.500000   43.00000
# 580                                  4.866981            62.000000   36.00000
# 581                                 11.554220            62.000000  184.00000
# 582                                 47.544716            62.000000  154.00000
# 583                                 16.130330            64.000000  328.00000
#
#        lag_180    lag_270   lag_360  mediana Dispositivos  \
# 0    120.16915  118.39103  97.39639                  34.0
# 1    120.16915  118.39103  97.39639                 124.0
# 2    120.16915  118.39103  97.39639                  81.0
# 3    120.16915  118.39103  97.39639                  37.0
# 4    120.16915  118.39103  97.39639                  30.0
# ..         ...        ...       ...                   ...
# 579   63.00000  272.00000  25.00000                  14.0
# 580  174.00000  286.00000  47.00000                   2.0
# 581   91.00000  202.00000  39.00000                  12.0
# 582  241.00000  276.00000  25.00000                  14.0
# 583  204.00000  169.00000  27.00000                  12.0
#
#      mediana Sistema operativo  mediana Agrupación de canales predeterminada
# 0                          0.0                                          12.0
# 1                          0.0                                          61.5
# 2                          3.0                                          42.5
# 3                          0.0                                          27.5
# 4                          1.0                                          16.0
# ..                         ...                                           ...
# 579                        1.0                                           8.5
# 580                        0.0                                           4.0
# 581                        0.0                                          11.5
# 582                        0.0                                          11.5
# 583                        0.0                                           7.5
#
# [582 rows x 37 columns]
#    Número de vistas de página  Usuarios nuevos  Usuarios  \
# 0                        71.0             39.0      39.0
# 1                       279.0            142.0     147.0
# 2                       207.0            103.0     117.0
# 3                       110.0             77.0      81.0
# 4                        80.0             53.0      57.0
#
#    Número de sesiones por usuario  Sesiones  Argentina  Otros Paises  mobile  \
# 0                        1.205128      47.0       70.0           1.0    37.0
# 1                        1.156463     170.0      222.0          57.0   155.0
# 2                        1.230769     144.0      174.0          33.0   124.0
# 3                        1.074074      87.0       86.0          24.0    72.0
# 4                        1.052632      60.0       60.0          20.0    48.0
#
#    desktop  tablet  ...  Agrupación de canales predeterminada promedio  \
# 0     34.0     0.0  ...                                          17.75
# 1    124.0     0.0  ...                                          69.75
# 2     81.0     2.0  ...                                          51.75
# 3     37.0     1.0  ...                                          27.50
# 4     30.0     2.0  ...                                          20.00
#
#    Agrupación de canales predeterminada std  mediana_de_medianas     lag_90  \
# 0                                 17.210098           106.905607  124.82723
# 1                                 54.061886           106.905607  124.82723
# 2                                 42.310608           106.905607  124.82723
# 3                                  8.500000           106.905607  124.82723
# 4                                  8.154754           106.905607  124.82723
#
#      lag_180    lag_270   lag_360  mediana Dispositivos  \
# 0  120.16915  118.39103  97.39639                  34.0
# 1  120.16915  118.39103  97.39639                 124.0
# 2  120.16915  118.39103  97.39639                  81.0
# 3  120.16915  118.39103  97.39639                  37.0
# 4  120.16915  118.39103  97.39639                  30.0
#
#    mediana Sistema operativo  mediana Agrupación de canales predeterminada
# 0                        0.0                                          12.0
# 1                        0.0                                          61.5
# 2                        3.0                                          42.5
# 3                        0.0                                          27.5
# 4                        1.0                                          16.0
#
# [5 rows x 37 columns]

# %%
print(dataset.columns)
print(dataset.shape)
print(dataset.head())
# Out:
# Index(['Número de vistas de página', 'Usuarios nuevos', 'Usuarios',
#        'Número de sesiones por usuario', 'Sesiones', 'Argentina',
#        'Otros Paises', 'mobile', 'desktop', 'tablet',
#        'Categoría de dispositivo promedio', 'Categoría de dispositivo std',
#        'Windows', 'Android', 'Linux', 'Macintosh',
#        'Sistema operativo (not set)', 'iOS', 'Windows Phone', 'Chrome OS',
#        'Tizen', 'Sistema operativo promedio', 'Sistema operativo std',
#        'Organic Search', 'Social', 'Direct', 'Referral',
#        'Agrupación de canales predeterminada promedio',
#        'Agrupación de canales predeterminada std', 'mediana_de_medianas',
#        'lag_90', 'lag_180', 'lag_270', 'lag_360', 'mediana Dispositivos',
#        'mediana Sistema operativo',
#        'mediana Agrupación de canales predeterminada'],
#       dtype='object')
# (582, 37)
#    Número de vistas de página  Usuarios nuevos  Usuarios  \
# 0                        71.0             39.0      39.0
# 1                       279.0            142.0     147.0
# 2                       207.0            103.0     117.0
# 3                       110.0             77.0      81.0
# 4                        80.0             53.0      57.0
#
#    Número de sesiones por usuario  Sesiones  Argentina  Otros Paises  mobile  \
# 0                        1.205128      47.0       70.0           1.0    37.0
# 1                        1.156463     170.0      222.0          57.0   155.0
# 2                        1.230769     144.0      174.0          33.0   124.0
# 3                        1.074074      87.0       86.0          24.0    72.0
# 4                        1.052632      60.0       60.0          20.0    48.0
#
#    desktop  tablet  ...  Agrupación de canales predeterminada promedio  \
# 0     34.0     0.0  ...                                          17.75
# 1    124.0     0.0  ...                                          69.75
# 2     81.0     2.0  ...                                          51.75
# 3     37.0     1.0  ...                                          27.50
# 4     30.0     2.0  ...                                          20.00
#
#    Agrupación de canales predeterminada std  mediana_de_medianas     lag_90  \
# 0                                 17.210098           106.905607  124.82723
# 1                                 54.061886           106.905607  124.82723
# 2                                 42.310608           106.905607  124.82723
# 3                                  8.500000           106.905607  124.82723
# 4                                  8.154754           106.905607  124.82723
#
#      lag_180    lag_270   lag_360  mediana Dispositivos  \
# 0  120.16915  118.39103  97.39639                  34.0
# 1  120.16915  118.39103  97.39639                 124.0
# 2  120.16915  118.39103  97.39639                  81.0
# 3  120.16915  118.39103  97.39639                  37.0
# 4  120.16915  118.39103  97.39639                  30.0
#
#    mediana Sistema operativo  mediana Agrupación de canales predeterminada
# 0                        0.0                                          12.0
# 1                        0.0                                          61.5
# 2                        3.0                                          42.5
# 3                        0.0                                          27.5
# 4                        1.0                                          16.0
#
# [5 rows x 37 columns]

# %%
#predictor Flag
from copy import deepcopy
from datetime import datetime as dt

# %%
print( dataset[int(dataset.shape[0]*0.70):].shape)
# Out:
# (175, 37)

# %%
#115*0.75 = 86.25=86
#train_df,test_df = dataset[1:86], dataset[86:]
# parrtir en 80 - 20 segun la profe
# probar sin normalizar los datos, es decir sin escalarlos
#normalizar
#partir datos de entrenamiento y prueba
#dataset.shape[0]=1734 o es 115 en caso del ejemplo
print('dataset.shape[0]',dataset.shape[0],' dataset.shape[1]',dataset.shape[1])
formaFinal=int(dataset.shape[0]*0.70)#70% para train y 30% para test
print(formaFinal)
train_df,test_df = dataset[1:formaFinal], dataset[formaFinal:] #spliteo test/train
train = train_df
test = test_df
# Normalización del conjunto de entrenamiento
train_previo_log1p=deepcopy(train)
for column in train.columns:
    train.loc[:, column] = np.log1p(train[column])
train_previo_zscore = deepcopy(train)
for column in train.columns:
    mean = train[column].mean()  # Media del conjunto de entrenamiento
    std = train[column].std()    # Desviación estándar del conjunto de entrenamiento
    train[column] = (train[column] - mean) / std
    if std != 0:
        train[column] = (train[column] - mean) / std
    else:
        train[column] = 0
test_previo_log1p=deepcopy(test)
for column1 in test.columns:
    test.loc[:, column1] = np.log1p(test[column1])
# Normalización del conjunto de prueba
test_previo_zscore = deepcopy(test)
for column1 in test.columns:
    mean_train = train_previo_zscore[column1].mean()  # Media del conjunto de entrenamiento
    std_train = train_previo_zscore[column1].std()    # Desviación estándar del conjunto de entrenamiento
    if std_train != 0:
        test[column1] = (test[column1] - mean_train) / std_train
    else:
        test[column1] = 0 

print('train_df',train_df.shape)
print('test_df',test_df.shape)
print('test',test.shape,test.values[11])
# Out:
# dataset.shape[0] 582  dataset.shape[1] 37
# 407
# train_df (406, 37)
# test_df (175, 37)
# test (175, 37) [-0.28407843 -0.4619948  -0.65671607 -0.42441653 -0.59247904 -0.15608443
#  -0.87490798  0.76153848 -1.4490523   0.96955808 -0.31418626 -0.06197226
#  -1.35544577  0.83350937 -0.69017585 -0.88478924 -0.06853176 -1.11188821
#   0.         -0.15825676  0.         -0.36155957 -0.07642696 -0.01416593
#  -0.92576787 -0.48032504  0.83872693 -0.3245348  -0.1716917   0.57946221
#   0.89803703 -2.98687829 -0.49402867  3.62208021 -0.93122917 -0.49068071
#  -0.46747635]
# <ipython-input-8-882300e98399>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train[column] = (train[column] - mean) / std
# <ipython-input-8-882300e98399>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train[column] = (train[column] - mean) / std
# <ipython-input-8-882300e98399>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train[column] = 0
# <ipython-input-8-882300e98399>:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[column1] = (test[column1] - mean_train) / std_train
# <ipython-input-8-882300e98399>:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[column1] = 0  # O algún otro valor neutral que prefieras

# %%
#reshape a entrada

def split_series(series, n_past, n_future):
  #
  # n_past ==> no of past observations
  #
  # n_future ==> no of future observations
  #
  X, y = list(), list()
  for window_start in range(len(series)):
    past_end = window_start + n_past
    future_end = past_end + n_future
    if future_end > len(series):
      break
    # slicing the past and future parts of the window
    #past, future = series[window_start:past_end, :], series[past_end:future_end, :]
    #window_start cuando comienza  past_end es cuando termina y future_endes cuando termina las series a comparar, 0 es porque solo va a tomar la primera columna
    #la cual es la de total de vistas
    past, future = series[window_start:past_end, :], series[past_end:future_end, 0]
    X.append(past)
    y.append(future)
  return np.array(X), np.array(y)
# Out:
# "\nn_past = 50 #va a mirar 10 dias al pasado para predecir x dias a futuro\nn_future = 7 #anterior 5 #probar 7 dias a futuro\nn_features = dataset.shape[1] # Columnas totales del dataset\n\n#Now convert both the train and test data into samples using the split_series function.\n\nX_train, y_train = split_series(train.values,n_past, n_future)\nX_train = X_train.reshape((X_train.shape[0], X_train.shape[1],n_features))\n#y_train = y_train.reshape((y_train.shape[0], y_train.shape[1], n_features))\ny_train = y_train.reshape((y_train.shape[0], y_train.shape[1], 1)) #no hace falta reshapear\nX_test, y_test = split_series(test.values,n_past, n_future)\nX_test = X_test.reshape((X_test.shape[0], X_test.shape[1],n_features))\n#y_test = y_test.reshape((y_test.shape[0], y_test.shape[1], n_features))\ny_test = y_test.reshape((y_test.shape[0], y_test.shape[1], 1)) #no hace falta reshapear\nprint('X_train',X_train.shape,X_train)\nprint('y_train',y_train.shape,y_train)\nprint('X_test',X_test.shape,X_test)\nprint('y_test',y_test.shape,y_test)\n"

# %%
# !df -h
# Out:
# Filesystem      Size  Used Avail Use% Mounted on
# overlay         236G   35G  202G  15% /
# tmpfs            64M     0   64M   0% /dev
# shm             5.7G     0  5.7G   0% /dev/shm
# /dev/root       2.0G  1.2G  820M  59% /usr/sbin/docker-init
# tmpfs           6.4G  516K  6.4G   1% /var/colab
# /dev/sda1       242G   60G  183G  25% /kaggle/input
# tmpfs           6.4G     0  6.4G   0% /proc/acpi
# tmpfs           6.4G     0  6.4G   0% /proc/scsi
# tmpfs           6.4G     0  6.4G   0% /sys/firmware
# drive           100G   61G   40G  61% /content/drive

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 85
# model name	: Intel(R) Xeon(R) CPU @ 2.00GHz
# stepping	: 3
# microcode	: 0xffffffff
# cpu MHz		: 2000.172
# cache size	: 39424 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa mmio_stale_data retbleed bhi
# bogomips	: 4000.34
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 1
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 85
# model name	: Intel(R) Xeon(R) CPU @ 2.00GHz
# stepping	: 3
# microcode	: 0xffffffff
# cpu MHz		: 2000.172
# cache size	: 39424 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 1
# initial apicid	: 1
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa mmio_stale_data retbleed bhi
# bogomips	: 4000.34
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:

# %%
# !cat /proc/meminfo
# Out:
# MemTotal:       13290460 kB
# MemFree:         1493976 kB
# MemAvailable:   11241444 kB
# Buffers:          542048 kB
# Cached:          9119252 kB
# SwapCached:            0 kB
# Active:          1338104 kB
# Inactive:        9759388 kB
# Active(anon):       1788 kB
# Inactive(anon):  1436572 kB
# Active(file):    1336316 kB
# Inactive(file):  8322816 kB
# Unevictable:          20 kB
# Mlocked:              20 kB
# SwapTotal:             0 kB
# SwapFree:              0 kB
# Dirty:              2456 kB
# Writeback:             0 kB
# AnonPages:       1436236 kB
# Mapped:           727808 kB
# Shmem:              2156 kB
# KReclaimable:     413740 kB
# Slab:             489656 kB
# SReclaimable:     413740 kB
# SUnreclaim:        75916 kB
# KernelStack:        7696 kB
# PageTables:        27152 kB
# SecPageTables:         0 kB
# NFS_Unstable:          0 kB
# Bounce:                0 kB
# WritebackTmp:          0 kB
# CommitLimit:     6645228 kB
# Committed_AS:    3977928 kB
# VmallocTotal:   34359738367 kB
# VmallocUsed:       81852 kB
# VmallocChunk:          0 kB
# Percpu:             1144 kB
# HardwareCorrupted:     0 kB
# AnonHugePages:         0 kB
# ShmemHugePages:        0 kB
# ShmemPmdMapped:        0 kB
# FileHugePages:         0 kB
# FilePmdMapped:         0 kB
# CmaTotal:              0 kB
# CmaFree:               0 kB
# Unaccepted:            0 kB
# HugePages_Total:       0
# HugePages_Free:        0
# HugePages_Rsvd:        0
# HugePages_Surp:        0
# Hugepagesize:       2048 kB
# Hugetlb:               0 kB
# DirectMap4k:      185144 kB
# DirectMap2M:     6103040 kB
# DirectMap1G:     9437184 kB

# %%
# !/usr/local/cuda/bin/nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2023 NVIDIA Corporation
# Built on Tue_Aug_15_22:02:13_PDT_2023
# Cuda compilation tools, release 12.2, V12.2.140
# Build cuda_12.2.r12.2/compiler.33191640_0

# %%
# !which nvidia-smi
# Out:
# /opt/bin/nvidia-smi

# %%
# !nvidia-smi
# Out:
# Wed Oct 30 20:11:06 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
# !python --version
# Out:
# Python 3.10.12

# %%
import keras_tuner as kt
import datetime
from datetime import timedelta
from pytz import timezone
import tensorflow.keras.backend as K
import datetime
from datetime import timedelta
from pytz import timezone
print(tf. __version__)
print(pd. __version__)
print(np. __version__)
print(kt. __version__)
# Out:
# 2.15.0
# 2.1.4
# 1.26.4
# 1.4.7

# %%
# Establecer la semilla
seed_value = 42
import random  
# Establecer semillas
np.random.seed(seed_value)
random.seed(seed_value)
tf.random.set_seed(seed_value)
from tensorflow.keras.saving import register_keras_serializable

# %%
print('std',train_previo_zscore['Número de vistas de página'].std())
print('mean',train_previo_zscore['Número de vistas de página'].mean() )
# Out:
# std 0.8811457909642999
# mean 4.484421019032126

# %%
media_train=train_previo_zscore['Número de vistas de página'].std()
std_train=train_previo_zscore['Número de vistas de página'].mean()
#esta metrica esta en el codigo de github del ganador
@register_keras_serializable()
def smape_loss(y_true, y_pred):
    #revierto zscore
    media_train=4.484421019032126
    std_train =0.8811457909642999
    y_true=(y_true*std_train)+media_train
    y_pred=(y_pred*std_train)+media_train
    #revierto log1p
    y_true=tf.math.expm1(y_true)
    y_pred=tf.math.expm1(y_pred)
    epsilon = 0.1
    y_pred = tf.convert_to_tensor(y_pred)
    y_true = tf.cast(y_true, y_pred.dtype)
    # Calcular el denominador de SMAPE
    summ = tf.maximum(tf.abs(y_true) + tf.abs(y_pred) + epsilon, 0.5 + epsilon)

    # Calcular SMAPE
    smape = tf.abs(y_pred - y_true) / summ * 2.0

    # Retornar la media de SMAPE
    return K.mean(smape, axis=-1)

@register_keras_serializable()
def mae_denorm(y_true, y_pred):
    #revierto zscore
    media_train=4.484421019032126
    std_train =0.8811457909642999
    y_true1=(y_true*std_train)+media_train
    y_pred1=(y_pred*std_train)+media_train
    #revierto log1p
    y_true2=tf.math.expm1(y_true1)
    y_pred2=tf.math.expm1(y_pred1)

    return tf.keras.losses.mean_absolute_error(y_true2, y_pred2)

# %%
pathModelosJsonMejor="/content/drive/MyDrive/a Tesis de Grado/Tesis Versiones/tesis 2024/UA/editorial universitaria/modelos/modelos resultados/mejores modelos guardados/modelo"
nombreMejorModeloMejor="/ ndays Editorial 60hyperband mae 60 zscore.h5"#el mejor modelo es el hyperband de 28 dias y 107 época

reconstructed_model2 = tf.keras.models.load_model(pathModelosJsonMejor+nombreMejorModeloMejor,custom_objects={'smape_loss':smape_loss,'mae_denorm':mae_denorm})

# %%
from tensorflow.keras.callbacks import TensorBoard

# %%
pathModelosJson="/content/drive/MyDrive/a Tesis de Grado/Tesis Versiones/tesis 2024/GA4/editorial unam/modelos/modelos resultados/prueba 500 epocas 1 capa sin early stopping Editorial GA4 Mejor de Editorial UA"
nombreMejorModelo="ndays60EditorialGA4_500epochs1capa.h5"
class PrintTimeCallback(tf.keras.callbacks.Callback):#https://www.tensorflow.org/guide/keras/writing_your_own_callbacks
    def on_epoch_end(self, epoch, logs=None):
        cambio=datetime.datetime.now(timezone('UTC')) - timedelta(hours=3)
        salida=f"{cambio:%Y-%m-%d %H:%M:%S }"
        print('Tiempo on_epoch_end',salida)
n_past=60
cambio=datetime.datetime.now(timezone('UTC')) - timedelta(hours=3)
tiempoFinal=f"{cambio:%Y-%m-%d %H:%M:%S }"
print('Tiempo  Inicio y n_past',tiempoFinal , ' n_past:-->',n_past)
n_future = 60
n_features = train.shape[1]
X_train, y_train = split_series(train.values,n_past, n_future)
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1],n_features))
y_train = y_train.reshape((y_train.shape[0], y_train.shape[1], 1)) #no hace falta reshapear
X_test, y_test = split_series(test.values,n_past, n_future)
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1],n_features))
y_test = y_test.reshape((y_test.shape[0], y_test.shape[1], 1)) #no hace falta reshapear
logpaht=pathModelosJson+f"/logsndays60_500epochs1capa"
from tensorflow.keras.callbacks import ReduceLROnPlateau
#reduce_lr = ReduceLROnPlateau(monitor='val_smape_loss_zscore', factor=0.5, patience=5, min_lr=1e-50)
callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=50)#https://pub.towardsai.net/keras-earlystopping-callback-to-train-the-neural-networks-perfectly-2a3f865148f7
mcp_save = tf.keras.callbacks.ModelCheckpoint(pathModelosJson+"/"+'hyperband{epoch:03d}-{val_loss:03f}-'+nombreMejorModelo, save_best_only=True, monitor='val_loss', mode='min')#https://stackoverflow.com/questions/48285129/saving-best-model-in-keras
history_modelo=reconstructed_model2.fit(X_train,y_train,epochs=500,validation_data=(X_test,y_test),batch_size=192,verbose=1,
                                        callbacks=[PrintTimeCallback(),
                                                   mcp_save,#reduce_lr,
                                                   TensorBoard(log_dir=logpaht, write_graph=False, profile_batch=0)
                                                   ])
cambio=datetime.datetime.now(timezone('UTC')) - timedelta(hours=3)
tiempoFinalDespues=f"{cambio:%Y-%m-%d %H:%M:%S }"
print('Tiempo Final y n_past',tiempoFinalDespues , ' n_past:-->',n_past)
#reentreno 70-30
# Out:
# Tiempo  Inicio y n_past 2024-10-30 17:12:34   n_past:--> 60
# Epoch 1/500
# 1/2 [==============>...............] - ETA: 3s - loss: 3.3942 - smape_loss: 1.8375 - mae_denorm: 18.6827Tiempo on_epoch_end 2024-10-30 17:12:40
# 2/2 [==============================] - 5s 1s/step - loss: 3.3767 - smape_loss: 1.8363 - mae_denorm: 18.3609 - val_loss: 0.7364 - val_smape_loss: 0.6036 - val_mae_denorm: 71.0498
# Epoch 2/500
# 1/2 [==============>...............] - ETA: 0s - loss: 3.0995 - smape_loss: 1.7890 - mae_denorm: 14.2397Tiempo on_epoch_end 2024-10-30 17:12:40
# 2/2 [==============================] - 0s 88ms/step - loss: 3.0046 - smape_loss: 1.7803 - mae_denorm: 12.9780 - val_loss: 0.7519 - val_smape_loss: 0.6148 - val_mae_denorm: 72.1639
# Epoch 3/500
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 1/2 [==============>...............] - ETA: 0s - loss: 2.6617 - smape_loss: 1.7188 - mae_denorm: 8.7876Tiempo on_epoch_end 2024-10-30 17:12:40
# 2/2 [==============================] - 0s 91ms/step - loss: 2.5257 - smape_loss: 1.6856 - mae_denorm: 8.0332 - val_loss: 0.7735 - val_smape_loss: 0.6300 - val_mae_denorm: 73.7455
# Epoch 4/500
# 1/2 [==============>...............] - ETA: 0s - loss: 2.0802 - smape_loss: 1.5773 - mae_denorm: 5.0147Tiempo on_epoch_end 2024-10-30 17:12:40
# 2/2 [==============================] - 0s 86ms/step - loss: 2.0077 - smape_loss: 1.5558 - mae_denorm: 4.5880 - val_loss: 0.8019 - val_smape_loss: 0.6494 - val_mae_denorm: 75.8240
# Epoch 5/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5904 - smape_loss: 1.4339 - mae_denorm: 2.6948Tiempo on_epoch_end 2024-10-30 17:12:40
# 2/2 [==============================] - 0s 79ms/step - loss: 1.5250 - smape_loss: 1.4114 - mae_denorm: 2.5191 - val_loss: 0.8363 - val_smape_loss: 0.6724 - val_mae_denorm: 78.3841
# Epoch 6/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1685 - smape_loss: 1.3060 - mae_denorm: 1.4827Tiempo on_epoch_end 2024-10-30 17:12:40
# 2/2 [==============================] - 0s 81ms/step - loss: 1.1628 - smape_loss: 1.3173 - mae_denorm: 1.4823 - val_loss: 0.8752 - val_smape_loss: 0.6977 - val_mae_denorm: 81.3103
# Epoch 7/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0080 - smape_loss: 1.2989 - mae_denorm: 1.1739Tiempo on_epoch_end 2024-10-30 17:12:40
# 2/2 [==============================] - 0s 82ms/step - loss: 1.0099 - smape_loss: 1.2866 - mae_denorm: 1.1343 - val_loss: 0.9139 - val_smape_loss: 0.7222 - val_mae_denorm: 84.2922
# Epoch 8/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0420 - smape_loss: 1.2629 - mae_denorm: 1.0889Tiempo on_epoch_end 2024-10-30 17:12:40
# 2/2 [==============================] - 0s 79ms/step - loss: 1.0453 - smape_loss: 1.2571 - mae_denorm: 1.0855 - val_loss: 0.9463 - val_smape_loss: 0.7422 - val_mae_denorm: 86.9167
# Epoch 9/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1155 - smape_loss: 1.2281 - mae_denorm: 1.0787Tiempo on_epoch_end 2024-10-30 17:12:41
# 2/2 [==============================] - 0s 91ms/step - loss: 1.1233 - smape_loss: 1.2376 - mae_denorm: 1.0981 - val_loss: 0.9676 - val_smape_loss: 0.7551 - val_mae_denorm: 88.7527
# Epoch 10/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1958 - smape_loss: 1.2429 - mae_denorm: 1.1345Tiempo on_epoch_end 2024-10-30 17:12:41
# 2/2 [==============================] - 0s 85ms/step - loss: 1.1798 - smape_loss: 1.2331 - mae_denorm: 1.1139 - val_loss: 0.9775 - val_smape_loss: 0.7609 - val_mae_denorm: 89.6743
# Epoch 11/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1966 - smape_loss: 1.2362 - mae_denorm: 1.1292Tiempo on_epoch_end 2024-10-30 17:12:41
# 2/2 [==============================] - 0s 88ms/step - loss: 1.1809 - smape_loss: 1.2266 - mae_denorm: 1.1112 - val_loss: 0.9775 - val_smape_loss: 0.7608 - val_mae_denorm: 89.7567
# Epoch 12/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1452 - smape_loss: 1.2185 - mae_denorm: 1.1160Tiempo on_epoch_end 2024-10-30 17:12:41
# 2/2 [==============================] - 0s 93ms/step - loss: 1.1318 - smape_loss: 1.2182 - mae_denorm: 1.0884 - val_loss: 0.9700 - val_smape_loss: 0.7562 - val_mae_denorm: 89.1870
# Epoch 13/500
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0547 - smape_loss: 1.2094 - mae_denorm: 1.0411Tiempo on_epoch_end 2024-10-30 17:12:41
# 2/2 [==============================] - 0s 88ms/step - loss: 1.0554 - smape_loss: 1.2121 - mae_denorm: 1.0501 - val_loss: 0.9580 - val_smape_loss: 0.7489 - val_mae_denorm: 88.2226
# Epoch 14/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9867 - smape_loss: 1.2081 - mae_denorm: 0.9952Tiempo on_epoch_end 2024-10-30 17:12:41
# 2/2 [==============================] - 0s 75ms/step - loss: 0.9776 - smape_loss: 1.2119 - mae_denorm: 1.0038 - val_loss: 0.9443 - val_smape_loss: 0.7404 - val_mae_denorm: 87.1138
# Epoch 15/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9303 - smape_loss: 1.2234 - mae_denorm: 0.9769Tiempo on_epoch_end 2024-10-30 17:12:41
# 2/2 [==============================] - 0s 79ms/step - loss: 0.9239 - smape_loss: 1.2245 - mae_denorm: 0.9645 - val_loss: 0.9306 - val_smape_loss: 0.7320 - val_mae_denorm: 86.0287
# Epoch 16/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8842 - smape_loss: 1.2262 - mae_denorm: 0.9304Tiempo on_epoch_end 2024-10-30 17:12:41
# 2/2 [==============================] - 0s 80ms/step - loss: 0.8973 - smape_loss: 1.2314 - mae_denorm: 0.9406 - val_loss: 0.9192 - val_smape_loss: 0.7248 - val_mae_denorm: 85.1411
# Epoch 17/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8974 - smape_loss: 1.2409 - mae_denorm: 0.9072Tiempo on_epoch_end 2024-10-30 17:12:41
# 2/2 [==============================] - 0s 77ms/step - loss: 0.8986 - smape_loss: 1.2388 - mae_denorm: 0.9417 - val_loss: 0.9114 - val_smape_loss: 0.7198 - val_mae_denorm: 84.5660
# Epoch 18/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9111 - smape_loss: 1.2306 - mae_denorm: 0.9478Tiempo on_epoch_end 2024-10-30 17:12:42
# 2/2 [==============================] - 0s 83ms/step - loss: 0.9167 - smape_loss: 1.2372 - mae_denorm: 0.9636 - val_loss: 0.9079 - val_smape_loss: 0.7176 - val_mae_denorm: 84.3600
# Epoch 19/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9167 - smape_loss: 1.2252 - mae_denorm: 1.0073Tiempo on_epoch_end 2024-10-30 17:12:42
# 2/2 [==============================] - 0s 80ms/step - loss: 0.9300 - smape_loss: 1.2351 - mae_denorm: 0.9818 - val_loss: 0.9087 - val_smape_loss: 0.7179 - val_mae_denorm: 84.5188
# Epoch 20/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9210 - smape_loss: 1.2276 - mae_denorm: 0.9859Tiempo on_epoch_end 2024-10-30 17:12:42
# 2/2 [==============================] - 0s 135ms/step - loss: 0.9266 - smape_loss: 1.2315 - mae_denorm: 0.9782 - val_loss: 0.9134 - val_smape_loss: 0.7207 - val_mae_denorm: 85.0140
# Epoch 21/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9143 - smape_loss: 1.2278 - mae_denorm: 0.9621Tiempo on_epoch_end 2024-10-30 17:12:42
# 2/2 [==============================] - 0s 88ms/step - loss: 0.9107 - smape_loss: 1.2259 - mae_denorm: 0.9578 - val_loss: 0.9207 - val_smape_loss: 0.7251 - val_mae_denorm: 85.7565
# Epoch 22/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9011 - smape_loss: 1.2210 - mae_denorm: 0.9075Tiempo on_epoch_end 2024-10-30 17:12:42
# 2/2 [==============================] - 0s 90ms/step - loss: 0.8925 - smape_loss: 1.2138 - mae_denorm: 0.9361 - val_loss: 0.9292 - val_smape_loss: 0.7302 - val_mae_denorm: 86.6198
# Epoch 23/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8809 - smape_loss: 1.1969 - mae_denorm: 0.9421Tiempo on_epoch_end 2024-10-30 17:12:42
# 2/2 [==============================] - 0s 132ms/step - loss: 0.8794 - smape_loss: 1.1940 - mae_denorm: 0.9214 - val_loss: 0.9372 - val_smape_loss: 0.7350 - val_mae_denorm: 87.4515
# Epoch 24/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8787 - smape_loss: 1.1818 - mae_denorm: 0.9259Tiempo on_epoch_end 2024-10-30 17:12:42
# 2/2 [==============================] - 0s 97ms/step - loss: 0.8759 - smape_loss: 1.1775 - mae_denorm: 0.9180 - val_loss: 0.9439 - val_smape_loss: 0.7390 - val_mae_denorm: 88.1729
# Epoch 25/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8778 - smape_loss: 1.1649 - mae_denorm: 0.9131Tiempo on_epoch_end 2024-10-30 17:12:43
# 2/2 [==============================] - 0s 91ms/step - loss: 0.8779 - smape_loss: 1.1659 - mae_denorm: 0.9203 - val_loss: 0.9484 - val_smape_loss: 0.7415 - val_mae_denorm: 88.6879
# Epoch 26/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8829 - smape_loss: 1.1621 - mae_denorm: 0.9073Tiempo on_epoch_end 2024-10-30 17:12:43
# 2/2 [==============================] - 0s 92ms/step - loss: 0.8802 - smape_loss: 1.1591 - mae_denorm: 0.9230 - val_loss: 0.9501 - val_smape_loss: 0.7425 - val_mae_denorm: 88.9471
# Epoch 27/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8725 - smape_loss: 1.1378 - mae_denorm: 0.9065Tiempo on_epoch_end 2024-10-30 17:12:43
# 2/2 [==============================] - 0s 144ms/step - loss: 0.8803 - smape_loss: 1.1546 - mae_denorm: 0.9232 - val_loss: 0.9495 - val_smape_loss: 0.7420 - val_mae_denorm: 88.9801
# Epoch 28/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8818 - smape_loss: 1.1630 - mae_denorm: 0.9308Tiempo on_epoch_end 2024-10-30 17:12:43
# 2/2 [==============================] - 0s 111ms/step - loss: 0.8770 - smape_loss: 1.1515 - mae_denorm: 0.9201 - val_loss: 0.9469 - val_smape_loss: 0.7404 - val_mae_denorm: 88.8100
# Epoch 29/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8732 - smape_loss: 1.1554 - mae_denorm: 0.9194Tiempo on_epoch_end 2024-10-30 17:12:43
# 2/2 [==============================] - 0s 80ms/step - loss: 0.8720 - smape_loss: 1.1506 - mae_denorm: 0.9152 - val_loss: 0.9433 - val_smape_loss: 0.7381 - val_mae_denorm: 88.5404
# Epoch 30/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8732 - smape_loss: 1.1542 - mae_denorm: 0.9105Tiempo on_epoch_end 2024-10-30 17:12:43
# 2/2 [==============================] - 0s 80ms/step - loss: 0.8674 - smape_loss: 1.1503 - mae_denorm: 0.9106 - val_loss: 0.9395 - val_smape_loss: 0.7358 - val_mae_denorm: 88.2511
# Epoch 31/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8668 - smape_loss: 1.1531 - mae_denorm: 0.8985Tiempo on_epoch_end 2024-10-30 17:12:43
# 2/2 [==============================] - 0s 84ms/step - loss: 0.8651 - smape_loss: 1.1518 - mae_denorm: 0.9081 - val_loss: 0.9362 - val_smape_loss: 0.7337 - val_mae_denorm: 87.9963
# Epoch 32/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.
500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8101 - smape_loss: 1.0840 - mae_denorm: 0.8781Tiempo on_epoch_end 2024-10-30 17:12:49
# 2/2 [==============================] - 0s 65ms/step - loss: 0.8116 - smape_loss: 1.0809 - mae_denorm: 0.8627 - val_loss: 0.9544 - val_smape_loss: 0.7445 - val_mae_denorm: 90.0191
# Epoch 89/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8215 - smape_loss: 1.0802 - mae_denorm: 0.8867Tiempo on_epoch_end 2024-10-30 17:12:49
# 2/2 [==============================] - 0s 66ms/step - loss: 0.8108 - smape_loss: 1.0798 - mae_denorm: 0.8621 - val_loss: 0.9548 - val_smape_loss: 0.7448 - val_mae_denorm: 90.0434
# Epoch 90/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8124 - smape_loss: 1.0784 - mae_denorm: 0.8504Tiempo on_epoch_end 2024-10-30 17:12:50
# 2/2 [==============================] - 0s 60ms/step - loss: 0.8101 - smape_loss: 1.0786 - mae_denorm: 0.8615 - val_loss: 0.9552 - val_smape_loss: 0.7451 - val_mae_denorm: 90.0685
# Epoch 91/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8204 - smape_loss: 1.0801 - mae_denorm: 0.8500Tiempo on_epoch_end 2024-10-30 17:12:50
# 2/2 [==============================] - 0s 58ms/step - loss: 0.8094 - smape_loss: 1.0774 - mae_denorm: 0.8610 - val_loss: 0.9553 - val_smape_loss: 0.7452 - val_mae_denorm: 90.0597
# Epoch 92/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8117 - smape_loss: 1.0699 - mae_denorm: 0.8440Tiempo on_epoch_end 2024-10-30 17:12:50
# 2/2 [==============================] - 0s 79ms/step - loss: 0.8087 - smape_loss: 1.0761 - mae_denorm: 0.8602 - val_loss: 0.9551 - val_smape_loss: 0.7450 - val_mae_denorm: 90.0108
# Epoch 93/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8033 - smape_loss: 1.0715 - mae_denorm: 0.8625Tiempo on_epoch_end 2024-10-30 17:12:50
# 2/2 [==============================] - 0s 67ms/step - loss: 0.8080 - smape_loss: 1.0751 - mae_denorm: 0.8595 - val_loss: 0.9548 - val_smape_loss: 0.7449 - val_mae_denorm: 89.9547
# Epoch 94/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8126 - smape_loss: 1.0893 - mae_denorm: 0.8785Tiempo on_epoch_end 2024-10-30 17:12:50
# 2/2 [==============================] - 0s 57ms/step - loss: 0.8075 - smape_loss: 1.0739 - mae_denorm: 0.8588 - val_loss: 0.9551 - val_smape_loss: 0.7452 - val_mae_denorm: 89.9661
# Epoch 95/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7941 - smape_loss: 1.0668 - mae_denorm: 0.8628Tiempo on_epoch_end 2024-10-30 17:12:50
# 2/2 [==============================] - 0s 58ms/step - loss: 0.8066 - smape_loss: 1.0726 - mae_denorm: 0.8582 - val_loss: 0.9566 - val_smape_loss: 0.7460 - val_mae_denorm: 90.0790
# Epoch 96/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8069 - smape_loss: 1.0701 - mae_denorm: 0.8483Tiempo on_epoch_end 2024-10-30 17:12:50
# 2/2 [==============================] - 0s 57ms/step - loss: 0.8060 - smape_loss: 1.0720 - mae_denorm: 0.8580 - val_loss: 0.9580 - val_smape_loss: 0.7469 - val_mae_denorm: 90.1916
# Epoch 97/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.
500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7978 - smape_loss: 1.0529 - mae_denorm: 0.8541Tiempo on_epoch_end 2024-10-30 17:12:51
# 2/2 [==============================] - 0s 59ms/step - loss: 0.7984 - smape_loss: 1.0579 - mae_denorm: 0.8510 - val_loss: 0.9633 - val_smape_loss: 0.7506 - val_mae_denorm: 90.2553
# Epoch 108/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8093 - smape_loss: 1.0637 - mae_denorm: 0.8698Tiempo on_epoch_end 2024-10-30 17:12:51
# 2/2 [==============================] - 0s 65ms/step - loss: 0.7977 - smape_loss: 1.0571 - mae_denorm: 0.8505 - val_loss: 0.9648 - val_smape_loss: 0.7516 - val_mae_denorm: 90.3469
# Epoch 109/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7884 - smape_loss: 1.0608 - mae_denorm: 0.8555Tiempo on_epoch_end 2024-10-30 17:12:51
# 2/2 [==============================] - 0s 65ms/step - loss: 0.7969 - smape_loss: 1.0563 - mae_denorm: 0.8501 - val_loss: 0.9661 - val_smape_loss: 0.7524 - val_mae_denorm: 90.4214
# Epoch 110/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8036 - smape_loss: 1.0698 - mae_denorm: 0.8836Tiempo on_epoch_end 2024-10-30 17:12:51
# 2/2 [==============================] - 0s 68ms/step - loss: 0.7964 - smape_loss: 1.0556 - mae_denorm: 0.8498 - val_loss: 0.9669 - val_smape_loss: 0.7530 - val_mae_denorm: 90.4556
# Epoch 111/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8003 - smape_loss: 1.0492 - mae_denorm: 0.8314Tiempo on_epoch_end 2024-10-30 17:12:52
# 2/2 [==============================] - 0s 57ms/step - loss: 0.7957 - smape_loss: 1.0542 - mae_denorm: 0.8492 - val_loss: 0.9670 - val_smape_loss: 0.7531 - val_mae_denorm: 90.4214
# Epoch 112/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7857 - smape_loss: 1.0391 - mae_denorm: 0.8480Tiempo on_epoch_end 2024-10-30 17:12:52
# 2/2 [==============================] - 0s 64ms/step - loss: 0.7949 - smape_loss: 1.0518 - mae_denorm: 0.8483 - val_loss: 0.9669 - val_smape_loss: 0.7531 - val_mae_denorm: 90.3730
# Epoch 113/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7935 - smape_loss: 1.0497 - mae_denorm: 0.8490Tiempo on_epoch_end 2024-10-30 17:12:52
# 2/2 [==============================] - 0s 61ms/step - loss: 0.7943 - smape_loss: 1.0497 - mae_denorm: 0.8476 - val_loss: 0.9676 - val_smape_loss: 0.7536 - val_mae_denorm: 90.3871
# Epoch 114/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7989 - smape_loss: 1.0484 - mae_denorm: 0.8416Tiempo on_epoch_end 2024-10-30 17:12:52
# 2/2 [==============================] - 0s 73ms/step - loss: 0.7937 - smape_loss: 1.0484 - mae_denorm: 0.8471 - val_loss: 0.9688 - val_smape_loss: 0.7544 - val_mae_denorm: 90.4445
# Epoch 115/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7895 - smape_loss: 1.0435 - mae_denorm: 0.8484Tiempo on_epoch_end 2024-10-30 17:12:52
# 2/2 [==============================] - 0s 63ms/step - loss: 0.7929 - smape_loss: 1.0474 - mae_denorm: 0.8465 - val_loss: 0.9701 - val_smape_loss: 0.7552 - val_mae_denorm: 90.5010
# Epoch 116/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.8049 - smape_loss: 1.0547 - mae_denorm: 0.8515Tiempo on_epoch_end 2024-10-30 17:12:52
# 2/2 [==============================] - 0s 74ms/step - loss: 0.7923 - smape_loss: 1.0468 - mae_denorm: 0.8461 - val_loss: 0.9710 - val_smape_loss: 0.7558 - val_mae_denorm: 90.5346
# Epoch 117/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7909 - smape_loss: 1.0431 - mae_denorm: 0.8270Tiempo on_epoch_end 2024-10-30 17:12:52
# 2/2 [==============================] - 0s 65ms/step - loss: 0.7916 - smape_loss: 1.0455 - mae_denorm: 0.8455 - val_loss: 0.9714 - val_smape_loss: 0.7561 - val_mae_denorm: 90.5145
# Epoch 118/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7930 - smape_loss: 1.0479 - mae_denorm: 0.8375Tiempo on_epoch_end 2024-10-30 17:12:52
# 2/2 [==============================] - 0s 74ms/step - loss: 0.7909 - smape_loss: 1.0436 - mae_denorm: 0.8448 - val_loss: 0.9717 - val_smape_loss: 0.7564 - val_mae_denorm: 90.4846
# Epoch 119/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7903 - smape_loss: 1.0290 - mae_denorm: 0.8073Tiempo on_epoch_end 2024-10-30 17:12:52
# 2/2 [==============================] - 0s 72ms/step - loss: 0.7903 - smape_loss: 1.0418 - mae_denorm: 0.8442 - val_loss: 0.9725 - val_smape_loss: 0.7569 - val_mae_denorm: 90.5007
# Epoch 120/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7936 - smape_loss: 1.0448 - mae_denorm: 0.8606Tiempo on_epoch_end 2024-10-30 17:12:52
# 2/2 [==============================] - 0s 68ms/step - loss: 0.7897 - smape_loss: 1.0403 - mae_denorm: 0.8436 - val_loss: 0.9734 - val_smape_loss: 0.7575 - val_mae_denorm: 90.5412
# Epoch 121/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7846 - smape_loss: 1.0480 - mae_denorm: 0.8236Tiempo on_epoch_end 2024-10-30 17:12:52
# 2/2 [==============================] - 0s 61ms/step - loss: 0.7890 - smape_loss: 1.0392 - mae_denorm: 0.8431 - val_loss: 0.9747 - val_smape_loss: 0.7583 - val_mae_denorm: 90.6102
# Epoch 122/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7840 - smape_loss: 1.0446 - mae_denorm: 0.8256Tiempo on_epoch_end 2024-10-30 17:12:53
# 2/2 [==============================] - 0s 61ms/step - loss: 0.7883 - smape_loss: 1.0383 - mae_denorm: 0.8427 - val_loss: 0.9758 - val_smape_loss: 0.7591 - val_mae_denorm: 90.6758
# Epoch 123/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7828 - smape_loss: 1.0335 - mae_denorm: 0.8600Tiempo on_epoch_end 2024-10-30 17:12:53
# 2/2 [==============================] - 0s 71ms/step - loss: 0.7877 - smape_loss: 1.0376 - mae_denorm: 0.8425 - val_loss: 0.9768 - val_smape_loss: 0.7597 - val_mae_denorm: 90.7327
# Epoch 124/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7853 - smape_loss: 1.0219 - mae_denorm: 0.8450Tiempo on_epoch_end 2024-10-30 17:12:53
# 2/2 [==============================] - 0s 75ms/step - loss: 0.7872 - smape_loss: 1.0361 - mae_denorm: 0.8422 - val_loss: 0.9770 - val_smape_loss: 0.7599 - val_mae_denorm: 90.7102
# Epoch 125/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7993 - smape_loss: 1.0428 - mae_denorm: 0.8293Tiempo on_epoch_end 2024-10-30 17:12:53
# 2/2 [==============================] - 0s 64ms/step - loss: 0.7865 - smape_loss: 1.0334 - mae_denorm: 0.8415 - val_loss: 0.9772 - val_smape_loss: 0.7600 - val_mae_denorm: 90.6704
# Epoch 126/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7929 - smape_loss: 1.0429 - mae_denorm: 0.8440Tiempo on_epoch_end 2024-10-30 17:12:53
# 2/2 [==============================] - 0s 60ms/step - loss: 0.7859 - smape_loss: 1.0313 - mae_denorm: 0.8410 - val_loss: 0.9780 - val_smape_loss: 0.7606 - val_mae_denorm: 90.6693
# Epoch 127/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7752 - smape_loss: 1.0371 - mae_denorm: 0.8762Tiempo on_epoch_end 2024-10-30 17:12:53
# 2/2 [==============================] - 0s 58ms/step - loss: 0.7852 - smape_loss: 1.0302 - mae_denorm: 0.8405 - val_loss: 0.9795 - val_smape_loss: 0.7616 - val_mae_denorm: 90.7284
# Epoch 128/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7781 - smape_loss: 1.0330 - mae_denorm: 0.8518Tiempo on_epoch_end 2024-10-30 17:12:53
# 2/2 [==============================] - 0s 59ms/step - loss: 0.7847 - smape_loss: 1.0307 - mae_denorm: 0.8403 - val_loss: 0.9809 - val_smape_loss: 0.7625 - val_mae_denorm: 90.7696
# Epoch 129/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7844 - smape_loss: 1.0236 - mae_denorm: 0.8609Tiempo on_epoch_end 2024-10-30 17:12:53
# 2/2 [==============================] - 0s 71ms/step - loss: 0.7841 - smape_loss: 1.0300 - mae_denorm: 0.8398 - val_loss: 0.9811 - val_smape_loss: 0.7627 - val_mae_denorm: 90.7013
# Epoch 130/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7767 - smape_loss: 1.0270 - mae_denorm: 0.8638Tiempo on_epoch_end 2024-10-30 17:12:53
# 2/2 [==============================] - 0s 73ms/step - loss: 0.7835 - smape_loss: 1.0275 - mae_denorm: 0.8391 - val_loss: 0.9817 - val_smape_loss: 0.7631 - val_mae_denorm: 90.6709
# Epoch 131/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7860 - smape_loss: 1.0336 - mae_denorm: 0.8411Tiempo on_epoch_end 2024-10-30 17:12:53
# 2/2 [==============================] - 0s 82ms/step - loss: 0.7829 - smape_loss: 1.0258 - mae_denorm: 0.8387 - val_loss: 0.9830 - val_smape_loss: 0.7640 - val_mae_denorm: 90.7206
# Epoch 132/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7880 - smape_loss: 1.0401 - mae_denorm: 0.8549Tiempo on_epoch_end 2024-10-30 17:12:54
# 2/2 [==============================] - 0s 84ms/step - loss: 0.7823 - smape_loss: 1.0254 - mae_denorm: 0.8384 - val_loss: 0.9842 - val_smape_loss: 0.7648 - val_mae_denorm: 90.7389
# Epoch 133/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7769 - smape_loss: 1.0196 - mae_denorm: 0.8174Tiempo on_epoch_end 2024-10-30 17:12:54
# 2/2 [==============================] - 0s 123ms/step - loss: 0.7818 - smape_loss: 1.0250 - mae_denorm: 0.8381 - val_loss: 0.9850 - val_smape_loss: 0.7654 - val_mae_denorm: 90.7352
# Epoch 134/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7741 - smape_loss: 1.0174 - mae_denorm: 0.8295Tiempo on_epoch_end 2024-10-30 17:12:54
# 2/2 [==============================] - 0s 87ms/step - loss: 0.7813 - smape_loss: 1.0235 - mae_denorm: 0.8377 - val_loss: 0.9853 - val_smape_loss: 0.7656 - val_mae_denorm: 90.6831
# Epoch 135/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7654 - smape_loss: 1.0118 - mae_denorm: 0.8295Tiempo on_epoch_end 2024-10-30 17:12:54
# 2/2 [==============================] - 0s 76ms/step - loss: 0.7806 - smape_loss: 1.0218 - mae_denorm: 0.8371 - val_loss: 0.9865 - val_smape_loss: 0.7664 - val_mae_denorm: 90.7152
# Epoch 136/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7823 - smape_loss: 1.0201 - mae_denorm: 0.8459Tiempo on_epoch_end 2024-10-30 17:12:54
# 2/2 [==============================] - 0s 86ms/step - loss: 0.7801 - smape_loss: 1.0216 - mae_denorm: 0.8370 - val_loss: 0.9877 - val_smape_loss: 0.7672 - val_mae_denorm: 90.7491
# Epoch 137/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7741 - smape_loss: 1.0269 - mae_denorm: 0.8426Tiempo on_epoch_end 2024-10-30 17:12:54
# 2/2 [==============================] - 0s 77ms/step - loss: 0.7797 - smape_loss: 1.0208 - mae_denorm: 0.8368 - val_loss: 0.9884 - val_smape_loss: 0.7677 - val_mae_denorm: 90.7271
# Epoch 138/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7861 - smape_loss: 1.0261 - mae_denorm: 0.8659Tiempo on_epoch_end 2024-10-30 17:12:54
# 2/2 [==============================] - 0s 129ms/step - loss: 0.7791 - smape_loss: 1.0191 - mae_denorm: 0.8363 - val_loss: 0.9892 - val_smape_loss: 0.7683 - val_mae_denorm: 90.7163
# Epoch 139/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7769 - smape_loss: 1.0218 - mae_denorm: 0.8544Tiempo on_epoch_end 2024-10-30 17:12:54
# 2/2 [==============================] - 0s 78ms/step - loss: 0.7785 - smape_loss: 1.0179 - mae_denorm: 0.8358 - val_loss: 0.9902 - val_smape_loss: 0.7689 - val_mae_denorm: 90.7159
# Epoch 140/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7587 - smape_loss: 1.0190 - mae_denorm: 0.8269Tiempo on_epoch_end 2024-10-30 17:12:55
# 2/2 [==============================] - 0s 82ms/step - loss: 0.7780 - smape_loss: 1.0165 - mae_denorm: 0.8354 - val_loss: 0.9912 - val_smape_loss: 0.7696 - val_mae_denorm: 90.7162
# Epoch 141/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7798 - smape_loss: 1.0057 - mae_denorm: 0.8085Tiempo on_epoch_end 2024-10-30 17:12:55
# 2/2 [==============================] - 0s 80ms/step - loss: 0.7775 - smape_loss: 1.0159 - mae_denorm: 0.8349 - val_loss: 0.9926 - val_smape_loss: 0.7705 - val_mae_denorm: 90.7693
# Epoch 142/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7849 - smape_loss: 1.0168 - mae_denorm: 0.8386Tiempo on_epoch_end 2024-10-30 17:12:55
# ...
# Epoch 454/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7370 - smape_loss: 0.9472 - mae_denorm: 0.7921Tiempo on_epoch_end 2024-10-30 17:13:30
# 2/2 [==============================] - 0s 67ms/step - loss: 0.7329 - smape_loss: 0.9486 - mae_denorm: 0.7968 - val_loss: 1.1214 - val_smape_loss: 0.8496 - val_mae_denorm: 93.9150
# Epoch 455/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.
500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7415 - smape_loss: 0.9526 - mae_denorm: 0.7914Tiempo on_epoch_end 2024-10-30 17:13:34
# 2/2 [==============================] - 0s 65ms/step - loss: 0.7302 - smape_loss: 0.9445 - mae_denorm: 0.7933 - val_loss: 1.1328 - val_smape_loss: 0.8561 - val_mae_denorm: 94.4380
# Epoch 494/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7309 - smape_loss: 0.9473 - mae_denorm: 0.7883Tiempo on_epoch_end 2024-10-30 17:13:34
# 2/2 [==============================] - 0s 66ms/step - loss: 0.7302 - smape_loss: 0.9468 - mae_denorm: 0.7933 - val_loss: 1.1314 - val_smape_loss: 0.8553 - val_mae_denorm: 94.3846
# Epoch 495/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7333 - smape_loss: 0.9631 - mae_denorm: 0.8142Tiempo on_epoch_end 2024-10-30 17:13:34
# 2/2 [==============================] - 0s 75ms/step - loss: 0.7302 - smape_loss: 0.9438 - mae_denorm: 0.7933 - val_loss: 1.1324 - val_smape_loss: 0.8559 - val_mae_denorm: 94.4828
# Epoch 496/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7235 - smape_loss: 0.9478 - mae_denorm: 0.7861Tiempo on_epoch_end 2024-10-30 17:13:35
# 2/2 [==============================] - 0s 72ms/step - loss: 0.7301 - smape_loss: 0.9468 - mae_denorm: 0.7932 - val_loss: 1.1310 - val_smape_loss: 0.8551 - val_mae_denorm: 94.3398
# Epoch 497/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7285 - smape_loss: 0.9429 - mae_denorm: 0.7896Tiempo on_epoch_end 2024-10-30 17:13:35
# 2/2 [==============================] - 0s 77ms/step - loss: 0.7303 - smape_loss: 0.9433 - mae_denorm: 0.7933 - val_loss: 1.1339 - val_smape_loss: 0.8567 - val_mae_denorm: 94.5202
# Epoch 498/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7280 - smape_loss: 0.9469 - mae_denorm: 0.7661Tiempo on_epoch_end 2024-10-30 17:13:35
# 2/2 [==============================] - 0s 79ms/step - loss: 0.7301 - smape_loss: 0.9470 - mae_denorm: 0.7931 - val_loss: 1.1325 - val_smape_loss: 0.8560 - val_mae_denorm: 94.4037
# Epoch 499/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7277 - smape_loss: 0.9284 - mae_denorm: 0.7890Tiempo on_epoch_end 2024-10-30 17:13:35
# 2/2 [==============================] - 0s 107ms/step - loss: 0.7301 - smape_loss: 0.9446 - mae_denorm: 0.7930 - val_loss: 1.1343 - val_smape_loss: 0.8570 - val_mae_denorm: 94.5107
# Epoch 500/500
# 1/2 [==============>...............] - ETA: 0s - loss: 0.7305 - smape_loss: 0.9455 - mae_denorm: 0.7893Tiempo on_epoch_end 2024-10-30 17:13:35
# 2/2 [==============================] - 0s 102ms/step - loss: 0.7298 - smape_loss: 0.9453 - mae_denorm: 0.7928 - val_loss: 1.1334 - val_smape_loss: 0.8565 - val_mae_denorm: 94.4500
# Tiempo Final y n_past 2024-10-30 17:13:58   n_past:--> 60

# %%
from matplotlib import pyplot as plt
plt.plot(history_modelo.history['loss'])
plt.plot(history_modelo.history['val_loss'])
#plt.plot(history_modelo.history['val_smape_loss_zscore'])
plt.title('model accuracy')
plt.ylabel('loss')
plt.xlabel('epoch')
#plt.legend(['loss', 'val_loss','val_smape_loss_zscore'], loc='upper left')
plt.legend(['loss', 'val_loss'], loc='upper left')
plt.show()
best_score=min(history_modelo.history['val_loss'])
print('best_score',best_score)
#best_score_smape=min(history_modelo.history['val_smape_loss_zscore'])
#print('best_score smape',best_score_smape)
# Out:
# best_score 0.7364087104797363

# %%
from keras.utils import plot_model

fileplot=pathModelosJson
plot_model(reconstructed_model2, to_file=fileplot+'/model_plot.png', show_shapes=True, show_layer_names=True)

# %%
# %load_ext tensorboard

# %tensorboard --logdir "/content/drive/MyDrive/a Tesis de Grado/Tesis Versiones/tesis2023/Google Analytics 4/Tum Transmedia/modelos/modelos guardados/prueba1-30porciento/logs10divNday21DiasAtras"

# %%
from tensorflow.keras.saving import register_keras_serializable
media_train=train_previo_zscore['Número de vistas de página'].std()
std_train=train_previo_zscore['Número de vistas de página'].mean()
#esta metrica esta en el codigo de github del ganador
@register_keras_serializable()
def smape_loss(y_true, y_pred):
    #revierto zscore
    global media_train
    global std_train
    y_true=(y_true*std_train)+media_train
    y_pred=(y_pred*std_train)+media_train
    #revierto log1p
    y_true=tf.math.expm1(y_true)
    y_pred=tf.math.expm1(y_pred)
    epsilon = 0.1
    y_pred = tf.convert_to_tensor(y_pred)
    y_true = tf.cast(y_true, y_pred.dtype)
    # Calcular el denominador de SMAPE
    summ = tf.maximum(tf.abs(y_true) + tf.abs(y_pred) + epsilon, 0.5 + epsilon)

    # Calcular SMAPE
    smape = tf.abs(y_pred - y_true) / summ * 2.0

    # Retornar la media de SMAPE
    return K.mean(smape, axis=-1)

@register_keras_serializable()
def mae_denorm(y_true, y_pred):
    #revierto zscore
    global media_train
    global std_train
    y_true1=(y_true*std_train)+media_train
    y_pred1=(y_pred*std_train)+media_train
    #revierto log1p
    y_true2=tf.math.expm1(y_true1)
    y_pred2=tf.math.expm1(y_pred1)

    return tf.keras.losses.mean_absolute_error(y_true2, y_pred2)

# %%
#el mejor modelo de verdad
#pathModelosJsonMejor="/content/drive/MyDrive/a Tesis de Grado/Tesis Versiones/tesis 2024/UA/editorial universitaria/modelos/modelos resultados/mejores modelos guardados/modelo"
#nombreMejorModeloMejor="/ ndays Editorial 60hyperband mae 60 zscore.h5
pathModelosJsonMejor="/content/drive/MyDrive/a Tesis de Grado/Tesis Versiones/tesis 2024/GA4/editorial unam/modelos/modelos resultados/prueba 500 epocas 1 capa sin early stopping Editorial GA4 Mejor de Editorial UA"
nombreMejorModeloMejor="/hyperband001-0.736409-ndays60EditorialGA4_500epochs1capa.h5"#el mejor modelo es el hyperband de 28 dias y 107 época
n_past=60
cambio=datetime.datetime.now(timezone('UTC')) - timedelta(hours=3)
tiempoFinal=f"{cambio:%Y-%m-%d %H:%M:%S }"
print('Tiempo  Inicio y n_past',tiempoFinal , ' n_past:-->',n_past)
n_future = 60
n_features = train.shape[1]
X_train, y_train = split_series(train.values,n_past, n_future)
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1],n_features))
y_train = y_train.reshape((y_train.shape[0], y_train.shape[1], 1)) #no hace falta reshapear
X_test, y_test = split_series(test.values,n_past, n_future)
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1],n_features))
y_test = y_test.reshape((y_test.shape[0], y_test.shape[1], 1)) #no hace falta reshapear

reconstructed_model3 = tf.keras.models.load_model(pathModelosJsonMejor+nombreMejorModeloMejor,custom_objects={'smape_loss':smape_loss,'mae_denorm':mae_denorm})
# Out:
# Tiempo  Inicio y n_past 2024-10-30 17:19:50   n_past:--> 60

# %%
print("Evaluate on test data")
results = reconstructed_model3.evaluate(X_test,y_test, batch_size=64)
print("test loss", results)
# Out:
# Evaluate on test data
# 1/1 [==============================] - 1s 635ms/step - loss: 0.7364 - smape_loss: 0.6036 - mae_denorm: 71.0498
# test loss [0.7364087104797363, 0.6036470532417297, 71.04979705810547]

# %%
pred_e1d1=reconstructed_model3.predict(X_test, batch_size=192)
pred_e1d1=deepcopy(pred_e1d1)
reshapePred=pred_e1d1.reshape((pred_e1d1.shape[0]*pred_e1d1.shape[2]),pred_e1d1.shape[1])
reshapeY_test=y_test.reshape((y_test.shape[0]*y_test.shape[2]),y_test.shape[1])
print(pred_e1d1.shape,reshapePred.shape)
print('y_test',y_test.shape,reshapeY_test.shape)
def smape2(a, f):
    print('len(a)',len(a))

    #std=train_previo_zscore['Predictor Flag'].std()
    #media=train_previo_zscore['Predictor Flag'].mean()
    std=train_previo_zscore['Número de vistas de página'].std()
    media=train_previo_zscore['Número de vistas de página'].mean()
    #revierto zscore
    a=(a*std)+media
    f=(f*std)+media

    a=np.round(np.expm1(a))
    f=np.round(np.expm1(f))
    print('a',a)
    print('f',f)
    return (1/len(a) * np.sum(2 * np.abs(f-a) / (np.abs(a) + np.abs(f))) )

def mae_manual(a, f):
    print('len(a)', len(a))

    # Obtener la desviación estándar y media
    std = train_previo_zscore['Número de vistas de página'].std()
    media = train_previo_zscore['Número de vistas de página'].mean()

    # Revertir z-score
    a = (a * std) + media
    f = (f * std) + media

    a=np.round(np.expm1(a))
    f=np.round(np.expm1(f))
    #print('a mae',a)
    #print('f mae',f)

    epsilon = 0.1  # Valor para evitar divisiones por cero
    diff =np.abs(a-f)
    return np.mean(diff)#(1 / len(a)) * np.sum(diff)

def rmse_manual(a, f):
    print('len(a)', len(a))

    # Obtener la desviación estándar y media
    std = train_previo_zscore['Número de vistas de página'].std()
    media = train_previo_zscore['Número de vistas de página'].mean()

    # Revertir z-score
    a = (a * std) + media
    f = (f * std) + media

    a=np.round(np.expm1(a))
    f=np.round(np.expm1(f))

    # Calcular el RMSE (Error Cuadrático Medio)
    diff = np.square(a - f)  # Cuadrado de la diferencia
    mse = np.mean(diff)  # Error Cuadrático Medio
    rmse_calculado = np.sqrt(mse)  # Raíz cuadrada del MSE

    return rmse_calculado

auxpred=reshapePred.reshape((y_test.shape[0]*y_test.shape[1]),1)
auxpred2=auxpred.reshape((auxpred.shape[0]),)
auxY_test=reshapeY_test.reshape((y_test.shape[0]*y_test.shape[1]),1)
print(auxpred.shape)
print('smape',smape2(auxY_test,auxpred))
print('mae',mae_manual(auxY_test,auxpred))
print('rmse',rmse_manual(auxY_test,auxpred))
print(auxpred2.shape)
print(np.array([1,2,3]).shape)
print(auxpred2)
# Out:
# 1/1 [==============================] - 0s 30ms/step
# (56, 60, 1) (56, 60)
# y_test (56, 60, 1) (56, 60)
# (3360, 1)
# len(a) 3360
# a [[ 53.]
#  [ 83.]
#  [102.]
#  ...
#  [ 48.]
#  [140.]
#  [ 55.]]
# f [[ 87.]
#  [ 91.]
#  [ 91.]
#  ...
#  [121.]
#  [121.]
#  [121.]]
# smape 0.6042800485270311
# len(a) 3360
# mae 71.07797619047619
# len(a) 3360
# rmse 104.79610588912075
# (3360,)
# (3,)
# [-0.00800467  0.03695207  0.0372953  ...  0.36510962  0.36510962
#   0.36510962]

# %%
test_previo_log1p['Número de vistas de página']
X_test5, y_test5 = split_series(test_previo_log1p.values,n_past, n_future)
y_test5
# Out:
# array([[ 53.,  83., 102., ..., 103., 192., 166.],
#        [ 83., 102., 143., ..., 192., 166., 107.],
#        [102., 143., 167., ..., 166., 107.,  51.],
#        ...,
#        [174., 143.,  62., ...,  82.,  19.,  48.],
#        [143.,  62.,  92., ...,  19.,  48., 140.],
#        [ 62.,  92., 103., ...,  48., 140.,  55.]])

# %%
y_test5.shape
# Out:
# (56, 60)

# %%
auxY_test.shape
# Out:
# (3360, 1)

# %%
# Obtener la desviación estándar y media
import matplotlib.pyplot as plt
std = train_previo_zscore['Número de vistas de página'].std()
media = train_previo_zscore['Número de vistas de página'].mean()

# Revertir z-score
#denorm_actually=(auxY_test*std)+media
#denorm_forecast=(auxpred*std)+media

#denorm_actually = np.array(denorm_actually)
#denorm_forecast = np.array(denorm_forecast)
def denorm_manual(a, f):
    print('len(a)', len(a))

    # Obtener la desviación estándar y media
    std = train_previo_zscore['Número de vistas de página'].std()
    media = train_previo_zscore['Número de vistas de página'].mean()

    # Revertir z-score
    a = (a * std) + media
    f = (f * std) + media

    a=np.round(np.expm1(a))
    f=np.round(np.expm1(f))

    return a,f
denorm_actually,denorm_forecast=  denorm_manual(auxY_test,auxpred)
# Crear un rango de índices para el eje x
x = np.arange(len(denorm_actually))

# Crear el plot
plt.figure(figsize=(10, 6))
#ultimos 60
#plt.plot( denorm_actually[-60:], label='Valores de Reales', color='blue')
#plt.plot( denorm_forecast[-60:], label='Valores de Pronosticados', color='orange')
#primeros 60
plt.plot(np.arange(len(denorm_actually[:60])) ,denorm_actually[:60], label='Valores de Reales', color='blue')
plt.plot(np.arange(len(denorm_actually[:60])) ,denorm_forecast[:60], label='Valores de Pronosticados', color='orange')
print(denorm_actually[:1])
plt.title('Comparación de valores de Actuales y Predichos')
plt.xlabel('-')
plt.ylabel('Vistas')
plt.legend()
plt.grid()
plt.show()
# Out:
# len(a) 3360
# [[53.]]

# %%
mae_manual(auxY_test[:60],auxpred[:60])
# Out:
# len(a) 60
# 68.45

# %%
#plt.plot(train_previo_log1p[:60]['Número de vistas de página'])
plt.plot(test_previo_log1p[60:120]['Número de vistas de página'])

# %%
test_previo_log1p.shape
# Out:
# (175, 37)
