# %%
# !pip install keras-tuner==1.4.7
# !pip install pandas==2.1.4
# !pip install numpy==1.26.4
# !pip install tensorflow==2.15.0
# Out:
# Collecting keras-tuner==1.4.7
#   Downloading keras_tuner-1.4.7-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (from keras-tuner==1.4.7) (3.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras-tuner==1.4.7) (24.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from keras-tuner==1.4.7) (2.32.3)
# Collecting kt-legacy (from keras-tuner==1.4.7)
#   Downloading kt_legacy-1.0.5-py3-none-any.whl.metadata (221 bytes)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras->keras-tuner==1.4.7) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras->keras-tuner==1.4.7) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras->keras-tuner==1.4.7) (13.9.3)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras->keras-tuner==1.4.7) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras->keras-tuner==1.4.7) (3.11.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras->keras-tuner==1.4.7) (0.13.0)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.10/dist-packages (from keras->keras-tuner==1.4.7) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner==1.4.7) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner==1.4.7) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner==1.4.7) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner==1.4.7) (2024.8.30)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from optree->keras->keras-tuner==1.4.7) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras->keras-tuner==1.4.7) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras->keras-tuner==1.4.7) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras->keras-tuner==1.4.7) (0.1.2)
# Downloading keras_tuner-1.4.7-py3-none-any.whl (129 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.1/129.1 kB 3.1 MB/s eta 0:00:00
# Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Installing collected packages: kt-legacy, keras-tuner
# Successfully installed keras-tuner-1.4.7 kt-legacy-1.0.5
# Collecting pandas==2.1.4
#   Downloading pandas-2.1.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas==2.1.4) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas==2.1.4) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas==2.1.4) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas==2.1.4) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas==2.1.4) (1.16.0)
# Downloading pandas-2.1.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 27.1 MB/s eta 0:00:00
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.1.4 which is incompatible.
# Successfully installed pandas-2.1.4
# Requirement already satisfied: numpy==1.26.4 in /usr/local/lib/python3.10/dist-packages (1.26.4)
# Collecting tensorflow==2.15.0
#   Downloading tensorflow-2.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.4 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (18.1.1)
# Collecting ml-dtypes~=0.2.0 (from tensorflow==2.15.0)
#   Downloading ml_dtypes-0.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (1.26.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (4.12.2)
# Collecting wrapt<1.15,>=1.11.0 (from tensorflow==2.15.0)
#   Downloading wrapt-1.14.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (0.37.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (1.64.1)
# Collecting tensorboard<2.16,>=2.15 (from tensorflow==2.15.0)
#   Downloading tensorboard-2.15.2-py3-none-any.whl.metadata (1.7 kB)
# Collecting tensorflow-estimator<2.16,>=2.15.0 (from tensorflow==2.15.0)
#   Downloading tensorflow_estimator-2.15.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting keras<2.16,>=2.15.0 (from tensorflow==2.15.0)
#   Downloading keras-2.15.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow==2.15.0) (0.44.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (1.2.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.7)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.0.6)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.0.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.2.2)
# Downloading tensorflow-2.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (475.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 475.2/475.2 MB 3.6 MB/s eta 0:00:00
# Downloading keras-2.15.0-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 39.2 MB/s eta 0:00:00
# Downloading ml_dtypes-0.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 32.3 MB/s eta 0:00:00
# Downloading tensorboard-2.15.2-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 59.8 MB/s eta 0:00:00
# Downloading tensorflow_estimator-2.15.0-py2.py3-none-any.whl (441 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.0/442.0 kB 25.5 MB/s eta 0:00:00
# Downloading wrapt-1.14.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 6.9 MB/s eta 0:00:00
# Installing collected packages: wrapt, tensorflow-estimator, ml-dtypes, keras, tensorboard, tensorflow
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.16.0
#     Uninstalling wrapt-1.16.0:
#       Successfully uninstalled wrapt-1.16.0
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml-dtypes 0.4.1
#     Uninstalling ml-dtypes-0.4.1:
#       Successfully uninstalled ml-dtypes-0.4.1
#   Attempting uninstall: keras
#     Found existing installation: keras 3.4.1
#     Uninstalling keras-3.4.1:
#       Successfully uninstalled keras-3.4.1
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.17.0
#     Uninstalling tensorboard-2.17.0:
#       Successfully uninstalled tensorboard-2.17.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.17.0
#     Uninstalling tensorflow-2.17.0:
#       Successfully uninstalled tensorflow-2.17.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorstore 0.1.67 requires ml-dtypes>=0.3.1, but you have ml-dtypes 0.2.0 which is incompatible.
# tf-keras 2.17.0 requires tensorflow<2.18,>=2.17, but you have tensorflow 2.15.0 which is incompatible.
# Successfully installed keras-2.15.0 ml-dtypes-0.2.0 tensorboard-2.15.2 tensorflow-2.15.0 tensorflow-estimator-2.15.0 wrapt-1.14.1

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras #desde tensorflow 2 se importa keras,  como paquete integrado de tensorflow
import pandas as pd
import numpy as np
from math import sqrt
from numpy import concatenate
from matplotlib import pyplot
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM, GRU
import tensorflow as tf
from datetime import datetime
from keras.models import Sequential
from keras.layers import Dense,Flatten,LSTM,RepeatVector,TimeDistributed#, GRUCellV2
from copy import deepcopy

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Reading the data set, parsing the dates and inferring the date format to date time. We also fill the Nan’s with 0.
#agrego index_col=0 para solucionar Unnamed: 0 porque https://stackoverflow.com/questions/43983622/remove-unnamed-columns-in-pandas-dataframe
dataset = read_csv("/content/drive/MyDrive/a Tesis de Grado/Tesis Versiones/tesis 2024/GA4/editorial unam/preprocesamiento/outlier/salidaCSV/salidaKNN2024EditorialUniversitariaGA4.csv", index_col=0)
#dataset.fillna(0, inplace=True)//pasar nans a ceros
#revisar lo que hago en el otro dataset
print(dataset.size)
print(dataset.columns)

print(dataset.shape)
print(dataset)
dataset.head()
# Out:
# 21534
# Index(['Número de vistas de página', 'Usuarios nuevos', 'Usuarios',
#        'Número de sesiones por usuario', 'Sesiones', 'Argentina',
#        'Otros Paises', 'mobile', 'desktop', 'tablet',
#        'Categoría de dispositivo promedio', 'Categoría de dispositivo std',
#        'Windows', 'Android', 'Linux', 'Macintosh',
#        'Sistema operativo (not set)', 'iOS', 'Windows Phone', 'Chrome OS',
#        'Tizen', 'Sistema operativo promedio', 'Sistema operativo std',
#        'Organic Search', 'Social', 'Direct', 'Referral',
#        'Agrupación de canales predeterminada promedio',
#        'Agrupación de canales predeterminada std', 'mediana_de_medianas',
#        'lag_90', 'lag_180', 'lag_270', 'lag_360', 'mediana Dispositivos',
#        'mediana Sistema operativo',
#        'mediana Agrupación de canales predeterminada'],
#       dtype='object')
# (582, 37)
#      Número de vistas de página  Usuarios nuevos  Usuarios  \
# 0                          71.0             39.0      39.0
# 1                         279.0            142.0     147.0
# 2                         207.0            103.0     117.0
# 3                         110.0             77.0      81.0
# 4                          80.0             53.0      57.0
# ..                          ...              ...       ...
# 579                        82.0             25.0      28.0
# 580                        19.0              8.0       9.0
# 581                        48.0             13.0      18.0
# 582                       140.0             18.0      23.0
# 583                        55.0             27.0      30.0
#
#      Número de sesiones por usuario  Sesiones  Argentina  Otros Paises  \
# 0                          1.205128      47.0       70.0           1.0
# 1                          1.156463     170.0      222.0          57.0
# 2                          1.230769     144.0      174.0          33.0
# 3                          1.074074      87.0       86.0          24.0
# 4                          1.052632      60.0       60.0          20.0
# ..                              ...       ...        ...           ...
# 579                        1.153846      30.0       74.0           8.0
# 580                        1.125000       9.0       15.0           4.0
# 581                        1.375000      22.0       44.0           4.0
# 582                        1.318182      29.0       31.0         109.0
# 583                        1.066667      32.0       36.0          19.0
#
#      mobile  desktop  tablet  ...  \
# 0      37.0     34.0     0.0  ...
# 1     155.0    124.0     0.0  ...
# 2     124.0     81.0     2.0  ...
# 3      72.0     37.0     1.0  ...
# 4      48.0     30.0     2.0  ...
# ..      ...      ...     ...  ...
# 579    14.0     68.0     0.0  ...
# 580    17.0      2.0     0.0  ...
# 581    12.0     36.0     0.0  ...
# 582    14.0    126.0     0.0  ...
# 583    12.0     41.0     2.0  ...
#
#      Agrupación de canales predeterminada promedio  \
# 0                                            17.75
# 1                                            69.75
# 2                                            51.75
# 3                                            27.50
# 4                                            20.00
# ..                                             ...
# 579                                          20.50
# 580                                           4.75
# 581                                          12.00
# 582                                          35.00
# 583                                          13.75
#
#      Agrupación de canales predeterminada std  mediana_de_medianas     lag_90  \
# 0                                   17.210098           106.905607  124.82723
# 1                                   54.061886           106.905607  124.82723
# 2                                   42.310608           106.905607  124.82723
# 3                                    8.500000           106.905607  124.82723
# 4                                    8.154754           106.905607  124.82723
# ..                                        ...                  ...        ...
# 579                                 26.612967            63.500000   43.00000
# 580                                  4.866981            62.000000   36.00000
# 581                                 11.554220            62.000000  184.00000
# 582                                 47.544716            62.000000  154.00000
# 583                                 16.130330            64.000000  328.00000
#
#        lag_180    lag_270   lag_360  mediana Dispositivos  \
# 0    120.16915  118.39103  97.39639                  34.0
# 1    120.16915  118.39103  97.39639                 124.0
# 2    120.16915  118.39103  97.39639                  81.0
# 3    120.16915  118.39103  97.39639                  37.0
# 4    120.16915  118.39103  97.39639                  30.0
# ..         ...        ...       ...                   ...
# 579   63.00000  272.00000  25.00000                  14.0
# 580  174.00000  286.00000  47.00000                   2.0
# 581   91.00000  202.00000  39.00000                  12.0
# 582  241.00000  276.00000  25.00000                  14.0
# 583  204.00000  169.00000  27.00000                  12.0
#
#      mediana Sistema operativo  mediana Agrupación de canales predeterminada
# 0                          0.0                                          12.0
# 1                          0.0                                          61.5
# 2                          3.0                                          42.5
# 3                          0.0                                          27.5
# 4                          1.0                                          16.0
# ..                         ...                                           ...
# 579                        1.0                                           8.5
# 580                        0.0                                           4.0
# 581                        0.0                                          11.5
# 582                        0.0                                          11.5
# 583                        0.0                                           7.5
#
# [582 rows x 37 columns]
#    Número de vistas de página  Usuarios nuevos  Usuarios  \
# 0                        71.0             39.0      39.0
# 1                       279.0            142.0     147.0
# 2                       207.0            103.0     117.0
# 3                       110.0             77.0      81.0
# 4                        80.0             53.0      57.0
#
#    Número de sesiones por usuario  Sesiones  Argentina  Otros Paises  mobile  \
# 0                        1.205128      47.0       70.0           1.0    37.0
# 1                        1.156463     170.0      222.0          57.0   155.0
# 2                        1.230769     144.0      174.0          33.0   124.0
# 3                        1.074074      87.0       86.0          24.0    72.0
# 4                        1.052632      60.0       60.0          20.0    48.0
#
#    desktop  tablet  ...  Agrupación de canales predeterminada promedio  \
# 0     34.0     0.0  ...                                          17.75
# 1    124.0     0.0  ...                                          69.75
# 2     81.0     2.0  ...                                          51.75
# 3     37.0     1.0  ...                                          27.50
# 4     30.0     2.0  ...                                          20.00
#
#    Agrupación de canales predeterminada std  mediana_de_medianas     lag_90  \
# 0                                 17.210098           106.905607  124.82723
# 1                                 54.061886           106.905607  124.82723
# 2                                 42.310608           106.905607  124.82723
# 3                                  8.500000           106.905607  124.82723
# 4                                  8.154754           106.905607  124.82723
#
#      lag_180    lag_270   lag_360  mediana Dispositivos  \
# 0  120.16915  118.39103  97.39639                  34.0
# 1  120.16915  118.39103  97.39639                 124.0
# 2  120.16915  118.39103  97.39639                  81.0
# 3  120.16915  118.39103  97.39639                  37.0
# 4  120.16915  118.39103  97.39639                  30.0
#
#    mediana Sistema operativo  mediana Agrupación de canales predeterminada
# 0                        0.0                                          12.0
# 1                        0.0                                          61.5
# 2                        3.0                                          42.5
# 3                        0.0                                          27.5
# 4                        1.0                                          16.0
#
# [5 rows x 37 columns]

# %%
print(dataset.columns)
print(dataset.shape)
print(dataset.head())
# Out:
# Index(['Número de vistas de página', 'Usuarios nuevos', 'Usuarios',
#        'Número de sesiones por usuario', 'Sesiones', 'Argentina',
#        'Otros Paises', 'mobile', 'desktop', 'tablet',
#        'Categoría de dispositivo promedio', 'Categoría de dispositivo std',
#        'Windows', 'Android', 'Linux', 'Macintosh',
#        'Sistema operativo (not set)', 'iOS', 'Windows Phone', 'Chrome OS',
#        'Tizen', 'Sistema operativo promedio', 'Sistema operativo std',
#        'Organic Search', 'Social', 'Direct', 'Referral',
#        'Agrupación de canales predeterminada promedio',
#        'Agrupación de canales predeterminada std', 'mediana_de_medianas',
#        'lag_90', 'lag_180', 'lag_270', 'lag_360', 'mediana Dispositivos',
#        'mediana Sistema operativo',
#        'mediana Agrupación de canales predeterminada'],
#       dtype='object')
# (582, 37)
#    Número de vistas de página  Usuarios nuevos  Usuarios  \
# 0                        71.0             39.0      39.0
# 1                       279.0            142.0     147.0
# 2                       207.0            103.0     117.0
# 3                       110.0             77.0      81.0
# 4                        80.0             53.0      57.0
#
#    Número de sesiones por usuario  Sesiones  Argentina  Otros Paises  mobile  \
# 0                        1.205128      47.0       70.0           1.0    37.0
# 1                        1.156463     170.0      222.0          57.0   155.0
# 2                        1.230769     144.0      174.0          33.0   124.0
# 3                        1.074074      87.0       86.0          24.0    72.0
# 4                        1.052632      60.0       60.0          20.0    48.0
#
#    desktop  tablet  ...  Agrupación de canales predeterminada promedio  \
# 0     34.0     0.0  ...                                          17.75
# 1    124.0     0.0  ...                                          69.75
# 2     81.0     2.0  ...                                          51.75
# 3     37.0     1.0  ...                                          27.50
# 4     30.0     2.0  ...                                          20.00
#
#    Agrupación de canales predeterminada std  mediana_de_medianas     lag_90  \
# 0                                 17.210098           106.905607  124.82723
# 1                                 54.061886           106.905607  124.82723
# 2                                 42.310608           106.905607  124.82723
# 3                                  8.500000           106.905607  124.82723
# 4                                  8.154754           106.905607  124.82723
#
#      lag_180    lag_270   lag_360  mediana Dispositivos  \
# 0  120.16915  118.39103  97.39639                  34.0
# 1  120.16915  118.39103  97.39639                 124.0
# 2  120.16915  118.39103  97.39639                  81.0
# 3  120.16915  118.39103  97.39639                  37.0
# 4  120.16915  118.39103  97.39639                  30.0
#
#    mediana Sistema operativo  mediana Agrupación de canales predeterminada
# 0                        0.0                                          12.0
# 1                        0.0                                          61.5
# 2                        3.0                                          42.5
# 3                        0.0                                          27.5
# 4                        1.0                                          16.0
#
# [5 rows x 37 columns]

# %%
#predictor Flag
from copy import deepcopy
from datetime import datetime as dt

# %%
#-Habia algo aca en el preprocesamiento anterior
print( dataset[int(dataset.shape[0]*0.70):].shape)
# Out:
# (175, 37)

# %%
#115*0.75 = 86.25=86
#train_df,test_df = dataset[1:86], dataset[86:]
# parrtir en 80 - 20 segun la profe
# probar sin normalizar los datos, es decir sin escalarlos
#normalizar
#partir datos de entrenamiento y prueba
#dataset.shape[0]=1734 o es 115 en caso del ejemplo
print('dataset.shape[0]',dataset.shape[0],' dataset.shape[1]',dataset.shape[1])
formaFinal=int(dataset.shape[0]*0.70)#80% para train y 20% para test
print(formaFinal)
train_df,test_df = dataset[1:formaFinal], dataset[formaFinal:] #spliteo test/train
train = train_df
test = test_df
# Normalización del conjunto de entrenamiento
train_previo_log1p=deepcopy(train)
for column in train.columns:
    train.loc[:, column] = np.log1p(train[column])
train_previo_zscore = deepcopy(train)
for column in train.columns:
    mean = train[column].mean()  # Media del conjunto de entrenamiento
    std = train[column].std()    # Desviación estándar del conjunto de entrenamiento
    train[column] = (train[column] - mean) / std
    if std != 0:
        train[column] = (train[column] - mean) / std
    else:
        train[column] = 0
test_previo_log1p=deepcopy(test)
for column1 in test.columns:
    test.loc[:, column1] = np.log1p(test[column1])
# Normalización del conjunto de prueba
test_previo_zscore = deepcopy(test)
for column1 in test.columns:
    mean_train = train_previo_zscore[column1].mean()  # Media del conjunto de entrenamiento
    std_train = train_previo_zscore[column1].std()    # Desviación estándar del conjunto de entrenamiento
    if std_train != 0:
        test[column1] = (test[column1] - mean_train) / std_train
    else:
        test[column1] = 0  

print('train_df',train_df.shape)
print('test_df',test_df.shape)
print('test',test.shape,test.values[11])
# Out:
# dataset.shape[0] 582  dataset.shape[1] 37
# 407
# train_df (406, 37)
# test_df (175, 37)
# test (175, 37) [-0.28407843 -0.4619948  -0.65671607 -0.42441653 -0.59247904 -0.15608443
#  -0.87490798  0.76153848 -1.4490523   0.96955808 -0.31418626 -0.06197226
#  -1.35544577  0.83350937 -0.69017585 -0.88478924 -0.06853176 -1.11188821
#   0.         -0.15825676  0.         -0.36155957 -0.07642696 -0.01416593
#  -0.92576787 -0.48032504  0.83872693 -0.3245348  -0.1716917   0.57946221
#   0.89803703 -2.98687829 -0.49402867  3.62208021 -0.93122917 -0.49068071
#  -0.46747635]
# <ipython-input-9-821e345de358>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train[column] = (train[column] - mean) / std
# <ipython-input-9-821e345de358>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train[column] = (train[column] - mean) / std
# <ipython-input-9-821e345de358>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train[column] = 0
# <ipython-input-9-821e345de358>:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[column1] = (test[column1] - mean_train) / std_train
# <ipython-input-9-821e345de358>:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[column1] = 0  # O algún otro valor neutral que prefieras

# %%
#reshape a entrada

def split_series(series, n_past, n_future):
  #
  # n_past ==> no of past observations
  #
  # n_future ==> no of future observations
  #
  X, y = list(), list()
  for window_start in range(len(series)):
    past_end = window_start + n_past
    future_end = past_end + n_future
    if future_end > len(series):
      break
    # slicing the past and future parts of the window
    #past, future = series[window_start:past_end, :], series[past_end:future_end, :]
    #window_start cuando comienza  past_end es cuando termina y future_endes cuando termina las series a comparar, 0 es porque solo va a tomar la primera columna
    #la cual es la de total de vistas
    past, future = series[window_start:past_end, :], series[past_end:future_end, 0]
    X.append(past)
    y.append(future)
  return np.array(X), np.array(y)
# Out:
# "\nn_past = 50 #va a mirar 10 dias al pasado para predecir x dias a futuro\nn_future = 7 #anterior 5 #probar 7 dias a futuro\nn_features = dataset.shape[1] # Columnas totales del dataset\n\n#Now convert both the train and test data into samples using the split_series function.\n\nX_train, y_train = split_series(train.values,n_past, n_future)\nX_train = X_train.reshape((X_train.shape[0], X_train.shape[1],n_features))\n#y_train = y_train.reshape((y_train.shape[0], y_train.shape[1], n_features))\ny_train = y_train.reshape((y_train.shape[0], y_train.shape[1], 1)) #no hace falta reshapear\nX_test, y_test = split_series(test.values,n_past, n_future)\nX_test = X_test.reshape((X_test.shape[0], X_test.shape[1],n_features))\n#y_test = y_test.reshape((y_test.shape[0], y_test.shape[1], n_features))\ny_test = y_test.reshape((y_test.shape[0], y_test.shape[1], 1)) #no hace falta reshapear\nprint('X_train',X_train.shape,X_train)\nprint('y_train',y_train.shape,y_train)\nprint('X_test',X_test.shape,X_test)\nprint('y_test',y_test.shape,y_test)\n"

# %%
# !df -h
# Out:
# Filesystem      Size  Used Avail Use% Mounted on
# overlay         236G   35G  202G  15% /
# tmpfs            64M     0   64M   0% /dev
# shm             5.7G     0  5.7G   0% /dev/shm
# /dev/root       2.0G  1.2G  820M  59% /usr/sbin/docker-init
# tmpfs           6.4G  904K  6.4G   1% /var/colab
# /dev/sda1       242G   62G  181G  26% /kaggle/input
# tmpfs           6.4G     0  6.4G   0% /proc/acpi
# tmpfs           6.4G     0  6.4G   0% /proc/scsi
# tmpfs           6.4G     0  6.4G   0% /sys/firmware
# drive           100G   61G   40G  61% /content/drive

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 85
# model name	: Intel(R) Xeon(R) CPU @ 2.00GHz
# stepping	: 3
# microcode	: 0xffffffff
# cpu MHz		: 2000.198
# cache size	: 39424 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa mmio_stale_data retbleed bhi
# bogomips	: 4000.39
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 1
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 85
# model name	: Intel(R) Xeon(R) CPU @ 2.00GHz
# stepping	: 3
# microcode	: 0xffffffff
# cpu MHz		: 2000.198
# cache size	: 39424 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 1
# initial apicid	: 1
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa mmio_stale_data retbleed bhi
# bogomips	: 4000.39
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:

# %%
# !cat /proc/meminfo
# Out:
# MemTotal:       13290452 kB
# MemFree:          353272 kB
# MemAvailable:   10835832 kB
# Buffers:          554404 kB
# Cached:          9852872 kB
# SwapCached:            0 kB
# Active:          1376780 kB
# Inactive:       10763172 kB
# Active(anon):       2140 kB
# Inactive(anon):  1749476 kB
# Active(file):    1374640 kB
# Inactive(file):  9013696 kB
# Unevictable:          20 kB
# Mlocked:              20 kB
# SwapTotal:             0 kB
# SwapFree:              0 kB
# Dirty:               968 kB
# Writeback:             0 kB
# AnonPages:       1732700 kB
# Mapped:           981180 kB
# Shmem:             18928 kB
# KReclaimable:     419792 kB
# Slab:             503272 kB
# SReclaimable:     419792 kB
# SUnreclaim:        83480 kB
# KernelStack:        8316 kB
# PageTables:        29556 kB
# SecPageTables:         0 kB
# NFS_Unstable:          0 kB
# Bounce:                0 kB
# WritebackTmp:          0 kB
# CommitLimit:     6645224 kB
# Committed_AS:    4898432 kB
# VmallocTotal:   34359738367 kB
# VmallocUsed:       86484 kB
# VmallocChunk:          0 kB
# Percpu:             1144 kB
# HardwareCorrupted:     0 kB
# AnonHugePages:     10240 kB
# ShmemHugePages:        0 kB
# ShmemPmdMapped:        0 kB
# FileHugePages:         0 kB
# FilePmdMapped:         0 kB
# CmaTotal:              0 kB
# CmaFree:               0 kB
# Unaccepted:            0 kB
# HugePages_Total:       0
# HugePages_Free:        0
# HugePages_Rsvd:        0
# HugePages_Surp:        0
# Hugepagesize:       2048 kB
# Hugetlb:               0 kB
# DirectMap4k:      232248 kB
# DirectMap2M:     6055936 kB
# DirectMap1G:     9437184 kB

# %%
# !/usr/local/cuda/bin/nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2023 NVIDIA Corporation
# Built on Tue_Aug_15_22:02:13_PDT_2023
# Cuda compilation tools, release 12.2, V12.2.140
# Build cuda_12.2.r12.2/compiler.33191640_0

# %%
# !which nvidia-smi
# Out:
# /opt/bin/nvidia-smi

# %%
# !nvidia-smi
# Out:
# Wed Oct 30 18:21:23 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   72C    P0              30W /  70W |    259MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# +---------------------------------------------------------------------------------------+

# %%
# !python --version
# Out:
# Python 3.10.12

# %%
import keras_tuner as kt
import datetime
from datetime import timedelta
from pytz import timezone
import tensorflow.keras.backend as K
import datetime
from datetime import timedelta
from pytz import timezone
print(tf. __version__)
print(pd. __version__)
print(np. __version__)
print(kt. __version__)
# Out:
# 2.15.0
# 2.1.4
# 1.26.4
# 1.4.7

# %%
# Establecer la semilla
seed_value = 42
import random  
# Establecer semillas
np.random.seed(seed_value)
random.seed(seed_value)
tf.random.set_seed(seed_value)
from tensorflow.keras.saving import register_keras_serializable

# %%
print('std',train_previo_zscore['Número de vistas de página'].std())
print('mean',train_previo_zscore['Número de vistas de página'].mean() )
# Out:
# std 0.8811457909642999
# mean 4.484421019032126

# %%
media_train=train_previo_zscore['Número de vistas de página'].std()
std_train=train_previo_zscore['Número de vistas de página'].mean()
#esta metrica esta en el codigo de github del ganador
@register_keras_serializable()
def smape_loss(y_true, y_pred):
    #revierto zscore
    media_train=4.484421019032126
    std_train =0.8811457909642999
    y_true=(y_true*std_train)+media_train
    y_pred=(y_pred*std_train)+media_train
    #revierto log1p
    y_true=tf.math.expm1(y_true)
    y_pred=tf.math.expm1(y_pred)
    epsilon = 0.1
    y_pred = tf.convert_to_tensor(y_pred)
    y_true = tf.cast(y_true, y_pred.dtype)
    # Calcular el denominador de SMAPE
    summ = tf.maximum(tf.abs(y_true) + tf.abs(y_pred) + epsilon, 0.5 + epsilon)

    # Calcular SMAPE
    smape = tf.abs(y_pred - y_true) / summ * 2.0

    # Retornar la media de SMAPE
    return K.mean(smape, axis=-1)

@register_keras_serializable()
def mae_denorm(y_true, y_pred):
    #revierto zscore
    media_train=4.484421019032126
    std_train =0.8811457909642999
    y_true1=(y_true*std_train)+media_train
    y_pred1=(y_pred*std_train)+media_train
    #revierto log1p
    y_true2=tf.math.expm1(y_true1)
    y_pred2=tf.math.expm1(y_pred1)

    return tf.keras.losses.mean_absolute_error(y_true2, y_pred2)

# %%
pathModelosJsonMejor="/content/drive/MyDrive/a Tesis de Grado/Tesis Versiones/tesis 2024/UA/tum transmedia/modelos/modelos resultados/mejores modelos guardados/modelo"
nombreMejorModeloMejor="/ ndays60hyperband mae 60 zscore.h5"#el mejor modelo es el hyperband de 28 dias y 107 época

reconstructed_model2 = tf.keras.models.load_model(pathModelosJsonMejor+nombreMejorModeloMejor,custom_objects={'smape_loss':smape_loss,'mae_denorm':mae_denorm})

# %%
from tensorflow.keras.callbacks import TensorBoard

# %%
pathModelosJson="/content/drive/MyDrive/a Tesis de Grado/Tesis Versiones/tesis 2024/GA4/editorial unam/modelos/modelos resultados/prueba 500 epocas 1 capa sin early stopping Editorial GA4 Mejor de TUM"
nombreMejorModelo="ndays60EditorialGA4_500epochs1capa.h5"
class PrintTimeCallback(tf.keras.callbacks.Callback):#https://www.tensorflow.org/guide/keras/writing_your_own_callbacks
    def on_epoch_end(self, epoch, logs=None):
        cambio=datetime.datetime.now(timezone('UTC')) - timedelta(hours=3)
        salida=f"{cambio:%Y-%m-%d %H:%M:%S }"
        print('Tiempo on_epoch_end',salida)
n_past=60
cambio=datetime.datetime.now(timezone('UTC')) - timedelta(hours=3)
tiempoFinal=f"{cambio:%Y-%m-%d %H:%M:%S }"
print('Tiempo  Inicio y n_past',tiempoFinal , ' n_past:-->',n_past)
n_future = 60
n_features = train.shape[1]
X_train, y_train = split_series(train.values,n_past, n_future)
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1],n_features))
y_train = y_train.reshape((y_train.shape[0], y_train.shape[1], 1)) #no hace falta reshapear
X_test, y_test = split_series(test.values,n_past, n_future)
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1],n_features))
y_test = y_test.reshape((y_test.shape[0], y_test.shape[1], 1)) #no hace falta reshapear
logpaht=pathModelosJson+f"/logsndays60_500epochs1capa"
from tensorflow.keras.callbacks import ReduceLROnPlateau
#reduce_lr = ReduceLROnPlateau(monitor='val_smape_loss_zscore', factor=0.5, patience=5, min_lr=1e-50)
callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=50)#https://pub.towardsai.net/keras-earlystopping-callback-to-train-the-neural-networks-perfectly-2a3f865148f7
mcp_save = tf.keras.callbacks.ModelCheckpoint(pathModelosJson+"/"+'hyperband{epoch:03d}-{val_loss:03f}-'+nombreMejorModelo, save_best_only=True, monitor='val_loss', mode='min')#https://stackoverflow.com/questions/48285129/saving-best-model-in-keras
history_modelo=reconstructed_model2.fit(X_train,y_train,epochs=500,validation_data=(X_test,y_test),batch_size=64,verbose=1,
                                        callbacks=[PrintTimeCallback(),
                                                   mcp_save,#reduce_lr,
                                                   TensorBoard(log_dir=logpaht, write_graph=False, profile_batch=0)
                                                   ])
cambio=datetime.datetime.now(timezone('UTC')) - timedelta(hours=3)
tiempoFinalDespues=f"{cambio:%Y-%m-%d %H:%M:%S }"
print('Tiempo Final y n_past',tiempoFinalDespues , ' n_past:-->',n_past)
#reentreno 70-30
# Out:
# Tiempo  Inicio y n_past 2024-10-30 15:21:35   n_past:--> 60
# Epoch 1/500
# 4/5 [=======================>......] - ETA: 0s - loss: 2.8091 - smape_loss: 1.4736 - mae_denorm: 16.1275Tiempo on_epoch_end 2024-10-30 15:21:38
# 5/5 [==============================] - 3s 213ms/step - loss: 2.6249 - smape_loss: 1.4536 - mae_denorm: 14.5190 - val_loss: 1.3215 - val_smape_loss: 0.9559 - val_mae_denorm: 89.9399
# Epoch 2/500
# 4/5 [=======================>......] - ETA: 0s - loss: 1.1929 - smape_loss: 1.2686 - mae_denorm: 1.4059
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Tiempo on_epoch_end 2024-10-30 15:21:39
# 5/5 [==============================] - 0s 30ms/step - loss: 1.1764 - smape_loss: 1.2608 - mae_denorm: 1.3603 - val_loss: 1.9971 - val_smape_loss: 1.2471 - val_mae_denorm: 104.5077
# Epoch 3/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.9552 - smape_loss: 1.2498 - mae_denorm: 0.9899Tiempo on_epoch_end 2024-10-30 15:21:39
# 5/5 [==============================] - 0s 27ms/step - loss: 0.9420 - smape_loss: 1.2476 - mae_denorm: 0.9920 - val_loss: 2.1934 - val_smape_loss: 1.3191 - val_mae_denorm: 115.6275
# Epoch 4/500
# 5/5 [==============================] - ETA: 0s - loss: 0.8873 - smape_loss: 1.2036 - mae_denorm: 0.9282Tiempo on_epoch_end 2024-10-30 15:21:39
# 5/5 [==============================] - 0s 25ms/step - loss: 0.8873 - smape_loss: 1.2036 - mae_denorm: 0.9282 - val_loss: 2.1969 - val_smape_loss: 1.3284 - val_mae_denorm: 124.2968
# Epoch 5/500
# 5/5 [==============================] - ETA: 0s - loss: 0.8623 - smape_loss: 1.1586 - mae_denorm: 0.9051Tiempo on_epoch_end 2024-10-30 15:21:39
# 5/5 [==============================] - 0s 25ms/step - loss: 0.8623 - smape_loss: 1.1586 - mae_denorm: 0.9051 - val_loss: 2.2742 - val_smape_loss: 1.3553 - val_mae_denorm: 133.8783
# Epoch 6/500
# 5/5 [==============================] - ETA: 0s - loss: 0.8562 - smape_loss: 1.1361 - mae_denorm: 0.9011Tiempo on_epoch_end 2024-10-30 15:21:39
# 5/5 [==============================] - 0s 26ms/step - loss: 0.8562 - smape_loss: 1.1361 - mae_denorm: 0.9011 - val_loss: 2.3006 - val_smape_loss: 1.3659 - val_mae_denorm: 140.2878
# Epoch 7/500
# 5/5 [==============================] - ETA: 0s - loss: 0.8399 - smape_loss: 1.0942 - mae_denorm: 0.8869Tiempo on_epoch_end 2024-10-30 15:21:39
# 5/5 [==============================] - 0s 23ms/step - loss: 0.8399 - smape_loss: 1.0942 - mae_denorm: 0.8869 - val_loss: 2.2778 - val_smape_loss: 1.3608 - val_mae_denorm: 142.5282
# Epoch 8/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.8648 - smape_loss: 1.1343 - mae_denorm: 0.9196Tiempo on_epoch_end 2024-10-30 15:21:39
# 5/5 [==============================] - 0s 23ms/step - loss: 0.8298 - smape_loss: 1.0947 - mae_denorm: 0.8776 - val_loss: 2.3331 - val_smape_loss: 1.3770 - val_mae_denorm: 148.0651
# Epoch 9/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.8188 - smape_loss: 1.0915 - mae_denorm: 0.8871Tiempo on_epoch_end 2024-10-30 15:21:39
# 5/5 [==============================] - 0s 24ms/step - loss: 0.8181 - smape_loss: 1.0792 - mae_denorm: 0.8681 - val_loss: 2.3224 - val_smape_loss: 1.3747 - val_mae_denorm: 148.6225
# Epoch 10/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.8076 - smape_loss: 1.0949 - mae_denorm: 0.9213Tiempo on_epoch_end 2024-10-30 15:21:40
# 5/5 [==============================] - 0s 21ms/step - loss: 0.8093 - smape_loss: 1.0584 - mae_denorm: 0.8608 - val_loss: 2.3235 - val_smape_loss: 1.3755 - val_mae_denorm: 148.6577
# Epoch 11/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7934 - smape_loss: 1.0295 - mae_denorm: 0.8065Tiempo on_epoch_end 2024-10-30 15:21:40
# 5/5 [==============================] - 0s 21ms/step - loss: 0.8021 - smape_loss: 1.0484 - mae_denorm: 0.8548 - val_loss: 2.3383 - val_smape_loss: 1.3797 - val_mae_denorm: 148.5625
# Epoch 12/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7847 - smape_loss: 1.0095 - mae_denorm: 0.8801Tiempo on_epoch_end 2024-10-30 15:21:40
# 5/5 [==============================] - 0s 22ms/step - loss: 0.7947 - smape_loss: 1.0409 - mae_denorm: 0.8489 - val_loss: 2.3420 - val_smape_loss: 1.3813 - val_mae_denorm: 147.3759
# Epoch 13/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7777 - smape_loss: 1.0164 - mae_denorm: 0.8580Tiempo on_epoch_end 2024-10-30 15:21:40
# 5/5 [==============================] - 0s 20ms/step - loss: 0.7891 - smape_loss: 1.0308 - mae_denorm: 0.8451 - val_loss: 2.3604 - val_smape_loss: 1.3866 - val_mae_denorm: 147.1931
# Epoch 14/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7969 - smape_loss: 0.9875 - mae_denorm: 0.7689Tiempo on_epoch_end 2024-10-30 15:21:40
# 5/5 [==============================] - 0s 23ms/step - loss: 0.7839 - smape_loss: 1.0201 - mae_denorm: 0.8414 - val_loss: 2.3644 - val_smape_loss: 1.3875 - val_mae_denorm: 145.1631
# Epoch 15/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7977 - smape_loss: 1.0041 - mae_denorm: 0.7959Tiempo on_epoch_end 2024-10-30 15:21:40
# 5/5 [==============================] - 0s 25ms/step - loss: 0.7771 - smape_loss: 1.0149 - mae_denorm: 0.8358 - val_loss: 2.3739 - val_smape_loss: 1.3898 - val_mae_denorm: 144.1195
# Epoch 16/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7831 - smape_loss: 1.0048 - mae_denorm: 0.8733Tiempo on_epoch_end 2024-10-30 15:21:40
# 5/5 [==============================] - 0s 23ms/step - loss: 0.7729 - smape_loss: 1.0081 - mae_denorm: 0.8336 - val_loss: 2.3738 - val_smape_loss: 1.3902 - val_mae_denorm: 142.0644
# Epoch 17/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7463 - smape_loss: 1.0142 - mae_denorm: 0.8057Tiempo on_epoch_end 2024-10-30 15:21:40
# 5/5 [==============================] - 0s 21ms/step - loss: 0.7684 - smape_loss: 0.9991 - mae_denorm: 0.8303 - val_loss: 2.3794 - val_smape_loss: 1.3911 - val_mae_denorm: 141.8559
# Epoch 18/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7527 - smape_loss: 1.0026 - mae_denorm: 0.7774Tiempo on_epoch_end 2024-10-30 15:21:40
# 5/5 [==============================] - 0s 24ms/step - loss: 0.7656 - smape_loss: 0.9999 - mae_denorm: 0.8287 - val_loss: 2.3753 - val_smape_loss: 1.3903 - val_mae_denorm: 140.8140
# Epoch 19/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7492 - smape_loss: 0.9773 - mae_denorm: 0.8398Tiempo on_epoch_end 2024-10-30 15:21:41
# 5/5 [==============================] - 0s 20ms/step - loss: 0.7619 - smape_loss: 0.9947 - mae_denorm: 0.8253 - val_loss: 2.3827 - val_smape_loss: 1.3918 - val_mae_denorm: 140.4657
# Epoch 20/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7669 - smape_loss: 0.9672 - mae_denorm: 0.8765Tiempo on_epoch_end 2024-10-30 15:21:41
# 5/5 [==============================] - 0s 24ms/step - loss: 0.7597 - smape_loss: 0.9943 - mae_denorm: 0.8241 - val_loss: 2.3724 - val_smape_loss: 1.3896 - val_mae_denorm: 139.3641
# Epoch 21/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7887 - smape_loss: 1.0040 - mae_denorm: 0.8554Tiempo on_epoch_end 2024-10-30 15:21:41
# 5/5 [==============================] - 0s 21ms/step - loss: 0.7593 - smape_loss: 0.9895 - mae_denorm: 0.8235 - val_loss: 2.3938 - val_smape_loss: 1.3942 - val_mae_denorm: 140.7555
# Epoch 22/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7378 - smape_loss: 0.9688 - mae_denorm: 0.7862Tiempo on_epoch_end 2024-10-30 15:21:41
# 5/5 [==============================] - 0s 23ms/step - loss: 0.7571 - smape_loss: 0.9938 - mae_denorm: 0.8218 - val_loss: 2.3740 - val_smape_loss: 1.3889 - val_mae_denorm: 139.2344
# Epoch 23/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7461 - smape_loss: 0.9920 - mae_denorm: 0.9004Tiempo on_epoch_end 2024-10-30 15:21:41
# 5/5 [==============================] - 0s 22ms/step - loss: 0.7538 - smape_loss: 0.9831 - mae_denorm: 0.8189 - val_loss: 2.3890 - val_smape_loss: 1.3925 - val_mae_denorm: 139.6741
# Epoch 24/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7436 - smape_loss: 0.9813 - mae_denorm: 0.8431Tiempo on_epoch_end 2024-10-30 15:21:41
# 5/5 [==============================] - 0s 20ms/step - loss: 0.7557 - smape_loss: 0.9898 - mae_denorm: 0.8210 - val_loss: 2.3879 - val_smape_loss: 1.3922 - val_mae_denorm: 139.2545
# Epoch 25/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7803 - smape_loss: 0.9697 - mae_denorm: 0.7845Tiempo on_epoch_end 2024-10-30 15:21:41
# 5/5 [==============================] - 0s 36ms/step - loss: 0.7546 - smape_loss: 0.9856 - mae_denorm: 0.8207 - val_loss: 2.3740 - val_smape_loss: 1.3894 - val_mae_denorm: 137.3233
# Epoch 26/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.7622 - smape_loss: 0.9953 - mae_denorm: 0.8189Tiempo on_epoch_end 2024-10-30 15:21:41
# 5/5 [==============================] - 0s 32ms/step - loss: 0.7571 - smape_loss: 0.9920 - mae_denorm: 0.8215 - val_loss: 2.3792 - val_smape_loss: 1.3902 - val_mae_denorm: 138.4037
# Epoch 27/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7496 - smape_loss: 0.9446 - mae_denorm: 0.8290Tiempo on_epoch_end 2024-10-30 15:21:41
# 5/5 [==============================] - 0s 25ms/step - loss: 0.7531 - smape_loss: 0.9906 - mae_denorm: 0.8188 - val_loss: 2.3895 - val_smape_loss: 1.3922 - val_mae_denorm: 138.7996
# Epoch 28/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7427 - smape_loss: 0.9992 - mae_denorm: 0.7845Tiempo on_epoch_end 2024-10-30 15:21:42
# 5/5 [==============================] - 0s 36ms/step - loss: 0.7512 - smape_loss: 0.9827 - mae_denorm: 0.8166 - val_loss: 2.3877 - val_smape_loss: 1.3915 - val_mae_denorm: 139.2519
# Epoch 29/500
# 5/5 [==============================] - ETA: 0s - loss: 0.7542 - smape_loss: 0.9893 - mae_denorm: 0.8194Tiempo on_epoch_end 2024-10-30 15:21:42
# 5/5 [==============================] - 0s 25ms/step - loss: 0.7542 - smape_loss: 0.9893 - mae_denorm: 0.8194 - val_loss: 2.3929 - val_smape_loss: 1.3921 - val_mae_denorm: 141.5097
# Epoch 30/500
# 5/5 [==============================] - ETA: 0s - loss: 0.7527 - smape_loss: 0.9856 - mae_denorm: 0.8181Tiempo on_epoch_end 2024-10-30 15:21:42
# 5/5 [==============================] - 0s 27ms/step - loss: 0.7527 - smape_loss: 0.9856 - mae_denorm: 0.8181 - val_loss: 2.3995 - val_smape_loss: 1.3937 - val_mae_denorm: 141.0512
# Epoch 31/500
# 5/5 [==============================] - ETA: 0s - loss: 0.7503 - smape_loss: 0.9852 - mae_denorm: 0.8165Tiempo on_epoch_end 2024-10-30 15:21:42
# 5/5 [==============================] - 0s 28ms/step - loss: 0.7503 - smape_loss: 0.9852 - mae_denorm: 0.8165 - val_loss: 2.3826 - val_smape_loss: 1.3894 - val_mae_denorm: 139.1209
# Epoch 32/500
# 5/5 [==============================] - ETA: 0s - loss: 0.7470 - smape_loss: 0.9837 - mae_denorm: 0.8129Tiempo on_epoch_end 2024-10-30 15:21:42
# 5/5 [==============================] - 0s 34ms/step - loss: 0.7470 - smape_loss: 0.9837 - mae_denorm: 0.8129 - val_loss: 2.3695 - val_smape_loss: 1.3853 - val_mae_denorm: 138.4567
# Epoch 33/500
# 5/5 [==============================] - ETA: 0s - loss: 0.7452 - smape_loss: 0.9800 - mae_denorm: 0.8107Tiempo on_epoch_end 2024-10-30 15:21:42
# 5/5 [==============================] - 0s 32ms/step - loss: 0.7452 - smape_loss: 0.9800 - mae_denorm: 0.8107 - val_loss: 2.3799 - val_smape_loss: 1.3879 - val_mae_denorm: 138.5523
# Epoch 34/500
# 5/5 [==============================] - ETA: 0s - loss: 0.7449 - smape_loss: 0.9782 - mae_denorm: 0.8108Tiempo on_epoch_end 2024-10-30 15:21:42
# 5/5 [==============================] - 0s 29ms/step - loss: 0.7449 - smape_loss: 0.9782 - mae_denorm: 0.8108 - val_loss: 2.3741 - val_smape_loss: 1.3867 - val_mae_denorm: 137.8305
# Epoch 35/500
# 5/5 [==============================] - ETA: 0s - loss: 0.7433 - smape_loss: 0.9790 - mae_denorm: 0.8095Tiempo on_epoch_end 2024-10-30 15:21:43
# 5/5 [==============================] - 0s 29ms/step - loss: 0.7433 - smape_loss: 0.9790 - mae_denorm: 0.8095 - val_loss: 2.3653 - val_smape_loss: 1.3842 - val_mae_denorm: 137.2746
# Epoch 36/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.7464 - smape_loss: 0.9807 - mae_denorm: 0.8171Tiempo on_epoch_end 2024-10-30 15:21:43
# 5/5 [==============================] - 0s 31ms/step - loss: 0.7430 - smape_loss: 0.9784 - mae_denorm: 0.8082 - val_loss: 2.3595 - val_smape_loss: 1.3824 - val_mae_denorm: 136.4313
# Epoch 37/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.7473 - smape_loss: 0.9775 - mae_denorm: 0.8148Tiempo on_epoch_end 2024-10-30 15:21:43
# 5/5 [==============================] - 0s 32ms/step - loss: 0.7423 - smape_loss: 0.9763 - mae_denorm: 0.8085 - val_loss: 2.3534 - val_smape_loss: 1.3809 - val_mae_denorm: 136.2140
# Epoch 38/500
# 5/5 [==============================] - ETA: 0s - loss: 0.7409 - smape_loss: 0.9729 - mae_denorm: 0.8067Tiempo on_epoch_end 2024-10-30 15:21:43
# 5/5 [==============================] - 0s 39ms/step - loss: 0.7409 - smape_loss: 0.9729 - mae_denorm: 0.8067 - val_loss: 2.3431 - val_smape_loss: 1.3777 - val_mae_denorm: 136.2887
# Epoch 39/500
# 5/5 [==============================] - ETA: 0s - loss: 0.7412 - smape_loss: 0.9707 - mae_denorm: 0.8066Tiempo on_epoch_end 2024-10-30 15:21:43
# 5/5 [==============================] - 0s 33ms/step - loss: 0.7412 - smape_loss: 0.9707 - mae_denorm: 0.8066 - val_loss: 2.3310 - val_smape_loss: 1.3741 - val_mae_denorm: 135.3562
# Epoch 40/500
# 5/5 [==============================] - ETA: 0s - loss: 0.7412 - smape_loss: 0.9711 - mae_denorm: 0.8066Tiempo on_epoch_end 2024-10-30 15:21:43
# 5/5 [==============================] - 0s 29ms/step - loss: 0.7412 - smape_loss: 0.9711 - mae_denorm: 0.8066 - val_loss: 2.3342 - val_smape_loss: 1.3747 - val_mae_denorm: 135.2922
# Epoch 41/500
# 5/5 [==============================] - ETA: 0s - loss: 0.7401 - smape_loss: 0.9705 - mae_denorm: 0.8054Tiempo on_epoch_end 2024-10-30 15:21:44
# 5/5 [==============================] - 0s 31ms/step - loss: 0.7401 - smape_loss: 0.9705 - mae_denorm: 0.8054 - val_loss: 2.3477 - val_smape_loss: 1.3779 - val_mae_denorm: 135.6805
# Epoch 42/500
# 5/5 [==============================] - ETA: 0s - loss: 0.7394 - smape_loss: 0.9704 - mae_denorm: 0.8044Tiempo on_epoch_end 2024-10-30 15:21:44
# 5/5 [==============================] - 0s 31ms/step - loss: 0.7394 - smape_loss: 0.9704 - mae_denorm: 0.8044 - val_loss: 2.3544 - val_smape_loss: 1.3796 - val_mae_denorm: 136.4341
# Epoch 43/500
# 3/5 [=================>............] - ETA: 0s - loss: 0.7389 - smape_loss: 0.9588 - mae_denorm: 0.7757Tiempo on_epoch_end 2024-10-30 15:21:44
# 5/5 [==============================] - 0s 35ms/step - loss: 0.7383 - smape_loss: 0.9666 - mae_denorm: 0.8037 - val_loss: 2.3433 - val_smape_loss: 1.3763 - val_mae_denorm: 135.2169
# Epoch 44/500
# 5/5 [==============================] - ETA: 0s - loss: 0.7372 - smape_loss: 0.9653 - mae_denorm: 0.8019Tiempo on_epoch_end 2024-10-30 15:21:44
# 5/5 [==============================] - 0s 31ms/step - loss: 0.7372 - smape_loss: 0.9653 - mae_denorm: 0.8019 - val_loss: 2.3426 - val_smape_loss: 1.3758 - val_mae_denorm: 135.5597
# Epoch 45/500
# 5/5 [==============================] - ETA: 0s - loss: 0.7362 - smape_loss: 0.9662 - mae_denorm: 0.8008Tiempo on_epoch_end 2024-10-30 15:21:44
# 5/5 [==============================] - 0s 31ms/step - loss: 0.7362 - smape_loss: 0.9662 - mae_denorm: 0.8008 - val_loss: 2.3388 - val_smape_loss: 1.3745 - val_mae_denorm: 134.9629
# Epoch 46/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.7402 - smape_loss: 0.9617 - mae_denorm: 0.8101Tiempo on_epoch_end 2024-10-30 15:21:44
# 5/5 [==============================] - 0s 32ms/step - loss: 0.7362 - smape_loss: 0.9622 - mae_denorm: 0.8005 - val_loss: 2.3268 - val_smape_loss: 1.3711 - val_mae_denorm: 133.5407
# Epoch 47/500
# 5/5 [==============================] - ETA: 0s - loss: 0.7350 - smape_loss: 0.9589 - mae_denorm: 0.7994Tiempo on_epoch_end 2024-10-30 15:21:45
# 5/5 [==============================] - 0s 46ms/step - loss: 0.7350 - smape_loss: 0.9589 - mae_denorm: 0.7994 - val_loss: 2.3292 - val_smape_loss: 1.3718 - val_mae_denorm: 134.0400
# Epoch 48/500
# 5/5 [==============================] - ETA: 0s - loss: 0.7346 - smape_loss: 0.9587 - mae_denorm: 0.7982Tiempo on_epoch_end 2024-10-30 15:21:45
# 5/5 [==============================] - 0s 30ms/step - loss: 0.7346 - smape_loss: 0.9587 - mae_denorm: 0.7982 - val_loss: 2.3222 - val_smape_loss: 1.3695 - val_mae_denorm: 133.7285
# Epoch 49/500
# 5/5 [==============================] - ETA: 0s - loss: 0.7333 - smape_loss: 0.9556 - mae_denorm: 0.7967Tiempo on_epoch_end 2024-10-30 15:21:45
# 5/5 [==============================] - 0s 33ms/step - loss: 0.7333 - smape_loss: 0.9556 - mae_denorm: 0.7967 - val_loss: 2.3289 - val_smape_loss: 1.3711 - val_mae_denorm: 133.8917
# Epoch 50/500
# 5/5 [==============================] - ETA: 0s - loss: 0.7334 - smape_loss: 0.9594 - mae_denorm: 0.7965Tiempo on_epoch_end 2024-10-30 15:21:45
# 5/5 [==============================] - 0s 29ms/step - loss: 0.7334 - smape_loss: 0.9594 - mae_denorm: 0.7965 - val_loss: 2.3330 - val_smape_loss: 1.3717 - val_mae_denorm: 133.9162
# Epoch 51/500
# 5/5 [==============================] - ETA: 0s - loss: 0.7350 - smape_loss: 0.9574 - mae_denorm: 0.7987Tiempo on_epoch_end 2024-10-30 15:21:45
# 5/5 [==============================] - 0s 28ms/step - loss: 0.7350 - smape_loss: 0.9574 - mae_denorm: 0.7987 - val_loss: 2.3222 - val_smape_loss: 1.3689 - val_mae_denorm: 133.1344
# Epoch 52/500
# 5/5 [==============================] - ETA: 0s - loss: 0.7331 - smape_loss: 0.9580 - mae_denorm: 0.7960Tiempo on_epoch_end 2024-10-30 15:21:45
# 5/5 [==============================] - 0s 25ms/step - loss: 0.7331 - smape_loss: 0.9580 - mae_denorm: 0.7960 - val_loss: 2.3251 - val_smape_loss: 1.3693 - val_mae_denorm: 134.2186
# Epoch 53/500
# 5/5 [==============================] - ETA: 0s - loss: 0.7312 - smape_loss: 0.9506 - mae_denorm: 0.7935Tiempo on_epoch_end 2024-10-30 15:21:45
# 5/5 [==============================] - 0s 27ms/step - loss: 0.7312 - smape_loss: 0.9506 - mae_denorm: 0.7935 - val_loss: 2.3129 - val_smape_loss: 1.3656 - val_mae_denorm: 133.0871
# Epoch 54/500
# 5/5 [==============================] - ETA: 0s - loss: 0.7306 - smape_loss: 0.9521 - mae_denorm: 0.7925Tiempo on_epoch_end 2024-10-30 15:21:45
# 5/5 [==============================] - 0s 23ms/step - loss: 0.7306 - smape_loss: 0.9521 - mae_denorm: 0.7925 - val_loss: 2.3191 - val_smape_loss: 1.3673 - val_mae_denorm: 133.5448
# Epoch 55/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7132 - smape_loss: 0.9398 - mae_denorm: 0.7618Tiempo on_epoch_end 2024-10-30 15:21:46
# 5/5 [==============================] - 0s 24ms/step - loss: 0.7300 - smape_loss: 0.9517 - mae_denorm: 0.7915 - val_loss: 2.3105 - val_smape_loss: 1.3647 - val_mae_denorm: 132.6842
# Epoch 56/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7323 - smape_loss: 0.9536 - mae_denorm: 0.8284Tiempo on_epoch_end 2024-10-30 15:21:46
# 5/5 [==============================] - 0s 22ms/step - loss: 0.7306 - smape_loss: 0.9475 - mae_denorm: 0.7921 - val_loss: 2.3016 - val_smape_loss: 1.3624 - val_mae_denorm: 132.5712
# Epoch 57/500
# 5/5 [==============================] - ETA: 0s - loss: 0.7307 - smape_loss: 0.9520 - mae_denorm: 0.7921Tiempo on_epoch_end 2024-10-30 15:21:46
# 5/5 [==============================] - 0s 25ms/step - loss: 0.7307 - smape_loss: 0.9520 - mae_denorm: 0.7921 - val_loss: 2.3122 - val_smape_loss: 1.3648 - val_mae_denorm: 133.8643
# Epoch 58/500
# 5/5 [==============================] - ETA: 0s - loss: 0.7327 - smape_loss: 0.9477 - mae_denorm: 0.7943Tiempo on_epoch_end 2024-10-30 15:21:46
# 5/5 [==============================] - 0s 27ms/step - loss: 0.7327 - smape_loss: 0.9477 - mae_denorm: 0.7943 - val_loss: 2.2902 - val_smape_loss: 1.3588 - val_mae_denorm: 131.9917
# Epoch 59/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7186 - smape_loss: 0.9105 - mae_denorm: 0.7093Tiempo on_epoch_end 2024-10-30 15:21:46
# 5/5 [==============================] - 0s 21ms/step - loss: 0.7393 - smape_loss: 0.9639 - mae_denorm: 0.8057 - val_loss: 2.2945 - val_smape_loss: 1.3599 - val_mae_denorm: 132.6130
# Epoch 60/500
# 5/5 [==============================] - ETA: 0s - loss: 0.7409 - smape_loss: 0.9632 - mae_denorm: 0.8015Tiempo on_epoch_end 2024-10-30 15:21:46
# 5/5 [==============================] - 0s 26ms/step - loss: 0.7409 - smape_loss: 0.9632 - mae_denorm: 0.8015 - val_loss: 2.2766 - val_smape_loss: 1.3547 - val_mae_denorm: 131.2126
# Epoch 61/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7635 - smape_loss: 0.9498 - mae_denorm: 0.8459Tiempo on_epoch_end 2024-10-30 15:21:46
# 5/5 [==============================] - 0s 27ms/step - loss: 0.7436 - smape_loss: 0.9688 - mae_denorm: 0.8078 - val_loss: 2.2705 - val_smape_loss: 1.3533 - val_mae_denorm: 132.9197
# Epoch 62/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7515 - smape_loss: 0.9551 - mae_denorm: 0.7893Tiempo on_epoch_end 2024-10-30 15:21:46
# 5/5 [==============================] - 0s 21ms/step - loss: 0.7367 - smape_loss: 0.9633 - mae_denorm: 0.7987 - val_loss: 2.2651 - val_smape_loss: 1.3513 - val_mae_denorm: 132.3823
# Epoch 63/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7520 - smape_loss: 0.9369 - mae_denorm: 0.7682Tiempo on_epoch_end 2024-10-30 15:21:46
# 5/5 [==============================] - 0s 21ms/step - loss: 0.7321 - smape_loss: 0.9498 - mae_denorm: 0.7929 - val_loss: 2.2767 - val_smape_loss: 1.3543 - val_mae_denorm: 132.3137
# Epoch 64/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7336 - smape_loss: 0.9410 - mae_denorm: 0.8014Tiempo on_epoch_end 2024-10-30 15:21:47
# 5/5 [==============================] - 0s 22ms/step - loss: 0.7309 - smape_loss: 0.9487 - mae_denorm: 0.7925 - val_loss: 2.2906 - val_smape_loss: 1.3585 - val_mae_denorm: 133.7943
# Epoch 65/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7442 - smape_loss: 0.9725 - mae_denorm: 0.7828Tiempo on_epoch_end 2024-10-30 15:21:47
# 5/5 [==============================] - 0s 21ms/step - loss: 0.7287 - smape_loss: 0.9472 - mae_denorm: 0.7897 - val_loss: 2.2832 - val_smape_loss: 1.3562 - val_mae_denorm: 132.6343
# Epoch 66/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7391 - smape_loss: 0.9992 - mae_denorm: 0.9040Tiempo on_epoch_end 2024-10-30 15:21:47
# 5/5 [==============================] - 0s 23ms/step - loss: 0.7270 - smape_loss: 0.9451 - mae_denorm: 0.7873 - val_loss: 2.2937 - val_smape_loss: 1.3587 - val_mae_denorm: 133.9687
# Epoch 67/500
# 5/5 [==============================] - ETA: 0s - loss: 0.7266 - smape_loss: 0.9405 - mae_denorm: 0.7874Tiempo on_epoch_end 2024-10-30 15:21:47
# 5/5 [==============================] - 0s 23ms/step - loss: 0.7266 - smape_loss: 0.9405 - mae_denorm: 0.7874 - val_loss: 2.2760 - val_smape_loss: 1.3536 - val_mae_denorm: 132.8074
# Epoch 68/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7110 - smape_loss: 0.9346 - mae_denorm: 0.8379Tiempo on_epoch_end 2024-10-30 15:21:47
# 5/5 [==============================] - 0s 22ms/step - loss: 0.7260 - smape_loss: 0.9403 - mae_denorm: 0.7862 - val_loss: 2.2733 - val_smape_loss: 1.3530 - val_mae_denorm: 132.7517
# Epoch 69/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7325 - smape_loss: 0.9323 - mae_denorm: 0.7715Tiempo on_epoch_end 2024-10-30 15:21:47
# 5/5 [==============================] - 0s 25ms/step - loss: 0.7253 - smape_loss: 0.9399 - mae_denorm: 0.7851 - val_loss: 2.2825 - val_smape_loss: 1.3552 - val_mae_denorm: 133.4414
# Epoch 70/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7342 - smape_loss: 0.9291 - mae_denorm: 0.7660Tiempo on_epoch_end 2024-10-30 15:21:47
# 5/5 [==============================] - 0s 21ms/step - loss: 0.7242 - smape_loss: 0.9341 - mae_denorm: 0.7838 - val_loss: 2.2782 - val_smape_loss: 1.3541 - val_mae_denorm: 133.4735
# Epoch 71/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7253 - smape_loss: 0.9541 - mae_denorm: 0.7976Tiempo on_epoch_end 2024-10-30 15:21:47
# 5/5 [==============================] - 0s 20ms/step - loss: 0.7238 - smape_loss: 0.9367 - mae_denorm: 0.7833 - val_loss: 2.2740 - val_smape_loss: 1.3529 - val_mae_denorm: 133.4819
# Epoch 72/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.6976 - smape_loss: 0.9047 - mae_denorm: 0.7663Tiempo on_epoch_end 2024-10-30 15:21:47
# 5/5 [==============================] - 0s 22ms/step - loss: 0.7240 - smape_loss: 0.9349 - mae_denorm: 0.7835 - val_loss: 2.2805 - val_smape_loss: 1.3546 - val_mae_denorm: 133.8668
# Epoch 73/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7517 - smape_loss: 0.9557 - mae_denorm: 0.8374Tiempo on_epoch_end 2024-10-30 15:21:48
# 5/5 [==============================] - 0s 20ms/step - loss: 0.7238 - smape_loss: 0.9367 - mae_denorm: 0.7830 - val_loss: 2.2736 - val_smape_loss: 1.3525 - val_mae_denorm: 133.8081
# Epoch 74/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7337 - smape_loss: 0.9245 - mae_denorm: 0.7359Tiempo on_epoch_end 2024-10-30 15:21:48
# 5/5 [==============================] - 0s 24ms/step - loss: 0.7234 - smape_loss: 0.9332 - mae_denorm: 0.7827 - val_loss: 2.2796 - val_smape_loss: 1.3542 - val_mae_denorm: 134.3118
# Epoch 75/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7029 - smape_loss: 0.9282 - mae_denorm: 0.7783Tiempo on_epoch_end 2024-10-30 15:21:48
# 5/5 [==============================] - 0s 20ms/step - loss: 0.7236 - smape_loss: 0.9346 - mae_denorm: 0.7830 - val_loss: 2.2774 - val_smape_loss: 1.3534 - val_mae_denorm: 134.1456
# Epoch 76/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.6828 - smape_loss: 0.8972 - mae_denorm: 0.7721Tiempo on_epoch_end 2024-10-30 15:21:48
# 5/5 [==============================] - 0s 23ms/step - loss: 0.7250 - smape_loss: 0.9382 - mae_denorm: 0.7848 - val_loss: 2.2704 - val_smape_loss: 1.3514 - val_mae_denorm: 134.1333
# Epoch 77/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7173 - smape_loss: 0.9144 - mae_denorm: 0.7376Tiempo on_epoch_end 2024-10-30 15:21:48
# 5/5 [==============================] - 0s 20ms/step - loss: 0.7234 - smape_loss: 0.9323 - mae_denorm: 0.7825 - val_loss: 2.2770 - val_smape_loss: 1.3534 - val_mae_denorm: 135.0369
# Epoch 78/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.6787 - smape_loss: 0.9341 - mae_denorm: 0.7611Tiempo on_epoch_end 2024-10-30 15:21:48
# 5/5 [==============================] - 0s 22ms/step - loss: 0.7228 - smape_loss: 0.9345 - mae_denorm: 0.7821 - val_loss: 2.2739 - val_smape_loss: 1.3522 - val_mae_denorm: 134.8892
# Epoch 79/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7265 - smape_loss: 0.9455 - mae_denorm: 0.7643Tiempo on_epoch_end 2024-10-30 15:21:48
# 5/5 [==============================] - 0s 26ms/step - loss: 0.7227 - smape_loss: 0.9314 - mae_denorm: 0.7821 - val_loss: 2.2746 - val_smape_loss: 1.3526 - val_mae_denorm: 135.9294
# Epoch 80/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7223 - smape_loss: 0.9332 - mae_denorm: 0.8298Tiempo on_epoch_end 2024-10-30 15:21:48
# 5/5 [==============================] - 0s 23ms/step - loss: 0.7248 - smape_loss: 0.9340 - mae_denorm: 0.7845 - val_loss: 2.2800 - val_smape_loss: 1.3538 - val_mae_denorm: 135.8826
# Epoch 81/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7262 - smape_loss: 0.9494 - mae_denorm: 0.7622Tiempo on_epoch_end 2024-10-30 15:21:48
# 5/5 [==============================] - 0s 22ms/step - loss: 0.7240 - smape_loss: 0.9341 - mae_denorm: 0.7835 - val_loss: 2.2873 - val_smape_loss: 1.3560 - val_mae_denorm: 136.3449
# Epoch 82/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7179 - smape_loss: 0.9490 - mae_denorm: 0.7302Tiempo on_epoch_end 2024-10-30 15:21:49
# 5/5 [==============================] - 0s 20ms/step - loss: 0.7225 - smape_loss: 0.9346 - mae_denorm: 0.7817 - val_loss: 2.2719 - val_smape_loss: 1.3518 - val_mae_denorm: 135.7815
# Epoch 83/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7107 - smape_loss: 0.9062 - mae_denorm: 0.8256Tiempo on_epoch_end 2024-10-30 15:21:49
# 5/5 [==============================] - 0s 22ms/step - loss: 0.7229 - smape_loss: 0.9326 - mae_denorm: 0.7820 - val_loss: 2.2700 - val_smape_loss: 1.3513 - val_mae_denorm: 136.6633
# Epoch 84/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7244 - smape_loss: 0.9367 - mae_denorm: 0.7786Tiempo on_epoch_end 2024-10-30 15:21:49
# 5/5 [==============================] - 0s 22ms/step - loss: 0.7220 - smape_loss: 0.9295 - mae_denorm: 0.7808 - val_loss: 2.2668 - val_smape_loss: 1.3501 - val_mae_denorm: 136.1823
# Epoch 85/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7154 - smape_loss: 0.9132 - mae_denorm: 0.7658Tiempo on_epoch_end 2024-10-30 15:21:49
# 5/5 [==============================] - 0s 20ms/step - loss: 0.7208 - smape_loss: 0.9302 - mae_denorm: 0.7796 - val_loss: 2.2760 - val_smape_loss: 1.3529 - val_mae_denorm: 137.1993
# Epoch 86/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7244 - smape_loss: 0.9671 - mae_denorm: 0.7883Tiempo on_epoch_end 2024-10-30 15:21:49
# 5/5 [==============================] - 0s 22ms/step - loss: 0.7207 - smape_loss: 0.9326 - mae_denorm: 0.7791 - val_loss: 2.2843 - val_smape_loss: 1.3554 - val_mae_denorm: 138.3788
# Epoch 87/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7026 - smape_loss: 0.9372 - mae_denorm: 0.8010Tiempo on_epoch_end 2024-10-30 15:21:49
# 5/5 [==============================] - 0s 23ms/step - loss: 0.7220 - smape_loss: 0.9287 - mae_denorm: 0.7806 - val_loss: 2.2759 - val_smape_loss: 1.3528 - val_mae_denorm: 137.8135
# Epoch 88/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7191 - smape_loss: 0.9598 - mae_denorm: 0.8378Tiempo on_epoch_end 2024-10-30 15:21:49
# 5/5 [==============================] - 0s 24ms/step - loss: 0.7234 - smape_loss: 0.9315 - mae_denorm: 0.7824 - val_loss: 2.2679 - val_smape_loss: 1.3504 - val_mae_denorm: 137.1958
# Epoch 89/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7177 - smape_loss: 0.9180 - mae_denorm: 0.7722Tiempo on_epoch_end 2024-10-30 15:21:49
# 5/5 [==============================] - 0s 20ms/step - loss: 0.7220 - smape_loss: 0.9318 - mae_denorm: 0.7809 - val_loss: 2.2689 - val_smape_loss: 1.3503 - val_mae_denorm: 137.0396
# Epoch 90/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7185 - smape_loss: 0.9107 - mae_denorm: 0.7787Tiempo on_epoch_end 2024-10-30 15:21:49
# 5/5 [==============================] - 0s 20ms/step - loss: 0.7216 - smape_loss: 0.9276 - mae_denorm: 0.7804 - val_loss: 2.2857 - val_smape_loss: 1.3552 - val_mae_denorm: 138.5454
# Epoch 91/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7380 - smape_loss: 0.9236 - mae_denorm: 0.7615Tiempo on_epoch_end 2024-10-30 15:21:49
# 5/5 [==============================] - 0s 20ms/step - loss: 0.7227 - smape_loss: 0.9299 - mae_denorm: 0.7819 - val_loss: 2.2740 - val_smape_loss: 1.3518 - val_mae_denorm: 137.1835
# Epoch 92/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7044 - smape_loss: 0.8939 - mae_denorm: 0.7401Tiempo on_epoch_end 2024-10-30 15:21:50
# 5/5 [==============================] - 0s 19ms/step - loss: 0.7231 - smape_loss: 0.9307 - mae_denorm: 0.7826 - val_loss: 2.2791 - val_smape_loss: 1.3533 - val_mae_denorm: 138.2909
# Epoch 93/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7057 - smape_loss: 0.9196 - mae_denorm: 0.7966Tiempo on_epoch_end 2024-10-30 15:21:50
# 5/5 [==============================] - 0s 19ms/step - loss: 0.7230 - smape_loss: 0.9340 - mae_denorm: 0.7824 - val_loss: 2.2833 - val_smape_loss: 1.3546 - val_mae_denorm: 139.7263
# Epoch 94/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7254 - smape_loss: 0.9603 - mae_denorm: 0.7785Tiempo on_epoch_end 2024-10-30 15:21:50
# 5/5 [==============================] - 0s 21ms/step - loss: 0.7230 - smape_loss: 0.9311 - mae_denorm: 0.7824 - val_loss: 2.2795 - val_smape_loss: 1.3539 - val_mae_denorm: 139.5491
# Epoch 95/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7069 - smape_loss: 0.9306 - mae_denorm: 0.8284Tiempo on_epoch_end 2024-10-30 15:21:50
# 5/5 [==============================] - 0s 20ms/step - loss: 0.7214 - smape_loss: 0.9301 - mae_denorm: 0.7812 - val_loss: 2.2678 - val_smape_loss: 1.3505 - val_mae_denorm: 138.9779
# Epoch 96/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7068 - smape_loss: 0.9308 - mae_denorm: 0.7858Tiempo on_epoch_end 2024-10-30 15:21:50
# 5/5 [==============================] - 0s 22ms/step - loss: 0.7191 - smape_loss: 0.9261 - mae_denorm: 0.7776 - val_loss: 2.2850 - val_smape_loss: 1.3559 - val_mae_denorm: 140.5261
# Epoch 97/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7259 - smape_loss: 0.9527 - mae_denorm: 0.7903Tiempo on_epoch_end 2024-10-30 15:21:50
# 5/5 [==============================] - 0s 22ms/step - loss: 0.7181 - smape_loss: 0.9254 - mae_denorm: 0.7762 - val_loss: 2.2792 - val_smape_loss: 1.3538 - val_mae_denorm: 139.6415
# Epoch 98/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.6940 - smape_loss: 0.9123 - mae_denorm: 0.7889Tiempo on_epoch_end 2024-10-30 15:21:50
# 5/5 [==============================] - 0s 26ms/step - loss: 0.7179 - smape_loss: 0.9243 - mae_denorm: 0.7763 - val_loss: 2.2707 - val_smape_loss: 1.3514 - val_mae_denorm: 139.0349
# Epoch 99/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.6931 - smape_loss: 0.9124 - mae_denorm: 0.7892Tiempo on_epoch_end 2024-10-30 15:21:50
# 5/5 [==============================] - 0s 23ms/step - loss: 0.7185 - smape_loss: 0.9236 - mae_denorm: 0.7769 - val_loss: 2.2882 - val_smape_loss: 1.3567 - val_mae_denorm: 140.7180
# Epoch 100/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7089 - smape_loss: 0.9104 - mae_denorm: 0.7060Tiempo on_epoch_end 2024-10-30 15:21:50
# 5/5 [==============================] - 0s 21ms/step - loss: 0.7180 - smape_loss: 0.9252 - mae_denorm: 0.7763 - val_loss: 2.2758 - val_smape_loss: 1.3536 - val_mae_denorm: 140.6623
# Epoch 101/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7239 - smape_loss: 0.9005 - mae_denorm: 0.7744Tiempo on_epoch_end 2024-10-30 15:21:51
# 5/5 [==============================] - 0s 23ms/step - loss: 0.7182 - smape_loss: 0.9245 - mae_denorm: 0.7764 - val_loss: 2.2850 - val_smape_loss: 1.3562 - val_mae_denorm: 141.5186
# Epoch 102/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.6970 - smape_loss: 0.9193 - mae_denorm: 0.7948Tiempo on_epoch_end 2024-10-30 15:21:51
# 5/5 [==============================] - 0s 23ms/step - loss: 0.7176 - smape_loss: 0.9231 - mae_denorm: 0.7761 - val_loss: 2.2739 - val_smape_loss: 1.3530 - val_mae_denorm: 140.6159
# Epoch 103/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7256 - smape_loss: 0.9417 - mae_denorm: 0.8712Tiempo on_epoch_end 2024-10-30 15:21:51
# 5/5 [==============================] - 0s 21ms/step - loss: 0.7168 - smape_loss: 0.9216 - mae_denorm: 0.7751 - val_loss: 2.2724 - val_smape_loss: 1.3527 - val_mae_denorm: 140.6973
# Epoch 104/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7436 - smape_loss: 0.9421 - mae_denorm: 0.8094Tiempo on_epoch_end 2024-10-30 15:21:51
# 5/5 [==============================] - 0s 21ms/step - loss: 0.7184 - smape_loss: 0.9271 - mae_denorm: 0.7770 - val_loss: 2.2907 - val_smape_loss: 1.3581 - val_mae_denorm: 142.3140
# Epoch 105/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7294 - smape_loss: 0.9530 - mae_denorm: 0.7728Tiempo on_epoch_end 2024-10-30 15:21:51
# 5/5 [==============================] - 0s 20ms/step - loss: 0.7185 - smape_loss: 0.9249 - mae_denorm: 0.7773 - val_loss: 2.2701 - val_smape_loss: 1.3523 - val_mae_denorm: 141.2784
# Epoch 106/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7040 - smape_loss: 0.9046 - mae_denorm: 0.7719Tiempo on_epoch_end 2024-10-30 15:21:51
# 5/5 [==============================] - 0s 21ms/step - loss: 0.7164 - smape_loss: 0.9202 - mae_denorm: 0.7746 - val_loss: 2.2760 - val_smape_loss: 1.3542 - val_mae_denorm: 142.3223
# Epoch 107/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7131 - smape_loss: 0.9229 - mae_denorm: 0.7322Tiempo on_epoch_end 2024-10-30 15:21:51
# 5/5 [==============================] - 0s 25ms/step - loss: 0.7171 - smape_loss: 0.9217 - mae_denorm: 0.7750 - val_loss: 2.2905 - val_smape_loss: 1.3591 - val_mae_denorm: 144.1285
# Epoch 108/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7426 - smape_loss: 0.9373 - mae_denorm: 0.8630Tiempo on_epoch_end 2024-10-30 15:21:51
# 5/5 [==============================] - 0s 23ms/step - loss: 0.7179 - smape_loss: 0.9218 - mae_denorm: 0.7753 - val_loss: 2.2985 - val_smape_loss: 1.3617 - val_mae_denorm: 145.0044
# Epoch 109/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7133 - smape_loss: 0.9326 - mae_denorm: 0.7898Tiempo on_epoch_end 2024-10-30 15:21:51
# 5/5 [==============================] - 0s 20ms/step - loss: 0.7171 - smape_loss: 0.9239 - mae_denorm: 0.7749 - val_loss: 2.2732 - val_smape_loss: 1.3539 - val_mae_denorm: 142.4782
# Epoch 110/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7221 - smape_loss: 0.9157 - mae_denorm: 0.8343Tiempo on_epoch_end 2024-10-30 15:21:51
# 5/5 [==============================] - 0s 20ms/step - loss: 0.7173 - smape_loss: 0.9206 - mae_denorm: 0.7756 - val_loss: 2.2989 - val_smape_loss: 1.3614 - val_mae_denorm: 144.7137
# Epoch 111/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7119 - smape_loss: 0.9277 - mae_denorm: 0.7349Tiempo on_epoch_end 2024-10-30 15:21:52
# 5/5 [==============================] - 0s 24ms/step - loss: 0.7175 - smape_loss: 0.9215 - mae_denorm: 0.7752 - val_loss: 2.3152 - val_smape_loss: 1.3667 - val_mae_denorm: 146.7335
# Epoch 112/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7020 - smape_loss: 0.9261 - mae_denorm: 0.8049Tiempo on_epoch_end 2024-10-30 15:21:52
# 5/5 [==============================] - 0s 20ms/step - loss: 0.7161 - smape_loss: 0.9258 - mae_denorm: 0.7743 - val_loss: 2.2763 - val_smape_loss: 1.3557 - val_mae_denorm: 143.7404
# Epoch 113/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7181 - smape_loss: 0.9383 - mae_denorm: 0.8027Tiempo on_epoch_end 2024-10-30 15:21:52
# 5/5 [==============================] - 0s 21ms/step - loss: 0.7150 - smape_loss: 0.9181 - mae_denorm: 0.7725 - val_loss: 2.2910 - val_smape_loss: 1.3608 - val_mae_denorm: 146.3472
# Epoch 114/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7295 - smape_loss: 0.9335 - mae_denorm: 0.8207Tiempo on_epoch_end 2024-10-30 15:21:52
# 5/5 [==============================] - 0s 20ms/step - loss: 0.7158 - smape_loss: 0.9200 - mae_denorm: 0.7733 - val_loss: 2.2946 - val_smape_loss: 1.3618 - val_mae_denorm: 147.2681
# Epoch 115/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7252 - smape_loss: 0.9500 - mae_denorm: 0.7517Tiempo on_epoch_end 2024-10-30 15:21:52
# 5/5 [==============================] - 0s 23ms/step - loss: 0.7156 - smape_loss: 0.9200 - mae_denorm: 0.7732 - val_loss: 2.2933 - val_smape_loss: 1.3614 - val_mae_denorm: 146.3230
# Epoch 116/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7238 - smape_loss: 0.9378 - mae_denorm: 0.8158Tiempo on_epoch_end 2024-10-30 15:21:52
# 5/5 [==============================] - 0s 25ms/step - loss: 0.7154 - smape_loss: 0.9205 - mae_denorm: 0.7733 - val_loss: 2.2739 - val_smape_loss: 1.3558 - val_mae_denorm: 145.5159
# Epoch 117/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7056 - smape_loss: 0.8969 - mae_denorm: 0.7111Tiempo on_epoch_end 2024-10-30 15:21:52
# 5/5 [==============================] - 0s 24ms/step - loss: 0.7141 - smape_loss: 0.9143 - mae_denorm: 0.7716 - val_loss: 2.3066 - val_smape_loss: 1.3657 - val_mae_denorm: 148.3106
# Epoch 118/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7227 - smape_loss: 0.9387 - mae_denorm: 0.8126Tiempo on_epoch_end 2024-10-30 15:21:52
# 5/5 [==============================] - 0s 20ms/step - loss: 0.7139 - smape_loss: 0.9173 - mae_denorm: 0.7711 - val_loss: 2.2796 - val_smape_loss: 1.3576 - val_mae_denorm: 145.8756
# Epoch 119/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7247 - smape_loss: 0.9089 - mae_denorm: 0.7443Tiempo on_epoch_end 2024-10-30 15:21:52
# 5/5 [==============================] - 0s 23ms/step - loss: 0.7155 - smape_loss: 0.9174 - mae_denorm: 0.7728 - val_loss: 2.2950 - val_smape_loss: 1.3633 - val_mae_denorm: 148.2058
# Epoch 120/500
# 5/5 [==============================] - ETA: 0s - loss: 0.7135 - smape_loss: 0.9170 - mae_denorm: 0.7708Tiempo on_epoch_end 2024-10-30 15:21:53
# 5/5 [==============================] - 0s 27ms/step - loss: 0.7135 - smape_loss: 0.9170 - mae_denorm: 0.7708 - val_loss: 2.3034 - val_smape_loss: 1.3660 - val_mae_denorm: 149.3189
# Epoch 121/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7298 - smape_loss: 0.9328 - mae_denorm: 0.7733Tiempo on_epoch_end 2024-10-30 15:21:53
# 5/5 [==============================] - 0s 20ms/step - loss: 0.7138 - smape_loss: 0.9180 - mae_denorm: 0.7711 - val_loss: 2.3093 - val_smape_loss: 1.3680 - val_mae_denorm: 150.2504
# Epoch 122/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7230 - smape_loss: 0.9363 - mae_denorm: 0.7480Tiempo on_epoch_end 2024-10-30 15:21:53
# 5/5 [==============================] - 0s 20ms/step - loss: 0.7122 - smape_loss: 0.9132 - mae_denorm: 0.7693 - val_loss: 2.3053 - val_smape_loss: 1.3669 - val_mae_denorm: 149.9194
# Epoch 123/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.6895 - smape_loss: 0.9010 - mae_denorm: 0.8130Tiempo on_epoch_end 2024-10-30 15:21:53
# 5/5 [==============================] - 0s 23ms/step - loss: 0.7112 - smape_loss: 0.9105 - mae_denorm: 0.7680 - val_loss: 2.3133 - val_smape_loss: 1.3692 - val_mae_denorm: 150.7678
# Epoch 124/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7109 - smape_loss: 0.9159 - mae_denorm: 0.7870Tiempo on_epoch_end 2024-10-30 15:21:53
# 5/5 [==============================] - 0s 22ms/step - loss: 0.7113 - smape_loss: 0.9137 - mae_denorm: 0.7679 - val_loss: 2.3044 - val_smape_loss: 1.3668 - val_mae_denorm: 150.2966
# Epoch 125/500
# 5/5 [==============================] - ETA: 0s - loss: 0.7108 - smape_loss: 0.9120 - mae_denorm: 0.7674Tiempo on_epoch_end 2024-10-30 15:21:53
# 5/5 [==============================] - 0s 29ms/step - loss: 0.7108 - smape_loss: 0.9120 - mae_denorm: 0.7674 - val_loss: 2.3025 - val_smape_loss: 1.3661 - val_mae_denorm: 150.4268
# Epoch 126/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7315 - smape_loss: 0.9518 - mae_denorm: 0.7998Tiempo on_epoch_end 2024-10-30 15:21:53
# 5/5 [==============================] - 0s 21ms/step - loss: 0.7128 - smape_loss: 0.9143 - mae_denorm: 0.7701 - val_loss: 2.3153 - val_smape_loss: 1.3696 - val_mae_denorm: 151.3803
# Epoch 127/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.6992 - smape_loss: 0.9447 - mae_denorm: 0.8494Tiempo on_epoch_end 2024-10-30 15:21:53
# 5/5 [==============================] - 0s 20ms/step - loss: 0.7127 - smape_loss: 0.9178 - mae_denorm: 0.7697 - val_loss: 2.2961 - val_smape_loss: 1.3637 - val_mae_denorm: 148.9969
# Epoch 128/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7206 - smape_loss: 0.9330 - mae_denorm: 0.7942Tiempo on_epoch_end 2024-10-30 15:21:53
# 5/5 [==============================] - 0s 20ms/step - loss: 0.7144 - smape_loss: 0.9121 - mae_denorm: 0.7721 - val_loss: 2.3211 - val_smape_loss: 1.3714 - val_mae_denorm: 151.8445
# Epoch 129/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7298 - smape_loss: 0.9251 - mae_denorm: 0.8109Tiempo on_epoch_end 2024-10-30 15:21:54
# 5/5 [==============================] - 0s 20ms/step - loss: 0.7121 - smape_loss: 0.9132 - mae_denorm: 0.7690 - val_loss: 2.3072 - val_smape_loss: 1.3671 - val_mae_denorm: 150.7495
# Epoch 130/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7098 - smape_loss: 0.9284 - mae_denorm: 0.7701Tiempo on_epoch_end 2024-10-30 15:21:54
# 5/5 [==============================] - 0s 19ms/step - loss: 0.7114 - smape_loss: 0.9124 - mae_denorm: 0.7677 - val_loss: 2.3222 - val_smape_loss: 1.3716 - val_mae_denorm: 151.2935
# Epoch 131/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7296 - smape_loss: 0.9259 - mae_denorm: 0.8533Tiempo on_epoch_end 2024-10-30 15:21:54
# 5/5 [==============================] - 0s 23ms/step - loss: 0.7122 - smape_loss: 0.9143 - mae_denorm: 0.7689 - val_loss: 2.3036 - val_smape_loss: 1.3658 - val_mae_denorm: 149.5949
# Epoch 132/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7127 - smape_loss: 0.8849 - mae_denorm: 0.8108Tiempo on_epoch_end 2024-10-30 15:21:54
# 5/5 [==============================] - 0s 22ms/step - loss: 0.7124 - smape_loss: 0.9139 - mae_denorm: 0.7691 - val_loss: 2.3130 - val_smape_loss: 1.3689 - val_mae_denorm: 150.8965
# Epoch 133/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7097 - smape_loss: 0.9046 - mae_denorm: 0.8016Tiempo on_epoch_end 2024-10-30 15:21:54
# 5/5 [==============================] - 0s 23ms/step - loss: 0.7115 - smape_loss: 0.9116 - mae_denorm: 0.7679 - val_loss: 2.3357 - val_smape_loss: 1.3758 - val_mae_denorm: 153.4492
# Epoch 134/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7029 - smape_loss: 0.9324 - mae_denorm: 0.7805Tiempo on_epoch_end 2024-10-30 15:21:54
# 5/5 [==============================] - 0s 23ms/step - loss: 0.7110 - smape_loss: 0.9139 - mae_denorm: 0.7679 - val_loss: 2.3151 - val_smape_loss: 1.3695 - val_mae_denorm: 151.9007
# Epoch 135/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.6815 - smape_loss: 0.9170 - mae_denorm: 0.7431Tiempo on_epoch_end 2024-10-30 15:21:54
# 5/5 [==============================] - 0s 24ms/step - loss: 0.7105 - smape_loss: 0.9125 - mae_denorm: 0.7673 - val_loss: 2.3259 - val_smape_loss: 1.3721 - val_mae_denorm: 153.2819
# Epoch 136/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7100 - smape_loss: 0.9266 - mae_denorm: 0.7614Tiempo on_epoch_end 2024-10-30 15:21:54
# 5/5 [==============================] - 0s 23ms/step - loss: 0.7092 - smape_loss: 0.9072 - mae_denorm: 0.7651 - val_loss: 2.3187 - val_smape_loss: 1.3698 - val_mae_denorm: 152.9477
# Epoch 137/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7166 - smape_loss: 0.9334 - mae_denorm: 0.7645Tiempo on_epoch_end 2024-10-30 15:21:54
# 5/5 [==============================] - 0s 21ms/step - loss: 0.7083 - smape_loss: 0.9068 - mae_denorm: 0.7650 - val_loss: 2.3102 - val_smape_loss: 1.3671 - val_mae_denorm: 151.9193
# Epoch 138/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7028 - smape_loss: 0.9184 - mae_denorm: 0.7918Tiempo on_epoch_end 2024-10-30 15:21:55
# 5/5 [==============================] - 0s 23ms/step - loss: 0.7073 - smape_loss: 0.9064 - mae_denorm: 0.7634 - val_loss: 2.3090 - val_smape_loss: 1.3670 - val_mae_denorm: 152.1790
# Epoch 139/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7122 - smape_loss: 0.9209 - mae_denorm: 0.8043Tiempo on_epoch_end 2024-10-30 15:21:55
# 5/5 [==============================] - 0s 21ms/step - loss: 0.7069 - smape_loss: 0.9054 - mae_denorm: 0.7629 - val_loss: 2.3064 - val_smape_loss: 1.3663 - val_mae_denorm: 152.3555
# Epoch 140/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7009 - smape_loss: 0.9067 - mae_denorm: 0.7852Tiempo on_epoch_end 2024-10-30 15:21:55
# 5/5 [==============================] - 0s 21ms/step - loss: 0.7067 - smape_loss: 0.9045 - mae_denorm: 0.7627 - val_loss: 2.3087 - val_smape_loss: 1.3672 - val_mae_denorm: 152.4271
# Epoch 141/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.6957 - smape_loss: 0.8913 - mae_denorm: 0.7357Tiempo on_epoch_end 2024-10-30 15:21:55
# 5/5 [==============================] - 0s 21ms/step - loss: 0.7059 - smape_loss: 0.8997 - mae_denorm: 0.7617 - val_loss: 2.2982 - val_smape_loss: 1.3637 - val_mae_denorm: 151.0867
# Epoch 142/500
# ...
# Epoch 454/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.6982 - smape_loss: 0.8683 - mae_denorm: 0.7073Tiempo on_epoch_end 2024-10-30 15:22:36
# 5/5 [==============================] - 0s 23ms/step - loss: 0.7068 - smape_loss: 0.9023 - mae_denorm: 0.7614 - val_loss: 2.1307 - val_smape_loss: 1.2832 - val_mae_denorm: 190.9274
# Epoch 455/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7038 - smape_loss: 0.9209 - mae_denorm: 0.7680Tiempo on_epoch_end 2024-10-30 15:22:36
# 5/5 [==============================] - 0s 23ms/step - loss: 0.7123 - smape_loss: 0.9096 - mae_denorm: 0.7689 - val_loss: 2.1366 - val_smape_loss: 1.2846 - val_mae_denorm: 191.0421
# Epoch 456/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.6903 - smape_loss: 0.9284 - mae_denorm: 0.8355Tiempo on_epoch_end 2024-10-30 15:22:36
# 5/5 [==============================] - 0s 25ms/step - loss: 0.7104 - smape_loss: 0.9115 - mae_denorm: 0.7668 - val_loss: 2.1349 - val_smape_loss: 1.2841 - val_mae_denorm: 191.8603
# Epoch 457/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7261 - smape_loss: 0.9131 - mae_denorm: 0.7398Tiempo on_epoch_end 2024-10-30 15:22:36
# 5/5 [==============================] - 0s 26ms/step - loss: 0.7089 - smape_loss: 0.9041 - mae_denorm: 0.7642 - val_loss: 2.1337 - val_smape_loss: 1.2831 - val_mae_denorm: 192.7013
# Epoch 458/500
# 1/5 [=====>........................] - ETA: 0s - loss: 0.6934 - smape_loss: 0.8988 - mae_denorm: 0.7796Tiempo on_epoch_end 2024-10-30 15:22:36
# 5/5 [==============================] - 0s 22ms/step - loss: 0.7030 - smape_loss: 0.8941 - mae_denorm: 0.7576 - val_loss: 2.1177 - val_smape_loss: 1.2783 - val_mae_denorm: 191.6775
# Epoch 459/500
# 5/5 [==============================] - ETA: 0s - loss: 0.7015 - smape_loss: 0.8931 - mae_denorm: 0.7562Tiempo on_epoch_end 2024-10-30 15:22:36
# 5/5 [==============================] - 0s 32ms/step - loss: 0.7015 - smape_loss: 0.8931 - mae_denorm: 0.7562 - val_loss: 2.1270 - val_smape_loss: 1.2816 - val_mae_denorm: 193.3279
# Epoch 460/500
# 5/5 [==============================] - ETA: 0s - loss: 0.7021 - smape_loss: 0.8968 - mae_denorm: 0.7569Tiempo on_epoch_end 2024-10-30 15:22:36
# 5/5 [==============================] - 0s 28ms/step - loss: 0.7021 - smape_loss: 0.8968 - mae_denorm: 0.7569 - val_loss: 2.1125 - val_smape_loss: 1.2769 - val_mae_denorm: 192.1933
# Epoch 461/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.7086 - smape_loss: 0.9040 - mae_denorm: 0.7637Tiempo on_epoch_end 2024-10-30 15:22:36
# 5/5 [==============================] - 0s 33ms/step - loss: 0.7068 - smape_loss: 0.8998 - mae_denorm: 0.7617 - val_loss: 2.1225 - val_smape_loss: 1.2806 - val_mae_denorm: 194.6185
# Epoch 462/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.7077 - smape_loss: 0.9015 - mae_denorm: 0.7568Tiempo on_epoch_end 2024-10-30 15:22:37
# 5/5 [==============================] - 0s 35ms/step - loss: 0.7037 - smape_loss: 0.8981 - mae_denorm: 0.7579 - val_loss: 2.1347 - val_smape_loss: 1.2848 - val_mae_denorm: 195.4900
# Epoch 463/500
# 5/5 [==============================] - ETA: 0s - loss: 0.6985 - smape_loss: 0.8888 - mae_denorm: 0.7525Tiempo on_epoch_end 2024-10-30 15:22:37
# 5/5 [==============================] - 0s 34ms/step - loss: 0.6985 - smape_loss: 0.8888 - mae_denorm: 0.7525 - val_loss: 2.1273 - val_smape_loss: 1.2826 - val_mae_denorm: 195.3958
# Epoch 464/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6998 - smape_loss: 0.8934 - mae_denorm: 0.7650Tiempo on_epoch_end 2024-10-30 15:22:37
# 5/5 [==============================] - 0s 34ms/step - loss: 0.6975 - smape_loss: 0.8872 - mae_denorm: 0.7506 - val_loss: 2.1235 - val_smape_loss: 1.2812 - val_mae_denorm: 194.6167
# Epoch 465/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6963 - smape_loss: 0.8876 - mae_denorm: 0.7490Tiempo on_epoch_end 2024-10-30 15:22:37
# 5/5 [==============================] - 0s 43ms/step - loss: 0.6989 - smape_loss: 0.8897 - mae_denorm: 0.7524 - val_loss: 2.1273 - val_smape_loss: 1.2826 - val_mae_denorm: 195.2526
# Epoch 466/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6972 - smape_loss: 0.8880 - mae_denorm: 0.7761Tiempo on_epoch_end 2024-10-30 15:22:37
# 5/5 [==============================] - 0s 37ms/step - loss: 0.6968 - smape_loss: 0.8844 - mae_denorm: 0.7502 - val_loss: 2.1296 - val_smape_loss: 1.2830 - val_mae_denorm: 195.6527
# Epoch 467/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6906 - smape_loss: 0.8785 - mae_denorm: 0.7459Tiempo on_epoch_end 2024-10-30 15:22:38
# 5/5 [==============================] - 0s 41ms/step - loss: 0.6960 - smape_loss: 0.8826 - mae_denorm: 0.7492 - val_loss: 2.1220 - val_smape_loss: 1.2808 - val_mae_denorm: 195.3139
# Epoch 468/500
# 5/5 [==============================] - ETA: 0s - loss: 0.6989 - smape_loss: 0.8890 - mae_denorm: 0.7524Tiempo on_epoch_end 2024-10-30 15:22:38
# 5/5 [==============================] - 0s 35ms/step - loss: 0.6989 - smape_loss: 0.8890 - mae_denorm: 0.7524 - val_loss: 2.1037 - val_smape_loss: 1.2746 - val_mae_denorm: 192.9671
# Epoch 469/500
# 5/5 [==============================] - ETA: 0s - loss: 0.6959 - smape_loss: 0.8855 - mae_denorm: 0.7491Tiempo on_epoch_end 2024-10-30 15:22:38
# 5/5 [==============================] - 0s 34ms/step - loss: 0.6959 - smape_loss: 0.8855 - mae_denorm: 0.7491 - val_loss: 2.1033 - val_smape_loss: 1.2744 - val_mae_denorm: 193.0113
# Epoch 470/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6969 - smape_loss: 0.8878 - mae_denorm: 0.7652Tiempo on_epoch_end 2024-10-30 15:22:38
# 5/5 [==============================] - 0s 38ms/step - loss: 0.6990 - smape_loss: 0.8864 - mae_denorm: 0.7529 - val_loss: 2.0959 - val_smape_loss: 1.2727 - val_mae_denorm: 192.9975
# Epoch 471/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.7061 - smape_loss: 0.8931 - mae_denorm: 0.7577Tiempo on_epoch_end 2024-10-30 15:22:38
# 5/5 [==============================] - 0s 46ms/step - loss: 0.7064 - smape_loss: 0.8980 - mae_denorm: 0.7608 - val_loss: 2.0969 - val_smape_loss: 1.2735 - val_mae_denorm: 192.2774
# Epoch 472/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6998 - smape_loss: 0.8943 - mae_denorm: 0.7550Tiempo on_epoch_end 2024-10-30 15:22:39
# 5/5 [==============================] - 0s 55ms/step - loss: 0.7019 - smape_loss: 0.8950 - mae_denorm: 0.7556 - val_loss: 2.1044 - val_smape_loss: 1.2761 - val_mae_denorm: 193.8423
# Epoch 473/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.7023 - smape_loss: 0.8913 - mae_denorm: 0.7456Tiempo on_epoch_end 2024-10-30 15:22:39
# 5/5 [==============================] - 0s 43ms/step - loss: 0.7026 - smape_loss: 0.8944 - mae_denorm: 0.7573 - val_loss: 2.0915 - val_smape_loss: 1.2729 - val_mae_denorm: 193.6358
# Epoch 474/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6975 - smape_loss: 0.8796 - mae_denorm: 0.7553Tiempo on_epoch_end 2024-10-30 15:22:39
# 5/5 [==============================] - 0s 43ms/step - loss: 0.6965 - smape_loss: 0.8810 - mae_denorm: 0.7499 - val_loss: 2.1177 - val_smape_loss: 1.2813 - val_mae_denorm: 197.2617
# Epoch 475/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.7011 - smape_loss: 0.8890 - mae_denorm: 0.7531Tiempo on_epoch_end 2024-10-30 15:22:39
# 5/5 [==============================] - 0s 40ms/step - loss: 0.6992 - smape_loss: 0.8909 - mae_denorm: 0.7525 - val_loss: 2.0858 - val_smape_loss: 1.2695 - val_mae_denorm: 192.6771
# Epoch 476/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.7110 - smape_loss: 0.9061 - mae_denorm: 0.7690Tiempo on_epoch_end 2024-10-30 15:22:39
# 5/5 [==============================] - 0s 52ms/step - loss: 0.7074 - smape_loss: 0.9059 - mae_denorm: 0.7626 - val_loss: 2.0933 - val_smape_loss: 1.2730 - val_mae_denorm: 195.0546
# Epoch 477/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.7094 - smape_loss: 0.8952 - mae_denorm: 0.7587Tiempo on_epoch_end 2024-10-30 15:22:40
# 5/5 [==============================] - 0s 42ms/step - loss: 0.7055 - smape_loss: 0.8952 - mae_denorm: 0.7608 - val_loss: 2.1133 - val_smape_loss: 1.2798 - val_mae_denorm: 199.3052
# Epoch 478/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.7080 - smape_loss: 0.9060 - mae_denorm: 0.7739Tiempo on_epoch_end 2024-10-30 15:22:40
# 5/5 [==============================] - 0s 41ms/step - loss: 0.7083 - smape_loss: 0.9004 - mae_denorm: 0.7628 - val_loss: 2.1099 - val_smape_loss: 1.2780 - val_mae_denorm: 197.0253
# Epoch 479/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6961 - smape_loss: 0.8846 - mae_denorm: 0.7486Tiempo on_epoch_end 2024-10-30 15:22:40
# 5/5 [==============================] - 0s 43ms/step - loss: 0.6970 - smape_loss: 0.8862 - mae_denorm: 0.7509 - val_loss: 2.0797 - val_smape_loss: 1.2678 - val_mae_denorm: 192.9808
# Epoch 480/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6914 - smape_loss: 0.8778 - mae_denorm: 0.7445Tiempo on_epoch_end 2024-10-30 15:22:40
# 5/5 [==============================] - 0s 44ms/step - loss: 0.6940 - smape_loss: 0.8807 - mae_denorm: 0.7473 - val_loss: 2.0632 - val_smape_loss: 1.2634 - val_mae_denorm: 193.6514
# Epoch 481/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6942 - smape_loss: 0.8808 - mae_denorm: 0.7643Tiempo on_epoch_end 2024-10-30 15:22:40
# 5/5 [==============================] - 0s 46ms/step - loss: 0.6946 - smape_loss: 0.8769 - mae_denorm: 0.7476 - val_loss: 2.0961 - val_smape_loss: 1.2728 - val_mae_denorm: 196.1897
# Epoch 482/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6971 - smape_loss: 0.8933 - mae_denorm: 0.7589Tiempo on_epoch_end 2024-10-30 15:22:41
# 5/5 [==============================] - 0s 45ms/step - loss: 0.6969 - smape_loss: 0.8854 - mae_denorm: 0.7498 - val_loss: 2.0943 - val_smape_loss: 1.2724 - val_mae_denorm: 196.1250
# Epoch 483/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6944 - smape_loss: 0.8866 - mae_denorm: 0.7563Tiempo on_epoch_end 2024-10-30 15:22:41
# 5/5 [==============================] - 0s 51ms/step - loss: 0.6972 - smape_loss: 0.8864 - mae_denorm: 0.7498 - val_loss: 2.0990 - val_smape_loss: 1.2737 - val_mae_denorm: 198.5212
# Epoch 484/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6912 - smape_loss: 0.8731 - mae_denorm: 0.7397Tiempo on_epoch_end 2024-10-30 15:22:41
# 5/5 [==============================] - 0s 42ms/step - loss: 0.6941 - smape_loss: 0.8817 - mae_denorm: 0.7460 - val_loss: 2.0819 - val_smape_loss: 1.2686 - val_mae_denorm: 195.3854
# Epoch 485/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6878 - smape_loss: 0.8715 - mae_denorm: 0.7415Tiempo on_epoch_end 2024-10-30 15:22:41
# 5/5 [==============================] - 0s 55ms/step - loss: 0.6912 - smape_loss: 0.8738 - mae_denorm: 0.7440 - val_loss: 2.1039 - val_smape_loss: 1.2757 - val_mae_denorm: 198.0650
# Epoch 486/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6906 - smape_loss: 0.8806 - mae_denorm: 0.7554Tiempo on_epoch_end 2024-10-30 15:22:41
# 5/5 [==============================] - 0s 42ms/step - loss: 0.6890 - smape_loss: 0.8721 - mae_denorm: 0.7415 - val_loss: 2.0834 - val_smape_loss: 1.2701 - val_mae_denorm: 196.2949
# Epoch 487/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6885 - smape_loss: 0.8698 - mae_denorm: 0.7432Tiempo on_epoch_end 2024-10-30 15:22:42
# 5/5 [==============================] - 0s 36ms/step - loss: 0.6874 - smape_loss: 0.8681 - mae_denorm: 0.7401 - val_loss: 2.0725 - val_smape_loss: 1.2660 - val_mae_denorm: 195.9158
# Epoch 488/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6853 - smape_loss: 0.8658 - mae_denorm: 0.7280Tiempo on_epoch_end 2024-10-30 15:22:42
# 5/5 [==============================] - 0s 48ms/step - loss: 0.6845 - smape_loss: 0.8655 - mae_denorm: 0.7361 - val_loss: 2.0540 - val_smape_loss: 1.2603 - val_mae_denorm: 194.5535
# Epoch 489/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6927 - smape_loss: 0.8760 - mae_denorm: 0.7362Tiempo on_epoch_end 2024-10-30 15:22:42
# 5/5 [==============================] - 0s 53ms/step - loss: 0.6883 - smape_loss: 0.8730 - mae_denorm: 0.7410 - val_loss: 2.0529 - val_smape_loss: 1.2602 - val_mae_denorm: 195.4007
# Epoch 490/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6853 - smape_loss: 0.8673 - mae_denorm: 0.7430Tiempo on_epoch_end 2024-10-30 15:22:42
# 5/5 [==============================] - 0s 42ms/step - loss: 0.6871 - smape_loss: 0.8700 - mae_denorm: 0.7395 - val_loss: 2.0670 - val_smape_loss: 1.2658 - val_mae_denorm: 199.1924
# Epoch 491/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6811 - smape_loss: 0.8642 - mae_denorm: 0.7338Tiempo on_epoch_end 2024-10-30 15:22:42
# 5/5 [==============================] - 0s 39ms/step - loss: 0.6851 - smape_loss: 0.8651 - mae_denorm: 0.7374 - val_loss: 2.0535 - val_smape_loss: 1.2607 - val_mae_denorm: 197.2910
# Epoch 492/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6956 - smape_loss: 0.8813 - mae_denorm: 0.7508Tiempo on_epoch_end 2024-10-30 15:22:43
# 5/5 [==============================] - 0s 37ms/step - loss: 0.6909 - smape_loss: 0.8758 - mae_denorm: 0.7438 - val_loss: 2.0428 - val_smape_loss: 1.2584 - val_mae_denorm: 198.3369
# Epoch 493/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6908 - smape_loss: 0.8730 - mae_denorm: 0.7382Tiempo on_epoch_end 2024-10-30 15:22:43
# 5/5 [==============================] - 0s 37ms/step - loss: 0.6904 - smape_loss: 0.8757 - mae_denorm: 0.7429 - val_loss: 2.0471 - val_smape_loss: 1.2609 - val_mae_denorm: 200.3070
# Epoch 494/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6943 - smape_loss: 0.8854 - mae_denorm: 0.7487Tiempo on_epoch_end 2024-10-30 15:22:43
# 5/5 [==============================] - 0s 46ms/step - loss: 0.6932 - smape_loss: 0.8850 - mae_denorm: 0.7463 - val_loss: 2.0160 - val_smape_loss: 1.2493 - val_mae_denorm: 197.0210
# Epoch 495/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.7076 - smape_loss: 0.9142 - mae_denorm: 0.7755Tiempo on_epoch_end 2024-10-30 15:22:43
# 5/5 [==============================] - 0s 53ms/step - loss: 0.7094 - smape_loss: 0.9133 - mae_denorm: 0.7652 - val_loss: 2.0345 - val_smape_loss: 1.2553 - val_mae_denorm: 198.7442
# Epoch 496/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.7095 - smape_loss: 0.9146 - mae_denorm: 0.7692Tiempo on_epoch_end 2024-10-30 15:22:43
# 5/5 [==============================] - 0s 42ms/step - loss: 0.7101 - smape_loss: 0.9113 - mae_denorm: 0.7681 - val_loss: 2.0294 - val_smape_loss: 1.2544 - val_mae_denorm: 198.6798
# Epoch 497/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.7152 - smape_loss: 0.9146 - mae_denorm: 0.7650Tiempo on_epoch_end 2024-10-30 15:22:44
# 5/5 [==============================] - 0s 43ms/step - loss: 0.7160 - smape_loss: 0.9165 - mae_denorm: 0.7706 - val_loss: 2.0514 - val_smape_loss: 1.2625 - val_mae_denorm: 200.6207
# Epoch 498/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.7075 - smape_loss: 0.9050 - mae_denorm: 0.7583Tiempo on_epoch_end 2024-10-30 15:22:44
# 5/5 [==============================] - 0s 48ms/step - loss: 0.7090 - smape_loss: 0.9056 - mae_denorm: 0.7618 - val_loss: 2.0662 - val_smape_loss: 1.2658 - val_mae_denorm: 201.0568
# Epoch 499/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6964 - smape_loss: 0.8806 - mae_denorm: 0.7496Tiempo on_epoch_end 2024-10-30 15:22:44
# 5/5 [==============================] - 0s 47ms/step - loss: 0.6958 - smape_loss: 0.8842 - mae_denorm: 0.7486 - val_loss: 2.0459 - val_smape_loss: 1.2592 - val_mae_denorm: 197.5183
# Epoch 500/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6880 - smape_loss: 0.8772 - mae_denorm: 0.7543Tiempo on_epoch_end 2024-10-30 15:22:44
# 5/5 [==============================] - 0s 38ms/step - loss: 0.6945 - smape_loss: 0.8784 - mae_denorm: 0.7475 - val_loss: 2.0554 - val_smape_loss: 1.2615 - val_mae_denorm: 198.3939
# Tiempo Final y n_past 2024-10-30 15:22:59   n_past:--> 60

# %%
from matplotlib import pyplot as plt
plt.plot(history_modelo.history['loss'])
plt.plot(history_modelo.history['val_loss'])
#plt.plot(history_modelo.history['val_smape_loss_zscore'])
plt.title('model accuracy')
plt.ylabel('loss')
plt.xlabel('epoch')
#plt.legend(['loss', 'val_loss','val_smape_loss_zscore'], loc='upper left')
plt.legend(['loss', 'val_loss'], loc='upper left')
plt.show()
best_score=min(history_modelo.history['val_loss'])
print('best_score',best_score)
#best_score_smape=min(history_modelo.history['val_smape_loss_zscore'])
#print('best_score smape',best_score_smape)
# Out:
# best_score 1.321516752243042

# %%
from keras.utils import plot_model

fileplot=pathModelosJson
plot_model(reconstructed_model2, to_file=fileplot+'/model_plot.png', show_shapes=True, show_layer_names=True)

# %%
from tensorflow.keras.saving import register_keras_serializable
media_train=train_previo_zscore['Número de vistas de página'].std()
std_train=train_previo_zscore['Número de vistas de página'].mean()
#esta metrica esta en el codigo de github del ganador
@register_keras_serializable()
def smape_loss(y_true, y_pred):
    #revierto zscore
    global media_train
    global std_train
    y_true=(y_true*std_train)+media_train
    y_pred=(y_pred*std_train)+media_train
    #revierto log1p
    y_true=tf.math.expm1(y_true)
    y_pred=tf.math.expm1(y_pred)
    epsilon = 0.1
    y_pred = tf.convert_to_tensor(y_pred)
    y_true = tf.cast(y_true, y_pred.dtype)
    # Calcular el denominador de SMAPE
    summ = tf.maximum(tf.abs(y_true) + tf.abs(y_pred) + epsilon, 0.5 + epsilon)

    # Calcular SMAPE
    smape = tf.abs(y_pred - y_true) / summ * 2.0

    # Retornar la media de SMAPE
    return K.mean(smape, axis=-1)

@register_keras_serializable()
def mae_denorm(y_true, y_pred):
    #revierto zscore
    global media_train
    global std_train
    y_true1=(y_true*std_train)+media_train
    y_pred1=(y_pred*std_train)+media_train
    #revierto log1p
    y_true2=tf.math.expm1(y_true1)
    y_pred2=tf.math.expm1(y_pred1)

    return tf.keras.losses.mean_absolute_error(y_true2, y_pred2)

# %%
#el mejor modelo de verdad
#pathModelosJsonMejor="/content/drive/MyDrive/a Tesis de Grado/Tesis Versiones/tesis 2024/UA/tum transmedia/modelos/modelos resultados/mejores modelos guardados/modelo"
#nombreMejorModeloMejor="/ ndays60hyperband mae 60 zscore.h5"#el mejor modelo es el hyperband de 28 dias y 107 época
pathModelosJsonMejor="/content/drive/MyDrive/a Tesis de Grado/Tesis Versiones/tesis 2024/GA4/editorial unam/modelos/modelos resultados/prueba 500 epocas 1 capa sin early stopping Editorial GA4 Mejor de TUM"
nombreMejorModeloMejor="/hyperband001-1.321517-ndays60EditorialGA4_500epochs1capa.h5"#el mejor modelo es el hyperband de 28 dias y 107 época
n_past=60
cambio=datetime.datetime.now(timezone('UTC')) - timedelta(hours=3)
tiempoFinal=f"{cambio:%Y-%m-%d %H:%M:%S }"
print('Tiempo  Inicio y n_past',tiempoFinal , ' n_past:-->',n_past)
n_future = 60
n_features = train.shape[1]
X_train, y_train = split_series(train.values,n_past, n_future)
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1],n_features))
y_train = y_train.reshape((y_train.shape[0], y_train.shape[1], 1)) #no hace falta reshapear
X_test, y_test = split_series(test.values,n_past, n_future)
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1],n_features))
y_test = y_test.reshape((y_test.shape[0], y_test.shape[1], 1)) #no hace falta reshapear

reconstructed_model3 = tf.keras.models.load_model(pathModelosJsonMejor+nombreMejorModeloMejor,custom_objects={'smape_loss':smape_loss,'mae_denorm':mae_denorm})
# Out:
# Tiempo  Inicio y n_past 2024-10-30 16:14:19   n_past:--> 60

# %%
print("Evaluate on test data")
results = reconstructed_model3.evaluate(X_test,y_test, batch_size=64)
print("test loss", results)
# Out:
# Evaluate on test data
# 1/1 [==============================] - 2s 2s/step - loss: 1.3215 - smape_loss: 0.9559 - mae_denorm: 89.9399
# test loss [1.321516752243042, 0.9559388160705566, 89.93993377685547]

# %%
pred_e1d1=reconstructed_model3.predict(X_test, batch_size=64)
pred_e1d1=deepcopy(pred_e1d1)
reshapePred=pred_e1d1.reshape((pred_e1d1.shape[0]*pred_e1d1.shape[2]),pred_e1d1.shape[1])
reshapeY_test=y_test.reshape((y_test.shape[0]*y_test.shape[2]),y_test.shape[1])
print(pred_e1d1.shape,reshapePred.shape)
print('y_test',y_test.shape,reshapeY_test.shape)
def smape2(a, f):
    print('len(a)',len(a))

    #std=train_previo_zscore['Predictor Flag'].std()
    #media=train_previo_zscore['Predictor Flag'].mean()
    std=train_previo_zscore['Número de vistas de página'].std()
    media=train_previo_zscore['Número de vistas de página'].mean()
    #revierto zscore
    a=(a*std)+media
    f=(f*std)+media

    a=np.round(np.expm1(a))
    f=np.round(np.expm1(f))
    print('a',a)
    print('f',f)
    return (1/len(a) * np.sum(2 * np.abs(f-a) / (np.abs(a) + np.abs(f))) )

def mae_manual(a, f):
    print('len(a)', len(a))

    # Obtener la desviación estándar y media
    std = train_previo_zscore['Número de vistas de página'].std()
    media = train_previo_zscore['Número de vistas de página'].mean()

    # Revertir z-score
    a = (a * std) + media
    f = (f * std) + media

    a=np.round(np.expm1(a))
    f=np.round(np.expm1(f))
    #print('a mae',a)
    #print('f mae',f)

    epsilon = 0.1  # Valor para evitar divisiones por cero
    diff =np.abs(a-f)
    return np.mean(diff)#(1 / len(a)) * np.sum(diff)

def rmse_manual(a, f):
    print('len(a)', len(a))

    # Obtener la desviación estándar y media
    std = train_previo_zscore['Número de vistas de página'].std()
    media = train_previo_zscore['Número de vistas de página'].mean()

    # Revertir z-score
    a = (a * std) + media
    f = (f * std) + media

    a=np.round(np.expm1(a))
    f=np.round(np.expm1(f))

    # Calcular el RMSE (Error Cuadrático Medio)
    diff = np.square(a - f)  # Cuadrado de la diferencia
    mse = np.mean(diff)  # Error Cuadrático Medio
    rmse_calculado = np.sqrt(mse)  # Raíz cuadrada del MSE

    return rmse_calculado

auxpred=reshapePred.reshape((y_test.shape[0]*y_test.shape[1]),1)
auxpred2=auxpred.reshape((auxpred.shape[0]),)
auxY_test=reshapeY_test.reshape((y_test.shape[0]*y_test.shape[1]),1)
print(auxpred.shape)
print('smape',smape2(auxY_test,auxpred))
print('mae',mae_manual(auxY_test,auxpred))
print('rmse',rmse_manual(auxY_test,auxpred))
print(auxpred2.shape)
print(np.array([1,2,3]).shape)
print(auxpred2)
# Out:
# 1/1 [==============================] - 0s 19ms/step
# (56, 60, 1) (56, 60)
# y_test (56, 60, 1) (56, 60)
# (3360, 1)
# len(a) 3360
# a [[ 53.]
#  [ 83.]
#  [102.]
#  ...
#  [ 48.]
#  [140.]
#  [ 55.]]
# f [[139.]
#  [147.]
#  [155.]
#  ...
#  [ 18.]
#  [ 18.]
#  [ 18.]]
# smape 0.9568072360541565
# len(a) 3360
# mae 89.94464285714285
# len(a) 3360
# rmse 129.76339273939354
# (3360,)
# (3,)
# [ 0.51539546  0.5794554   0.6389505  ... -1.7361536  -1.7354859
#  -1.73473   ]

# %%
test_previo_log1p['Número de vistas de página']
X_test5, y_test5 = split_series(test_previo_log1p.values,n_past, n_future)
y_test5
# Out:
# array([[ 53.,  83., 102., ..., 103., 192., 166.],
#        [ 83., 102., 143., ..., 192., 166., 107.],
#        [102., 143., 167., ..., 166., 107.,  51.],
#        ...,
#        [174., 143.,  62., ...,  82.,  19.,  48.],
#        [143.,  62.,  92., ...,  19.,  48., 140.],
#        [ 62.,  92., 103., ...,  48., 140.,  55.]])

# %%
y_test5.shape

# %%
auxY_test.shape

# %%
# Obtener la desviación estándar y media
import matplotlib.pyplot as plt
std = train_previo_zscore['Número de vistas de página'].std()
media = train_previo_zscore['Número de vistas de página'].mean()

# Revertir z-score
#denorm_actually=(auxY_test*std)+media
#denorm_forecast=(auxpred*std)+media

#denorm_actually = np.array(denorm_actually)
#denorm_forecast = np.array(denorm_forecast)
def denorm_manual(a, f):
    print('len(a)', len(a))

    # Obtener la desviación estándar y media
    std = train_previo_zscore['Número de vistas de página'].std()
    media = train_previo_zscore['Número de vistas de página'].mean()

    # Revertir z-score
    a = (a * std) + media
    f = (f * std) + media

    a=np.round(np.expm1(a))
    f=np.round(np.expm1(f))

    return a,f
denorm_actually,denorm_forecast=  denorm_manual(auxY_test,auxpred)
# Crear un rango de índices para el eje x
x = np.arange(len(denorm_actually))

# Crear el plot
plt.figure(figsize=(10, 6))
#ultimos 60
#plt.plot( denorm_actually[-60:], label='Valores de Reales', color='blue')
#plt.plot( denorm_forecast[-60:], label='Valores de Pronosticados', color='orange')
#primeros 60
plt.plot(np.arange(len(denorm_actually[:60])) ,denorm_actually[:60], label='Valores de Reales', color='blue')
plt.plot(np.arange(len(denorm_actually[:60])) ,denorm_forecast[:60], label='Valores de Pronosticados', color='orange')
print(denorm_actually[:1])
plt.title('Comparación de valores de Actuales y Predichos')
plt.xlabel('-')
plt.ylabel('Vistas')
plt.legend()
plt.grid()
plt.show()
# Out:
# len(a) 3360
# [[53.]]

# %%
mae_manual(auxY_test[:60],auxpred[:60])
# Out:
# len(a) 60
# 68.45

# %%
#plt.plot(train_previo_log1p[:60]['Número de vistas de página'])
plt.plot(test_previo_log1p[60:120]['Número de vistas de página'])

# %%
test_previo_log1p.shape
# Out:
# (175, 37)
