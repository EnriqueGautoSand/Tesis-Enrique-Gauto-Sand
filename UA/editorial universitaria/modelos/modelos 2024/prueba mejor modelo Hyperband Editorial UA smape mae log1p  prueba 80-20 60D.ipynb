# %%
# !pip install keras-tuner==1.4.7
# !pip install pandas==2.1.4
# !pip install numpy==1.26.4
# !pip install tensorflow==2.15.0
# Out:
# Collecting keras-tuner==1.4.7
#   Downloading keras_tuner-1.4.7-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (from keras-tuner==1.4.7) (3.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras-tuner==1.4.7) (24.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from keras-tuner==1.4.7) (2.32.3)
# Collecting kt-legacy (from keras-tuner==1.4.7)
#   Downloading kt_legacy-1.0.5-py3-none-any.whl.metadata (221 bytes)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras->keras-tuner==1.4.7) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras->keras-tuner==1.4.7) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras->keras-tuner==1.4.7) (13.9.3)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras->keras-tuner==1.4.7) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras->keras-tuner==1.4.7) (3.11.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras->keras-tuner==1.4.7) (0.13.0)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.10/dist-packages (from keras->keras-tuner==1.4.7) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner==1.4.7) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner==1.4.7) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner==1.4.7) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner==1.4.7) (2024.8.30)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from optree->keras->keras-tuner==1.4.7) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras->keras-tuner==1.4.7) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras->keras-tuner==1.4.7) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras->keras-tuner==1.4.7) (0.1.2)
# Downloading keras_tuner-1.4.7-py3-none-any.whl (129 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.1/129.1 kB 7.2 MB/s eta 0:00:00
# Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Installing collected packages: kt-legacy, keras-tuner
# Successfully installed keras-tuner-1.4.7 kt-legacy-1.0.5
# Collecting pandas==2.1.4
#   Downloading pandas-2.1.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas==2.1.4) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas==2.1.4) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas==2.1.4) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas==2.1.4) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas==2.1.4) (1.16.0)
# Downloading pandas-2.1.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 29.7 MB/s eta 0:00:00
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.1.4 which is incompatible.
# Successfully installed pandas-2.1.4
# Requirement already satisfied: numpy==1.26.4 in /usr/local/lib/python3.10/dist-packages (1.26.4)
# Collecting tensorflow==2.15.0
#   Downloading tensorflow-2.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.4 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (18.1.1)
# Collecting ml-dtypes~=0.2.0 (from tensorflow==2.15.0)
#   Downloading ml_dtypes-0.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (1.26.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (4.12.2)
# Collecting wrapt<1.15,>=1.11.0 (from tensorflow==2.15.0)
#   Downloading wrapt-1.14.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (0.37.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (1.64.1)
# Collecting tensorboard<2.16,>=2.15 (from tensorflow==2.15.0)
#   Downloading tensorboard-2.15.2-py3-none-any.whl.metadata (1.7 kB)
# Collecting tensorflow-estimator<2.16,>=2.15.0 (from tensorflow==2.15.0)
#   Downloading tensorflow_estimator-2.15.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting keras<2.16,>=2.15.0 (from tensorflow==2.15.0)
#   Downloading keras-2.15.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow==2.15.0) (0.44.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (1.2.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.7)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.0.6)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.0.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.2.2)
# Downloading tensorflow-2.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (475.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 475.2/475.2 MB 3.5 MB/s eta 0:00:00
# Downloading keras-2.15.0-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 74.0 MB/s eta 0:00:00
# Downloading ml_dtypes-0.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 63.1 MB/s eta 0:00:00
# Downloading tensorboard-2.15.2-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 101.5 MB/s eta 0:00:00
# Downloading tensorflow_estimator-2.15.0-py2.py3-none-any.whl (441 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.0/442.0 kB 38.7 MB/s eta 0:00:00
# Downloading wrapt-1.14.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 8.2 MB/s eta 0:00:00
# Installing collected packages: wrapt, tensorflow-estimator, ml-dtypes, keras, tensorboard, tensorflow
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.16.0
#     Uninstalling wrapt-1.16.0:
#       Successfully uninstalled wrapt-1.16.0
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml-dtypes 0.4.1
#     Uninstalling ml-dtypes-0.4.1:
#       Successfully uninstalled ml-dtypes-0.4.1
#   Attempting uninstall: keras
#     Found existing installation: keras 3.4.1
#     Uninstalling keras-3.4.1:
#       Successfully uninstalled keras-3.4.1
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.17.0
#     Uninstalling tensorboard-2.17.0:
#       Successfully uninstalled tensorboard-2.17.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.17.0
#     Uninstalling tensorflow-2.17.0:
#       Successfully uninstalled tensorflow-2.17.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorstore 0.1.67 requires ml-dtypes>=0.3.1, but you have ml-dtypes 0.2.0 which is incompatible.
# tf-keras 2.17.0 requires tensorflow<2.18,>=2.17, but you have tensorflow 2.15.0 which is incompatible.
# Successfully installed keras-2.15.0 ml-dtypes-0.2.0 tensorboard-2.15.2 tensorflow-2.15.0 tensorflow-estimator-2.15.0 wrapt-1.14.1

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras #desde tensorflow 2 se importa keras,  como paquete integrado de tensorflow
import pandas as pd
import numpy as np
from math import sqrt
from numpy import concatenate
from matplotlib import pyplot
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM, GRU
import tensorflow as tf
from datetime import datetime
from keras.models import Sequential
from keras.layers import Dense,Flatten,LSTM,RepeatVector,TimeDistributed#, GRUCellV2
from copy import deepcopy

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Reading the data set, parsing the dates and inferring the date format to date time. We also fill the Nan’s with 0.
#agrego index_col=0 para solucionar Unnamed: 0 porque https://stackoverflow.com/questions/43983622/remove-unnamed-columns-in-pandas-dataframe
dataset = read_csv("/content/drive/MyDrive/a Tesis de Grado/Tesis Versiones/tesis 2024/UA/editorial universitaria/preprocesamiento/outlier/salidaCSV/salidaKNN2024EditorialUniversitariaOctubre.csv", index_col=0)
#dataset.fillna(0, inplace=True)//pasar nans a ceros
#revisar lo que hago en el otro dataset
print(dataset.size)
print(dataset.columns)

print(dataset.shape)
print(dataset)
dataset.head()
# Out:
# 67044
# Index(['Número de vistas de página', 'Usuarios nuevos', 'Usuarios',
#        'Número de sesiones por usuario', 'Sesiones', 'Argentina',
#        'Otros Paises', 'mobile', 'desktop', 'tablet',
#        'Categoría de dispositivo promedio', 'Categoría de dispositivo std',
#        'Windows', 'Android', 'Linux', 'Macintosh',
#        'Sistema operativo (not set)', 'iOS', 'Windows Phone', 'Chrome OS',
#        'Tizen', 'Sistema operativo promedio', 'Sistema operativo std',
#        'Organic Search', 'Social', 'Direct', 'Referral',
#        'Agrupación de canales predeterminada promedio',
#        'Agrupación de canales predeterminada std', 'mediana_de_medianas',
#        'lag_90', 'lag_180', 'lag_270', 'lag_360', 'mediana Dispositivos',
#        'mediana Sistema operativo',
#        'mediana Agrupación de canales predeterminada'],
#       dtype='object')
# (1812, 37)
#       Número de vistas de página  Usuarios nuevos  Usuarios  \
# 0                          541.0             22.0      22.0
# 1                          226.0             23.0      26.0
# 2                          136.0             18.0      24.0
# 3                          229.0             11.0      16.0
# 4                           60.0             10.0      13.0
# ...                          ...              ...       ...
# 1810                        46.0             32.0      39.0
# 1811                        58.0             30.0      35.0
# 1812                        88.0             40.0      48.0
# 1813                       103.0             44.0      58.0
# 1814                       148.0             61.0      73.0
#
#       Número de sesiones por usuario  Sesiones  Argentina  Otros Paises  \
# 0                           1.636364      36.0      540.0           1.0
# 1                           1.346154      35.0      212.0          14.0
# 2                           1.458333      35.0      133.0           3.0
# 3                           1.812500      29.0      224.0           5.0
# 4                           1.461538      19.0       56.0           4.0
# ...                              ...       ...        ...           ...
# 1810                        1.102564      43.0       27.0          19.0
# 1811                        1.028571      36.0       42.0          16.0
# 1812                        1.104167      53.0       65.0          23.0
# 1813                        1.137931      66.0       87.0          16.0
# 1814                        1.123288      82.0      137.0          11.0
#
#       mobile  desktop  tablet  ...  \
# 0       49.0    492.0     0.0  ...
# 1        8.0    211.0     7.0  ...
# 2       17.0    119.0     0.0  ...
# 3       14.0    215.0     0.0  ...
# 4       20.0     40.0     0.0  ...
# ...      ...      ...     ...  ...
# 1810    21.0     25.0     0.0  ...
# 1811    22.0     36.0     0.0  ...
# 1812    40.0     48.0     0.0  ...
# 1813    29.0     74.0     0.0  ...
# 1814    36.0    111.0     1.0  ...
#
#       Agrupación de canales predeterminada promedio  \
# 0                                            135.25
# 1                                             56.50
# 2                                             34.00
# 3                                             57.25
# 4                                             15.00
# ...                                             ...
# 1810                                          11.50
# 1811                                          14.50
# 1812                                          22.00
# 1813                                          25.75
# 1814                                          37.00
#
#       Agrupación de canales predeterminada std  mediana_de_medianas    lag_90  \
# 0                                   202.460340            89.697167  104.5151
# 1                                    84.049095            89.697167  104.5151
# 2                                    39.344630            89.697167  104.5151
# 3                                    94.035570            89.697167  104.5151
# 4                                     9.433981            89.697167  104.5151
# ...                                        ...                  ...       ...
# 1810                                  9.912114           132.000000   46.0000
# 1811                                 17.471405           132.000000  126.0000
# 1812                                 19.836834           127.000000  171.0000
# 1813                                 26.938587           123.000000  104.0000
# 1814                                 35.881752           127.000000  111.0000
#
#          lag_180   lag_270   lag_360  mediana Dispositivos  \
# 0     100.866425  99.52464  100.1708                  49.0
# 1     100.866425  99.52464  100.1708                   8.0
# 2     100.866425  99.52464  100.1708                  17.0
# 3     100.866425  99.52464  100.1708                  14.0
# 4     100.866425  99.52464  100.1708                  20.0
# ...          ...       ...       ...                   ...
# 1810  225.000000  84.00000  251.0000                  21.0
# 1811  214.000000  18.00000  176.0000                  22.0
# 1812  283.000000  38.00000   91.0000                  40.0
# 1813   89.000000  37.00000   54.0000                  29.0
# 1814   52.000000  43.00000   31.0000                  36.0
#
#       mediana Sistema operativo  mediana Agrupación de canales predeterminada
# 0                           1.0                                          28.0
# 1                           0.0                                          12.5
# 2                           0.0                                          20.0
# 3                           0.0                                           4.5
# 4                           0.0                                          18.0
# ...                         ...                                           ...
# 1810                        2.0                                           9.5
# 1811                        0.0                                           6.5
# 1812                        1.0                                          18.5
# 1813                        0.0                                          16.0
# 1814                        1.0                                          22.0
#
# [1812 rows x 37 columns]
#    Número de vistas de página  Usuarios nuevos  Usuarios  \
# 0                       541.0             22.0      22.0
# 1                       226.0             23.0      26.0
# 2                       136.0             18.0      24.0
# 3                       229.0             11.0      16.0
# 4                        60.0             10.0      13.0
#
#    Número de sesiones por usuario  Sesiones  Argentina  Otros Paises  mobile  \
# 0                        1.636364      36.0      540.0           1.0    49.0
# 1                        1.346154      35.0      212.0          14.0     8.0
# 2                        1.458333      35.0      133.0           3.0    17.0
# 3                        1.812500      29.0      224.0           5.0    14.0
# 4                        1.461538      19.0       56.0           4.0    20.0
#
#    desktop  tablet  ...  Agrupación de canales predeterminada promedio  \
# 0    492.0     0.0  ...                                         135.25
# 1    211.0     7.0  ...                                          56.50
# 2    119.0     0.0  ...                                          34.00
# 3    215.0     0.0  ...                                          57.25
# 4     40.0     0.0  ...                                          15.00
#
#    Agrupación de canales predeterminada std  mediana_de_medianas    lag_90  \
# 0                                202.460340            89.697167  104.5151
# 1                                 84.049095            89.697167  104.5151
# 2                                 39.344630            89.697167  104.5151
# 3                                 94.035570            89.697167  104.5151
# 4                                  9.433981            89.697167  104.5151
#
#       lag_180   lag_270   lag_360  mediana Dispositivos  \
# 0  100.866425  99.52464  100.1708                  49.0
# 1  100.866425  99.52464  100.1708                   8.0
# 2  100.866425  99.52464  100.1708                  17.0
# 3  100.866425  99.52464  100.1708                  14.0
# 4  100.866425  99.52464  100.1708                  20.0
#
#    mediana Sistema operativo  mediana Agrupación de canales predeterminada
# 0                        1.0                                          28.0
# 1                        0.0                                          12.5
# 2                        0.0                                          20.0
# 3                        0.0                                           4.5
# 4                        0.0                                          18.0
#
# [5 rows x 37 columns]

# %%
print(dataset.columns)
print(dataset.shape)
print(dataset.head())
# Out:
# Index(['Número de vistas de página', 'Usuarios nuevos', 'Usuarios',
#        'Número de sesiones por usuario', 'Sesiones', 'Argentina',
#        'Otros Paises', 'mobile', 'desktop', 'tablet',
#        'Categoría de dispositivo promedio', 'Categoría de dispositivo std',
#        'Windows', 'Android', 'Linux', 'Macintosh',
#        'Sistema operativo (not set)', 'iOS', 'Windows Phone', 'Chrome OS',
#        'Tizen', 'Sistema operativo promedio', 'Sistema operativo std',
#        'Organic Search', 'Social', 'Direct', 'Referral',
#        'Agrupación de canales predeterminada promedio',
#        'Agrupación de canales predeterminada std', 'mediana_de_medianas',
#        'lag_90', 'lag_180', 'lag_270', 'lag_360', 'mediana Dispositivos',
#        'mediana Sistema operativo',
#        'mediana Agrupación de canales predeterminada'],
#       dtype='object')
# (1812, 37)
#    Número de vistas de página  Usuarios nuevos  Usuarios  \
# 0                       541.0             22.0      22.0
# 1                       226.0             23.0      26.0
# 2                       136.0             18.0      24.0
# 3                       229.0             11.0      16.0
# 4                        60.0             10.0      13.0
#
#    Número de sesiones por usuario  Sesiones  Argentina  Otros Paises  mobile  \
# 0                        1.636364      36.0      540.0           1.0    49.0
# 1                        1.346154      35.0      212.0          14.0     8.0
# 2                        1.458333      35.0      133.0           3.0    17.0
# 3                        1.812500      29.0      224.0           5.0    14.0
# 4                        1.461538      19.0       56.0           4.0    20.0
#
#    desktop  tablet  ...  Agrupación de canales predeterminada promedio  \
# 0    492.0     0.0  ...                                         135.25
# 1    211.0     7.0  ...                                          56.50
# 2    119.0     0.0  ...                                          34.00
# 3    215.0     0.0  ...                                          57.25
# 4     40.0     0.0  ...                                          15.00
#
#    Agrupación de canales predeterminada std  mediana_de_medianas    lag_90  \
# 0                                202.460340            89.697167  104.5151
# 1                                 84.049095            89.697167  104.5151
# 2                                 39.344630            89.697167  104.5151
# 3                                 94.035570            89.697167  104.5151
# 4                                  9.433981            89.697167  104.5151
#
#       lag_180   lag_270   lag_360  mediana Dispositivos  \
# 0  100.866425  99.52464  100.1708                  49.0
# 1  100.866425  99.52464  100.1708                   8.0
# 2  100.866425  99.52464  100.1708                  17.0
# 3  100.866425  99.52464  100.1708                  14.0
# 4  100.866425  99.52464  100.1708                  20.0
#
#    mediana Sistema operativo  mediana Agrupación de canales predeterminada
# 0                        1.0                                          28.0
# 1                        0.0                                          12.5
# 2                        0.0                                          20.0
# 3                        0.0                                           4.5
# 4                        0.0                                          18.0
#
# [5 rows x 37 columns]

# %%
#predictor Flag
from copy import deepcopy
from datetime import datetime as dt

# %%
#-Habia algo aca en el preprocesamiento anterior

# %%
#115*0.75 = 86.25=86
#train_df,test_df = dataset[1:86], dataset[86:]
# parrtir en 80 - 20 segun la profe
#normalizar
#partir datos de entrenamiento y prueba
#dataset.shape[0]=1734 o es 115 en caso del ejemplo
print('dataset.shape[0]',dataset.shape[0],' dataset.shape[1]',dataset.shape[1])
formaFinal=int(dataset.shape[0]*0.80)#80% para train y 20% para test
print(formaFinal)
train_df,test_df = dataset[1:formaFinal], dataset[formaFinal:] #spliteo test/train
train = train_df
test = test_df
# Normalización del conjunto de entrenamiento
train_previo_log1p=deepcopy(train)
for column in train.columns:
    train.loc[:, column] = np.log1p(train[column])
train_previo_zscore = deepcopy(train)
for column in train.columns:
    mean = train[column].mean()  # Media del conjunto de entrenamiento
    std = train[column].std()    # Desviación estándar del conjunto de entrenamiento
    train[column] = (train[column] - mean) / std
    if std != 0:
        train[column] = (train[column] - mean) / std
    else:
        train[column] = 0
test_previo_log1p=deepcopy(test)
for column1 in test.columns:
    test.loc[:, column1] = np.log1p(test[column1])
# Normalización del conjunto de prueba
test_previo_zscore = deepcopy(test)
for column1 in test.columns:
    mean_train = train_previo_zscore[column1].mean()  # Media del conjunto de entrenamiento
    std_train = train_previo_zscore[column1].std()    # Desviación estándar del conjunto de entrenamiento
    if std_train != 0:
        test[column1] = (test[column1] - mean_train) / std_train
    else:
        test[column1] = 0  

print('train_df',train_df.shape)
print('test_df',test_df.shape)
print('test',test.shape,test.values[11])
# Out:
# dataset.shape[0] 1812  dataset.shape[1] 37
# 1449
# train_df (1448, 37)
# test_df (363, 37)
# test (363, 37) [ 0.28415351  1.1688435   1.02416001 -0.13314932  0.98638305  0.29219525
#   0.55355397  0.63233177  0.17913578 -0.31654803  0.27608745  0.03695034
#   0.24148466  0.61676554 -0.57537463  0.14709346 -0.26314637  0.7923334
#  -0.07800006 -0.13480537  0.          0.24945006  0.16704669  0.21340899
#   1.19930762  0.4991939   0.30510696  0.27205578  0.02022211  0.73229229
#  -0.46937797 -0.16210613 -0.62924135  0.51988287  0.75262886 -0.42932858
#   0.57881099]
# <ipython-input-8-f3b70a0d6653>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train[column] = (train[column] - mean) / std
# <ipython-input-8-f3b70a0d6653>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train[column] = (train[column] - mean) / std
# <ipython-input-8-f3b70a0d6653>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train[column] = 0
# <ipython-input-8-f3b70a0d6653>:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[column1] = (test[column1] - mean_train) / std_train
# <ipython-input-8-f3b70a0d6653>:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[column1] = 0  # O algún otro valor neutral que prefieras

# %%
#reshape a entrada

def split_series(series, n_past, n_future):
  #
  # n_past ==> no of past observations
  #
  # n_future ==> no of future observations
  #
  X, y = list(), list()
  for window_start in range(len(series)):
    past_end = window_start + n_past
    future_end = past_end + n_future
    if future_end > len(series):
      break
    # slicing the past and future parts of the window
    #past, future = series[window_start:past_end, :], series[past_end:future_end, :]
    #window_start cuando comienza  past_end es cuando termina y future_endes cuando termina las series a comparar, 0 es porque solo va a tomar la primera columna
    #la cual es la de total de vistas
    past, future = series[window_start:past_end, :], series[past_end:future_end, 0]
    X.append(past)
    y.append(future)
  return np.array(X), np.array(y)
# Out:
# "\nn_past = 50 #va a mirar 10 dias al pasado para predecir x dias a futuro\nn_future = 7 #anterior 5 #probar 7 dias a futuro\nn_features = dataset.shape[1] # Columnas totales del dataset\n\n#Now convert both the train and test data into samples using the split_series function.\n\nX_train, y_train = split_series(train.values,n_past, n_future)\nX_train = X_train.reshape((X_train.shape[0], X_train.shape[1],n_features))\n#y_train = y_train.reshape((y_train.shape[0], y_train.shape[1], n_features))\ny_train = y_train.reshape((y_train.shape[0], y_train.shape[1], 1)) #no hace falta reshapear\nX_test, y_test = split_series(test.values,n_past, n_future)\nX_test = X_test.reshape((X_test.shape[0], X_test.shape[1],n_features))\n#y_test = y_test.reshape((y_test.shape[0], y_test.shape[1], n_features))\ny_test = y_test.reshape((y_test.shape[0], y_test.shape[1], 1)) #no hace falta reshapear\nprint('X_train',X_train.shape,X_train)\nprint('y_train',y_train.shape,y_train)\nprint('X_test',X_test.shape,X_test)\nprint('y_test',y_test.shape,y_test)\n"

# %%
# !pip install keras-tuner -q

# %%
# !df -h
# Out:
# Filesystem      Size  Used Avail Use% Mounted on
# overlay         236G   35G  202G  15% /
# tmpfs            64M     0   64M   0% /dev
# shm             5.7G     0  5.7G   0% /dev/shm
# /dev/root       2.0G  1.2G  820M  59% /usr/sbin/docker-init
# /dev/sda1       242G   60G  182G  25% /opt/bin/.nvidia
# tmpfs           6.4G  488K  6.4G   1% /var/colab
# tmpfs           6.4G     0  6.4G   0% /proc/acpi
# tmpfs           6.4G     0  6.4G   0% /proc/scsi
# tmpfs           6.4G     0  6.4G   0% /sys/firmware
# drive           100G   61G   40G  61% /content/drive

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 85
# model name	: Intel(R) Xeon(R) CPU @ 2.00GHz
# stepping	: 3
# microcode	: 0xffffffff
# cpu MHz		: 2000.162
# cache size	: 39424 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa mmio_stale_data retbleed bhi
# bogomips	: 4000.32
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 1
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 85
# model name	: Intel(R) Xeon(R) CPU @ 2.00GHz
# stepping	: 3
# microcode	: 0xffffffff
# cpu MHz		: 2000.162
# cache size	: 39424 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 1
# initial apicid	: 1
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa mmio_stale_data retbleed bhi
# bogomips	: 4000.32
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:

# %%
# !cat /proc/meminfo
# Out:
# MemTotal:       13290452 kB
# MemFree:         1371176 kB
# MemAvailable:   11416840 kB
# Buffers:          541924 kB
# Cached:          9423648 kB
# SwapCached:            0 kB
# Active:          1336572 kB
# Inactive:        9918988 kB
# Active(anon):       1792 kB
# Inactive(anon):  1290336 kB
# Active(file):    1334780 kB
# Inactive(file):  8628652 kB
# Unevictable:          20 kB
# Mlocked:              20 kB
# SwapTotal:             0 kB
# SwapFree:              0 kB
# Dirty:               628 kB
# Writeback:             0 kB
# AnonPages:       1290048 kB
# Mapped:           726728 kB
# Shmem:              2128 kB
# KReclaimable:     407800 kB
# Slab:             483396 kB
# SReclaimable:     407800 kB
# SUnreclaim:        75596 kB
# KernelStack:        7852 kB
# PageTables:        25360 kB
# SecPageTables:         0 kB
# NFS_Unstable:          0 kB
# Bounce:                0 kB
# WritebackTmp:          0 kB
# CommitLimit:     6645224 kB
# Committed_AS:    4057388 kB
# VmallocTotal:   34359738367 kB
# VmallocUsed:       81980 kB
# VmallocChunk:          0 kB
# Percpu:             1168 kB
# HardwareCorrupted:     0 kB
# AnonHugePages:         0 kB
# ShmemHugePages:        0 kB
# ShmemPmdMapped:        0 kB
# FileHugePages:         0 kB
# FilePmdMapped:         0 kB
# CmaTotal:              0 kB
# CmaFree:               0 kB
# Unaccepted:            0 kB
# HugePages_Total:       0
# HugePages_Free:        0
# HugePages_Rsvd:        0
# HugePages_Surp:        0
# Hugepagesize:       2048 kB
# Hugetlb:               0 kB
# DirectMap4k:      166712 kB
# DirectMap2M:     5072896 kB
# DirectMap1G:    10485760 kB

# %%
# !/usr/local/cuda/bin/nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2023 NVIDIA Corporation
# Built on Tue_Aug_15_22:02:13_PDT_2023
# Cuda compilation tools, release 12.2, V12.2.140
# Build cuda_12.2.r12.2/compiler.33191640_0

# %%
# !which nvidia-smi
# Out:
# /opt/bin/nvidia-smi

# %%
# !nvidia-smi
# Out:
# Wed Oct 30 19:38:58 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   44C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
# !python --version
# Out:
# Python 3.10.12

# %%
import keras_tuner as kt
import datetime
from datetime import timedelta
from pytz import timezone
import tensorflow.keras.backend as K
import datetime
from datetime import timedelta
from pytz import timezone
print(tf. __version__)
print(pd. __version__)
print(np. __version__)
print(kt. __version__)
# Out:
# 2.15.0
# 2.1.4
# 1.26.4
# 1.4.7

# %%
# Establecer la semilla
seed_value = 42
import random 
# Establecer semillas
np.random.seed(seed_value)
random.seed(seed_value)
tf.random.set_seed(seed_value)
from tensorflow.keras.saving import register_keras_serializable

# %%
print('std',train_previo_zscore['Número de vistas de página'].std())
print('mean',train_previo_zscore['Número de vistas de página'].mean() )
# Out:
# std 0.8649864124052458
# mean 4.308087962814851

# %%
media_train=train_previo_zscore['Número de vistas de página'].std()
std_train=train_previo_zscore['Número de vistas de página'].mean()
#esta metrica esta en el codigo de github del ganador
@register_keras_serializable()
def smape_loss(y_true, y_pred):
    #revierto zscore
    global media_train
    global std_train
    y_true=(y_true*std_train)+media_train
    y_pred=(y_pred*std_train)+media_train
    #revierto log1p
    y_true=tf.math.expm1(y_true)
    y_pred=tf.math.expm1(y_pred)
    epsilon = 0.1
    y_pred = tf.convert_to_tensor(y_pred)
    y_true = tf.cast(y_true, y_pred.dtype)
    # Calcular el denominador de SMAPE
    summ = tf.maximum(tf.abs(y_true) + tf.abs(y_pred) + epsilon, 0.5 + epsilon)

    # Calcular SMAPE
    smape = tf.abs(y_pred - y_true) / summ * 2.0

    # Retornar la media de SMAPE
    return K.mean(smape, axis=-1)

@register_keras_serializable()
def mae_denorm(y_true, y_pred):
    #revierto zscore
    global media_train
    global std_train
    y_true1=(y_true*std_train)+media_train
    y_pred1=(y_pred*std_train)+media_train
    #revierto log1p
    y_true2=tf.math.expm1(y_true1)
    y_pred2=tf.math.expm1(y_pred1)

    return tf.keras.losses.mean_absolute_error(y_true2, y_pred2)

# %%
pathModelosJsonMejor="/content/drive/MyDrive/a Tesis de Grado/Tesis Versiones/tesis 2024/UA/editorial universitaria/modelos/modelos resultados/mejores modelos guardados/modelo"
nombreMejorModeloMejor="/ ndays Editorial 60hyperband mae 60 zscore.h5"#el mejor modelo es el hyperband de 28 dias y 107 época

reconstructed_model2 = tf.keras.models.load_model(pathModelosJsonMejor+nombreMejorModeloMejor,custom_objects={'smape_loss':smape_loss,'mae_denorm':mae_denorm})

# %%
from tensorflow.keras.callbacks import TensorBoard

# %%
pathModelosJson="/content/drive/MyDrive/a Tesis de Grado/Tesis Versiones/tesis 2024/UA/editorial universitaria/modelos/modelos resultados/prueba 500 epocas 1 capas sin early stopping Hyperband mejor modelo"
nombreMejorModelo="ndays60_500epochs1capa.h5"
class PrintTimeCallback(tf.keras.callbacks.Callback):#https://www.tensorflow.org/guide/keras/writing_your_own_callbacks
    def on_epoch_end(self, epoch, logs=None):
        cambio=datetime.datetime.now(timezone('UTC')) - timedelta(hours=3)
        salida=f"{cambio:%Y-%m-%d %H:%M:%S }"
        print('Tiempo on_epoch_end',salida)
n_past=60
cambio=datetime.datetime.now(timezone('UTC')) - timedelta(hours=3)
tiempoFinal=f"{cambio:%Y-%m-%d %H:%M:%S }"
print('Tiempo  Inicio y n_past',tiempoFinal , ' n_past:-->',n_past)
n_future = 60
n_features = train.shape[1]
X_train, y_train = split_series(train.values,n_past, n_future)
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1],n_features))
y_train = y_train.reshape((y_train.shape[0], y_train.shape[1], 1)) #no hace falta reshapear
X_test, y_test = split_series(test.values,n_past, n_future)
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1],n_features))
y_test = y_test.reshape((y_test.shape[0], y_test.shape[1], 1)) #no hace falta reshapear
logpaht=pathModelosJson+f"/logsndays60_500epochs1capa"
from tensorflow.keras.callbacks import ReduceLROnPlateau
#reduce_lr = ReduceLROnPlateau(monitor='val_smape_loss_zscore', factor=0.5, patience=5, min_lr=1e-50)
callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=50)#https://pub.towardsai.net/keras-earlystopping-callback-to-train-the-neural-networks-perfectly-2a3f865148f7
mcp_save = tf.keras.callbacks.ModelCheckpoint(pathModelosJson+"/"+'hyperband{epoch:03d}-{val_loss:03f}-'+nombreMejorModelo, save_best_only=True, monitor='val_loss', mode='min')#https://stackoverflow.com/questions/48285129/saving-best-model-in-keras
history_modelo=reconstructed_model2.fit(X_train,y_train,epochs=500,validation_data=(X_test,y_test),batch_size=192,verbose=1,
                                        callbacks=[PrintTimeCallback(),
                                                   mcp_save,#reduce_lr,
                                                   TensorBoard(log_dir=logpaht, write_graph=False, profile_batch=0)
                                                   ])
cambio=datetime.datetime.now(timezone('UTC')) - timedelta(hours=3)
tiempoFinalDespues=f"{cambio:%Y-%m-%d %H:%M:%S }"
print('Tiempo Final y n_past',tiempoFinalDespues , ' n_past:-->',n_past)
#reentreno 70-30
# Out:
# Tiempo  Inicio y n_past 2024-10-30 16:46:28   n_past:--> 60
# Epoch 1/500
# 6/7 [========================>.....] - ETA: 0s - loss: 2.3777 - smape_loss: 0.0049 - mae_denorm: 0.0043Tiempo on_epoch_end 2024-10-30 16:46:34
# 7/7 [==============================] - 6s 356ms/step - loss: 2.2751 - smape_loss: 0.0044 - mae_denorm: 0.0038 - val_loss: 0.8226 - val_smape_loss: 1.4725 - val_mae_denorm: 3602.3298
# Epoch 2/500
# 4/7 [================>.............] - ETA: 0s - loss: 1.1709 - smape_loss: 1.2216e-04 - mae_denorm: 1.2674e-04
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 7/7 [==============================] - ETA: 0s - loss: 1.1133 - smape_loss: 1.0088e-04 - mae_denorm: 1.0482e-04Tiempo on_epoch_end 2024-10-30 16:46:34
# 7/7 [==============================] - 0s 32ms/step - loss: 1.1133 - smape_loss: 1.0088e-04 - mae_denorm: 1.0482e-04 - val_loss: 1.0310 - val_smape_loss: 1.5409 - val_mae_denorm: 4507.2266
# Epoch 3/500
# 4/7 [================>.............] - ETA: 0s - loss: 1.1312 - smape_loss: 1.1242e-05 - mae_denorm: 1.1791e-05Tiempo on_epoch_end 2024-10-30 16:46:34
# 7/7 [==============================] - 0s 25ms/step - loss: 1.1287 - smape_loss: 6.9104e-06 - mae_denorm: 7.2484e-06 - val_loss: 1.1118 - val_smape_loss: 1.5655 - val_mae_denorm: 5987.0928
# Epoch 4/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.9932 - smape_loss: 9.2962e-07 - mae_denorm: 9.7603e-07Tiempo on_epoch_end 2024-10-30 16:46:35
# 7/7 [==============================] - 0s 24ms/step - loss: 0.9722 - smape_loss: 9.3620e-07 - mae_denorm: 9.8294e-07 - val_loss: 1.0398 - val_smape_loss: 1.5458 - val_mae_denorm: 4710.1772
# Epoch 5/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.8890 - smape_loss: 7.7045e-07 - mae_denorm: 8.0892e-07Tiempo on_epoch_end 2024-10-30 16:46:35
# 7/7 [==============================] - 0s 21ms/step - loss: 0.8859 - smape_loss: 8.2287e-07 - mae_denorm: 8.6396e-07 - val_loss: 1.0159 - val_smape_loss: 1.5374 - val_mae_denorm: 4464.8589
# Epoch 6/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.8770 - smape_loss: 7.6241e-07 - mae_denorm: 8.0048e-07Tiempo on_epoch_end 2024-10-30 16:46:35
# 7/7 [==============================] - 0s 22ms/step - loss: 0.8817 - smape_loss: 7.8387e-07 - mae_denorm: 8.2301e-07 - val_loss: 1.0744 - val_smape_loss: 1.5543 - val_mae_denorm: 5350.7183
# Epoch 7/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.8523 - smape_loss: 7.8957e-07 - mae_denorm: 8.2900e-07Tiempo on_epoch_end 2024-10-30 16:46:35
# 7/7 [==============================] - 0s 21ms/step - loss: 0.8549 - smape_loss: 7.7147e-07 - mae_denorm: 8.1000e-07 - val_loss: 1.1251 - val_smape_loss: 1.5676 - val_mae_denorm: 6658.3472
# Epoch 8/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.8591 - smape_loss: 7.8581e-07 - mae_denorm: 8.2505e-07Tiempo on_epoch_end 2024-10-30 16:46:35
# 7/7 [==============================] - 0s 23ms/step - loss: 0.8520 - smape_loss: 7.6973e-07 - mae_denorm: 8.0817e-07 - val_loss: 1.1077 - val_smape_loss: 1.5622 - val_mae_denorm: 6174.2949
# Epoch 9/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.8404 - smape_loss: 7.6199e-07 - mae_denorm: 8.0004e-07Tiempo on_epoch_end 2024-10-30 16:46:35
# 7/7 [==============================] - 0s 22ms/step - loss: 0.8393 - smape_loss: 7.6949e-07 - mae_denorm: 8.0792e-07 - val_loss: 1.0915 - val_smape_loss: 1.5568 - val_mae_denorm: 5781.6792
# Epoch 10/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.8403 - smape_loss: 7.6915e-07 - mae_denorm: 8.0756e-07Tiempo on_epoch_end 2024-10-30 16:46:35
# 7/7 [==============================] - 0s 22ms/step - loss: 0.8351 - smape_loss: 7.6921e-07 - mae_denorm: 8.0762e-07 - val_loss: 1.1086 - val_smape_loss: 1.5606 - val_mae_denorm: 6233.0103
# Epoch 11/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.8299 - smape_loss: 7.4743e-07 - mae_denorm: 7.8476e-07Tiempo on_epoch_end 2024-10-30 16:46:36
# 7/7 [==============================] - 0s 30ms/step - loss: 0.8297 - smape_loss: 7.6871e-07 - mae_denorm: 8.0710e-07 - val_loss: 1.1262 - val_smape_loss: 1.5644 - val_mae_denorm: 6775.2998
# Epoch 12/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.8300 - smape_loss: 7.4756e-07 - mae_denorm: 7.8489e-07Tiempo on_epoch_end 2024-10-30 16:46:36
# 7/7 [==============================] - 0s 21ms/step - loss: 0.8257 - smape_loss: 7.6848e-07 - mae_denorm: 8.0686e-07 - val_loss: 1.1320 - val_smape_loss: 1.5652 - val_mae_denorm: 6992.5327
# Epoch 13/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.8275 - smape_loss: 7.4574e-07 - mae_denorm: 7.8298e-07Tiempo on_epoch_end 2024-10-30 16:46:36
# 7/7 [==============================] - 0s 22ms/step - loss: 0.8219 - smape_loss: 7.6837e-07 - mae_denorm: 8.0675e-07 - val_loss: 1.1402 - val_smape_loss: 1.5667 - val_mae_denorm: 7318.4678
# Epoch 14/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.8242 - smape_loss: 7.6088e-07 - mae_denorm: 7.9888e-07Tiempo on_epoch_end 2024-10-30 16:46:36
# 7/7 [==============================] - 0s 21ms/step - loss: 0.8185 - smape_loss: 7.6829e-07 - mae_denorm: 8.0666e-07 - val_loss: 1.1522 - val_smape_loss: 1.5692 - val_mae_denorm: 7814.9570
# Epoch 15/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.8133 - smape_loss: 7.7372e-07 - mae_denorm: 8.1236e-07Tiempo on_epoch_end 2024-10-30 16:46:36
# 7/7 [==============================] - 0s 23ms/step - loss: 0.8152 - smape_loss: 7.6821e-07 - mae_denorm: 8.0658e-07 - val_loss: 1.1635 - val_smape_loss: 1.5714 - val_mae_denorm: 8337.0518
# Epoch 16/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.8067 - smape_loss: 7.4763e-07 - mae_denorm: 7.8497e-07Tiempo on_epoch_end 2024-10-30 16:46:36
# 7/7 [==============================] - 0s 21ms/step - loss: 0.8121 - smape_loss: 7.6816e-07 - mae_denorm: 8.0652e-07 - val_loss: 1.1729 - val_smape_loss: 1.5731 - val_mae_denorm: 8808.7734
# Epoch 17/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.8055 - smape_loss: 7.7972e-07 - mae_denorm: 8.1866e-07Tiempo on_epoch_end 2024-10-30 16:46:37
# 7/7 [==============================] - 0s 23ms/step - loss: 0.8093 - smape_loss: 7.6813e-07 - mae_denorm: 8.0649e-07 - val_loss: 1.1805 - val_smape_loss: 1.5745 - val_mae_denorm: 9236.6113
# Epoch 18/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.8081 - smape_loss: 7.9297e-07 - mae_denorm: 8.3257e-07Tiempo on_epoch_end 2024-10-30 16:46:37
# 7/7 [==============================] - 0s 21ms/step - loss: 0.8063 - smape_loss: 7.6810e-07 - mae_denorm: 8.0646e-07 - val_loss: 1.1931 - val_smape_loss: 1.5770 - val_mae_denorm: 10009.3779
# Epoch 19/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7959 - smape_loss: 7.9831e-07 - mae_denorm: 8.3818e-07Tiempo on_epoch_end 2024-10-30 16:46:37
# 7/7 [==============================] - 0s 24ms/step - loss: 0.8034 - smape_loss: 7.6811e-07 - mae_denorm: 8.0646e-07 - val_loss: 1.1953 - val_smape_loss: 1.5774 - val_mae_denorm: 10174.8018
# Epoch 20/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.8071 - smape_loss: 7.8087e-07 - mae_denorm: 8.1986e-07Tiempo on_epoch_end 2024-10-30 16:46:37
# 7/7 [==============================] - 0s 20ms/step - loss: 0.8007 - smape_loss: 7.6809e-07 - mae_denorm: 8.0645e-07 - val_loss: 1.2084 - val_smape_loss: 1.5801 - val_mae_denorm: 11072.5068
# Epoch 21/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.8036 - smape_loss: 7.4117e-07 - mae_denorm: 7.7818e-07Tiempo on_epoch_end 2024-10-30 16:46:37
# 7/7 [==============================] - 0s 22ms/step - loss: 0.7979 - smape_loss: 7.6808e-07 - mae_denorm: 8.0643e-07 - val_loss: 1.2119 - val_smape_loss: 1.5808 - val_mae_denorm: 11364.6592
# Epoch 22/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.8041 - smape_loss: 7.9636e-07 - mae_denorm: 8.3613e-07Tiempo on_epoch_end 2024-10-30 16:46:37
# 7/7 [==============================] - 0s 21ms/step - loss: 0.7953 - smape_loss: 7.6808e-07 - mae_denorm: 8.0644e-07 - val_loss: 1.2213 - val_smape_loss: 1.5830 - val_mae_denorm: 12147.5625
# Epoch 23/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7965 - smape_loss: 7.6226e-07 - mae_denorm: 8.0033e-07Tiempo on_epoch_end 2024-10-30 16:46:38
# 7/7 [==============================] - 0s 21ms/step - loss: 0.7925 - smape_loss: 7.6808e-07 - mae_denorm: 8.0643e-07 - val_loss: 1.2273 - val_smape_loss: 1.5843 - val_mae_denorm: 12670.4336
# Epoch 24/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7967 - smape_loss: 7.4109e-07 - mae_denorm: 7.7810e-07Tiempo on_epoch_end 2024-10-30 16:46:38
# 7/7 [==============================] - 0s 23ms/step - loss: 0.7899 - smape_loss: 7.6808e-07 - mae_denorm: 8.0643e-07 - val_loss: 1.2306 - val_smape_loss: 1.5851 - val_mae_denorm: 12985.7920
# Epoch 25/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7847 - smape_loss: 7.7126e-07 - mae_denorm: 8.0977e-07Tiempo on_epoch_end 2024-10-30 16:46:38
# 7/7 [==============================] - 0s 20ms/step - loss: 0.7873 - smape_loss: 7.6808e-07 - mae_denorm: 8.0644e-07 - val_loss: 1.2374 - val_smape_loss: 1.5868 - val_mae_denorm: 13602.9668
# Epoch 26/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7825 - smape_loss: 7.6741e-07 - mae_denorm: 8.0573e-07Tiempo on_epoch_end 2024-10-30 16:46:38
# 7/7 [==============================] - 0s 21ms/step - loss: 0.7847 - smape_loss: 7.6809e-07 - mae_denorm: 8.0645e-07 - val_loss: 1.2429 - val_smape_loss: 1.5882 - val_mae_denorm: 14162.3965
# Epoch 27/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7783 - smape_loss: 7.5248e-07 - mae_denorm: 7.9006e-07Tiempo on_epoch_end 2024-10-30 16:46:38
# 7/7 [==============================] - 0s 21ms/step - loss: 0.7819 - smape_loss: 7.6810e-07 - mae_denorm: 8.0645e-07 - val_loss: 1.2455 - val_smape_loss: 1.5890 - val_mae_denorm: 14432.0156
# Epoch 28/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7775 - smape_loss: 7.7224e-07 - mae_denorm: 8.1080e-07Tiempo on_epoch_end 2024-10-30 16:46:38
# 7/7 [==============================] - 0s 22ms/step - loss: 0.7792 - smape_loss: 7.6810e-07 - mae_denorm: 8.0645e-07 - val_loss: 1.2527 - val_smape_loss: 1.5908 - val_mae_denorm: 15191.4141
# Epoch 29/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7756 - smape_loss: 7.8065e-07 - mae_denorm: 8.1964e-07Tiempo on_epoch_end 2024-10-30 16:46:38
# 7/7 [==============================] - 0s 21ms/step - loss: 0.7765 - smape_loss: 7.6812e-07 - mae_denorm: 8.0648e-07 - val_loss: 1.2564 - val_smape_loss: 1.5920 - val_mae_denorm: 15633.7080
# Epoch 30/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7795 - smape_loss: 7.6388e-07 - mae_denorm: 8.0203e-07Tiempo on_epoch_end 2024-10-30 16:46:39
# 7/7 [==============================] - 0s 23ms/step - loss: 0.7740 - smape_loss: 7.6811e-07 - mae_denorm: 8.0647e-07 - val_loss: 1.2627 - val_smape_loss: 1.5937 - val_mae_denorm: 16350.5947
# Epoch 31/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7738 - smape_loss: 7.7174e-07 - mae_denorm: 8.1028e-07Tiempo on_epoch_end 2024-10-30 16:46:39
# 7/7 [==============================] - 0s 21ms/step - loss: 0.7712 - smape_loss: 7.6813e-07 - mae_denorm: 8.0649e-07 - val_loss: 1.2652 - val_smape_loss: 1.5947 - val_mae_denorm: 16640.9395
# Epoch 32/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7760 - smape_loss: 7.5992e-07 - mae_denorm: 7.9787e-07Tiempo on_epoch_end 2024-10-30 16:46:39
# 7/7 [==============================] - 0s 21ms/step - loss: 0.7686 - smape_loss: 7.6812e-07 - mae_denorm: 8.0647e-07 - val_loss: 1.2698 - val_smape_loss: 1.5961 - val_mae_denorm: 17185.0801
# Epoch 33/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7630 - smape_loss: 7.6653e-07 - mae_denorm: 8.0481e-07Tiempo on_epoch_end 2024-10-30 16:46:39
# 7/7 [==============================] - 0s 22ms/step - loss: 0.7658 - smape_loss: 7.6813e-07 - mae_denorm: 8.0649e-07 - val_loss: 1.2698 - val_smape_loss: 1.5967 - val_mae_denorm: 17176.5762
# Epoch 34/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7676 - smape_loss: 7.6414e-07 - mae_denorm: 8.0230e-07Tiempo on_epoch_end 2024-10-30 16:46:39
# 7/7 [==============================] - 0s 22ms/step - loss: 0.7633 - smape_loss: 7.6817e-07 - mae_denorm: 8.0653e-07 - val_loss: 1.2822 - val_smape_loss: 1.5997 - val_mae_denorm: 18769.1035
# Epoch 35/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7570 - smape_loss: 7.6281e-07 - mae_denorm: 8.0090e-07Tiempo on_epoch_end 2024-10-30 16:46:39
# 7/7 [==============================] - 0s 22ms/step - loss: 0.7610 - smape_loss: 7.6813e-07 - mae_denorm: 8.0649e-07 - val_loss: 1.2783 - val_smape_loss: 1.5995 - val_mae_denorm: 18285.8418
# Epoch 36/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7647 - smape_loss: 7.9785e-07 - mae_denorm: 8.3769e-07Tiempo on_epoch_end 2024-10-30 16:46:39
# 7/7 [==============================] - 0s 21ms/step - loss: 0.7588 - smape_loss: 7.6813e-07 - mae_denorm: 8.0649e-07 - val_loss: 1.2824 - val_smape_loss: 1.6007 - val_mae_denorm: 18865.7363
# Epoch 37/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7575 - smape_loss: 7.8294e-07 - mae_denorm: 8.2204e-07Tiempo on_epoch_end 2024-10-30 16:46:40
# 7/7 [==============================] - 0s 22ms/step - loss: 0.7560 - smape_loss: 7.6818e-07 - mae_denorm: 8.0655e-07 - val_loss: 1.2921 - val_smape_loss: 1.6031 - val_mae_denorm: 20190.2793
# Epoch 38/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7529 - smape_loss: 7.7870e-07 - mae_denorm: 8.1759e-07Tiempo on_epoch_end 2024-10-30 16:46:40
# 7/7 [==============================] - 0s 21ms/step - loss: 0.7536 - smape_loss: 7.6812e-07 - mae_denorm: 8.0648e-07 - val_loss: 1.2881 - val_smape_loss: 1.6028 - val_mae_denorm: 19590.2578
# Epoch 39/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7512 - smape_loss: 7.7927e-07 - mae_denorm: 8.1818e-07Tiempo on_epoch_end 2024-10-30 16:46:40
# 7/7 [==============================] - 0s 21ms/step - loss: 0.7515 - smape_loss: 7.6818e-07 - mae_denorm: 8.0654e-07 - val_loss: 1.2925 - val_smape_loss: 1.6041 - val_mae_denorm: 20150.3281
# Epoch 40/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7424 - smape_loss: 7.7967e-07 - mae_denorm: 8.1860e-07Tiempo on_epoch_end 2024-10-30 16:46:40
# 7/7 [==============================] - 0s 21ms/step - loss: 0.7490 - smape_loss: 7.6816e-07 - mae_denorm: 8.0653e-07 - val_loss: 1.2999 - val_smape_loss: 1.6058 - val_mae_denorm: 21166.3926
# Epoch 41/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7536 - smape_loss: 7.7164e-07 - mae_denorm: 8.1017e-07Tiempo on_epoch_end 2024-10-30 16:46:40
# 7/7 [==============================] - 0s 22ms/step - loss: 0.7469 - smape_loss: 7.6816e-07 - mae_denorm: 8.0652e-07 - val_loss: 1.2996 - val_smape_loss: 1.6061 - val_mae_denorm: 21140.0039
# Epoch 42/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7430 - smape_loss: 7.6091e-07 - mae_denorm: 7.9890e-07Tiempo on_epoch_end 2024-10-30 16:46:40
# 7/7 [==============================] - 0s 21ms/step - loss: 0.7447 - smape_loss: 7.6816e-07 - mae_denorm: 8.0653e-07 - val_loss: 1.3039 - val_smape_loss: 1.6070 - val_mae_denorm: 21658.1777
# Epoch 43/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7469 - smape_loss: 7.8660e-07 - mae_denorm: 8.2588e-07Tiempo on_epoch_end 2024-10-30 16:46:40
# 7/7 [==============================] - 0s 22ms/step - loss: 0.7428 - smape_loss: 7.6812e-07 - mae_denorm: 8.0648e-07 - val_loss: 1.3028 - val_smape_loss: 1.6069 - val_mae_denorm: 21458.3633
# Epoch 44/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7461 - smape_loss: 7.2267e-07 - mae_denorm: 7.5876e-07Tiempo on_epoch_end 2024-10-30 16:46:41
# 7/7 [==============================] - 0s 23ms/step - loss: 0.7409 - smape_loss: 7.6813e-07 - mae_denorm: 8.0649e-07 - val_loss: 1.3101 - val_smape_loss: 1.6083 - val_mae_denorm: 22536.5176
# Epoch 45/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7378 - smape_loss: 7.5447e-07 - mae_denorm: 7.9215e-07Tiempo on_epoch_end 2024-10-30 16:46:41
# 7/7 [==============================] - 0s 32ms/step - loss: 0.7391 - smape_loss: 7.6816e-07 - mae_denorm: 8.0652e-07 - val_loss: 1.3108 - val_smape_loss: 1.6084 - val_mae_denorm: 22608.4531
# Epoch 46/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7385 - smape_loss: 7.6766e-07 - mae_denorm: 8.0599e-07Tiempo on_epoch_end 2024-10-30 16:46:41
# 7/7 [==============================] - 0s 26ms/step - loss: 0.7375 - smape_loss: 7.6812e-07 - mae_denorm: 8.0648e-07 - val_loss: 1.3055 - val_smape_loss: 1.6076 - val_mae_denorm: 21744.1816
# Epoch 47/500
# 7/7 [==============================] - ETA: 0s - loss: 0.7355 - smape_loss: 7.6814e-07 - mae_denorm: 8.0650e-07Tiempo on_epoch_end 2024-10-30 16:46:41
# 7/7 [==============================] - 0s 61ms/step - loss: 0.7355 - smape_loss: 7.6814e-07 - mae_denorm: 8.0650e-07 - val_loss: 1.3099 - val_smape_loss: 1.6082 - val_mae_denorm: 22304.5586
# Epoch 48/500
# 7/7 [==============================] - ETA: 0s - loss: 0.7340 - smape_loss: 7.6818e-07 - mae_denorm: 8.0654e-07Tiempo on_epoch_end 2024-10-30 16:46:42
# 7/7 [==============================] - 0s 43ms/step - loss: 0.7340 - smape_loss: 7.6818e-07 - mae_denorm: 8.0654e-07 - val_loss: 1.3159 - val_smape_loss: 1.6091 - val_mae_denorm: 23159.7656
# Epoch 49/500
# 6/7 [========================>.....] - ETA: 0s - loss: 0.7344 - smape_loss: 7.4086e-07 - mae_denorm: 7.7785e-07Tiempo on_epoch_end 2024-10-30 16:46:42
# 7/7 [==============================] - 0s 50ms/step - loss: 0.7327 - smape_loss: 7.6819e-07 - mae_denorm: 8.0656e-07 - val_loss: 1.3135 - val_smape_loss: 1.6084 - val_mae_denorm: 22666.4551
# Epoch 50/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7317 - smape_loss: 7.9103e-07 - mae_denorm: 8.3054e-07Tiempo on_epoch_end 2024-10-30 16:46:42
# 7/7 [==============================] - 0s 26ms/step - loss: 0.7311 - smape_loss: 7.6819e-07 - mae_denorm: 8.0655e-07 - val_loss: 1.3164 - val_smape_loss: 1.6082 - val_mae_denorm: 23092.5703
# Epoch 51/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7244 - smape_loss: 7.7447e-07 - mae_denorm: 8.1315e-07Tiempo on_epoch_end 2024-10-30 16:46:42
# 7/7 [==============================] - 0s 25ms/step - loss: 0.7298 - smape_loss: 7.6813e-07 - mae_denorm: 8.0649e-07 - val_loss: 1.3108 - val_smape_loss: 1.6066 - val_mae_denorm: 22164.3418
# Epoch 52/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7283 - smape_loss: 7.3642e-07 - mae_denorm: 7.7320e-07Tiempo on_epoch_end 2024-10-30 16:46:43
# 7/7 [==============================] - 0s 27ms/step - loss: 0.7285 - smape_loss: 7.6817e-07 - mae_denorm: 8.0653e-07 - val_loss: 1.3158 - val_smape_loss: 1.6067 - val_mae_denorm: 22871.7500
# Epoch 53/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7258 - smape_loss: 7.8477e-07 - mae_denorm: 8.2396e-07Tiempo on_epoch_end 2024-10-30 16:46:43
# 7/7 [==============================] - 0s 32ms/step - loss: 0.7271 - smape_loss: 7.6819e-07 - mae_denorm: 8.0655e-07 - val_loss: 1.3149 - val_smape_loss: 1.6060 - val_mae_denorm: 22661.6816
# Epoch 54/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7269 - smape_loss: 7.6100e-07 - mae_denorm: 7.9901e-07Tiempo on_epoch_end 2024-10-30 16:46:43
# 7/7 [==============================] - 0s 24ms/step - loss: 0.7261 - smape_loss: 7.6820e-07 - mae_denorm: 8.0656e-07 - val_loss: 1.3185 - val_smape_loss: 1.6060 - val_mae_denorm: 23212.7480
# Epoch 55/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7273 - smape_loss: 8.0830e-07 - mae_denorm: 8.4867e-07Tiempo on_epoch_end 2024-10-30 16:46:43
# 7/7 [==============================] - 0s 26ms/step - loss: 0.7249 - smape_loss: 7.6820e-07 - mae_denorm: 8.0656e-07 - val_loss: 1.3183 - val_smape_loss: 1.6055 - val_mae_denorm: 23138.9219
# Epoch 56/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7193 - smape_loss: 7.5463e-07 - mae_denorm: 7.9231e-07Tiempo on_epoch_end 2024-10-30 16:46:43
# 7/7 [==============================] - 0s 33ms/step - loss: 0.7238 - smape_loss: 7.6820e-07 - mae_denorm: 8.0657e-07 - val_loss: 1.3180 - val_smape_loss: 1.6051 - val_mae_denorm: 23075.9648
# Epoch 57/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7221 - smape_loss: 7.5296e-07 - mae_denorm: 7.9056e-07Tiempo on_epoch_end 2024-10-30 16:46:44
# 7/7 [==============================] - 0s 35ms/step - loss: 0.7227 - smape_loss: 7.6819e-07 - mae_denorm: 8.0655e-07 - val_loss: 1.3137 - val_smape_loss: 1.6043 - val_mae_denorm: 22498.3516
# Epoch 58/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7278 - smape_loss: 7.6353e-07 - mae_denorm: 8.0166e-07Tiempo on_epoch_end 2024-10-30 16:46:44
# 7/7 [==============================] - 0s 33ms/step - loss: 0.7216 - smape_loss: 7.6817e-07 - mae_denorm: 8.0653e-07 - val_loss: 1.3116 - val_smape_loss: 1.6039 - val_mae_denorm: 22222.4590
# Epoch 59/500
# 7/7 [==============================] - ETA: 0s - loss: 0.7209 - smape_loss: 7.6818e-07 - mae_denorm: 8.0654e-07Tiempo on_epoch_end 2024-10-30 16:46:44
# 7/7 [==============================] - 0s 34ms/step - loss: 0.7209 - smape_loss: 7.6818e-07 - mae_denorm: 8.0654e-07 - val_loss: 1.3116 - val_smape_loss: 1.6037 - val_mae_denorm: 22218.5430
# Epoch 60/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7176 - smape_loss: 7.4480e-07 - mae_denorm: 7.8200e-07Tiempo on_epoch_end 2024-10-30 16:46:44
# 7/7 [==============================] - 0s 33ms/step - loss: 0.7202 - smape_loss: 7.6820e-07 - mae_denorm: 8.0656e-07 - val_loss: 1.3162 - val_smape_loss: 1.6043 - val_mae_denorm: 22919.3770
# Epoch 61/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7162 - smape_loss: 7.4583e-07 - mae_denorm: 7.8308e-07Tiempo on_epoch_end 2024-10-30 16:46:45
# 7/7 [==============================] - 0s 23ms/step - loss: 0.7193 - smape_loss: 7.6821e-07 - mae_denorm: 8.0657e-07 - val_loss: 1.3186 - val_smape_loss: 1.6044 - val_mae_denorm: 23368.8691
# Epoch 62/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7187 - smape_loss: 7.4596e-07 - mae_denorm: 7.8321e-07Tiempo on_epoch_end 2024-10-30 16:46:45
# 7/7 [==============================] - 0s 23ms/step - loss: 0.7184 - smape_loss: 7.6820e-07 - mae_denorm: 8.0656e-07 - val_loss: 1.3193 - val_smape_loss: 1.6045 - val_mae_denorm: 23492.9375
# Epoch 63/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7177 - smape_loss: 7.9062e-07 - mae_denorm: 8.3010e-07Tiempo on_epoch_end 2024-10-30 16:46:45
# 7/7 [==============================] - 0s 22ms/step - loss: 0.7178 - smape_loss: 7.6820e-07 - mae_denorm: 8.0656e-07 - val_loss: 1.3203 - val_smape_loss: 1.6046 - val_mae_denorm: 23713.6133
# Epoch 64/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7163 - smape_loss: 7.8073e-07 - mae_denorm: 8.1971e-07Tiempo on_epoch_end 2024-10-30 16:46:45
# 7/7 [==============================] - 0s 21ms/step - loss: 0.7169 - smape_loss: 7.6819e-07 - mae_denorm: 8.0656e-07 - val_loss: 1.3208 - val_smape_loss: 1.6046 - val_mae_denorm: 23893.2324
# Epoch 65/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7196 - smape_loss: 7.8768e-07 - mae_denorm: 8.2702e-07Tiempo on_epoch_end 2024-10-30 16:46:45
# 7/7 [==============================] - 0s 21ms/step - loss: 0.7162 - smape_loss: 7.6820e-07 - mae_denorm: 8.0656e-07 - val_loss: 1.3186 - val_smape_loss: 1.6044 - val_mae_denorm: 23647.1328
# Epoch 66/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7125 - smape_loss: 7.6823e-07 - mae_denorm: 8.0659e-07Tiempo on_epoch_end 2024-10-30 16:46:45
# 7/7 [==============================] - 0s 21ms/step - loss: 0.7153 - smape_loss: 7.6820e-07 - mae_denorm: 8.0656e-07 - val_loss: 1.3184 - val_smape_loss: 1.6044 - val_mae_denorm: 23768.3711
# Epoch 67/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7121 - smape_loss: 7.9239e-07 - mae_denorm: 8.3195e-07Tiempo on_epoch_end 2024-10-30 16:46:45
# 7/7 [==============================] - 0s 22ms/step - loss: 0.7145 - smape_loss: 7.6820e-07 - mae_denorm: 8.0656e-07 - val_loss: 1.3166 - val_smape_loss: 1.6042 - val_mae_denorm: 23562.3242
# Epoch 68/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7130 - smape_loss: 7.6813e-07 - mae_denorm: 8.0649e-07Tiempo on_epoch_end 2024-10-30 16:46:46
# 7/7 [==============================] - 0s 24ms/step - loss: 0.7140 - smape_loss: 7.6819e-07 - mae_denorm: 8.0655e-07 - val_loss: 1.3155 - val_smape_loss: 1.6041 - val_mae_denorm: 23568.5566
# Epoch 69/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7116 - smape_loss: 7.8164e-07 - mae_denorm: 8.2067e-07Tiempo on_epoch_end 2024-10-30 16:46:46
# 7/7 [==============================] - 0s 22ms/step - loss: 0.7132 - smape_loss: 7.6818e-07 - mae_denorm: 8.0654e-07 - val_loss: 1.3193 - val_smape_loss: 1.6047 - val_mae_denorm: 24164.4785
# Epoch 70/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7136 - smape_loss: 7.4483e-07 - mae_denorm: 7.8203e-07Tiempo on_epoch_end 2024-10-30 16:46:46
# 7/7 [==============================] - 0s 21ms/step - loss: 0.7126 - smape_loss: 7.6819e-07 - mae_denorm: 8.0655e-07 - val_loss: 1.3190 - val_smape_loss: 1.6047 - val_mae_denorm: 24286.8496
# Epoch 71/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7110 - smape_loss: 7.5336e-07 - mae_denorm: 7.9098e-07Tiempo on_epoch_end 2024-10-30 16:46:46
# 7/7 [==============================] - 0s 21ms/step - loss: 0.7118 - smape_loss: 7.6819e-07 - mae_denorm: 8.0655e-07 - val_loss: 1.3144 - val_smape_loss: 1.6043 - val_mae_denorm: 23677.1738
# Epoch 72/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7130 - smape_loss: 7.4780e-07 - mae_denorm: 7.8514e-07Tiempo on_epoch_end 2024-10-30 16:46:46
# 7/7 [==============================] - 0s 21ms/step - loss: 0.7111 - smape_loss: 7.6819e-07 - mae_denorm: 8.0655e-07 - val_loss: 1.3164 - val_smape_loss: 1.6047 - val_mae_denorm: 24095.0137
# Epoch 73/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7127 - smape_loss: 7.6519e-07 - mae_denorm: 8.0340e-07Tiempo on_epoch_end 2024-10-30 16:46:46
# 7/7 [==============================] - 0s 22ms/step - loss: 0.7104 - smape_loss: 7.6818e-07 - mae_denorm: 8.0654e-07 - val_loss: 1.3175 - val_smape_loss: 1.6050 - val_mae_denorm: 24361.5742
# Epoch 74/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7110 - smape_loss: 7.3097e-07 - mae_denorm: 7.6747e-07Tiempo on_epoch_end 2024-10-30 16:46:47
# 7/7 [==============================] - 0s 21ms/step - loss: 0.7099 - smape_loss: 7.6816e-07 - mae_denorm: 8.0653e-07 - val_loss: 1.3188 - val_smape_loss: 1.6052 - val_mae_denorm: 24579.3828
# Epoch 75/500
# 4/7 [================>.............] - ETA: 0s - loss: 0.7208 - smape_loss: 7.6729e-07 - mae_denorm: 8.0561e-07Tiempo on_epoch_end 2024-10-30 16:46:47
# 7/7 [==============================] - 0s 24ms/step - loss: 0.7091 - smape_loss: 7.6815e-07 - mae_denorm: 8.0651e-07 - val_loss: 1.3118 - val_smape_loss: 1.6045 - val_mae_denorm: 23791.2656
# Epoch 76/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7074 - smape_loss: 7.7722e-07 - mae_denorm: 8.1603e-07Tiempo on_epoch_end 2024-10-30 16:46:47
# 7/7 [==============================] - 0s 22ms/step - loss: 0.7085 - smape_loss: 7.6818e-07 - mae_denorm: 8.0654e-07 - val_loss: 1.3153 - val_smape_loss: 1.6051 - val_mae_denorm: 24366.4512
# Epoch 77/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7076 - smape_loss: 7.7857e-07 - mae_denorm: 8.1745e-07Tiempo on_epoch_end 2024-10-30 16:46:47
# 7/7 [==============================] - 0s 21ms/step - loss: 0.7080 - smape_loss: 7.6819e-07 - mae_denorm: 8.0655e-07 - val_loss: 1.3170 - val_smape_loss: 1.6055 - val_mae_denorm: 24769.6309
# Epoch 78/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7085 - smape_loss: 7.5944e-07 - mae_denorm: 7.9737e-07Tiempo on_epoch_end 2024-10-30 16:46:47
# 7/7 [==============================] - 0s 21ms/step - loss: 0.7076 - smape_loss: 7.6813e-07 - mae_denorm: 8.0649e-07 - val_loss: 1.3107 - val_smape_loss: 1.6051 - val_mae_denorm: 23942.2812
# Epoch 79/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7057 - smape_loss: 7.4674e-07 - mae_denorm: 7.8403e-07Tiempo on_epoch_end 2024-10-30 16:46:47
# 7/7 [==============================] - 0s 22ms/step - loss: 0.7068 - smape_loss: 7.6817e-07 - mae_denorm: 8.0653e-07 - val_loss: 1.3157 - val_smape_loss: 1.6057 - val_mae_denorm: 24793.1055
# Epoch 80/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7033 - smape_loss: 7.5596e-07 - mae_denorm: 7.9371e-07Tiempo on_epoch_end 2024-10-30 16:46:47
# 7/7 [==============================] - 0s 21ms/step - loss: 0.7063 - smape_loss: 7.6812e-07 - mae_denorm: 8.0648e-07 - val_loss: 1.3195 - val_smape_loss: 1.6062 - val_mae_denorm: 25379.1191
# Epoch 81/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7059 - smape_loss: 7.9695e-07 - mae_denorm: 8.3674e-07Tiempo on_epoch_end 2024-10-30 16:46:48
# 7/7 [==============================] - 0s 24ms/step - loss: 0.7058 - smape_loss: 7.6817e-07 - mae_denorm: 8.0653e-07 - val_loss: 1.3135 - val_smape_loss: 1.6056 - val_mae_denorm: 24697.7090
# Epoch 82/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7025 - smape_loss: 7.7277e-07 - mae_denorm: 8.1136e-07Tiempo on_epoch_end 2024-10-30 16:46:48
# 7/7 [==============================] - 0s 22ms/step - loss: 0.7052 - smape_loss: 7.6818e-07 - mae_denorm: 8.0654e-07 - val_loss: 1.3184 - val_smape_loss: 1.6065 - val_mae_denorm: 25471.4375
# Epoch 83/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7048 - smape_loss: 7.4712e-07 - mae_denorm: 7.8443e-07Tiempo on_epoch_end 2024-10-30 16:46:48
# 7/7 [==============================] - 0s 22ms/step - loss: 0.7043 - smape_loss: 7.6812e-07 - mae_denorm: 8.0648e-07 - val_loss: 1.3164 - val_smape_loss: 1.6063 - val_mae_denorm: 25339.1191
# Epoch 84/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7053 - smape_loss: 7.4602e-07 - mae_denorm: 7.8328e-07Tiempo on_epoch_end 2024-10-30 16:46:48
# 7/7 [==============================] - 0s 21ms/step - loss: 0.7036 - smape_loss: 7.6813e-07 - mae_denorm: 8.0649e-07 - val_loss: 1.3194 - val_smape_loss: 1.6068 - val_mae_denorm: 25820.5078
# Epoch 85/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7028 - smape_loss: 8.0353e-07 - mae_denorm: 8.4366e-07Tiempo on_epoch_end 2024-10-30 16:46:48
# 7/7 [==============================] - 0s 21ms/step - loss: 0.7031 - smape_loss: 7.6814e-07 - mae_denorm: 8.0650e-07 - val_loss: 1.3184 - val_smape_loss: 1.6067 - val_mae_denorm: 25890.3828
# Epoch 86/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7017 - smape_loss: 7.7227e-07 - mae_denorm: 8.1083e-07Tiempo on_epoch_end 2024-10-30 16:46:48
# 7/7 [==============================] - 0s 23ms/step - loss: 0.7024 - smape_loss: 7.6812e-07 - mae_denorm: 8.0648e-07 - val_loss: 1.3170 - val_smape_loss: 1.6069 - val_mae_denorm: 25711.7461
# Epoch 87/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7022 - smape_loss: 7.5013e-07 - mae_denorm: 7.8759e-07Tiempo on_epoch_end 2024-10-30 16:46:49
# 7/7 [==============================] - 0s 22ms/step - loss: 0.7021 - smape_loss: 7.6812e-07 - mae_denorm: 8.0648e-07 - val_loss: 1.3246 - val_smape_loss: 1.6080 - val_mae_denorm: 27018.0586
# Epoch 88/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7019 - smape_loss: 7.5563e-07 - mae_denorm: 7.9337e-07Tiempo on_epoch_end 2024-10-30 16:46:49
# 7/7 [==============================] - 0s 23ms/step - loss: 0.7014 - smape_loss: 7.6810e-07 - mae_denorm: 8.0645e-07 - val_loss: 1.3190 - val_smape_loss: 1.6074 - val_mae_denorm: 26383.4141
# Epoch 89/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7004 - smape_loss: 7.8021e-07 - mae_denorm: 8.1918e-07Tiempo on_epoch_end 2024-10-30 16:46:49
# 7/7 [==============================] - 0s 21ms/step - loss: 0.7009 - smape_loss: 7.6811e-07 - mae_denorm: 8.0647e-07 - val_loss: 1.3269 - val_smape_loss: 1.6086 - val_mae_denorm: 27655.7461
# Epoch 90/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.7011 - smape_loss: 7.8006e-07 - mae_denorm: 8.1902e-07Tiempo on_epoch_end 2024-10-30 16:46:49
# 7/7 [==============================] - 0s 21ms/step - loss: 0.7005 - smape_loss: 7.6808e-07 - mae_denorm: 8.0643e-07 - val_loss: 1.3223 - val_smape_loss: 1.6079 - val_mae_denorm: 27067.1699
# Epoch 91/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6953 - smape_loss: 7.9432e-07 - mae_denorm: 8.3398e-07Tiempo on_epoch_end 2024-10-30 16:46:49
# 7/7 [==============================] - 0s 21ms/step - loss: 0.6999 - smape_loss: 7.6812e-07 - mae_denorm: 8.0648e-07 - val_loss: 1.3254 - val_smape_loss: 1.6086 - val_mae_denorm: 27551.1699
# Epoch 92/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6999 - smape_loss: 7.4379e-07 - mae_denorm: 7.8093e-07Tiempo on_epoch_end 2024-10-30 16:46:49
# 7/7 [==============================] - 0s 22ms/step - loss: 0.6992 - smape_loss: 7.6811e-07 - mae_denorm: 8.0647e-07 - val_loss: 1.3274 - val_smape_loss: 1.6090 - val_mae_denorm: 28169.1152
# Epoch 93/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6987 - smape_loss: 7.9712e-07 - mae_denorm: 8.3692e-07Tiempo on_epoch_end 2024-10-30 16:46:49
# 7/7 [==============================] - 0s 23ms/step - loss: 0.6988 - smape_loss: 7.6809e-07 - mae_denorm: 8.0644e-07 - val_loss: 1.3254 - val_smape_loss: 1.6087 - val_mae_denorm: 27815.1055
# Epoch 94/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6954 - smape_loss: 7.7058e-07 - mae_denorm: 8.0906e-07Tiempo on_epoch_end 2024-10-30 16:46:50
# 7/7 [==============================] - 0s 23ms/step - loss: 0.6982 - smape_loss: 7.6810e-07 - mae_denorm: 8.0646e-07 - val_loss: 1.3294 - val_smape_loss: 1.6094 - val_mae_denorm: 28656.8066
# Epoch 95/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6973 - smape_loss: 7.6216e-07 - mae_denorm: 8.0023e-07Tiempo on_epoch_end 2024-10-30 16:46:50
# 7/7 [==============================] - 0s 22ms/step - loss: 0.6979 - smape_loss: 7.6807e-07 - mae_denorm: 8.0643e-07 - val_loss: 1.3240 - val_smape_loss: 1.6088 - val_mae_denorm: 27930.5625
# Epoch 96/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6980 - smape_loss: 7.6362e-07 - mae_denorm: 8.0175e-07Tiempo on_epoch_end 2024-10-30 16:46:50
# 7/7 [==============================] - 0s 21ms/step - loss: 0.6975 - smape_loss: 7.6811e-07 - mae_denorm: 8.0647e-07 - val_loss: 1.3329 - val_smape_loss: 1.6101 - val_mae_denorm: 29549.5527
# Epoch 97/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6965 - smape_loss: 7.6387e-07 - mae_denorm: 8.0201e-07Tiempo on_epoch_end 2024-10-30 16:46:50
# 7/7 [==============================] - 0s 22ms/step - loss: 0.6969 - smape_loss: 7.6804e-07 - mae_denorm: 8.0639e-07 - val_loss: 1.3293 - val_smape_loss: 1.6098 - val_mae_denorm: 29119.3906
# Epoch 98/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6962 - smape_loss: 7.6181e-07 - mae_denorm: 7.9985e-07Tiempo on_epoch_end 2024-10-30 16:46:50
# 7/7 [==============================] - 0s 22ms/step - loss: 0.6963 - smape_loss: 7.6808e-07 - mae_denorm: 8.0644e-07 - val_loss: 1.3333 - val_smape_loss: 1.6103 - val_mae_denorm: 29816.7891
# Epoch 99/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6945 - smape_loss: 7.2786e-07 - mae_denorm: 7.6421e-07Tiempo on_epoch_end 2024-10-30 16:46:50
# 7/7 [==============================] - 0s 22ms/step - loss: 0.6960 - smape_loss: 7.6806e-07 - mae_denorm: 8.0641e-07 - val_loss: 1.3295 - val_smape_loss: 1.6098 - val_mae_denorm: 29370.4434
# Epoch 100/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6936 - smape_loss: 7.7816e-07 - mae_denorm: 8.1702e-07Tiempo on_epoch_end 2024-10-30 16:46:51
# 7/7 [==============================] - 0s 22ms/step - loss: 0.6955 - smape_loss: 7.6806e-07 - mae_denorm: 8.0641e-07 - val_loss: 1.3367 - val_smape_loss: 1.6109 - val_mae_denorm: 30535.8711
# Epoch 101/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6960 - smape_loss: 7.9171e-07 - mae_denorm: 8.3125e-07Tiempo on_epoch_end 2024-10-30 16:46:51
# 7/7 [==============================] - 0s 22ms/step - loss: 0.6952 - smape_loss: 7.6806e-07 - mae_denorm: 8.0641e-07 - val_loss: 1.3318 - val_smape_loss: 1.6102 - val_mae_denorm: 29780.1953
# Epoch 102/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6960 - smape_loss: 7.7691e-07 - mae_denorm: 8.1571e-07Tiempo on_epoch_end 2024-10-30 16:46:51
# 7/7 [==============================] - 0s 21ms/step - loss: 0.6947 - smape_loss: 7.6803e-07 - mae_denorm: 8.0638e-07 - val_loss: 1.3350 - val_smape_loss: 1.6107 - val_mae_denorm: 30393.9512
# Epoch 103/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6969 - smape_loss: 7.6575e-07 - mae_denorm: 8.0400e-07Tiempo on_epoch_end 2024-10-30 16:46:51
# 7/7 [==============================] - 0s 21ms/step - loss: 0.6942 - smape_loss: 7.6805e-07 - mae_denorm: 8.0640e-07 - val_loss: 1.3373 - val_smape_loss: 1.6111 - val_mae_denorm: 31129.0566
# Epoch 104/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6920 - smape_loss: 7.3847e-07 - mae_denorm: 7.7535e-07Tiempo on_epoch_end 2024-10-30 16:46:51
# 7/7 [==============================] - 0s 22ms/step - loss: 0.6936 - smape_loss: 7.6804e-07 - mae_denorm: 8.0640e-07 - val_loss: 1.3367 - val_smape_loss: 1.6112 - val_mae_denorm: 30951.2695
# Epoch 105/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6938 - smape_loss: 7.4484e-07 - mae_denorm: 7.8204e-07Tiempo on_epoch_end 2024-10-30 16:46:51
# 7/7 [==============================] - 0s 21ms/step - loss: 0.6933 - smape_loss: 7.6805e-07 - mae_denorm: 8.0640e-07 - val_loss: 1.3385 - val_smape_loss: 1.6115 - val_mae_denorm: 31481.6914
# Epoch 106/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6904 - smape_loss: 7.4658e-07 - mae_denorm: 7.8386e-07Tiempo on_epoch_end 2024-10-30 16:46:51
# 7/7 [==============================] - 0s 23ms/step - loss: 0.6928 - smape_loss: 7.6804e-07 - mae_denorm: 8.0640e-07 - val_loss: 1.3377 - val_smape_loss: 1.6114 - val_mae_denorm: 31350.8086
# Epoch 107/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6913 - smape_loss: 7.8986e-07 - mae_denorm: 8.2930e-07Tiempo on_epoch_end 2024-10-30 16:46:52
# 7/7 [==============================] - 0s 23ms/step - loss: 0.6924 - smape_loss: 7.6800e-07 - mae_denorm: 8.0636e-07 - val_loss: 1.3348 - val_smape_loss: 1.6111 - val_mae_denorm: 31017.6738
# Epoch 108/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6905 - smape_loss: 7.6894e-07 - mae_denorm: 8.0734e-07Tiempo on_epoch_end 2024-10-30 16:46:52
# 7/7 [==============================] - 0s 21ms/step - loss: 0.6922 - smape_loss: 7.6802e-07 - mae_denorm: 8.0637e-07 - val_loss: 1.3425 - val_smape_loss: 1.6122 - val_mae_denorm: 32633.3164
# Epoch 109/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6903 - smape_loss: 7.4885e-07 - mae_denorm: 7.8624e-07Tiempo on_epoch_end 2024-10-30 16:46:52
# 7/7 [==============================] - 0s 22ms/step - loss: 0.6917 - smape_loss: 7.6800e-07 - mae_denorm: 8.0635e-07 - val_loss: 1.3380 - val_smape_loss: 1.6118 - val_mae_denorm: 31992.2266
# Epoch 110/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6891 - smape_loss: 7.6840e-07 - mae_denorm: 8.0677e-07Tiempo on_epoch_end 2024-10-30 16:46:52
# 7/7 [==============================] - 0s 22ms/step - loss: 0.6913 - smape_loss: 7.6798e-07 - mae_denorm: 8.0634e-07 - val_loss: 1.3444 - val_smape_loss: 1.6128 - val_mae_denorm: 33179.1797
# Epoch 111/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6876 - smape_loss: 7.7271e-07 - mae_denorm: 8.1130e-07Tiempo on_epoch_end 2024-10-30 16:46:52
# 7/7 [==============================] - 0s 21ms/step - loss: 0.6909 - smape_loss: 7.6798e-07 - mae_denorm: 8.0633e-07 - val_loss: 1.3386 - val_smape_loss: 1.6120 - val_mae_denorm: 32265.3691
# Epoch 112/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6889 - smape_loss: 7.2588e-07 - mae_denorm: 7.6212e-07Tiempo on_epoch_end 2024-10-30 16:46:52
# 7/7 [==============================] - 0s 21ms/step - loss: 0.6906 - smape_loss: 7.6798e-07 - mae_denorm: 8.0633e-07 - val_loss: 1.3407 - val_smape_loss: 1.6124 - val_mae_denorm: 32922.9805
# Epoch 113/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6892 - smape_loss: 7.0488e-07 - mae_denorm: 7.4008e-07Tiempo on_epoch_end 2024-10-30 16:46:52
# 7/7 [==============================] - 0s 22ms/step - loss: 0.6902 - smape_loss: 7.6796e-07 - mae_denorm: 8.0631e-07 - val_loss: 1.3452 - val_smape_loss: 1.6131 - val_mae_denorm: 33843.9375
# Epoch 114/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6912 - smape_loss: 7.4783e-07 - mae_denorm: 7.8518e-07Tiempo on_epoch_end 2024-10-30 16:46:53
# 7/7 [==============================] - 0s 23ms/step - loss: 0.6898 - smape_loss: 7.6796e-07 - mae_denorm: 8.0631e-07 - val_loss: 1.3426 - val_smape_loss: 1.6129 - val_mae_denorm: 33477.0859
# Epoch 115/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6883 - smape_loss: 7.4999e-07 - mae_denorm: 7.8744e-07Tiempo on_epoch_end 2024-10-30 16:46:53
# 7/7 [==============================] - 0s 22ms/step - loss: 0.6895 - smape_loss: 7.6792e-07 - mae_denorm: 8.0627e-07 - val_loss: 1.3419 - val_smape_loss: 1.6128 - val_mae_denorm: 33668.5664
# Epoch 116/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6889 - smape_loss: 7.7762e-07 - mae_denorm: 8.1646e-07Tiempo on_epoch_end 2024-10-30 16:46:53
# 7/7 [==============================] - 0s 21ms/step - loss: 0.6890 - smape_loss: 7.6791e-07 - mae_denorm: 8.0626e-07 - val_loss: 1.3445 - val_smape_loss: 1.6133 - val_mae_denorm: 34186.7656
# Epoch 117/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6868 - smape_loss: 7.6751e-07 - mae_denorm: 8.0583e-07Tiempo on_epoch_end 2024-10-30 16:46:53
# 7/7 [==============================] - 0s 21ms/step - loss: 0.6887 - smape_loss: 7.6793e-07 - mae_denorm: 8.0627e-07 - val_loss: 1.3449 - val_smape_loss: 1.6133 - val_mae_denorm: 34562.5195
# Epoch 118/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6835 - smape_loss: 7.5351e-07 - mae_denorm: 7.9114e-07Tiempo on_epoch_end 2024-10-30 16:46:53
# 7/7 [==============================] - 0s 22ms/step - loss: 0.6883 - smape_loss: 7.6792e-07 - mae_denorm: 8.0626e-07 - val_loss: 1.3457 - val_smape_loss: 1.6136 - val_mae_denorm: 34977.9102
# Epoch 119/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6867 - smape_loss: 7.7290e-07 - mae_denorm: 8.1150e-07Tiempo on_epoch_end 2024-10-30 16:46:53
# 7/7 [==============================] - 0s 21ms/step - loss: 0.6880 - smape_loss: 7.6792e-07 - mae_denorm: 8.0627e-07 - val_loss: 1.3451 - val_smape_loss: 1.6137 - val_mae_denorm: 35134.5234
# Epoch 120/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6895 - smape_loss: 7.5554e-07 - mae_denorm: 7.9327e-07Tiempo on_epoch_end 2024-10-30 16:46:54
# 7/7 [==============================] - 0s 24ms/step - loss: 0.6877 - smape_loss: 7.6790e-07 - mae_denorm: 8.0625e-07 - val_loss: 1.3500 - val_smape_loss: 1.6145 - val_mae_denorm: 36297.0820
# Epoch 121/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6826 - smape_loss: 7.4952e-07 - mae_denorm: 7.8695e-07Tiempo on_epoch_end 2024-10-30 16:46:54
# 7/7 [==============================] - 0s 22ms/step - loss: 0.6875 - smape_loss: 7.6791e-07 - mae_denorm: 8.0626e-07 - val_loss: 1.3490 - val_smape_loss: 1.6145 - val_mae_denorm: 36418.5938
# Epoch 122/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6887 - smape_loss: 7.6694e-07 - mae_denorm: 8.0524e-07Tiempo on_epoch_end 2024-10-30 16:46:54
# 7/7 [==============================] - 0s 22ms/step - loss: 0.6871 - smape_loss: 7.6789e-07 - mae_denorm: 8.0624e-07 - val_loss: 1.3512 - val_smape_loss: 1.6148 - val_mae_denorm: 37043.5078
# Epoch 123/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6902 - smape_loss: 7.9659e-07 - mae_denorm: 8.3636e-07Tiempo on_epoch_end 2024-10-30 16:46:54
# 7/7 [==============================] - 0s 22ms/step - loss: 0.6869 - smape_loss: 7.6791e-07 - mae_denorm: 8.0626e-07 - val_loss: 1.3486 - val_smape_loss: 1.6148 - val_mae_denorm: 36866.1133
# Epoch 124/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6866 - smape_loss: 7.6628e-07 - mae_denorm: 8.0455e-07Tiempo on_epoch_end 2024-10-30 16:46:54
# 7/7 [==============================] - 0s 22ms/step - loss: 0.6865 - smape_loss: 7.6790e-07 - mae_denorm: 8.0624e-07 - val_loss: 1.3481 - val_smape_loss: 1.6147 - val_mae_denorm: 37030.8281
# Epoch 125/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6877 - smape_loss: 7.4908e-07 - mae_denorm: 7.8649e-07Tiempo on_epoch_end 2024-10-30 16:46:54
# 7/7 [==============================] - 0s 23ms/step - loss: 0.6862 - smape_loss: 7.6787e-07 - mae_denorm: 8.0621e-07 - val_loss: 1.3545 - val_smape_loss: 1.6157 - val_mae_denorm: 38578.0391
# Epoch 126/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6874 - smape_loss: 7.8001e-07 - mae_denorm: 8.1896e-07Tiempo on_epoch_end 2024-10-30 16:46:54
# 7/7 [==============================] - 0s 26ms/step - loss: 0.6859 - smape_loss: 7.6787e-07 - mae_denorm: 8.0622e-07 - val_loss: 1.3526 - val_smape_loss: 1.6156 - val_mae_denorm: 38459.0547
# Epoch 127/500
# 7/7 [==============================] - ETA: 0s - loss: 0.6856 - smape_loss: 7.6788e-07 - mae_denorm: 8.0623e-07Tiempo on_epoch_end 2024-10-30 16:46:55
# 7/7 [==============================] - 0s 30ms/step - loss: 0.6856 - smape_loss: 7.6788e-07 - mae_denorm: 8.0623e-07 - val_loss: 1.3484 - val_smape_loss: 1.6154 - val_mae_denorm: 37810.3711
# Epoch 128/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6879 - smape_loss: 7.6714e-07 - mae_denorm: 8.0545e-07Tiempo on_epoch_end 2024-10-30 16:46:55
# 7/7 [==============================] - 0s 26ms/step - loss: 0.6853 - smape_loss: 7.6788e-07 - mae_denorm: 8.0623e-07 - val_loss: 1.3547 - val_smape_loss: 1.6163 - val_mae_denorm: 39836.4141
# Epoch 129/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6876 - smape_loss: 7.5858e-07 - mae_denorm: 7.9646e-07Tiempo on_epoch_end 2024-10-30 16:46:55
# 7/7 [==============================] - 0s 27ms/step - loss: 0.6850 - smape_loss: 7.6787e-07 - mae_denorm: 8.0621e-07 - val_loss: 1.3554 - val_smape_loss: 1.6167 - val_mae_denorm: 40282.4844
# Epoch 130/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6845 - smape_loss: 7.4342e-07 - mae_denorm: 7.8055e-07Tiempo on_epoch_end 2024-10-30 16:46:55
# 7/7 [==============================] - 0s 26ms/step - loss: 0.6846 - smape_loss: 7.6788e-07 - mae_denorm: 8.0623e-07 - val_loss: 1.3528 - val_smape_loss: 1.6163 - val_mae_denorm: 39790.6992
# Epoch 131/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6852 - smape_loss: 7.3318e-07 - mae_denorm: 7.6980e-07Tiempo on_epoch_end 2024-10-30 16:46:55
# 7/7 [==============================] - 0s 34ms/step - loss: 0.6847 - smape_loss: 7.6786e-07 - mae_denorm: 8.0621e-07 - val_loss: 1.3536 - val_smape_loss: 1.6167 - val_mae_denorm: 40230.2773
# Epoch 132/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6863 - smape_loss: 7.7493e-07 - mae_denorm: 8.1363e-07Tiempo on_epoch_end 2024-10-30 16:46:56
# 7/7 [==============================] - 0s 35ms/step - loss: 0.6844 - smape_loss: 7.6786e-07 - mae_denorm: 8.0620e-07 - val_loss: 1.3501 - val_smape_loss: 1.6164 - val_mae_denorm: 39690.1250
# Epoch 133/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6849 - smape_loss: 7.3483e-07 - mae_denorm: 7.7153e-07Tiempo on_epoch_end 2024-10-30 16:46:56
# 7/7 [==============================] - 0s 32ms/step - loss: 0.6843 - smape_loss: 7.6788e-07 - mae_denorm: 8.0622e-07 - val_loss: 1.3509 - val_smape_loss: 1.6165 - val_mae_denorm: 39855.0898
# Epoch 134/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6823 - smape_loss: 7.5579e-07 - mae_denorm: 7.9354e-07Tiempo on_epoch_end 2024-10-30 16:46:56
# ...
# 7/7 [==============================] - 0s 38ms/step - loss: 0.6388 - smape_loss: 7.6629e-07 - mae_denorm: 8.0456e-07 - val_loss: 1.4234 - val_smape_loss: 1.6390 - val_mae_denorm: 72066.4297
# Epoch 457/500
# 7/7 [==============================] - ETA: 0s - loss: 0.6385 - smape_loss: 7.6634e-07 - mae_denorm: 8.0460e-07Tiempo on_epoch_end 2024-10-30 16:47:56
# 7/7 [==============================] - 0s 40ms/step - loss: 0.6385 - smape_loss: 7.6634e-07 - mae_denorm: 8.0460e-07 - val_loss: 1.4273 - val_smape_loss: 1.6397 - val_mae_denorm: 74263.6328
# Epoch 458/500
# 7/7 [==============================] - ETA: 0s - loss: 0.6396 - smape_loss: 7.6636e-07 - mae_denorm: 8.0463e-07Tiempo on_epoch_end 2024-10-30 16:47:56
# 7/7 [==============================] - 0s 32ms/step - loss: 0.6396 - smape_loss: 7.6636e-07 - mae_denorm: 8.0463e-07 - val_loss: 1.4300 - val_smape_loss: 1.6400 - val_mae_denorm: 75637.0078
# Epoch 459/500
# 4/7 [================>.............] - ETA: 0s - loss: 0.6435 - smape_loss: 7.8166e-07 - mae_denorm: 8.2070e-07Tiempo on_epoch_end 2024-10-30 16:47:56
# 7/7 [==============================] - 0s 24ms/step - loss: 0.6397 - smape_loss: 7.6628e-07 - mae_denorm: 8.0455e-07 - val_loss: 1.4332 - val_smape_loss: 1.6404 - val_mae_denorm: 77285.8906
# Epoch 460/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6391 - smape_loss: 7.3640e-07 - mae_denorm: 7.7317e-07Tiempo on_epoch_end 2024-10-30 16:47:56
# 7/7 [==============================] - 0s 23ms/step - loss: 0.6387 - smape_loss: 7.6626e-07 - mae_denorm: 8.0452e-07 - val_loss: 1.4258 - val_smape_loss: 1.6395 - val_mae_denorm: 72979.2188
# Epoch 461/500
# 4/7 [================>.............] - ETA: 0s - loss: 0.6356 - smape_loss: 7.8890e-07 - mae_denorm: 8.2830e-07Tiempo on_epoch_end 2024-10-30 16:47:57
# 7/7 [==============================] - 0s 24ms/step - loss: 0.6383 - smape_loss: 7.6625e-07 - mae_denorm: 8.0451e-07 - val_loss: 1.4296 - val_smape_loss: 1.6400 - val_mae_denorm: 74976.2500
# Epoch 462/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6354 - smape_loss: 7.7773e-07 - mae_denorm: 8.1657e-07Tiempo on_epoch_end 2024-10-30 16:47:57
# 7/7 [==============================] - 0s 23ms/step - loss: 0.6382 - smape_loss: 7.6629e-07 - mae_denorm: 8.0456e-07 - val_loss: 1.4262 - val_smape_loss: 1.6395 - val_mae_denorm: 73625.7344
# Epoch 463/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6373 - smape_loss: 8.1553e-07 - mae_denorm: 8.5625e-07Tiempo on_epoch_end 2024-10-30 16:47:57
# 7/7 [==============================] - 0s 23ms/step - loss: 0.6388 - smape_loss: 7.6628e-07 - mae_denorm: 8.0455e-07 - val_loss: 1.4287 - val_smape_loss: 1.6400 - val_mae_denorm: 74841.6406
# Epoch 464/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6373 - smape_loss: 7.4211e-07 - mae_denorm: 7.7917e-07Tiempo on_epoch_end 2024-10-30 16:47:57
# 7/7 [==============================] - 0s 22ms/step - loss: 0.6381 - smape_loss: 7.6625e-07 - mae_denorm: 8.0452e-07 - val_loss: 1.4252 - val_smape_loss: 1.6394 - val_mae_denorm: 73192.3828
# Epoch 465/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6395 - smape_loss: 7.6113e-07 - mae_denorm: 7.9914e-07Tiempo on_epoch_end 2024-10-30 16:47:57
# 7/7 [==============================] - 0s 23ms/step - loss: 0.6379 - smape_loss: 7.6623e-07 - mae_denorm: 8.0449e-07 - val_loss: 1.4289 - val_smape_loss: 1.6400 - val_mae_denorm: 75225.0156
# Epoch 466/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6381 - smape_loss: 7.9718e-07 - mae_denorm: 8.3698e-07Tiempo on_epoch_end 2024-10-30 16:47:57
# 7/7 [==============================] - 0s 23ms/step - loss: 0.6384 - smape_loss: 7.6622e-07 - mae_denorm: 8.0448e-07 - val_loss: 1.4311 - val_smape_loss: 1.6402 - val_mae_denorm: 76218.5000
# Epoch 467/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6374 - smape_loss: 7.7788e-07 - mae_denorm: 8.1672e-07Tiempo on_epoch_end 2024-10-30 16:47:58
# 7/7 [==============================] - 0s 25ms/step - loss: 0.6382 - smape_loss: 7.6624e-07 - mae_denorm: 8.0451e-07 - val_loss: 1.4208 - val_smape_loss: 1.6388 - val_mae_denorm: 71467.0156
# Epoch 468/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6392 - smape_loss: 7.9616e-07 - mae_denorm: 8.3592e-07Tiempo on_epoch_end 2024-10-30 16:47:58
# 7/7 [==============================] - 0s 23ms/step - loss: 0.6381 - smape_loss: 7.6623e-07 - mae_denorm: 8.0449e-07 - val_loss: 1.4285 - val_smape_loss: 1.6400 - val_mae_denorm: 74858.0625
# Epoch 469/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6409 - smape_loss: 8.0105e-07 - mae_denorm: 8.4105e-07Tiempo on_epoch_end 2024-10-30 16:47:58
# 7/7 [==============================] - 0s 23ms/step - loss: 0.6392 - smape_loss: 7.6627e-07 - mae_denorm: 8.0454e-07 - val_loss: 1.4366 - val_smape_loss: 1.6411 - val_mae_denorm: 78632.5625
# Epoch 470/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6383 - smape_loss: 7.5838e-07 - mae_denorm: 7.9625e-07Tiempo on_epoch_end 2024-10-30 16:47:58
# 7/7 [==============================] - 0s 22ms/step - loss: 0.6389 - smape_loss: 7.6628e-07 - mae_denorm: 8.0455e-07 - val_loss: 1.4270 - val_smape_loss: 1.6399 - val_mae_denorm: 74923.3906
# Epoch 471/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6365 - smape_loss: 7.5194e-07 - mae_denorm: 7.8949e-07Tiempo on_epoch_end 2024-10-30 16:47:58
# 7/7 [==============================] - 0s 22ms/step - loss: 0.6384 - smape_loss: 7.6626e-07 - mae_denorm: 8.0453e-07 - val_loss: 1.4243 - val_smape_loss: 1.6393 - val_mae_denorm: 73194.7188
# Epoch 472/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6411 - smape_loss: 7.4888e-07 - mae_denorm: 7.8627e-07Tiempo on_epoch_end 2024-10-30 16:47:58
# 7/7 [==============================] - 0s 22ms/step - loss: 0.6385 - smape_loss: 7.6626e-07 - mae_denorm: 8.0453e-07 - val_loss: 1.4314 - val_smape_loss: 1.6405 - val_mae_denorm: 77080.8281
# Epoch 473/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6395 - smape_loss: 7.7027e-07 - mae_denorm: 8.0873e-07Tiempo on_epoch_end 2024-10-30 16:47:59
# 7/7 [==============================] - 0s 24ms/step - loss: 0.6386 - smape_loss: 7.6624e-07 - mae_denorm: 8.0450e-07 - val_loss: 1.4265 - val_smape_loss: 1.6400 - val_mae_denorm: 74067.1250
# Epoch 474/500
# 4/7 [================>.............] - ETA: 0s - loss: 0.6384 - smape_loss: 7.6334e-07 - mae_denorm: 8.0146e-07Tiempo on_epoch_end 2024-10-30 16:47:59
# 7/7 [==============================] - 0s 24ms/step - loss: 0.6383 - smape_loss: 7.6627e-07 - mae_denorm: 8.0454e-07 - val_loss: 1.4269 - val_smape_loss: 1.6399 - val_mae_denorm: 74221.7891
# Epoch 475/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6392 - smape_loss: 7.5901e-07 - mae_denorm: 7.9692e-07Tiempo on_epoch_end 2024-10-30 16:47:59
# 7/7 [==============================] - 0s 22ms/step - loss: 0.6382 - smape_loss: 7.6624e-07 - mae_denorm: 8.0451e-07 - val_loss: 1.4232 - val_smape_loss: 1.6395 - val_mae_denorm: 72958.5000
# Epoch 476/500
# 4/7 [================>.............] - ETA: 0s - loss: 0.6341 - smape_loss: 7.3185e-07 - mae_denorm: 7.6840e-07Tiempo on_epoch_end 2024-10-30 16:47:59
# 7/7 [==============================] - 0s 26ms/step - loss: 0.6382 - smape_loss: 7.6619e-07 - mae_denorm: 8.0445e-07 - val_loss: 1.4280 - val_smape_loss: 1.6402 - val_mae_denorm: 75012.2031
# Epoch 477/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6376 - smape_loss: 7.9207e-07 - mae_denorm: 8.3162e-07Tiempo on_epoch_end 2024-10-30 16:47:59
# 7/7 [==============================] - 0s 22ms/step - loss: 0.6377 - smape_loss: 7.6622e-07 - mae_denorm: 8.0448e-07 - val_loss: 1.4218 - val_smape_loss: 1.6389 - val_mae_denorm: 71920.4531
# Epoch 478/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6361 - smape_loss: 8.0637e-07 - mae_denorm: 8.4664e-07Tiempo on_epoch_end 2024-10-30 16:47:59
# 7/7 [==============================] - 0s 22ms/step - loss: 0.6372 - smape_loss: 7.6614e-07 - mae_denorm: 8.0440e-07 - val_loss: 1.4228 - val_smape_loss: 1.6395 - val_mae_denorm: 72453.3672
# Epoch 479/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6363 - smape_loss: 7.6747e-07 - mae_denorm: 8.0580e-07Tiempo on_epoch_end 2024-10-30 16:48:00
# 7/7 [==============================] - 0s 23ms/step - loss: 0.6372 - smape_loss: 7.6611e-07 - mae_denorm: 8.0437e-07 - val_loss: 1.4253 - val_smape_loss: 1.6396 - val_mae_denorm: 73069.1641
# Epoch 480/500
# 4/7 [================>.............] - ETA: 0s - loss: 0.6377 - smape_loss: 7.9119e-07 - mae_denorm: 8.3070e-07Tiempo on_epoch_end 2024-10-30 16:48:00
# 7/7 [==============================] - 0s 24ms/step - loss: 0.6378 - smape_loss: 7.6621e-07 - mae_denorm: 8.0447e-07 - val_loss: 1.4188 - val_smape_loss: 1.6389 - val_mae_denorm: 70725.9375
# Epoch 481/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6408 - smape_loss: 7.4270e-07 - mae_denorm: 7.7979e-07Tiempo on_epoch_end 2024-10-30 16:48:00
# 7/7 [==============================] - 0s 22ms/step - loss: 0.6376 - smape_loss: 7.6613e-07 - mae_denorm: 8.0439e-07 - val_loss: 1.4207 - val_smape_loss: 1.6391 - val_mae_denorm: 71469.3203
# Epoch 482/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6382 - smape_loss: 7.4265e-07 - mae_denorm: 7.7973e-07Tiempo on_epoch_end 2024-10-30 16:48:00
# 7/7 [==============================] - 0s 23ms/step - loss: 0.6373 - smape_loss: 7.6617e-07 - mae_denorm: 8.0443e-07 - val_loss: 1.4334 - val_smape_loss: 1.6410 - val_mae_denorm: 77078.4766
# Epoch 483/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6374 - smape_loss: 7.6488e-07 - mae_denorm: 8.0308e-07Tiempo on_epoch_end 2024-10-30 16:48:00
# 7/7 [==============================] - 0s 22ms/step - loss: 0.6376 - smape_loss: 7.6616e-07 - mae_denorm: 8.0442e-07 - val_loss: 1.4162 - val_smape_loss: 1.6384 - val_mae_denorm: 69513.9531
# Epoch 484/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6415 - smape_loss: 7.2602e-07 - mae_denorm: 7.6228e-07Tiempo on_epoch_end 2024-10-30 16:48:00
# 7/7 [==============================] - 0s 23ms/step - loss: 0.6377 - smape_loss: 7.6614e-07 - mae_denorm: 8.0440e-07 - val_loss: 1.4245 - val_smape_loss: 1.6397 - val_mae_denorm: 73465.4531
# Epoch 485/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6365 - smape_loss: 8.0827e-07 - mae_denorm: 8.4863e-07Tiempo on_epoch_end 2024-10-30 16:48:00
# 7/7 [==============================] - 0s 23ms/step - loss: 0.6379 - smape_loss: 7.6625e-07 - mae_denorm: 8.0452e-07 - val_loss: 1.4302 - val_smape_loss: 1.6406 - val_mae_denorm: 76210.7656
# Epoch 486/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6372 - smape_loss: 7.6056e-07 - mae_denorm: 7.9854e-07Tiempo on_epoch_end 2024-10-30 16:48:01
# 7/7 [==============================] - 0s 25ms/step - loss: 0.6369 - smape_loss: 7.6608e-07 - mae_denorm: 8.0433e-07 - val_loss: 1.4264 - val_smape_loss: 1.6400 - val_mae_denorm: 74400.3359
# Epoch 487/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6380 - smape_loss: 7.9158e-07 - mae_denorm: 8.3111e-07Tiempo on_epoch_end 2024-10-30 16:48:01
# 7/7 [==============================] - 0s 22ms/step - loss: 0.6372 - smape_loss: 7.6610e-07 - mae_denorm: 8.0436e-07 - val_loss: 1.4261 - val_smape_loss: 1.6401 - val_mae_denorm: 73883.5938
# Epoch 488/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6390 - smape_loss: 7.9480e-07 - mae_denorm: 8.3449e-07Tiempo on_epoch_end 2024-10-30 16:48:01
# 7/7 [==============================] - 0s 22ms/step - loss: 0.6365 - smape_loss: 7.6610e-07 - mae_denorm: 8.0436e-07 - val_loss: 1.4245 - val_smape_loss: 1.6398 - val_mae_denorm: 73175.2500
# Epoch 489/500
# 4/7 [================>.............] - ETA: 0s - loss: 0.6390 - smape_loss: 7.6392e-07 - mae_denorm: 8.0207e-07Tiempo on_epoch_end 2024-10-30 16:48:01
# 7/7 [==============================] - 0s 25ms/step - loss: 0.6364 - smape_loss: 7.6609e-07 - mae_denorm: 8.0434e-07 - val_loss: 1.4198 - val_smape_loss: 1.6392 - val_mae_denorm: 70810.4844
# Epoch 490/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6324 - smape_loss: 8.2021e-07 - mae_denorm: 8.6117e-07Tiempo on_epoch_end 2024-10-30 16:48:01
# 7/7 [==============================] - 0s 23ms/step - loss: 0.6361 - smape_loss: 7.6606e-07 - mae_denorm: 8.0431e-07 - val_loss: 1.4194 - val_smape_loss: 1.6392 - val_mae_denorm: 70805.6797
# Epoch 491/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6375 - smape_loss: 7.5934e-07 - mae_denorm: 7.9725e-07Tiempo on_epoch_end 2024-10-30 16:48:01
# 7/7 [==============================] - 0s 23ms/step - loss: 0.6364 - smape_loss: 7.6607e-07 - mae_denorm: 8.0433e-07 - val_loss: 1.4257 - val_smape_loss: 1.6399 - val_mae_denorm: 73487.5391
# Epoch 492/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6366 - smape_loss: 7.6496e-07 - mae_denorm: 8.0316e-07Tiempo on_epoch_end 2024-10-30 16:48:02
# 7/7 [==============================] - 0s 25ms/step - loss: 0.6367 - smape_loss: 7.6613e-07 - mae_denorm: 8.0439e-07 - val_loss: 1.4223 - val_smape_loss: 1.6396 - val_mae_denorm: 72173.8594
# Epoch 493/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6383 - smape_loss: 7.9194e-07 - mae_denorm: 8.3148e-07Tiempo on_epoch_end 2024-10-30 16:48:02
# 7/7 [==============================] - 0s 22ms/step - loss: 0.6380 - smape_loss: 7.6619e-07 - mae_denorm: 8.0445e-07 - val_loss: 1.4253 - val_smape_loss: 1.6401 - val_mae_denorm: 74054.3750
# Epoch 494/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6370 - smape_loss: 7.6068e-07 - mae_denorm: 7.9866e-07Tiempo on_epoch_end 2024-10-30 16:48:02
# 7/7 [==============================] - 0s 23ms/step - loss: 0.6368 - smape_loss: 7.6606e-07 - mae_denorm: 8.0431e-07 - val_loss: 1.4211 - val_smape_loss: 1.6393 - val_mae_denorm: 71522.5391
# Epoch 495/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6359 - smape_loss: 7.6633e-07 - mae_denorm: 8.0460e-07Tiempo on_epoch_end 2024-10-30 16:48:02
# 7/7 [==============================] - 0s 23ms/step - loss: 0.6367 - smape_loss: 7.6612e-07 - mae_denorm: 8.0438e-07 - val_loss: 1.4177 - val_smape_loss: 1.6391 - val_mae_denorm: 70728.2734
# Epoch 496/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6357 - smape_loss: 7.6983e-07 - mae_denorm: 8.0828e-07Tiempo on_epoch_end 2024-10-30 16:48:02
# 7/7 [==============================] - 0s 22ms/step - loss: 0.6361 - smape_loss: 7.6604e-07 - mae_denorm: 8.0430e-07 - val_loss: 1.4182 - val_smape_loss: 1.6391 - val_mae_denorm: 70305.1953
# Epoch 497/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6321 - smape_loss: 7.9086e-07 - mae_denorm: 8.3036e-07Tiempo on_epoch_end 2024-10-30 16:48:02
# 7/7 [==============================] - 0s 22ms/step - loss: 0.6361 - smape_loss: 7.6609e-07 - mae_denorm: 8.0435e-07 - val_loss: 1.4212 - val_smape_loss: 1.6395 - val_mae_denorm: 71708.8750
# Epoch 498/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6354 - smape_loss: 7.7067e-07 - mae_denorm: 8.0916e-07Tiempo on_epoch_end 2024-10-30 16:48:03
# 7/7 [==============================] - 0s 31ms/step - loss: 0.6364 - smape_loss: 7.6606e-07 - mae_denorm: 8.0432e-07 - val_loss: 1.4223 - val_smape_loss: 1.6395 - val_mae_denorm: 71488.5938
# Epoch 499/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6400 - smape_loss: 7.6385e-07 - mae_denorm: 8.0199e-07Tiempo on_epoch_end 2024-10-30 16:48:03
# 7/7 [==============================] - 0s 23ms/step - loss: 0.6358 - smape_loss: 7.6607e-07 - mae_denorm: 8.0433e-07 - val_loss: 1.4236 - val_smape_loss: 1.6398 - val_mae_denorm: 72112.1562
# Epoch 500/500
# 5/7 [====================>.........] - ETA: 0s - loss: 0.6350 - smape_loss: 7.4313e-07 - mae_denorm: 7.8024e-07Tiempo on_epoch_end 2024-10-30 16:48:03
# 7/7 [==============================] - 0s 23ms/step - loss: 0.6357 - smape_loss: 7.6600e-07 - mae_denorm: 8.0426e-07 - val_loss: 1.4199 - val_smape_loss: 1.6393 - val_mae_denorm: 71069.3672
# Tiempo Final y n_past 2024-10-30 16:48:53   n_past:--> 60

# %%
from matplotlib import pyplot as plt
plt.plot(history_modelo.history['loss'])
plt.plot(history_modelo.history['val_loss'])
#plt.plot(history_modelo.history['val_smape_loss_zscore'])
plt.title('model accuracy')
plt.ylabel('loss')
plt.xlabel('epoch')
#plt.legend(['loss', 'val_loss','val_smape_loss_zscore'], loc='upper left')
plt.legend(['loss', 'val_loss'], loc='upper left')
plt.show()
best_score=min(history_modelo.history['val_loss'])
print('best_score',best_score)
#best_score_smape=min(history_modelo.history['val_smape_loss_zscore'])
#print('best_score smape',best_score_smape)
# Out:
# best_score 0.8226404190063477

# %%
from keras.utils import plot_model

fileplot=pathModelosJson
plot_model(reconstructed_model2, to_file=fileplot+'/model_plot.png', show_shapes=True, show_layer_names=True)

# %%
# %load_ext tensorboard

# %tensorboard --logdir "/content/drive/MyDrive/a Tesis de Grado/Tesis Versiones/tesis2023/Google Analytics 4/Tum Transmedia/modelos/modelos guardados/prueba1-30porciento/logs10divNday21DiasAtras"

# %%
from tensorflow.keras.saving import register_keras_serializable
media_train=train_previo_zscore['Número de vistas de página'].std()
std_train=train_previo_zscore['Número de vistas de página'].mean()
#esta metrica esta en el codigo de github del ganador
@register_keras_serializable()
def smape_loss(y_true, y_pred):
    #revierto zscore
    global media_train
    global std_train
    y_true=(y_true*std_train)+media_train
    y_pred=(y_pred*std_train)+media_train
    #revierto log1p
    y_true=tf.math.expm1(y_true)
    y_pred=tf.math.expm1(y_pred)
    epsilon = 0.1
    y_pred = tf.convert_to_tensor(y_pred)
    y_true = tf.cast(y_true, y_pred.dtype)
    # Calcular el denominador de SMAPE
    summ = tf.maximum(tf.abs(y_true) + tf.abs(y_pred) + epsilon, 0.5 + epsilon)

    # Calcular SMAPE
    smape = tf.abs(y_pred - y_true) / summ * 2.0

    # Retornar la media de SMAPE
    return K.mean(smape, axis=-1)

@register_keras_serializable()
def mae_denorm(y_true, y_pred):
    #revierto zscore
    global media_train
    global std_train
    y_true1=(y_true*std_train)+media_train
    y_pred1=(y_pred*std_train)+media_train
    #revierto log1p
    y_true2=tf.math.expm1(y_true1)
    y_pred2=tf.math.expm1(y_pred1)

    return tf.keras.losses.mean_absolute_error(y_true2, y_pred2)

# %%
#el mejor modelo de verdad
#pathModelosJsonMejor="/content/drive/MyDrive/a Tesis de Grado/Tesis Versiones/tesis 2024/UA/editorial universitaria/modelos/modelos resultados/mejores modelos guardados/modelo"
#nombreMejorModeloMejor="/ ndays Editorial 60hyperband mae 60 zscore.h5"#el mejor modelo es el hyperband de 28 dias y 107 época
pathModelosJsonMejor="/content/drive/MyDrive/a Tesis de Grado/Tesis Versiones/tesis 2024/UA/editorial universitaria/modelos/modelos resultados/prueba 500 epocas 1 capas sin early stopping Hyperband mejor modelo"
nombreMejorModeloMejor="/hyperband001-0.822640-ndays60_500epochs1capa.h5"
n_past=60
cambio=datetime.datetime.now(timezone('UTC')) - timedelta(hours=3)
tiempoFinal=f"{cambio:%Y-%m-%d %H:%M:%S }"
print('Tiempo  Inicio y n_past',tiempoFinal , ' n_past:-->',n_past)
n_future = 60
n_features = train.shape[1]
X_train, y_train = split_series(train.values,n_past, n_future)
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1],n_features))
y_train = y_train.reshape((y_train.shape[0], y_train.shape[1], 1)) #no hace falta reshapear
X_test, y_test = split_series(test.values,n_past, n_future)
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1],n_features))
y_test = y_test.reshape((y_test.shape[0], y_test.shape[1], 1)) #no hace falta reshapear

reconstructed_model3 = tf.keras.models.load_model(pathModelosJsonMejor+nombreMejorModeloMejor,custom_objects={'smape_loss':smape_loss,'mae_denorm':mae_denorm})
# Out:
# Tiempo  Inicio y n_past 2024-10-30 16:54:55   n_past:--> 60

# %%
print("Evaluate on test data")
results = reconstructed_model3.evaluate(X_test,y_test, batch_size=64)
print("test loss", results)
# Out:
# Evaluate on test data
# 4/4 [==============================] - 1s 8ms/step - loss: 0.8226 - smape_loss: 1.4725 - mae_denorm: 3602.3298
# test loss [0.8226404190063477, 1.4725149869918823, 3602.329833984375]

# %%
pred_e1d1=reconstructed_model3.predict(X_test)
pred_e1d1=deepcopy(pred_e1d1)
reshapePred=pred_e1d1.reshape((pred_e1d1.shape[0]*pred_e1d1.shape[2]),pred_e1d1.shape[1])
reshapeY_test=y_test.reshape((y_test.shape[0]*y_test.shape[2]),y_test.shape[1])
print(pred_e1d1.shape,reshapePred.shape)
print('y_test',y_test.shape,reshapeY_test.shape)
print(pred_e1d1)
# Out:
# 8/8 [==============================] - 1s 5ms/step
# (244, 60, 1) (244, 60)
# y_test (244, 60, 1) (244, 60)
# [[[ 0.24982011]
#   [ 0.27445424]
#   [ 0.27153257]
#   ...
#   [ 0.25423732]
#   [ 0.25423732]
#   [ 0.25423732]]
#
#  [[-0.06895716]
#   [-0.10482176]
#   [-0.12745173]
#   ...
#   [-0.14283869]
#   [-0.14283869]
#   [-0.14283869]]
#
#  [[ 0.0161228 ]
#   [-0.03743925]
#   [-0.05830623]
#   ...
#   [-0.04784582]
#   [-0.04784582]
#   [-0.04784582]]
#
#  ...
#
#  [[ 0.53763336]
#   [ 0.56881875]
#   [ 0.5522084 ]
#   ...
#   [ 0.5216614 ]
#   [ 0.5216614 ]
#   [ 0.5216614 ]]
#
#  [[ 0.38116255]
#   [ 0.45721915]
#   [ 0.4778111 ]
#   ...
#   [ 0.49201143]
#   [ 0.49201143]
#   [ 0.49201143]]
#
#  [[ 0.14533657]
#   [ 0.19184305]
#   [ 0.21075556]
#   ...
#   [ 0.22143736]
#   [ 0.22143736]
#   [ 0.22143736]]]

# %%
print('MEAN',train_previo_zscore['Número de vistas de página'].mean())
print('STD',train_previo_zscore['Número de vistas de página'].std())
# Out:
# MEAN 4.308087962814851
# STD 0.8649864124052458

# %%
pred_e1d1=reconstructed_model3.predict(X_test, batch_size=192)
pred_e1d1=deepcopy(pred_e1d1)
reshapePred=pred_e1d1.reshape((pred_e1d1.shape[0]*pred_e1d1.shape[2]),pred_e1d1.shape[1])
reshapeY_test=y_test.reshape((y_test.shape[0]*y_test.shape[2]),y_test.shape[1])
print(pred_e1d1.shape,reshapePred.shape)
print('y_test',y_test.shape,reshapeY_test.shape)
def smape2(a, f):
    print('len(a)',len(a))

    #std=train_previo_zscore['Predictor Flag'].std()
    #media=train_previo_zscore['Predictor Flag'].mean()
    std=train_previo_zscore['Número de vistas de página'].std()
    media=train_previo_zscore['Número de vistas de página'].mean()
    #revierto zscore
    a=(a*std)+media
    f=(f*std)+media

    a=np.round(np.expm1(a))
    f=np.round(np.expm1(f))
    print('a',a)
    print('f',f)
    return (1/len(a) * np.sum(2 * np.abs(f-a) / (np.abs(a) + np.abs(f))) )

def mae_manual(a, f):
    print('len(a)', len(a))

    # Obtener la desviación estándar y media
    std = train_previo_zscore['Número de vistas de página'].std()
    media = train_previo_zscore['Número de vistas de página'].mean()

    # Revertir z-score
    a = (a * std) + media
    f = (f * std) + media

    a=np.round(np.expm1(a))
    f=np.round(np.expm1(f))
    print('a mae',a)
    print('f mae',f)

    epsilon = 0.1  # Valor para evitar divisiones por cero
    diff =np.abs(a-f)
    return np.mean(diff)#(1 / len(a)) * np.sum(diff)

def rmse_manual(a, f):
    print('len(a)', len(a))

    # Obtener la desviación estándar y media
    std = train_previo_zscore['Número de vistas de página'].std()
    media = train_previo_zscore['Número de vistas de página'].mean()

    # Revertir z-score
    a = (a * std) + media
    f = (f * std) + media

    a=np.round(np.expm1(a))
    f=np.round(np.expm1(f))

    # Calcular el RMSE (Error Cuadrático Medio)
    diff = np.square(a - f)  # Cuadrado de la diferencia
    mse = np.mean(diff)  # Error Cuadrático Medio
    rmse_calculado = np.sqrt(mse)  # Raíz cuadrada del MSE

    return rmse_calculado

auxpred=reshapePred.reshape((y_test.shape[0]*y_test.shape[1]),1)
auxpred2=auxpred.reshape((auxpred.shape[0]),)
auxY_test=reshapeY_test.reshape((y_test.shape[0]*y_test.shape[1]),1)
print(auxpred.shape)
print('smape',smape2(auxY_test,auxpred))
print('mae',mae_manual(auxY_test,auxpred))
print('rmse',rmse_manual(auxY_test,auxpred))
print(auxpred2.shape)
print(np.array([1,2,3]).shape)
print(auxpred2)
# Out:
# 244/244 [==============================] - 2s 6ms/step
# (244, 60, 1) (244, 60)
# y_test (244, 60, 1) (244, 60)
# (14640, 1)
# len(a) 14640
# a [[ 28.]
#  [ 54.]
#  [157.]
#  ...
#  [ 88.]
#  [103.]
#  [148.]]
# f [[91.]
#  [93.]
#  [93.]
#  ...
#  [89.]
#  [89.]
#  [89.]]
# smape 0.6400025149091376
# len(a) 14640
# a mae [[ 28.]
#  [ 54.]
#  [157.]
#  ...
#  [ 88.]
#  [103.]
#  [148.]]
# f mae [[91.]
#  [93.]
#  [93.]
#  ...
#  [89.]
#  [89.]
#  [89.]]
# mae 85.34890710382514
# len(a) 14640
# rmse 130.67067958318822
# (14640,)
# (3,)
# [0.24982014 0.27445427 0.27153262 ... 0.22143723 0.22143723 0.22143723]

# %%
test_previo_log1p['Número de vistas de página']
X_test5, y_test5 = split_series(test_previo_log1p.values,n_past, n_future)
y_test5
# Out:
# array([[ 28.,  54., 157., ...,  17.,  58.,  61.],
#        [ 54., 157., 265., ...,  58.,  61.,  58.],
#        [157., 265., 202., ...,  61.,  58.,  28.],
#        ...,
#        [ 80.,  63.,  82., ...,  46.,  58.,  88.],
#        [ 63.,  82., 188., ...,  58.,  88., 103.],
#        [ 82., 188., 202., ...,  88., 103., 148.]])

# %%
y_test5.shape
# Out:
# (244, 60)

# %%
auxY_test.shape
# Out:
# (14640, 1)

# %%
# Obtener la desviación estándar y media
import matplotlib.pyplot as plt
std = train_previo_zscore['Número de vistas de página'].std()
media = train_previo_zscore['Número de vistas de página'].mean()

# Revertir z-score
#denorm_actually=(auxY_test*std)+media
#denorm_forecast=(auxpred*std)+media

#denorm_actually = np.array(denorm_actually)
#denorm_forecast = np.array(denorm_forecast)
def denorm_manual(a, f):
    print('len(a)', len(a))

    # Obtener la desviación estándar y media
    std = train_previo_zscore['Número de vistas de página'].std()
    media = train_previo_zscore['Número de vistas de página'].mean()

    # Revertir z-score
    a = (a * std) + media
    f = (f * std) + media

    a=np.round(np.expm1(a))
    f=np.round(np.expm1(f))

    return a,f
denorm_actually,denorm_forecast=  denorm_manual(auxY_test,auxpred)
# Crear un rango de índices para el eje x
x = np.arange(len(denorm_actually))

# Crear el plot
plt.figure(figsize=(10, 6))
#ultimos 60
plt.plot( denorm_actually[:60], label='Valores de Reales', color='blue')
plt.plot( denorm_forecast[:60], label='Valores de Pronosticados', color='orange')
#primeros 60
#plt.plot(np.arange(len(denorm_actually[:90])) ,denorm_actually[:90], label='Valores de Reales', color='blue')
#plt.plot(np.arange(len(denorm_actually[:90])) ,denorm_forecast[:90], label='Valores de Pronosticados', color='orange')
print(denorm_actually[:1])
plt.title('Comparación de valores de Actuales y Predichos')
plt.xlabel('-')
plt.ylabel('Vistas')
plt.legend()
plt.grid()
plt.show()
# Out:
# len(a) 14640
# [[28.]]

# %%
mae_manual(auxY_test[:60],auxpred[:60])
# Out:
# len(a) 60
# a mae [[ 28.]
#  [ 54.]
#  [157.]
#  [265.]
#  [202.]
#  [ 23.]
#  [ 24.]
#  [ 15.]
#  [ 41.]
#  [386.]
#  [106.]
#  [ 57.]
#  [ 40.]
#  [107.]
#  [ 31.]
#  [ 11.]
#  [112.]
#  [ 80.]
#  [121.]
#  [ 37.]
#  [ 19.]
#  [  6.]
#  [ 29.]
#  [ 60.]
#  [ 19.]
#  [152.]
#  [161.]
#  [ 28.]
#  [ 84.]
#  [ 18.]
#  [ 38.]
#  [ 37.]
#  [ 43.]
#  [ 35.]
#  [ 32.]
#  [ 52.]
#  [ 14.]
#  [ 50.]
#  [ 34.]
#  [ 33.]
#  [ 24.]
#  [ 33.]
#  [ 15.]
#  [ 13.]
#  [ 24.]
#  [ 42.]
#  [ 25.]
#  [ 45.]
#  [ 28.]
#  [ 26.]
#  [ 49.]
#  [ 40.]
#  [ 26.]
#  [ 28.]
#  [ 47.]
#  [ 76.]
#  [ 17.]
#  [ 17.]
#  [ 58.]
#  [ 61.]]
# f mae [[91.]
#  [93.]
#  [93.]
#  [92.]
#  [92.]
#  [92.]
#  [92.]
#  [92.]
#  [92.]
#  [92.]
#  [92.]
#  [92.]
#  [92.]
#  [92.]
#  [92.]
#  [92.]
#  [92.]
#  [92.]
#  [92.]
#  [92.]
#  [92.]
#  [92.]
#  [92.]
#  [92.]
#  [92.]
#  [92.]
#  [92.]
#  [92.]
#  [92.]
#  [92.]
#  [92.]
#  [92.]
#  [92.]
#  [92.]
#  [92.]
#  [92.]
#  [92.]
#  [92.]
#  [92.]
#  [92.]
#  [92.]
#  [92.]
#  [92.]
#  [92.]
#  [92.]
#  [92.]
#  [92.]
#  [92.]
#  [92.]
#  [92.]
#  [92.]
#  [92.]
#  [92.]
#  [92.]
#  [92.]
#  [92.]
#  [92.]
#  [92.]
#  [92.]
#  [92.]]
# 61.36666666666667

# %%
plt.plot(test_previo_log1p['Número de vistas de página'][60:120])
