# %%
# !pip install keras-tuner==1.4.7
# !pip install pandas==2.1.4
# !pip install numpy==1.26.4
# !pip install tensorflow==2.15.0
# Out:
# Collecting keras-tuner==1.4.7
#   Downloading keras_tuner-1.4.7-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (from keras-tuner==1.4.7) (3.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras-tuner==1.4.7) (24.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from keras-tuner==1.4.7) (2.32.3)
# Collecting kt-legacy (from keras-tuner==1.4.7)
#   Downloading kt_legacy-1.0.5-py3-none-any.whl.metadata (221 bytes)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras->keras-tuner==1.4.7) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras->keras-tuner==1.4.7) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras->keras-tuner==1.4.7) (13.9.3)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras->keras-tuner==1.4.7) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras->keras-tuner==1.4.7) (3.11.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras->keras-tuner==1.4.7) (0.13.0)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.10/dist-packages (from keras->keras-tuner==1.4.7) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner==1.4.7) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner==1.4.7) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner==1.4.7) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner==1.4.7) (2024.8.30)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from optree->keras->keras-tuner==1.4.7) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras->keras-tuner==1.4.7) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras->keras-tuner==1.4.7) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras->keras-tuner==1.4.7) (0.1.2)
# Downloading keras_tuner-1.4.7-py3-none-any.whl (129 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.1/129.1 kB 9.6 MB/s eta 0:00:00
# Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Installing collected packages: kt-legacy, keras-tuner
# Successfully installed keras-tuner-1.4.7 kt-legacy-1.0.5
# Collecting pandas==2.1.4
#   Downloading pandas-2.1.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas==2.1.4) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas==2.1.4) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas==2.1.4) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas==2.1.4) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas==2.1.4) (1.16.0)
# Downloading pandas-2.1.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 53.1 MB/s eta 0:00:00
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.1.4 which is incompatible.
# Successfully installed pandas-2.1.4
# Requirement already satisfied: numpy==1.26.4 in /usr/local/lib/python3.10/dist-packages (1.26.4)
# Collecting tensorflow==2.15.0
#   Downloading tensorflow-2.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.4 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (18.1.1)
# Collecting ml-dtypes~=0.2.0 (from tensorflow==2.15.0)
#   Downloading ml_dtypes-0.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (1.26.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (4.12.2)
# Collecting wrapt<1.15,>=1.11.0 (from tensorflow==2.15.0)
#   Downloading wrapt-1.14.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (0.37.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (1.64.1)
# Collecting tensorboard<2.16,>=2.15 (from tensorflow==2.15.0)
#   Downloading tensorboard-2.15.2-py3-none-any.whl.metadata (1.7 kB)
# Collecting tensorflow-estimator<2.16,>=2.15.0 (from tensorflow==2.15.0)
#   Downloading tensorflow_estimator-2.15.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting keras<2.16,>=2.15.0 (from tensorflow==2.15.0)
#   Downloading keras-2.15.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow==2.15.0) (0.44.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (1.2.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.7)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.0.4)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.0.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.2.2)
# Downloading tensorflow-2.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (475.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 475.2/475.2 MB 3.5 MB/s eta 0:00:00
# Downloading keras-2.15.0-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 53.0 MB/s eta 0:00:00
# Downloading ml_dtypes-0.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 48.2 MB/s eta 0:00:00
# Downloading tensorboard-2.15.2-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 83.6 MB/s eta 0:00:00
# Downloading tensorflow_estimator-2.15.0-py2.py3-none-any.whl (441 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.0/442.0 kB 33.4 MB/s eta 0:00:00
# Downloading wrapt-1.14.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 7.7 MB/s eta 0:00:00
# Installing collected packages: wrapt, tensorflow-estimator, ml-dtypes, keras, tensorboard, tensorflow
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.16.0
#     Uninstalling wrapt-1.16.0:
#       Successfully uninstalled wrapt-1.16.0
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml-dtypes 0.4.1
#     Uninstalling ml-dtypes-0.4.1:
#       Successfully uninstalled ml-dtypes-0.4.1
#   Attempting uninstall: keras
#     Found existing installation: keras 3.4.1
#     Uninstalling keras-3.4.1:
#       Successfully uninstalled keras-3.4.1
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.17.0
#     Uninstalling tensorboard-2.17.0:
#       Successfully uninstalled tensorboard-2.17.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.17.0
#     Uninstalling tensorflow-2.17.0:
#       Successfully uninstalled tensorflow-2.17.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorstore 0.1.66 requires ml-dtypes>=0.3.1, but you have ml-dtypes 0.2.0 which is incompatible.
# tf-keras 2.17.0 requires tensorflow<2.18,>=2.17, but you have tensorflow 2.15.0 which is incompatible.
# Successfully installed keras-2.15.0 ml-dtypes-0.2.0 tensorboard-2.15.2 tensorflow-2.15.0 tensorflow-estimator-2.15.0 wrapt-1.14.1

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras #desde tensorflow 2 se importa keras,  como paquete integrado de tensorflow
import pandas as pd
import numpy as np
from math import sqrt
from numpy import concatenate
from matplotlib import pyplot
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM, GRU
import tensorflow as tf
from datetime import datetime
from keras.models import Sequential
from keras.layers import Dense,Flatten,LSTM,RepeatVector,TimeDistributed#, GRUCellV2
from copy import deepcopy

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Reading the data set, parsing the dates and inferring the date format to date time. We also fill the Nan’s with 0.
#agrego index_col=0 para solucionar Unnamed: 0 porque https://stackoverflow.com/questions/43983622/remove-unnamed-columns-in-pandas-dataframe
dataset = read_csv("/content/drive/MyDrive/a Tesis de Grado/Tesis Versiones/tesis 2024/UA/editorial universitaria/preprocesamiento/outlier/salidaCSV/salidaKNN2024EditorialUniversitariaOctubre.csv", index_col=0)
#dataset.fillna(0, inplace=True)//pasar nans a ceros
#revisar lo que hago en el otro dataset
print(dataset.size)
print(dataset.columns)

print(dataset.shape)
print(dataset)
dataset.head()
# Out:
# 67044
# Index(['Número de vistas de página', 'Usuarios nuevos', 'Usuarios',
#        'Número de sesiones por usuario', 'Sesiones', 'Argentina',
#        'Otros Paises', 'mobile', 'desktop', 'tablet',
#        'Categoría de dispositivo promedio', 'Categoría de dispositivo std',
#        'Windows', 'Android', 'Linux', 'Macintosh',
#        'Sistema operativo (not set)', 'iOS', 'Windows Phone', 'Chrome OS',
#        'Tizen', 'Sistema operativo promedio', 'Sistema operativo std',
#        'Organic Search', 'Social', 'Direct', 'Referral',
#        'Agrupación de canales predeterminada promedio',
#        'Agrupación de canales predeterminada std', 'mediana_de_medianas',
#        'lag_90', 'lag_180', 'lag_270', 'lag_360', 'mediana Dispositivos',
#        'mediana Sistema operativo',
#        'mediana Agrupación de canales predeterminada'],
#       dtype='object')
# (1812, 37)
#       Número de vistas de página  Usuarios nuevos  Usuarios  \
# 0                          541.0             22.0      22.0
# 1                          226.0             23.0      26.0
# 2                          136.0             18.0      24.0
# 3                          229.0             11.0      16.0
# 4                           60.0             10.0      13.0
# ...                          ...              ...       ...
# 1810                        46.0             32.0      39.0
# 1811                        58.0             30.0      35.0
# 1812                        88.0             40.0      48.0
# 1813                       103.0             44.0      58.0
# 1814                       148.0             61.0      73.0
#
#       Número de sesiones por usuario  Sesiones  Argentina  Otros Paises  \
# 0                           1.636364      36.0      540.0           1.0
# 1                           1.346154      35.0      212.0          14.0
# 2                           1.458333      35.0      133.0           3.0
# 3                           1.812500      29.0      224.0           5.0
# 4                           1.461538      19.0       56.0           4.0
# ...                              ...       ...        ...           ...
# 1810                        1.102564      43.0       27.0          19.0
# 1811                        1.028571      36.0       42.0          16.0
# 1812                        1.104167      53.0       65.0          23.0
# 1813                        1.137931      66.0       87.0          16.0
# 1814                        1.123288      82.0      137.0          11.0
#
#       mobile  desktop  tablet  ...  \
# 0       49.0    492.0     0.0  ...
# 1        8.0    211.0     7.0  ...
# 2       17.0    119.0     0.0  ...
# 3       14.0    215.0     0.0  ...
# 4       20.0     40.0     0.0  ...
# ...      ...      ...     ...  ...
# 1810    21.0     25.0     0.0  ...
# 1811    22.0     36.0     0.0  ...
# 1812    40.0     48.0     0.0  ...
# 1813    29.0     74.0     0.0  ...
# 1814    36.0    111.0     1.0  ...
#
#       Agrupación de canales predeterminada promedio  \
# 0                                            135.25
# 1                                             56.50
# 2                                             34.00
# 3                                             57.25
# 4                                             15.00
# ...                                             ...
# 1810                                          11.50
# 1811                                          14.50
# 1812                                          22.00
# 1813                                          25.75
# 1814                                          37.00
#
#       Agrupación de canales predeterminada std  mediana_de_medianas    lag_90  \
# 0                                   202.460340            89.697167  104.5151
# 1                                    84.049095            89.697167  104.5151
# 2                                    39.344630            89.697167  104.5151
# 3                                    94.035570            89.697167  104.5151
# 4                                     9.433981            89.697167  104.5151
# ...                                        ...                  ...       ...
# 1810                                  9.912114           132.000000   46.0000
# 1811                                 17.471405           132.000000  126.0000
# 1812                                 19.836834           127.000000  171.0000
# 1813                                 26.938587           123.000000  104.0000
# 1814                                 35.881752           127.000000  111.0000
#
#          lag_180   lag_270   lag_360  mediana Dispositivos  \
# 0     100.866425  99.52464  100.1708                  49.0
# 1     100.866425  99.52464  100.1708                   8.0
# 2     100.866425  99.52464  100.1708                  17.0
# 3     100.866425  99.52464  100.1708                  14.0
# 4     100.866425  99.52464  100.1708                  20.0
# ...          ...       ...       ...                   ...
# 1810  225.000000  84.00000  251.0000                  21.0
# 1811  214.000000  18.00000  176.0000                  22.0
# 1812  283.000000  38.00000   91.0000                  40.0
# 1813   89.000000  37.00000   54.0000                  29.0
# 1814   52.000000  43.00000   31.0000                  36.0
#
#       mediana Sistema operativo  mediana Agrupación de canales predeterminada
# 0                           1.0                                          28.0
# 1                           0.0                                          12.5
# 2                           0.0                                          20.0
# 3                           0.0                                           4.5
# 4                           0.0                                          18.0
# ...                         ...                                           ...
# 1810                        2.0                                           9.5
# 1811                        0.0                                           6.5
# 1812                        1.0                                          18.5
# 1813                        0.0                                          16.0
# 1814                        1.0                                          22.0
#
# [1812 rows x 37 columns]
#    Número de vistas de página  Usuarios nuevos  Usuarios  \
# 0                       541.0             22.0      22.0
# 1                       226.0             23.0      26.0
# 2                       136.0             18.0      24.0
# 3                       229.0             11.0      16.0
# 4                        60.0             10.0      13.0
#
#    Número de sesiones por usuario  Sesiones  Argentina  Otros Paises  mobile  \
# 0                        1.636364      36.0      540.0           1.0    49.0
# 1                        1.346154      35.0      212.0          14.0     8.0
# 2                        1.458333      35.0      133.0           3.0    17.0
# 3                        1.812500      29.0      224.0           5.0    14.0
# 4                        1.461538      19.0       56.0           4.0    20.0
#
#    desktop  tablet  ...  Agrupación de canales predeterminada promedio  \
# 0    492.0     0.0  ...                                         135.25
# 1    211.0     7.0  ...                                          56.50
# 2    119.0     0.0  ...                                          34.00
# 3    215.0     0.0  ...                                          57.25
# 4     40.0     0.0  ...                                          15.00
#
#    Agrupación de canales predeterminada std  mediana_de_medianas    lag_90  \
# 0                                202.460340            89.697167  104.5151
# 1                                 84.049095            89.697167  104.5151
# 2                                 39.344630            89.697167  104.5151
# 3                                 94.035570            89.697167  104.5151
# 4                                  9.433981            89.697167  104.5151
#
#       lag_180   lag_270   lag_360  mediana Dispositivos  \
# 0  100.866425  99.52464  100.1708                  49.0
# 1  100.866425  99.52464  100.1708                   8.0
# 2  100.866425  99.52464  100.1708                  17.0
# 3  100.866425  99.52464  100.1708                  14.0
# 4  100.866425  99.52464  100.1708                  20.0
#
#    mediana Sistema operativo  mediana Agrupación de canales predeterminada
# 0                        1.0                                          28.0
# 1                        0.0                                          12.5
# 2                        0.0                                          20.0
# 3                        0.0                                           4.5
# 4                        0.0                                          18.0
#
# [5 rows x 37 columns]

# %%
print(dataset.columns)
print(dataset.shape)
print(dataset.head())
# Out:
# Index(['Número de vistas de página', 'Usuarios nuevos', 'Usuarios',
#        'Número de sesiones por usuario', 'Sesiones', 'Argentina',
#        'Otros Paises', 'mobile', 'desktop', 'tablet',
#        'Categoría de dispositivo promedio', 'Categoría de dispositivo std',
#        'Windows', 'Android', 'Linux', 'Macintosh',
#        'Sistema operativo (not set)', 'iOS', 'Windows Phone', 'Chrome OS',
#        'Tizen', 'Sistema operativo promedio', 'Sistema operativo std',
#        'Organic Search', 'Social', 'Direct', 'Referral',
#        'Agrupación de canales predeterminada promedio',
#        'Agrupación de canales predeterminada std', 'mediana_de_medianas',
#        'lag_90', 'lag_180', 'lag_270', 'lag_360', 'mediana Dispositivos',
#        'mediana Sistema operativo',
#        'mediana Agrupación de canales predeterminada'],
#       dtype='object')
# (1812, 37)
#    Número de vistas de página  Usuarios nuevos  Usuarios  \
# 0                       541.0             22.0      22.0
# 1                       226.0             23.0      26.0
# 2                       136.0             18.0      24.0
# 3                       229.0             11.0      16.0
# 4                        60.0             10.0      13.0
#
#    Número de sesiones por usuario  Sesiones  Argentina  Otros Paises  mobile  \
# 0                        1.636364      36.0      540.0           1.0    49.0
# 1                        1.346154      35.0      212.0          14.0     8.0
# 2                        1.458333      35.0      133.0           3.0    17.0
# 3                        1.812500      29.0      224.0           5.0    14.0
# 4                        1.461538      19.0       56.0           4.0    20.0
#
#    desktop  tablet  ...  Agrupación de canales predeterminada promedio  \
# 0    492.0     0.0  ...                                         135.25
# 1    211.0     7.0  ...                                          56.50
# 2    119.0     0.0  ...                                          34.00
# 3    215.0     0.0  ...                                          57.25
# 4     40.0     0.0  ...                                          15.00
#
#    Agrupación de canales predeterminada std  mediana_de_medianas    lag_90  \
# 0                                202.460340            89.697167  104.5151
# 1                                 84.049095            89.697167  104.5151
# 2                                 39.344630            89.697167  104.5151
# 3                                 94.035570            89.697167  104.5151
# 4                                  9.433981            89.697167  104.5151
#
#       lag_180   lag_270   lag_360  mediana Dispositivos  \
# 0  100.866425  99.52464  100.1708                  49.0
# 1  100.866425  99.52464  100.1708                   8.0
# 2  100.866425  99.52464  100.1708                  17.0
# 3  100.866425  99.52464  100.1708                  14.0
# 4  100.866425  99.52464  100.1708                  20.0
#
#    mediana Sistema operativo  mediana Agrupación de canales predeterminada
# 0                        1.0                                          28.0
# 1                        0.0                                          12.5
# 2                        0.0                                          20.0
# 3                        0.0                                           4.5
# 4                        0.0                                          18.0
#
# [5 rows x 37 columns]

# %%
#predictor Flag
from copy import deepcopy
from datetime import datetime as dt

# %%
#-Habia algo aca en el preprocesamiento anterior

# %%
#115*0.75 = 86.25=86
#train_df,test_df = dataset[1:86], dataset[86:]
# parrtir en 80 - 20 segun la profe
# probar sin normalizar los datos, es decir sin escalarlos
#normalizar
#partir datos de entrenamiento y prueba
#dataset.shape[0]=1734 o es 115 en caso del ejemplo
print('dataset.shape[0]',dataset.shape[0],' dataset.shape[1]',dataset.shape[1])
formaFinal=int(dataset.shape[0]*0.80)#80% para train y 20% para test
print(formaFinal)
train_df,test_df = dataset[1:formaFinal], dataset[formaFinal:] #spliteo test/train
train = train_df
test = test_df
# Normalización del conjunto de entrenamiento
train_previo_log1p=deepcopy(train)
for column in train.columns:
    train.loc[:, column] = np.log1p(train[column])
train_previo_zscore = deepcopy(train)
for column in train.columns:
    mean = train[column].mean()  # Media del conjunto de entrenamiento
    std = train[column].std()    # Desviación estándar del conjunto de entrenamiento
    train[column] = (train[column] - mean) / std
    if std != 0:
        train[column] = (train[column] - mean) / std
    else:
        train[column] = 0
test_previo_log1p=deepcopy(test)
for column1 in test.columns:
    test.loc[:, column1] = np.log1p(test[column1])
# Normalización del conjunto de prueba
test_previo_zscore = deepcopy(test)
for column1 in test.columns:
    mean_train = train_previo_zscore[column1].mean()  # Media del conjunto de entrenamiento
    std_train = train_previo_zscore[column1].std()    # Desviación estándar del conjunto de entrenamiento
    if std_train != 0:
        test[column1] = (test[column1] - mean_train) / std_train
    else:
        test[column1] = 0  

print('train_df',train_df.shape)
print('test_df',test_df.shape)
print('test',test.shape,test.values[11])
# Out:
# dataset.shape[0] 1812  dataset.shape[1] 37
# 1449
# train_df (1448, 37)
# test_df (363, 37)
# test (363, 37) [ 0.28415351  1.1688435   1.02416001 -0.13314932  0.98638305  0.29219525
#   0.55355397  0.63233177  0.17913578 -0.31654803  0.27608745  0.03695034
#   0.24148466  0.61676554 -0.57537463  0.14709346 -0.26314637  0.7923334
#  -0.07800006 -0.13480537  0.          0.24945006  0.16704669  0.21340899
#   1.19930762  0.4991939   0.30510696  0.27205578  0.02022211  0.73229229
#  -0.46937797 -0.16210613 -0.62924135  0.51988287  0.75262886 -0.42932858
#   0.57881099]
# <ipython-input-8-f3b70a0d6653>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train[column] = (train[column] - mean) / std
# <ipython-input-8-f3b70a0d6653>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train[column] = (train[column] - mean) / std
# <ipython-input-8-f3b70a0d6653>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train[column] = 0
# <ipython-input-8-f3b70a0d6653>:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[column1] = (test[column1] - mean_train) / std_train
# <ipython-input-8-f3b70a0d6653>:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[column1] = 0  # O algún otro valor neutral que prefieras

# %%
#reshape a entrada

def split_series(series, n_past, n_future):
  #
  # n_past ==> no of past observations
  #
  # n_future ==> no of future observations
  #
  X, y = list(), list()
  for window_start in range(len(series)):
    past_end = window_start + n_past
    future_end = past_end + n_future
    if future_end > len(series):
      break
    # slicing the past and future parts of the window
    #past, future = series[window_start:past_end, :], series[past_end:future_end, :]
    #window_start cuando comienza  past_end es cuando termina y future_endes cuando termina las series a comparar, 0 es porque solo va a tomar la primera columna
    #la cual es la de total de vistas
    past, future = series[window_start:past_end, :], series[past_end:future_end, 0]
    X.append(past)
    y.append(future)
  return np.array(X), np.array(y)
# Out:
# "\nn_past = 50 #va a mirar 10 dias al pasado para predecir x dias a futuro\nn_future = 7 #anterior 5 #probar 7 dias a futuro\nn_features = dataset.shape[1] # Columnas totales del dataset\n\n#Now convert both the train and test data into samples using the split_series function.\n\nX_train, y_train = split_series(train.values,n_past, n_future)\nX_train = X_train.reshape((X_train.shape[0], X_train.shape[1],n_features))\n#y_train = y_train.reshape((y_train.shape[0], y_train.shape[1], n_features))\ny_train = y_train.reshape((y_train.shape[0], y_train.shape[1], 1)) #no hace falta reshapear\nX_test, y_test = split_series(test.values,n_past, n_future)\nX_test = X_test.reshape((X_test.shape[0], X_test.shape[1],n_features))\n#y_test = y_test.reshape((y_test.shape[0], y_test.shape[1], n_features))\ny_test = y_test.reshape((y_test.shape[0], y_test.shape[1], 1)) #no hace falta reshapear\nprint('X_train',X_train.shape,X_train)\nprint('y_train',y_train.shape,y_train)\nprint('X_test',X_test.shape,X_test)\nprint('y_test',y_test.shape,y_test)\n"

# %%
# !pip install keras-tuner -q

# %%
# !df -h
# Out:
# Filesystem      Size  Used Avail Use% Mounted on
# overlay         236G   35G  202G  15% /
# tmpfs            64M     0   64M   0% /dev
# shm             5.7G     0  5.7G   0% /dev/shm
# /dev/root       2.0G  1.2G  820M  59% /usr/sbin/docker-init
# tmpfs           6.4G  584K  6.4G   1% /var/colab
# /dev/sda1       242G   59G  184G  25% /kaggle/input
# tmpfs           6.4G     0  6.4G   0% /proc/acpi
# tmpfs           6.4G     0  6.4G   0% /proc/scsi
# tmpfs           6.4G     0  6.4G   0% /sys/firmware
# drive           100G   58G   43G  58% /content/drive

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 85
# model name	: Intel(R) Xeon(R) CPU @ 2.00GHz
# stepping	: 3
# microcode	: 0xffffffff
# cpu MHz		: 2000.134
# cache size	: 39424 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa mmio_stale_data retbleed bhi
# bogomips	: 4000.26
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 1
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 85
# model name	: Intel(R) Xeon(R) CPU @ 2.00GHz
# stepping	: 3
# microcode	: 0xffffffff
# cpu MHz		: 2000.134
# cache size	: 39424 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 1
# initial apicid	: 1
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa mmio_stale_data retbleed bhi
# bogomips	: 4000.26
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:

# %%
# !cat /proc/meminfo
# Out:
# MemTotal:       13290460 kB
# MemFree:         1290876 kB
# MemAvailable:   11486052 kB
# Buffers:          536576 kB
# Cached:          9573500 kB
# SwapCached:            0 kB
# Active:          1344372 kB
# Inactive:       10000784 kB
# Active(anon):       1888 kB
# Inactive(anon):  1235588 kB
# Active(file):    1342484 kB
# Inactive(file):  8765196 kB
# Unevictable:          20 kB
# Mlocked:              20 kB
# SwapTotal:             0 kB
# SwapFree:              0 kB
# Dirty:               552 kB
# Writeback:             0 kB
# AnonPages:       1235284 kB
# Mapped:           726104 kB
# Shmem:              2224 kB
# KReclaimable:     412900 kB
# Slab:             488144 kB
# SReclaimable:     412900 kB
# SUnreclaim:        75244 kB
# KernelStack:        7724 kB
# PageTables:        22600 kB
# SecPageTables:         0 kB
# NFS_Unstable:          0 kB
# Bounce:                0 kB
# WritebackTmp:          0 kB
# CommitLimit:     6645228 kB
# Committed_AS:    3977828 kB
# VmallocTotal:   34359738367 kB
# VmallocUsed:       81884 kB
# VmallocChunk:          0 kB
# Percpu:             1144 kB
# HardwareCorrupted:     0 kB
# AnonHugePages:         0 kB
# ShmemHugePages:        0 kB
# ShmemPmdMapped:        0 kB
# FileHugePages:         0 kB
# FilePmdMapped:         0 kB
# CmaTotal:              0 kB
# CmaFree:               0 kB
# Unaccepted:            0 kB
# HugePages_Total:       0
# HugePages_Free:        0
# HugePages_Rsvd:        0
# HugePages_Surp:        0
# Hugepagesize:       2048 kB
# Hugetlb:               0 kB
# DirectMap4k:      176952 kB
# DirectMap2M:     6111232 kB
# DirectMap1G:     9437184 kB

# %%
# !/usr/local/cuda/bin/nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2023 NVIDIA Corporation
# Built on Tue_Aug_15_22:02:13_PDT_2023
# Cuda compilation tools, release 12.2, V12.2.140
# Build cuda_12.2.r12.2/compiler.33191640_0

# %%
# !which nvidia-smi
# Out:
# /opt/bin/nvidia-smi

# %%
# !nvidia-smi
# Out:
# Thu Oct 24 21:09:20 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   41C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
# !python --version
# Out:
# Python 3.10.12

# %%
import keras_tuner as kt
import datetime
from datetime import timedelta
from pytz import timezone
import tensorflow.keras.backend as K
import datetime
from datetime import timedelta
from pytz import timezone
print(tf. __version__)
print(pd. __version__)
print(np. __version__)
print(kt. __version__)
# Out:
# 2.15.0
# 2.1.4
# 1.26.4
# 1.4.7

# %%
# Establecer la semilla
seed_value = 42
import random
# Establecer semillas
np.random.seed(seed_value)
random.seed(seed_value)
tf.random.set_seed(seed_value)
from tensorflow.keras.saving import register_keras_serializable

# %%
print('std',train_previo_zscore['Número de vistas de página'].std())
print('mean',train_previo_zscore['Número de vistas de página'].mean() )
# Out:
# std 0.8649864124052458
# mean 4.308087962814851

# %%
media_train=train_previo_zscore['Número de vistas de página'].std()
std_train=train_previo_zscore['Número de vistas de página'].mean()
#esta metrica esta en el codigo de github del ganador
@register_keras_serializable()
def smape_loss(y_true, y_pred):
    #revierto zscore
    global media_train
    global std_train
    y_true=(y_true*std_train)+media_train
    y_pred=(y_pred*std_train)+media_train
    #revierto log1p
    y_true=tf.math.expm1(y_true)
    y_pred=tf.math.expm1(y_pred)
    epsilon = 0.1
    y_pred = tf.convert_to_tensor(y_pred)
    y_true = tf.cast(y_true, y_pred.dtype)
    # Calcular el denominador de SMAPE
    summ = tf.maximum(tf.abs(y_true) + tf.abs(y_pred) + epsilon, 0.5 + epsilon)

    # Calcular SMAPE
    smape = tf.abs(y_pred - y_true) / summ * 2.0

    # Retornar la media de SMAPE
    return K.mean(smape, axis=-1)

@register_keras_serializable()
def mae_denorm(y_true, y_pred):
    #revierto zscore
    global media_train
    global std_train
    y_true1=(y_true*std_train)+media_train
    y_pred1=(y_pred*std_train)+media_train
    #revierto log1p
    y_true2=tf.math.expm1(y_true1)
    y_pred2=tf.math.expm1(y_pred1)

    return tf.keras.losses.mean_absolute_error(y_true2, y_pred2)

# %%
pathModelosJsonMejor="/content/drive/MyDrive/a Tesis de Grado/Tesis Versiones/tesis 2024/UA/editorial universitaria/modelos/modelos resultados/prueba 500 epocas 1 capas sin early stopping"
nombreMejorModeloMejor="/hyperband500-3.221866-ndays60_500epochs1capa.h5"#el mejor modelo es el hyperband de 28 dias y 107 época

reconstructed_model2 = tf.keras.models.load_model(pathModelosJsonMejor+nombreMejorModeloMejor,custom_objects={'smape_loss':smape_loss,'mae_denorm':mae_denorm})

# %%
from tensorflow.keras.callbacks import TensorBoard

# %%
pathModelosJson="/content/drive/MyDrive/a Tesis de Grado/Tesis Versiones/tesis 2024/UA/editorial universitaria/modelos/modelos resultados/prueba2 1000 epocas 1 capas sin early stopping"
nombreMejorModelo="ndays60_1000epochs1capa.h5"
class PrintTimeCallback(tf.keras.callbacks.Callback):#https://www.tensorflow.org/guide/keras/writing_your_own_callbacks
    def on_epoch_end(self, epoch, logs=None):
        cambio=datetime.datetime.now(timezone('UTC')) - timedelta(hours=3)
        salida=f"{cambio:%Y-%m-%d %H:%M:%S }"
        print('Tiempo on_epoch_end',salida)
n_past=60
cambio=datetime.datetime.now(timezone('UTC')) - timedelta(hours=3)
tiempoFinal=f"{cambio:%Y-%m-%d %H:%M:%S }"
print('Tiempo  Inicio y n_past',tiempoFinal , ' n_past:-->',n_past)
n_future = 60
n_features = train.shape[1]
X_train, y_train = split_series(train.values,n_past, n_future)
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1],n_features))
y_train = y_train.reshape((y_train.shape[0], y_train.shape[1], 1)) #no hace falta reshapear
X_test, y_test = split_series(test.values,n_past, n_future)
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1],n_features))
y_test = y_test.reshape((y_test.shape[0], y_test.shape[1], 1)) #no hace falta reshapear
logpaht=pathModelosJson+f"/logsndays60_1000epochs1capa"
from tensorflow.keras.callbacks import ReduceLROnPlateau
#reduce_lr = ReduceLROnPlateau(monitor='val_smape_loss_zscore', factor=0.5, patience=5, min_lr=1e-50)
callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=50)#https://pub.towardsai.net/keras-earlystopping-callback-to-train-the-neural-networks-perfectly-2a3f865148f7
mcp_save = tf.keras.callbacks.ModelCheckpoint(pathModelosJson+"/"+'hyperband{epoch:03d}-{val_loss:03f}-'+nombreMejorModelo, save_best_only=True, monitor='val_loss', mode='min')#https://stackoverflow.com/questions/48285129/saving-best-model-in-keras
history_modelo=reconstructed_model2.fit(X_train,y_train,epochs=1000,validation_data=(X_test,y_test),batch_size=64,verbose=1,
                                        callbacks=[PrintTimeCallback(),
                                                   mcp_save,#reduce_lr,
                                                   TensorBoard(log_dir=logpaht, write_graph=False, profile_batch=0)
                                                   ])
cambio=datetime.datetime.now(timezone('UTC')) - timedelta(hours=3)
tiempoFinalDespues=f"{cambio:%Y-%m-%d %H:%M:%S }"
print('Tiempo Final y n_past',tiempoFinalDespues , ' n_past:-->',n_past)
#reentreno 70-30
# Out:
# Tiempo  Inicio y n_past 2024-10-24 18:10:48   n_past:--> 60
# Epoch 1/1000
# 20/21 [===========================>..] - ETA: 0s - loss: 0.5990 - smape_loss: 7.6428e-07 - mae_denorm: 8.0244e-07Tiempo on_epoch_end 2024-10-24 18:10:56
# 21/21 [==============================] - 8s 123ms/step - loss: 0.5981 - smape_loss: 7.5854e-07 - mae_denorm: 7.9642e-07 - val_loss: 3.2254 - val_smape_loss: 1.8573 - val_mae_denorm: 460754176.0000
# Epoch 2/1000
#  1/21 [>.............................] - ETA: 0s - loss: 0.6077 - smape_loss: 7.8679e-07 - mae_denorm: 8.2608e-07
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 19/21 [==========================>...] - ETA: 0s - loss: 0.5911 - smape_loss: 7.5748e-07 - mae_denorm: 7.9531e-07Tiempo on_epoch_end 2024-10-24 18:10:57
# 21/21 [==============================] - 1s 32ms/step - loss: 0.5927 - smape_loss: 7.5891e-07 - mae_denorm: 7.9681e-07 - val_loss: 3.1563 - val_smape_loss: 1.8553 - val_mae_denorm: 361066176.0000
# Epoch 3/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.5947 - smape_loss: 7.6581e-07 - mae_denorm: 8.0406e-07Tiempo on_epoch_end 2024-10-24 18:10:57
# 21/21 [==============================] - 0s 22ms/step - loss: 0.5951 - smape_loss: 7.6018e-07 - mae_denorm: 7.9814e-07 - val_loss: 3.2595 - val_smape_loss: 1.8615 - val_mae_denorm: 691735552.0000
# Epoch 4/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.5892 - smape_loss: 7.6650e-07 - mae_denorm: 8.0478e-07Tiempo on_epoch_end 2024-10-24 18:10:58
# 21/21 [==============================] - 0s 22ms/step - loss: 0.5898 - smape_loss: 7.6025e-07 - mae_denorm: 7.9821e-07 - val_loss: 3.2472 - val_smape_loss: 1.8591 - val_mae_denorm: 624498752.0000
# Epoch 5/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.5923 - smape_loss: 7.3632e-07 - mae_denorm: 7.7309e-07Tiempo on_epoch_end 2024-10-24 18:10:58
# 21/21 [==============================] - 0s 22ms/step - loss: 0.5903 - smape_loss: 7.5841e-07 - mae_denorm: 7.9629e-07 - val_loss: 3.2511 - val_smape_loss: 1.8573 - val_mae_denorm: 663490432.0000
# Epoch 6/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.5813 - smape_loss: 7.4556e-07 - mae_denorm: 7.8279e-07Tiempo on_epoch_end 2024-10-24 18:10:59
# 21/21 [==============================] - 0s 22ms/step - loss: 0.5834 - smape_loss: 7.5766e-07 - mae_denorm: 7.9549e-07 - val_loss: 3.2087 - val_smape_loss: 1.8542 - val_mae_denorm: 588599936.0000
# Epoch 7/1000
# 21/21 [==============================] - ETA: 0s - loss: 0.5886 - smape_loss: 7.5908e-07 - mae_denorm: 7.9699e-07Tiempo on_epoch_end 2024-10-24 18:10:59
# 21/21 [==============================] - 1s 28ms/step - loss: 0.5886 - smape_loss: 7.5908e-07 - mae_denorm: 7.9699e-07 - val_loss: 3.2187 - val_smape_loss: 1.8570 - val_mae_denorm: 739464768.0000
# Epoch 8/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.5940 - smape_loss: 7.5725e-07 - mae_denorm: 7.9506e-07Tiempo on_epoch_end 2024-10-24 18:11:00
# 21/21 [==============================] - 1s 31ms/step - loss: 0.5933 - smape_loss: 7.5931e-07 - mae_denorm: 7.9723e-07 - val_loss: 3.1287 - val_smape_loss: 1.8566 - val_mae_denorm: 871378112.0000
# Epoch 9/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.6007 - smape_loss: 7.5933e-07 - mae_denorm: 7.9725e-07Tiempo on_epoch_end 2024-10-24 18:11:01
# 21/21 [==============================] - 1s 27ms/step - loss: 0.6019 - smape_loss: 7.6313e-07 - mae_denorm: 8.0124e-07 - val_loss: 3.1529 - val_smape_loss: 1.8545 - val_mae_denorm: 905082048.0000
# Epoch 10/1000
# 21/21 [==============================] - ETA: 0s - loss: 0.5888 - smape_loss: 7.5973e-07 - mae_denorm: 7.9767e-07Tiempo on_epoch_end 2024-10-24 18:11:01
# 21/21 [==============================] - 1s 26ms/step - loss: 0.5888 - smape_loss: 7.5973e-07 - mae_denorm: 7.9767e-07 - val_loss: 3.1466 - val_smape_loss: 1.8508 - val_mae_denorm: 913689920.0000
# Epoch 11/1000
# 20/21 [===========================>..] - ETA: 0s - loss: 0.5859 - smape_loss: 7.5718e-07 - mae_denorm: 7.9499e-07Tiempo on_epoch_end 2024-10-24 18:11:02
# 21/21 [==============================] - 1s 28ms/step - loss: 0.5858 - smape_loss: 7.6059e-07 - mae_denorm: 7.9857e-07 - val_loss: 3.1574 - val_smape_loss: 1.8465 - val_mae_denorm: 1468071552.0000
# Epoch 12/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.5828 - smape_loss: 7.6890e-07 - mae_denorm: 8.0730e-07Tiempo on_epoch_end 2024-10-24 18:11:03
# 21/21 [==============================] - 1s 36ms/step - loss: 0.5833 - smape_loss: 7.5833e-07 - mae_denorm: 7.9620e-07 - val_loss: 3.1665 - val_smape_loss: 1.8524 - val_mae_denorm: 1364441728.0000
# Epoch 13/1000
# 21/21 [==============================] - ETA: 0s - loss: 0.5873 - smape_loss: 7.6029e-07 - mae_denorm: 7.9825e-07Tiempo on_epoch_end 2024-10-24 18:11:03
# 21/21 [==============================] - 0s 23ms/step - loss: 0.5873 - smape_loss: 7.6029e-07 - mae_denorm: 7.9825e-07 - val_loss: 3.1695 - val_smape_loss: 1.8515 - val_mae_denorm: 1143655296.0000
# Epoch 14/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.5968 - smape_loss: 7.5807e-07 - mae_denorm: 7.9593e-07Tiempo on_epoch_end 2024-10-24 18:11:03
# 21/21 [==============================] - 0s 23ms/step - loss: 0.5958 - smape_loss: 7.6277e-07 - mae_denorm: 8.0086e-07 - val_loss: 3.1674 - val_smape_loss: 1.8375 - val_mae_denorm: 1668648064.0000
# Epoch 15/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.6040 - smape_loss: 7.5520e-07 - mae_denorm: 7.9292e-07Tiempo on_epoch_end 2024-10-24 18:11:04
# 21/21 [==============================] - 1s 28ms/step - loss: 0.6015 - smape_loss: 7.6292e-07 - mae_denorm: 8.0102e-07 - val_loss: 3.0698 - val_smape_loss: 1.8418 - val_mae_denorm: 1248283776.0000
# Epoch 16/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.5865 - smape_loss: 7.7725e-07 - mae_denorm: 8.1607e-07Tiempo on_epoch_end 2024-10-24 18:11:05
# 21/21 [==============================] - 0s 22ms/step - loss: 0.5862 - smape_loss: 7.6182e-07 - mae_denorm: 7.9986e-07 - val_loss: 3.2324 - val_smape_loss: 1.8566 - val_mae_denorm: 3577361408.0000
# Epoch 17/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.5699 - smape_loss: 7.7245e-07 - mae_denorm: 8.1102e-07Tiempo on_epoch_end 2024-10-24 18:11:05
# 21/21 [==============================] - 0s 23ms/step - loss: 0.5698 - smape_loss: 7.6535e-07 - mae_denorm: 8.0357e-07 - val_loss: 3.1767 - val_smape_loss: 1.8554 - val_mae_denorm: 3351340800.0000
# Epoch 18/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.5765 - smape_loss: 7.6056e-07 - mae_denorm: 7.9854e-07Tiempo on_epoch_end 2024-10-24 18:11:05
# 21/21 [==============================] - 0s 22ms/step - loss: 0.5754 - smape_loss: 7.6296e-07 - mae_denorm: 8.0106e-07 - val_loss: 3.2932 - val_smape_loss: 1.8536 - val_mae_denorm: 3983532800.0000
# Epoch 19/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.5677 - smape_loss: 7.8789e-07 - mae_denorm: 8.2723e-07Tiempo on_epoch_end 2024-10-24 18:11:06
# 21/21 [==============================] - 0s 22ms/step - loss: 0.5677 - smape_loss: 7.7468e-07 - mae_denorm: 8.1337e-07 - val_loss: 3.4009 - val_smape_loss: 1.8346 - val_mae_denorm: 5478751744.0000
# Epoch 20/1000
# 21/21 [==============================] - ETA: 0s - loss: 0.5572 - smape_loss: 7.8650e-07 - mae_denorm: 8.2578e-07Tiempo on_epoch_end 2024-10-24 18:11:06
# 21/21 [==============================] - 0s 24ms/step - loss: 0.5572 - smape_loss: 7.8650e-07 - mae_denorm: 8.2578e-07 - val_loss: 3.3282 - val_smape_loss: 1.8491 - val_mae_denorm: 2883672576.0000
# Epoch 21/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.5633 - smape_loss: 7.7285e-07 - mae_denorm: 8.1144e-07Tiempo on_epoch_end 2024-10-24 18:11:07
# 21/21 [==============================] - 0s 22ms/step - loss: 0.5641 - smape_loss: 7.7302e-07 - mae_denorm: 8.1162e-07 - val_loss: 3.4473 - val_smape_loss: 1.8532 - val_mae_denorm: 3762919936.0000
# Epoch 22/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.5477 - smape_loss: 7.6938e-07 - mae_denorm: 8.0780e-07Tiempo on_epoch_end 2024-10-24 18:11:07
# 21/21 [==============================] - 0s 22ms/step - loss: 0.5479 - smape_loss: 7.6236e-07 - mae_denorm: 8.0043e-07 - val_loss: 3.6021 - val_smape_loss: 1.8333 - val_mae_denorm: 9697477632.0000
# Epoch 23/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.6310 - smape_loss: 7.6604e-07 - mae_denorm: 8.0430e-07Tiempo on_epoch_end 2024-10-24 18:11:08
# 21/21 [==============================] - 0s 23ms/step - loss: 0.6322 - smape_loss: 7.6649e-07 - mae_denorm: 8.0476e-07 - val_loss: 3.5336 - val_smape_loss: 1.8421 - val_mae_denorm: 2606965760.0000
# Epoch 24/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.6341 - smape_loss: 7.5697e-07 - mae_denorm: 7.9477e-07Tiempo on_epoch_end 2024-10-24 18:11:08
# 21/21 [==============================] - 0s 23ms/step - loss: 0.6312 - smape_loss: 7.6460e-07 - mae_denorm: 8.0279e-07 - val_loss: 3.5454 - val_smape_loss: 1.8407 - val_mae_denorm: 1586054144.0000
# Epoch 25/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.6188 - smape_loss: 7.6709e-07 - mae_denorm: 8.0540e-07Tiempo on_epoch_end 2024-10-24 18:11:09
# 21/21 [==============================] - 0s 22ms/step - loss: 0.6170 - smape_loss: 7.6616e-07 - mae_denorm: 8.0442e-07 - val_loss: 3.5147 - val_smape_loss: 1.8354 - val_mae_denorm: 773597184.0000
# Epoch 26/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.6035 - smape_loss: 7.5128e-07 - mae_denorm: 7.8880e-07Tiempo on_epoch_end 2024-10-24 18:11:09
# 21/21 [==============================] - 1s 24ms/step - loss: 0.6037 - smape_loss: 7.6428e-07 - mae_denorm: 8.0244e-07 - val_loss: 3.5393 - val_smape_loss: 1.8364 - val_mae_denorm: 1225185280.0000
# Epoch 27/1000
# 21/21 [==============================] - ETA: 0s - loss: 0.6062 - smape_loss: 7.6480e-07 - mae_denorm: 8.0299e-07Tiempo on_epoch_end 2024-10-24 18:11:10
# 21/21 [==============================] - 1s 24ms/step - loss: 0.6062 - smape_loss: 7.6480e-07 - mae_denorm: 8.0299e-07 - val_loss: 3.5219 - val_smape_loss: 1.8397 - val_mae_denorm: 877764416.0000
# Epoch 28/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.5622 - smape_loss: 7.7342e-07 - mae_denorm: 8.1204e-07Tiempo on_epoch_end 2024-10-24 18:11:10
# 21/21 [==============================] - 0s 22ms/step - loss: 0.5653 - smape_loss: 7.6423e-07 - mae_denorm: 8.0239e-07 - val_loss: 3.4586 - val_smape_loss: 1.8345 - val_mae_denorm: 900595840.0000
# Epoch 29/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.5515 - smape_loss: 7.5924e-07 - mae_denorm: 7.9716e-07Tiempo on_epoch_end 2024-10-24 18:11:11
# 21/21 [==============================] - 0s 22ms/step - loss: 0.5501 - smape_loss: 7.6492e-07 - mae_denorm: 8.0312e-07 - val_loss: 3.4507 - val_smape_loss: 1.8327 - val_mae_denorm: 818305152.0000
# Epoch 30/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.5312 - smape_loss: 7.8289e-07 - mae_denorm: 8.2198e-07Tiempo on_epoch_end 2024-10-24 18:11:11
# 21/21 [==============================] - 0s 22ms/step - loss: 0.5324 - smape_loss: 7.6460e-07 - mae_denorm: 8.0279e-07 - val_loss: 3.5497 - val_smape_loss: 1.8221 - val_mae_denorm: 1553598080.0000
# Epoch 31/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.5491 - smape_loss: 7.6320e-07 - mae_denorm: 8.0132e-07Tiempo on_epoch_end 2024-10-24 18:11:12
# 21/21 [==============================] - 0s 23ms/step - loss: 0.5538 - smape_loss: 7.6814e-07 - mae_denorm: 8.0650e-07 - val_loss: 3.3805 - val_smape_loss: 1.8230 - val_mae_denorm: 2912059648.0000
# Epoch 32/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.5647 - smape_loss: 7.6227e-07 - mae_denorm: 8.0034e-07Tiempo on_epoch_end 2024-10-24 18:11:12
# 21/21 [==============================] - 0s 23ms/step - loss: 0.5603 - smape_loss: 7.7054e-07 - mae_denorm: 8.0902e-07 - val_loss: 3.4265 - val_smape_loss: 1.8259 - val_mae_denorm: 4590878720.0000
# Epoch 33/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.5226 - smape_loss: 7.6009e-07 - mae_denorm: 7.9805e-07Tiempo on_epoch_end 2024-10-24 18:11:13
# 21/21 [==============================] - 1s 24ms/step - loss: 0.5221 - smape_loss: 7.6441e-07 - mae_denorm: 8.0258e-07 - val_loss: 3.4190 - val_smape_loss: 1.8213 - val_mae_denorm: 2586451200.0000
# Epoch 34/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.5792 - smape_loss: 7.7293e-07 - mae_denorm: 8.1152e-07Tiempo on_epoch_end 2024-10-24 18:11:13
# 21/21 [==============================] - 0s 24ms/step - loss: 0.5791 - smape_loss: 7.6472e-07 - mae_denorm: 8.0290e-07 - val_loss: 3.2666 - val_smape_loss: 1.8391 - val_mae_denorm: 1820371072.0000
# Epoch 35/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.5642 - smape_loss: 7.7347e-07 - mae_denorm: 8.1210e-07Tiempo on_epoch_end 2024-10-24 18:11:14
# 21/21 [==============================] - 1s 24ms/step - loss: 0.5623 - smape_loss: 7.6311e-07 - mae_denorm: 8.0122e-07 - val_loss: 3.3199 - val_smape_loss: 1.8426 - val_mae_denorm: 1622541568.0000
# Epoch 36/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.5324 - smape_loss: 7.8217e-07 - mae_denorm: 8.2122e-07Tiempo on_epoch_end 2024-10-24 18:11:14
# 21/21 [==============================] - 1s 25ms/step - loss: 0.5323 - smape_loss: 7.6337e-07 - mae_denorm: 8.0149e-07 - val_loss: 3.4117 - val_smape_loss: 1.8457 - val_mae_denorm: 8295750144.0000
# Epoch 37/1000
# 21/21 [==============================] - ETA: 0s - loss: 0.5292 - smape_loss: 7.6384e-07 - mae_denorm: 8.0198e-07Tiempo on_epoch_end 2024-10-24 18:11:15
# 21/21 [==============================] - 1s 27ms/step - loss: 0.5292 - smape_loss: 7.6384e-07 - mae_denorm: 8.0198e-07 - val_loss: 3.3961 - val_smape_loss: 1.8463 - val_mae_denorm: 6333268480.0000
# Epoch 38/1000
# 21/21 [==============================] - ETA: 0s - loss: 0.5338 - smape_loss: 7.6422e-07 - mae_denorm: 8.0239e-07Tiempo on_epoch_end 2024-10-24 18:11:15
# 21/21 [==============================] - 1s 31ms/step - loss: 0.5338 - smape_loss: 7.6422e-07 - mae_denorm: 8.0239e-07 - val_loss: 3.4582 - val_smape_loss: 1.8391 - val_mae_denorm: 9615817728.0000
# Epoch 39/1000
# 21/21 [==============================] - ETA: 0s - loss: 0.5128 - smape_loss: 7.5971e-07 - mae_denorm: 7.9765e-07Tiempo on_epoch_end 2024-10-24 18:11:16
# 21/21 [==============================] - 1s 28ms/step - loss: 0.5128 - smape_loss: 7.5971e-07 - mae_denorm: 7.9765e-07 - val_loss: 3.4087 - val_smape_loss: 1.8202 - val_mae_denorm: 7975075328.0000
# Epoch 40/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.6412 - smape_loss: 7.7712e-07 - mae_denorm: 8.1593e-07Tiempo on_epoch_end 2024-10-24 18:11:17
# 21/21 [==============================] - 1s 26ms/step - loss: 0.6420 - smape_loss: 7.6771e-07 - mae_denorm: 8.0605e-07 - val_loss: 3.1960 - val_smape_loss: 1.8184 - val_mae_denorm: 10844746752.0000
# Epoch 41/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.6502 - smape_loss: 7.8022e-07 - mae_denorm: 8.1919e-07Tiempo on_epoch_end 2024-10-24 18:11:17
# 21/21 [==============================] - 0s 22ms/step - loss: 0.6489 - smape_loss: 7.6714e-07 - mae_denorm: 8.0545e-07 - val_loss: 3.0804 - val_smape_loss: 1.8043 - val_mae_denorm: 5356313088.0000
# Epoch 42/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.6289 - smape_loss: 7.6828e-07 - mae_denorm: 8.0664e-07Tiempo on_epoch_end 2024-10-24 18:11:18
# 21/21 [==============================] - 1s 28ms/step - loss: 0.6280 - smape_loss: 7.6567e-07 - mae_denorm: 8.0390e-07 - val_loss: 3.0563 - val_smape_loss: 1.8038 - val_mae_denorm: 3886066944.0000
# Epoch 43/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.6084 - smape_loss: 7.6258e-07 - mae_denorm: 8.0066e-07Tiempo on_epoch_end 2024-10-24 18:11:18
# 21/21 [==============================] - 1s 28ms/step - loss: 0.6053 - smape_loss: 7.6380e-07 - mae_denorm: 8.0194e-07 - val_loss: 2.9618 - val_smape_loss: 1.7996 - val_mae_denorm: 1506816256.0000
# Epoch 44/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.5706 - smape_loss: 7.4616e-07 - mae_denorm: 7.8342e-07Tiempo on_epoch_end 2024-10-24 18:11:19
# 21/21 [==============================] - 1s 35ms/step - loss: 0.5677 - smape_loss: 7.6373e-07 - mae_denorm: 8.0186e-07 - val_loss: 2.8524 - val_smape_loss: 1.7860 - val_mae_denorm: 1111368960.0000
# Epoch 45/1000
# 21/21 [==============================] - ETA: 0s - loss: 0.5348 - smape_loss: 7.6034e-07 - mae_denorm: 7.9831e-07Tiempo on_epoch_end 2024-10-24 18:11:20
# 21/21 [==============================] - 1s 27ms/step - loss: 0.5348 - smape_loss: 7.6034e-07 - mae_denorm: 7.9831e-07 - val_loss: 3.0024 - val_smape_loss: 1.7939 - val_mae_denorm: 2364842496.0000
# Epoch 46/1000
# 21/21 [==============================] - ETA: 0s - loss: 0.5127 - smape_loss: 7.5665e-07 - mae_denorm: 7.9444e-07Tiempo on_epoch_end 2024-10-24 18:11:20
# 21/21 [==============================] - 1s 35ms/step - loss: 0.5127 - smape_loss: 7.5665e-07 - mae_denorm: 7.9444e-07 - val_loss: 3.0815 - val_smape_loss: 1.7958 - val_mae_denorm: 3755672576.0000
# Epoch 47/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.5030 - smape_loss: 7.5445e-07 - mae_denorm: 7.9212e-07Tiempo on_epoch_end 2024-10-24 18:11:21
# 21/21 [==============================] - 0s 23ms/step - loss: 0.5021 - smape_loss: 7.5639e-07 - mae_denorm: 7.9416e-07 - val_loss: 2.9900 - val_smape_loss: 1.7874 - val_mae_denorm: 3518657280.0000
# Epoch 48/1000
# 21/21 [==============================] - ETA: 0s - loss: 0.4832 - smape_loss: 7.5623e-07 - mae_denorm: 7.9399e-07Tiempo on_epoch_end 2024-10-24 18:11:22
# 21/21 [==============================] - 1s 34ms/step - loss: 0.4832 - smape_loss: 7.5623e-07 - mae_denorm: 7.9399e-07 - val_loss: 3.0666 - val_smape_loss: 1.7900 - val_mae_denorm: 3631063296.0000
# Epoch 49/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.4930 - smape_loss: 7.4545e-07 - mae_denorm: 7.8268e-07Tiempo on_epoch_end 2024-10-24 18:11:22
# 21/21 [==============================] - 0s 22ms/step - loss: 0.4917 - smape_loss: 7.6110e-07 - mae_denorm: 7.9911e-07 - val_loss: 3.1598 - val_smape_loss: 1.7971 - val_mae_denorm: 2791708416.0000
# Epoch 50/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.4776 - smape_loss: 7.6173e-07 - mae_denorm: 7.9977e-07Tiempo on_epoch_end 2024-10-24 18:11:22
# 21/21 [==============================] - 0s 23ms/step - loss: 0.4760 - smape_loss: 7.5494e-07 - mae_denorm: 7.9264e-07 - val_loss: 3.1908 - val_smape_loss: 1.7987 - val_mae_denorm: 2433580288.0000
# Epoch 51/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.4719 - smape_loss: 7.4438e-07 - mae_denorm: 7.8155e-07Tiempo on_epoch_end 2024-10-24 18:11:23
# 21/21 [==============================] - 0s 22ms/step - loss: 0.4707 - smape_loss: 7.5038e-07 - mae_denorm: 7.8785e-07 - val_loss: 2.9203 - val_smape_loss: 1.7718 - val_mae_denorm: 1441637888.0000
# Epoch 52/1000
# 21/21 [==============================] - ETA: 0s - loss: 0.4718 - smape_loss: 7.5411e-07 - mae_denorm: 7.9176e-07Tiempo on_epoch_end 2024-10-24 18:11:24
# 21/21 [==============================] - 1s 45ms/step - loss: 0.4718 - smape_loss: 7.5411e-07 - mae_denorm: 7.9176e-07 - val_loss: 2.8377 - val_smape_loss: 1.7679 - val_mae_denorm: 1101422976.0000
# Epoch 53/1000
# 21/21 [==============================] - ETA: 0s - loss: 0.4934 - smape_loss: 7.5930e-07 - mae_denorm: 7.9722e-07Tiempo on_epoch_end 2024-10-24 18:11:24
# 21/21 [==============================] - 1s 32ms/step - loss: 0.4934 - smape_loss: 7.5930e-07 - mae_denorm: 7.9722e-07 - val_loss: 2.7875 - val_smape_loss: 1.7560 - val_mae_denorm: 241906560.0000
# Epoch 54/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.4674 - smape_loss: 7.5197e-07 - mae_denorm: 7.8952e-07Tiempo on_epoch_end 2024-10-24 18:11:25
# 21/21 [==============================] - 0s 23ms/step - loss: 0.4672 - smape_loss: 7.5394e-07 - mae_denorm: 7.9159e-07 - val_loss: 2.8517 - val_smape_loss: 1.7581 - val_mae_denorm: 1124224640.0000
# Epoch 55/1000
# 21/21 [==============================] - ETA: 0s - loss: 0.4704 - smape_loss: 7.5272e-07 - mae_denorm: 7.9031e-07Tiempo on_epoch_end 2024-10-24 18:11:26
# 21/21 [==============================] - 1s 28ms/step - loss: 0.4704 - smape_loss: 7.5272e-07 - mae_denorm: 7.9031e-07 - val_loss: 2.7760 - val_smape_loss: 1.7369 - val_mae_denorm: 2424906240.0000
# Epoch 56/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.4774 - smape_loss: 7.5708e-07 - mae_denorm: 7.9489e-07Tiempo on_epoch_end 2024-10-24 18:11:26
# 21/21 [==============================] - 1s 27ms/step - loss: 0.4759 - smape_loss: 7.5745e-07 - mae_denorm: 7.9527e-07 - val_loss: 2.6862 - val_smape_loss: 1.7318 - val_mae_denorm: 5208184832.0000
# Epoch 57/1000
# 21/21 [==============================] - ETA: 0s - loss: 0.4577 - smape_loss: 7.5520e-07 - mae_denorm: 7.9291e-07Tiempo on_epoch_end 2024-10-24 18:11:27
# 21/21 [==============================] - 1s 25ms/step - loss: 0.4577 - smape_loss: 7.5520e-07 - mae_denorm: 7.9291e-07 - val_loss: 2.7561 - val_smape_loss: 1.7338 - val_mae_denorm: 8616356864.0000
# Epoch 58/1000
# 21/21 [==============================] - ETA: 0s - loss: 0.4514 - smape_loss: 7.4933e-07 - mae_denorm: 7.8675e-07Tiempo on_epoch_end 2024-10-24 18:11:27
# 21/21 [==============================] - 1s 27ms/step - loss: 0.4514 - smape_loss: 7.4933e-07 - mae_denorm: 7.8675e-07 - val_loss: 2.7806 - val_smape_loss: 1.7407 - val_mae_denorm: 6611115008.0000
# Epoch 59/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.4326 - smape_loss: 7.3419e-07 - mae_denorm: 7.7085e-07Tiempo on_epoch_end 2024-10-24 18:11:28
# 21/21 [==============================] - 1s 26ms/step - loss: 0.4307 - smape_loss: 7.4420e-07 - mae_denorm: 7.8136e-07 - val_loss: 2.7604 - val_smape_loss: 1.7379 - val_mae_denorm: 8530689024.0000
# Epoch 60/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.4287 - smape_loss: 7.3447e-07 - mae_denorm: 7.7115e-07Tiempo on_epoch_end 2024-10-24 18:11:28
# 21/21 [==============================] - 1s 28ms/step - loss: 0.4308 - smape_loss: 7.4855e-07 - mae_denorm: 7.8593e-07 - val_loss: 2.8687 - val_smape_loss: 1.7559 - val_mae_denorm: 17629353984.0000
# Epoch 61/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.5025 - smape_loss: 7.5513e-07 - mae_denorm: 7.9284e-07Tiempo on_epoch_end 2024-10-24 18:11:29
# 21/21 [==============================] - 1s 26ms/step - loss: 0.5001 - smape_loss: 7.6098e-07 - mae_denorm: 7.9898e-07 - val_loss: 2.8591 - val_smape_loss: 1.7584 - val_mae_denorm: 22792960000.0000
# Epoch 62/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.5198 - smape_loss: 7.5992e-07 - mae_denorm: 7.9787e-07Tiempo on_epoch_end 2024-10-24 18:11:30
# 21/21 [==============================] - 1s 32ms/step - loss: 0.5197 - smape_loss: 7.6121e-07 - mae_denorm: 7.9923e-07 - val_loss: 2.7078 - val_smape_loss: 1.7237 - val_mae_denorm: 1707936512.0000
# Epoch 63/1000
# 20/21 [===========================>..] - ETA: 0s - loss: 0.4923 - smape_loss: 7.6818e-07 - mae_denorm: 8.0654e-07Tiempo on_epoch_end 2024-10-24 18:11:30
# 21/21 [==============================] - 1s 29ms/step - loss: 0.4913 - smape_loss: 7.5817e-07 - mae_denorm: 7.9603e-07 - val_loss: 2.8193 - val_smape_loss: 1.7666 - val_mae_denorm: 7924780032.0000
# Epoch 64/1000
# 20/21 [===========================>..] - ETA: 0s - loss: 0.5003 - smape_loss: 7.6728e-07 - mae_denorm: 8.0559e-07Tiempo on_epoch_end 2024-10-24 18:11:31
# 21/21 [==============================] - 1s 27ms/step - loss: 0.4998 - smape_loss: 7.6713e-07 - mae_denorm: 8.0543e-07 - val_loss: 2.9622 - val_smape_loss: 1.7796 - val_mae_denorm: 24648036352.0000
# Epoch 65/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.4855 - smape_loss: 7.6212e-07 - mae_denorm: 8.0018e-07Tiempo on_epoch_end 2024-10-24 18:11:31
# 21/21 [==============================] - 0s 23ms/step - loss: 0.4856 - smape_loss: 7.5535e-07 - mae_denorm: 7.9307e-07 - val_loss: 3.0236 - val_smape_loss: 1.7904 - val_mae_denorm: 10693977088.0000
# Epoch 66/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.6050 - smape_loss: 7.5926e-07 - mae_denorm: 7.9718e-07Tiempo on_epoch_end 2024-10-24 18:11:32
# 21/21 [==============================] - 1s 24ms/step - loss: 0.6059 - smape_loss: 7.6816e-07 - mae_denorm: 8.0652e-07 - val_loss: 3.1077 - val_smape_loss: 1.7931 - val_mae_denorm: 5882054656.0000
# Epoch 67/1000
# 21/21 [==============================] - ETA: 0s - loss: 0.5532 - smape_loss: 7.6478e-07 - mae_denorm: 8.0297e-07Tiempo on_epoch_end 2024-10-24 18:11:32
# 21/21 [==============================] - 1s 25ms/step - loss: 0.5532 - smape_loss: 7.6478e-07 - mae_denorm: 8.0297e-07 - val_loss: 3.0749 - val_smape_loss: 1.7846 - val_mae_denorm: 4345478656.0000
# Epoch 68/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.5033 - smape_loss: 7.5054e-07 - mae_denorm: 7.8802e-07Tiempo on_epoch_end 2024-10-24 18:11:33
# 21/21 [==============================] - 0s 22ms/step - loss: 0.5029 - smape_loss: 7.5617e-07 - mae_denorm: 7.9393e-07 - val_loss: 3.0237 - val_smape_loss: 1.7856 - val_mae_denorm: 1259166464.0000
# Epoch 69/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.4688 - smape_loss: 7.4659e-07 - mae_denorm: 7.8387e-07Tiempo on_epoch_end 2024-10-24 18:11:33
# 21/21 [==============================] - 0s 23ms/step - loss: 0.4679 - smape_loss: 7.5780e-07 - mae_denorm: 7.9564e-07 - val_loss: 3.0027 - val_smape_loss: 1.7783 - val_mae_denorm: 1183491072.0000
# Epoch 70/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.4704 - smape_loss: 7.4968e-07 - mae_denorm: 7.8712e-07Tiempo on_epoch_end 2024-10-24 18:11:34
# 21/21 [==============================] - 0s 24ms/step - loss: 0.4705 - smape_loss: 7.5817e-07 - mae_denorm: 7.9603e-07 - val_loss: 2.9138 - val_smape_loss: 1.7789 - val_mae_denorm: 2302287104.0000
# Epoch 71/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.4699 - smape_loss: 7.6483e-07 - mae_denorm: 8.0303e-07Tiempo on_epoch_end 2024-10-24 18:11:34
# 21/21 [==============================] - 0s 22ms/step - loss: 0.4702 - smape_loss: 7.5783e-07 - mae_denorm: 7.9567e-07 - val_loss: 2.9018 - val_smape_loss: 1.8010 - val_mae_denorm: 3248777216.0000
# Epoch 72/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.4826 - smape_loss: 7.5119e-07 - mae_denorm: 7.8870e-07Tiempo on_epoch_end 2024-10-24 18:11:35
# 21/21 [==============================] - 0s 22ms/step - loss: 0.4831 - smape_loss: 7.5256e-07 - mae_denorm: 7.9015e-07 - val_loss: 2.9565 - val_smape_loss: 1.8033 - val_mae_denorm: 3198413568.0000
# Epoch 73/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.4616 - smape_loss: 7.5162e-07 - mae_denorm: 7.8915e-07Tiempo on_epoch_end 2024-10-24 18:11:35
# 21/21 [==============================] - 0s 21ms/step - loss: 0.4607 - smape_loss: 7.4972e-07 - mae_denorm: 7.8716e-07 - val_loss: 2.8856 - val_smape_loss: 1.8124 - val_mae_denorm: 2347103488.0000
# Epoch 74/1000
# 21/21 [==============================] - ETA: 0s - loss: 0.4502 - smape_loss: 7.5160e-07 - mae_denorm: 7.8913e-07Tiempo on_epoch_end 2024-10-24 18:11:36
# 21/21 [==============================] - 0s 23ms/step - loss: 0.4502 - smape_loss: 7.5160e-07 - mae_denorm: 7.8913e-07 - val_loss: 2.8673 - val_smape_loss: 1.8202 - val_mae_denorm: 2224655360.0000
# Epoch 75/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.4501 - smape_loss: 7.4220e-07 - mae_denorm: 7.7926e-07Tiempo on_epoch_end 2024-10-24 18:11:36
# 21/21 [==============================] - 0s 23ms/step - loss: 0.4505 - smape_loss: 7.5917e-07 - mae_denorm: 7.9707e-07 - val_loss: 2.9789 - val_smape_loss: 1.8082 - val_mae_denorm: 10132784128.0000
# Epoch 76/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.4886 - smape_loss: 7.6617e-07 - mae_denorm: 8.0443e-07Tiempo on_epoch_end 2024-10-24 18:11:37
# 21/21 [==============================] - 0s 22ms/step - loss: 0.4910 - smape_loss: 7.5689e-07 - mae_denorm: 7.9469e-07 - val_loss: 2.9363 - val_smape_loss: 1.8071 - val_mae_denorm: 2233937664.0000
# Epoch 77/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.6686 - smape_loss: 7.7054e-07 - mae_denorm: 8.0902e-07Tiempo on_epoch_end 2024-10-24 18:11:37
# 21/21 [==============================] - 0s 23ms/step - loss: 0.6692 - smape_loss: 7.6835e-07 - mae_denorm: 8.0672e-07 - val_loss: 3.1400 - val_smape_loss: 1.8497 - val_mae_denorm: 45734920.0000
# Epoch 78/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.6544 - smape_loss: 7.7261e-07 - mae_denorm: 8.1119e-07Tiempo on_epoch_end 2024-10-24 18:11:38
# 21/21 [==============================] - 0s 22ms/step - loss: 0.6531 - smape_loss: 7.6746e-07 - mae_denorm: 8.0578e-07 - val_loss: 3.0694 - val_smape_loss: 1.8456 - val_mae_denorm: 128255088.0000
# Epoch 79/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.6402 - smape_loss: 7.6823e-07 - mae_denorm: 8.0660e-07Tiempo on_epoch_end 2024-10-24 18:11:38
# 21/21 [==============================] - 0s 22ms/step - loss: 0.6395 - smape_loss: 7.6669e-07 - mae_denorm: 8.0498e-07 - val_loss: 3.0662 - val_smape_loss: 1.8408 - val_mae_denorm: 60799520.0000
# Epoch 80/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.6277 - smape_loss: 7.6281e-07 - mae_denorm: 8.0091e-07Tiempo on_epoch_end 2024-10-24 18:11:39
# 21/21 [==============================] - 0s 22ms/step - loss: 0.6303 - smape_loss: 7.6515e-07 - mae_denorm: 8.0336e-07 - val_loss: 3.0586 - val_smape_loss: 1.8378 - val_mae_denorm: 83432880.0000
# Epoch 81/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.6234 - smape_loss: 7.9450e-07 - mae_denorm: 8.3418e-07Tiempo on_epoch_end 2024-10-24 18:11:39
# 21/21 [==============================] - 0s 22ms/step - loss: 0.6234 - smape_loss: 7.6425e-07 - mae_denorm: 8.0242e-07 - val_loss: 3.0624 - val_smape_loss: 1.8358 - val_mae_denorm: 76948728.0000
# Epoch 82/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.6195 - smape_loss: 7.7334e-07 - mae_denorm: 8.1195e-07Tiempo on_epoch_end 2024-10-24 18:11:40
# 21/21 [==============================] - 0s 22ms/step - loss: 0.6201 - smape_loss: 7.6415e-07 - mae_denorm: 8.0231e-07 - val_loss: 3.0553 - val_smape_loss: 1.8336 - val_mae_denorm: 92141960.0000
# Epoch 83/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.6201 - smape_loss: 7.6611e-07 - mae_denorm: 8.0437e-07Tiempo on_epoch_end 2024-10-24 18:11:40
# 21/21 [==============================] - 0s 23ms/step - loss: 0.6193 - smape_loss: 7.6409e-07 - mae_denorm: 8.0224e-07 - val_loss: 3.0190 - val_smape_loss: 1.8321 - val_mae_denorm: 69949776.0000
# Epoch 84/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.6141 - smape_loss: 7.5019e-07 - mae_denorm: 7.8765e-07Tiempo on_epoch_end 2024-10-24 18:11:40
# 21/21 [==============================] - 0s 22ms/step - loss: 0.6132 - smape_loss: 7.6269e-07 - mae_denorm: 8.0078e-07 - val_loss: 3.0108 - val_smape_loss: 1.8307 - val_mae_denorm: 101292712.0000
# Epoch 85/1000
# 21/21 [==============================] - ETA: 0s - loss: 0.6122 - smape_loss: 7.6376e-07 - mae_denorm: 8.0190e-07Tiempo on_epoch_end 2024-10-24 18:11:41
# 21/21 [==============================] - 1s 27ms/step - loss: 0.6122 - smape_loss: 7.6376e-07 - mae_denorm: 8.0190e-07 - val_loss: 2.9932 - val_smape_loss: 1.8277 - val_mae_denorm: 206364144.0000
# Epoch 86/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.6097 - smape_loss: 7.7459e-07 - mae_denorm: 8.1327e-07Tiempo on_epoch_end 2024-10-24 18:11:42
# 21/21 [==============================] - 1s 25ms/step - loss: 0.6093 - smape_loss: 7.6284e-07 - mae_denorm: 8.0094e-07 - val_loss: 2.9529 - val_smape_loss: 1.8247 - val_mae_denorm: 200047824.0000
# Epoch 87/1000
# 21/21 [==============================] - ETA: 0s - loss: 0.6042 - smape_loss: 7.6150e-07 - mae_denorm: 7.9953e-07Tiempo on_epoch_end 2024-10-24 18:11:42
# 21/21 [==============================] - 1s 28ms/step - loss: 0.6042 - smape_loss: 7.6150e-07 - mae_denorm: 7.9953e-07 - val_loss: 2.9266 - val_smape_loss: 1.8212 - val_mae_denorm: 227808272.0000
# Epoch 88/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.5986 - smape_loss: 7.6227e-07 - mae_denorm: 8.0033e-07Tiempo on_epoch_end 2024-10-24 18:11:43
# 21/21 [==============================] - 1s 27ms/step - loss: 0.5989 - smape_loss: 7.6012e-07 - mae_denorm: 7.9808e-07 - val_loss: 2.8768 - val_smape_loss: 1.8205 - val_mae_denorm: 815068352.0000
# Epoch 89/1000
# 21/21 [==============================] - ETA: 0s - loss: 0.5915 - smape_loss: 7.6513e-07 - mae_denorm: 8.0334e-07Tiempo on_epoch_end 2024-10-24 18:11:43
# 21/21 [==============================] - 1s 27ms/step - loss: 0.5915 - smape_loss: 7.6513e-07 - mae_denorm: 8.0334e-07 - val_loss: 2.8933 - val_smape_loss: 1.8188 - val_mae_denorm: 378611456.0000
# Epoch 90/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.5471 - smape_loss: 7.6972e-07 - mae_denorm: 8.0816e-07Tiempo on_epoch_end 2024-10-24 18:11:44
# 21/21 [==============================] - 1s 25ms/step - loss: 0.5445 - smape_loss: 7.7700e-07 - mae_denorm: 8.1580e-07 - val_loss: 2.9636 - val_smape_loss: 1.8222 - val_mae_denorm: 780529792.0000
# Epoch 91/1000
# 20/21 [===========================>..] - ETA: 0s - loss: 0.5103 - smape_loss: 7.6085e-07 - mae_denorm: 7.9884e-07Tiempo on_epoch_end 2024-10-24 18:11:44
# 21/21 [==============================] - 1s 28ms/step - loss: 0.5098 - smape_loss: 7.5813e-07 - mae_denorm: 7.9599e-07 - val_loss: 3.0437 - val_smape_loss: 1.8278 - val_mae_denorm: 1555517952.0000
# Epoch 92/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.4866 - smape_loss: 7.5649e-07 - mae_denorm: 7.9426e-07Tiempo on_epoch_end 2024-10-24 18:11:45
# 21/21 [==============================] - 0s 23ms/step - loss: 0.4852 - smape_loss: 7.5575e-07 - mae_denorm: 7.9349e-07 - val_loss: 3.1623 - val_smape_loss: 1.8293 - val_mae_denorm: 2685953280.0000
# Epoch 93/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.4874 - smape_loss: 7.5752e-07 - mae_denorm: 7.9535e-07Tiempo on_epoch_end 2024-10-24 18:11:45
# 21/21 [==============================] - 0s 22ms/step - loss: 0.4852 - smape_loss: 7.6006e-07 - mae_denorm: 7.9802e-07 - val_loss: 3.0628 - val_smape_loss: 1.8210 - val_mae_denorm: 1262146176.0000
# Epoch 94/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.4783 - smape_loss: 7.4479e-07 - mae_denorm: 7.8198e-07Tiempo on_epoch_end 2024-10-24 18:11:46
# 21/21 [==============================] - 0s 23ms/step - loss: 0.4783 - smape_loss: 7.5044e-07 - mae_denorm: 7.8791e-07 - val_loss: 3.1484 - val_smape_loss: 1.8242 - val_mae_denorm: 1769390592.0000
# Epoch 95/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.4703 - smape_loss: 7.5730e-07 - mae_denorm: 7.9511e-07Tiempo on_epoch_end 2024-10-24 18:11:46
# 21/21 [==============================] - 0s 23ms/step - loss: 0.4696 - smape_loss: 7.4953e-07 - mae_denorm: 7.8696e-07 - val_loss: 3.1135 - val_smape_loss: 1.8324 - val_mae_denorm: 1178562048.0000
# Epoch 96/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.4560 - smape_loss: 7.6593e-07 - mae_denorm: 8.0417e-07Tiempo on_epoch_end 2024-10-24 18:11:47
# 21/21 [==============================] - 0s 23ms/step - loss: 0.4567 - smape_loss: 7.5290e-07 - mae_denorm: 7.9050e-07 - val_loss: 3.1401 - val_smape_loss: 1.8344 - val_mae_denorm: 1646233472.0000
# Epoch 97/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.4512 - smape_loss: 7.6884e-07 - mae_denorm: 8.0723e-07Tiempo on_epoch_end 2024-10-24 18:11:47
# 21/21 [==============================] - 0s 22ms/step - loss: 0.4497 - smape_loss: 7.5889e-07 - mae_denorm: 7.9679e-07 - val_loss: 3.0857 - val_smape_loss: 1.8287 - val_mae_denorm: 1313439104.0000
# Epoch 98/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.4392 - smape_loss: 7.5629e-07 - mae_denorm: 7.9405e-07Tiempo on_epoch_end 2024-10-24 18:11:48
# 21/21 [==============================] - 0s 22ms/step - loss: 0.4392 - smape_loss: 7.5648e-07 - mae_denorm: 7.9425e-07 - val_loss: 3.0977 - val_smape_loss: 1.8277 - val_mae_denorm: 1010119424.0000
# Epoch 99/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.4329 - smape_loss: 7.2473e-07 - mae_denorm: 7.6092e-07Tiempo on_epoch_end 2024-10-24 18:11:48
# 21/21 [==============================] - 0s 23ms/step - loss: 0.4336 - smape_loss: 7.4203e-07 - mae_denorm: 7.7908e-07 - val_loss: 3.1078 - val_smape_loss: 1.8282 - val_mae_denorm: 1614015616.0000
# Epoch 100/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.4219 - smape_loss: 7.4547e-07 - mae_denorm: 7.8269e-07Tiempo on_epoch_end 2024-10-24 18:11:49
# 21/21 [==============================] - 0s 23ms/step - loss: 0.4223 - smape_loss: 7.4642e-07 - mae_denorm: 7.8369e-07 - val_loss: 3.1160 - val_smape_loss: 1.8354 - val_mae_denorm: 1081318656.0000
# Epoch 101/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.4100 - smape_loss: 7.5152e-07 - mae_denorm: 7.8904e-07Tiempo on_epoch_end 2024-10-24 18:11:49
# 21/21 [==============================] - 0s 22ms/step - loss: 0.4085 - smape_loss: 7.4209e-07 - mae_denorm: 7.7914e-07 - val_loss: 3.1663 - val_smape_loss: 1.8368 - val_mae_denorm: 1146004096.0000
# Epoch 102/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.3928 - smape_loss: 7.2520e-07 - mae_denorm: 7.6141e-07Tiempo on_epoch_end 2024-10-24 18:11:50
# 21/21 [==============================] - 0s 22ms/step - loss: 0.3935 - smape_loss: 7.3316e-07 - mae_denorm: 7.6977e-07 - val_loss: 3.1818 - val_smape_loss: 1.8386 - val_mae_denorm: 606024128.0000
# Epoch 103/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.3955 - smape_loss: 7.5938e-07 - mae_denorm: 7.9730e-07Tiempo on_epoch_end 2024-10-24 18:11:50
# 21/21 [==============================] - 0s 23ms/step - loss: 0.3987 - smape_loss: 7.6446e-07 - mae_denorm: 8.0263e-07 - val_loss: 3.2157 - val_smape_loss: 1.8414 - val_mae_denorm: 478314112.0000
# Epoch 104/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.4152 - smape_loss: 7.4841e-07 - mae_denorm: 7.8578e-07Tiempo on_epoch_end 2024-10-24 18:11:51
# 21/21 [==============================] - 0s 23ms/step - loss: 0.4147 - smape_loss: 7.4636e-07 - mae_denorm: 7.8363e-07 - val_loss: 3.2145 - val_smape_loss: 1.8465 - val_mae_denorm: 302612000.0000
# Epoch 105/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.3878 - smape_loss: 7.2389e-07 - mae_denorm: 7.6004e-07Tiempo on_epoch_end 2024-10-24 18:11:51
# 21/21 [==============================] - 0s 22ms/step - loss: 0.3883 - smape_loss: 7.3162e-07 - mae_denorm: 7.6815e-07 - val_loss: 3.1954 - val_smape_loss: 1.8439 - val_mae_denorm: 208611824.0000
# Epoch 106/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.3752 - smape_loss: 7.3212e-07 - mae_denorm: 7.6868e-07Tiempo on_epoch_end 2024-10-24 18:11:52
# 21/21 [==============================] - 0s 22ms/step - loss: 0.3741 - smape_loss: 7.2872e-07 - mae_denorm: 7.6510e-07 - val_loss: 3.1710 - val_smape_loss: 1.8450 - val_mae_denorm: 209875632.0000
# Epoch 107/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.3676 - smape_loss: 7.4425e-07 - mae_denorm: 7.8141e-07Tiempo on_epoch_end 2024-10-24 18:11:52
# 21/21 [==============================] - 0s 22ms/step - loss: 0.3667 - smape_loss: 7.3046e-07 - mae_denorm: 7.6693e-07 - val_loss: 3.1264 - val_smape_loss: 1.8438 - val_mae_denorm: 214318544.0000
# Epoch 108/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.3669 - smape_loss: 7.3285e-07 - mae_denorm: 7.6944e-07Tiempo on_epoch_end 2024-10-24 18:11:53
# 21/21 [==============================] - 0s 22ms/step - loss: 0.3666 - smape_loss: 7.2917e-07 - mae_denorm: 7.6558e-07 - val_loss: 3.2775 - val_smape_loss: 1.8525 - val_mae_denorm: 474622528.0000
# Epoch 109/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.3599 - smape_loss: 7.0720e-07 - mae_denorm: 7.4251e-07Tiempo on_epoch_end 2024-10-24 18:11:53
# 21/21 [==============================] - 0s 22ms/step - loss: 0.3599 - smape_loss: 7.2175e-07 - mae_denorm: 7.5779e-07 - val_loss: 3.2176 - val_smape_loss: 1.8469 - val_mae_denorm: 345422208.0000
# Epoch 110/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.3610 - smape_loss: 7.2293e-07 - mae_denorm: 7.5903e-07Tiempo on_epoch_end 2024-10-24 18:11:54
# 21/21 [==============================] - 0s 24ms/step - loss: 0.3609 - smape_loss: 7.1425e-07 - mae_denorm: 7.4992e-07 - val_loss: 3.2029 - val_smape_loss: 1.8454 - val_mae_denorm: 380995680.0000
# Epoch 111/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.3535 - smape_loss: 7.3251e-07 - mae_denorm: 7.6909e-07Tiempo on_epoch_end 2024-10-24 18:11:54
# 21/21 [==============================] - 0s 23ms/step - loss: 0.3541 - smape_loss: 7.3491e-07 - mae_denorm: 7.7161e-07 - val_loss: 3.1548 - val_smape_loss: 1.8409 - val_mae_denorm: 326087584.0000
# Epoch 112/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.3532 - smape_loss: 7.0140e-07 - mae_denorm: 7.3642e-07Tiempo on_epoch_end 2024-10-24 18:11:55
# 21/21 [==============================] - 0s 24ms/step - loss: 0.3530 - smape_loss: 7.1047e-07 - mae_denorm: 7.4594e-07 - val_loss: 3.1265 - val_smape_loss: 1.8407 - val_mae_denorm: 278487744.0000
# Epoch 113/1000
# 20/21 [===========================>..] - ETA: 0s - loss: 0.3559 - smape_loss: 7.2667e-07 - mae_denorm: 7.6295e-07Tiempo on_epoch_end 2024-10-24 18:11:55
# 21/21 [==============================] - 1s 27ms/step - loss: 0.3562 - smape_loss: 7.3227e-07 - mae_denorm: 7.6883e-07 - val_loss: 3.1431 - val_smape_loss: 1.8454 - val_mae_denorm: 331957920.0000
# Epoch 114/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.3642 - smape_loss: 7.3095e-07 - mae_denorm: 7.6745e-07Tiempo on_epoch_end 2024-10-24 18:11:56
# 21/21 [==============================] - 1s 27ms/step - loss: 0.3638 - smape_loss: 7.2413e-07 - mae_denorm: 7.6029e-07 - val_loss: 3.2006 - val_smape_loss: 1.8501 - val_mae_denorm: 211760208.0000
# Epoch 115/1000
# 21/21 [==============================] - ETA: 0s - loss: 0.3563 - smape_loss: 7.1127e-07 - mae_denorm: 7.4679e-07Tiempo on_epoch_end 2024-10-24 18:11:56
# 21/21 [==============================] - 1s 28ms/step - loss: 0.3563 - smape_loss: 7.1127e-07 - mae_denorm: 7.4679e-07 - val_loss: 3.1332 - val_smape_loss: 1.8468 - val_mae_denorm: 156798816.0000
# Epoch 116/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.3436 - smape_loss: 7.1648e-07 - mae_denorm: 7.5225e-07Tiempo on_epoch_end 2024-10-24 18:11:57
# 21/21 [==============================] - 1s 25ms/step - loss: 0.3440 - smape_loss: 7.0906e-07 - mae_denorm: 7.4446e-07 - val_loss: 3.1908 - val_smape_loss: 1.8455 - val_mae_denorm: 269804896.0000
# Epoch 117/1000
# 20/21 [===========================>..] - ETA: 0s - loss: 0.3378 - smape_loss: 7.0209e-07 - mae_denorm: 7.3715e-07Tiempo on_epoch_end 2024-10-24 18:11:57
# 21/21 [==============================] - 1s 27ms/step - loss: 0.3382 - smape_loss: 6.9995e-07 - mae_denorm: 7.3490e-07 - val_loss: 3.2226 - val_smape_loss: 1.8459 - val_mae_denorm: 199979472.0000
# Epoch 118/1000
# 21/21 [==============================] - ETA: 0s - loss: 0.3352 - smape_loss: 6.9875e-07 - mae_denorm: 7.3364e-07Tiempo on_epoch_end 2024-10-24 18:11:58
# 21/21 [==============================] - 1s 30ms/step - loss: 0.3352 - smape_loss: 6.9875e-07 - mae_denorm: 7.3364e-07 - val_loss: 3.1588 - val_smape_loss: 1.8447 - val_mae_denorm: 142150896.0000
# Epoch 119/1000
# 21/21 [==============================] - ETA: 0s - loss: 0.3261 - smape_loss: 6.9178e-07 - mae_denorm: 7.2632e-07Tiempo on_epoch_end 2024-10-24 18:11:59
# 21/21 [==============================] - 1s 28ms/step - loss: 0.3261 - smape_loss: 6.9178e-07 - mae_denorm: 7.2632e-07 - val_loss: 3.1830 - val_smape_loss: 1.8486 - val_mae_denorm: 175621936.0000
# Epoch 120/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.3251 - smape_loss: 6.8307e-07 - mae_denorm: 7.1718e-07Tiempo on_epoch_end 2024-10-24 18:11:59
# 21/21 [==============================] - 0s 23ms/step - loss: 0.3247 - smape_loss: 6.8834e-07 - mae_denorm: 7.2271e-07 - val_loss: 3.1124 - val_smape_loss: 1.8451 - val_mae_denorm: 106485080.0000
# Epoch 121/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.3219 - smape_loss: 6.4968e-07 - mae_denorm: 6.8212e-07Tiempo on_epoch_end 2024-10-24 18:12:00
# 21/21 [==============================] - 0s 23ms/step - loss: 0.3210 - smape_loss: 6.7780e-07 - mae_denorm: 7.1164e-07 - val_loss: 3.1467 - val_smape_loss: 1.8475 - val_mae_denorm: 131987568.0000
# Epoch 122/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.3178 - smape_loss: 6.8321e-07 - mae_denorm: 7.1732e-07Tiempo on_epoch_end 2024-10-24 18:12:00
# 21/21 [==============================] - 0s 23ms/step - loss: 0.3183 - smape_loss: 6.7817e-07 - mae_denorm: 7.1203e-07 - val_loss: 3.1736 - val_smape_loss: 1.8483 - val_mae_denorm: 142180448.0000
# Epoch 123/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.3216 - smape_loss: 7.0367e-07 - mae_denorm: 7.3880e-07Tiempo on_epoch_end 2024-10-24 18:12:01
# 21/21 [==============================] - 0s 22ms/step - loss: 0.3209 - smape_loss: 6.9373e-07 - mae_denorm: 7.2836e-07 - val_loss: 3.2265 - val_smape_loss: 1.8512 - val_mae_denorm: 261492608.0000
# Epoch 124/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.3139 - smape_loss: 6.8188e-07 - mae_denorm: 7.1592e-07Tiempo on_epoch_end 2024-10-24 18:12:01
# 21/21 [==============================] - 1s 24ms/step - loss: 0.3155 - smape_loss: 6.7891e-07 - mae_denorm: 7.1281e-07 - val_loss: 3.2298 - val_smape_loss: 1.8499 - val_mae_denorm: 195843904.0000
# Epoch 125/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.3403 - smape_loss: 6.7419e-07 - mae_denorm: 7.0785e-07Tiempo on_epoch_end 2024-10-24 18:12:02
# 21/21 [==============================] - 0s 22ms/step - loss: 0.3392 - smape_loss: 6.7679e-07 - mae_denorm: 7.1059e-07 - val_loss: 3.3568 - val_smape_loss: 1.8553 - val_mae_denorm: 575220736.0000
# Epoch 126/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.3256 - smape_loss: 6.8670e-07 - mae_denorm: 7.2098e-07Tiempo on_epoch_end 2024-10-24 18:12:02
# 21/21 [==============================] - 0s 23ms/step - loss: 0.3254 - smape_loss: 6.8102e-07 - mae_denorm: 7.1502e-07 - val_loss: 3.3650 - val_smape_loss: 1.8550 - val_mae_denorm: 885857792.0000
# Epoch 127/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.3130 - smape_loss: 6.6597e-07 - mae_denorm: 6.9922e-07Tiempo on_epoch_end 2024-10-24 18:12:03
# 21/21 [==============================] - 0s 24ms/step - loss: 0.3127 - smape_loss: 6.7981e-07 - mae_denorm: 7.1375e-07 - val_loss: 3.3508 - val_smape_loss: 1.8568 - val_mae_denorm: 635507456.0000
# Epoch 128/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.3016 - smape_loss: 6.4025e-07 - mae_denorm: 6.7221e-07Tiempo on_epoch_end 2024-10-24 18:12:03
# 21/21 [==============================] - 0s 23ms/step - loss: 0.3010 - smape_loss: 6.5191e-07 - mae_denorm: 6.8446e-07 - val_loss: 3.2993 - val_smape_loss: 1.8518 - val_mae_denorm: 555138880.0000
# Epoch 129/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.2980 - smape_loss: 6.4530e-07 - mae_denorm: 6.7751e-07Tiempo on_epoch_end 2024-10-24 18:12:03
# 21/21 [==============================] - 0s 22ms/step - loss: 0.2971 - smape_loss: 6.5340e-07 - mae_denorm: 6.8603e-07 - val_loss: 3.3358 - val_smape_loss: 1.8579 - val_mae_denorm: 790473472.0000
# Epoch 130/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.2958 - smape_loss: 6.3866e-07 - mae_denorm: 6.7054e-07Tiempo on_epoch_end 2024-10-24 18:12:04
# 21/21 [==============================] - 0s 24ms/step - loss: 0.2961 - smape_loss: 6.4344e-07 - mae_denorm: 6.7556e-07 - val_loss: 3.3513 - val_smape_loss: 1.8576 - val_mae_denorm: 818044928.0000
# Epoch 131/1000
# ...
# 21/21 [==============================] - 1s 25ms/step - loss: 0.5750 - smape_loss: 7.5596e-07 - mae_denorm: 7.9371e-07 - val_loss: 4.5672 - val_smape_loss: 1.8315 - val_mae_denorm: 38032811579408384.0000
# Epoch 959/1000
# 21/21 [==============================] - ETA: 0s - loss: 0.5873 - smape_loss: 7.5663e-07 - mae_denorm: 7.9441e-07Tiempo on_epoch_end 2024-10-24 18:19:49
# 21/21 [==============================] - 1s 33ms/step - loss: 0.5873 - smape_loss: 7.5663e-07 - mae_denorm: 7.9441e-07 - val_loss: 4.5673 - val_smape_loss: 1.8291 - val_mae_denorm: 61683195023720448.0000
# Epoch 960/1000
# 21/21 [==============================] - ETA: 0s - loss: 0.6065 - smape_loss: 7.6170e-07 - mae_denorm: 7.9974e-07Tiempo on_epoch_end 2024-10-24 18:19:50
# 21/21 [==============================] - 1s 36ms/step - loss: 0.6065 - smape_loss: 7.6170e-07 - mae_denorm: 7.9974e-07 - val_loss: 4.4106 - val_smape_loss: 1.8208 - val_mae_denorm: 38847124493828096.0000
# Epoch 961/1000
# 20/21 [===========================>..] - ETA: 0s - loss: 0.5824 - smape_loss: 7.5957e-07 - mae_denorm: 7.9751e-07Tiempo on_epoch_end 2024-10-24 18:19:50
# 21/21 [==============================] - 1s 32ms/step - loss: 0.5829 - smape_loss: 7.5755e-07 - mae_denorm: 7.9538e-07 - val_loss: 4.3413 - val_smape_loss: 1.8189 - val_mae_denorm: 31469388586549248.0000
# Epoch 962/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.5744 - smape_loss: 7.6842e-07 - mae_denorm: 8.0679e-07Tiempo on_epoch_end 2024-10-24 18:19:51
# 21/21 [==============================] - 1s 34ms/step - loss: 0.5745 - smape_loss: 7.5500e-07 - mae_denorm: 7.9270e-07 - val_loss: 4.3278 - val_smape_loss: 1.8203 - val_mae_denorm: 26569103632236544.0000
# Epoch 963/1000
# 21/21 [==============================] - ETA: 0s - loss: 0.5641 - smape_loss: 7.5445e-07 - mae_denorm: 7.9212e-07Tiempo on_epoch_end 2024-10-24 18:19:52
# 21/21 [==============================] - 1s 33ms/step - loss: 0.5641 - smape_loss: 7.5445e-07 - mae_denorm: 7.9212e-07 - val_loss: 4.3574 - val_smape_loss: 1.8208 - val_mae_denorm: 24103895483547648.0000
# Epoch 964/1000
# 21/21 [==============================] - ETA: 0s - loss: 0.5624 - smape_loss: 7.5735e-07 - mae_denorm: 7.9517e-07Tiempo on_epoch_end 2024-10-24 18:19:53
# 21/21 [==============================] - 1s 36ms/step - loss: 0.5624 - smape_loss: 7.5735e-07 - mae_denorm: 7.9517e-07 - val_loss: 4.3499 - val_smape_loss: 1.8180 - val_mae_denorm: 21294316857065472.0000
# Epoch 965/1000
# 21/21 [==============================] - ETA: 0s - loss: 0.5921 - smape_loss: 7.6237e-07 - mae_denorm: 8.0044e-07Tiempo on_epoch_end 2024-10-24 18:19:53
# 21/21 [==============================] - 1s 36ms/step - loss: 0.5921 - smape_loss: 7.6237e-07 - mae_denorm: 8.0044e-07 - val_loss: 4.4409 - val_smape_loss: 1.8232 - val_mae_denorm: 23083082689019904.0000
# Epoch 966/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.5751 - smape_loss: 7.4920e-07 - mae_denorm: 7.8662e-07Tiempo on_epoch_end 2024-10-24 18:19:54
# 21/21 [==============================] - 1s 31ms/step - loss: 0.5753 - smape_loss: 7.5680e-07 - mae_denorm: 7.9459e-07 - val_loss: 4.4321 - val_smape_loss: 1.8257 - val_mae_denorm: 18579309115473920.0000
# Epoch 967/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.5728 - smape_loss: 7.6608e-07 - mae_denorm: 8.0434e-07Tiempo on_epoch_end 2024-10-24 18:19:55
# 21/21 [==============================] - 1s 32ms/step - loss: 0.5759 - smape_loss: 7.5842e-07 - mae_denorm: 7.9629e-07 - val_loss: 4.5757 - val_smape_loss: 1.8251 - val_mae_denorm: 47817099267014656.0000
# Epoch 968/1000
# 21/21 [==============================] - ETA: 0s - loss: 0.6213 - smape_loss: 7.6656e-07 - mae_denorm: 8.0484e-07Tiempo on_epoch_end 2024-10-24 18:19:55
# 21/21 [==============================] - 1s 28ms/step - loss: 0.6213 - smape_loss: 7.6656e-07 - mae_denorm: 8.0484e-07 - val_loss: 4.6106 - val_smape_loss: 1.8255 - val_mae_denorm: 106361738349248512.0000
# Epoch 969/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.5813 - smape_loss: 7.6961e-07 - mae_denorm: 8.0804e-07Tiempo on_epoch_end 2024-10-24 18:19:56
# 21/21 [==============================] - 1s 24ms/step - loss: 0.5807 - smape_loss: 7.5793e-07 - mae_denorm: 7.9578e-07 - val_loss: 4.5952 - val_smape_loss: 1.8264 - val_mae_denorm: 65634625065582592.0000
# Epoch 970/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.5638 - smape_loss: 7.6362e-07 - mae_denorm: 8.0175e-07Tiempo on_epoch_end 2024-10-24 18:19:56
# 21/21 [==============================] - 1s 29ms/step - loss: 0.5650 - smape_loss: 7.5431e-07 - mae_denorm: 7.9198e-07 - val_loss: 4.5537 - val_smape_loss: 1.8267 - val_mae_denorm: 52771636100726784.0000
# Epoch 971/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.5534 - smape_loss: 7.5166e-07 - mae_denorm: 7.8919e-07Tiempo on_epoch_end 2024-10-24 18:19:57
# 21/21 [==============================] - 1s 26ms/step - loss: 0.5552 - smape_loss: 7.5144e-07 - mae_denorm: 7.8897e-07 - val_loss: 4.4718 - val_smape_loss: 1.8284 - val_mae_denorm: 46898173834166272.0000
# Epoch 972/1000
# 21/21 [==============================] - ETA: 0s - loss: 0.5815 - smape_loss: 7.6066e-07 - mae_denorm: 7.9865e-07Tiempo on_epoch_end 2024-10-24 18:19:58
# 21/21 [==============================] - 1s 27ms/step - loss: 0.5815 - smape_loss: 7.6066e-07 - mae_denorm: 7.9865e-07 - val_loss: 4.4987 - val_smape_loss: 1.8247 - val_mae_denorm: 47810454952607744.0000
# Epoch 973/1000
# 21/21 [==============================] - ETA: 0s - loss: 0.5796 - smape_loss: 7.6177e-07 - mae_denorm: 7.9981e-07Tiempo on_epoch_end 2024-10-24 18:19:58
# 21/21 [==============================] - 1s 28ms/step - loss: 0.5796 - smape_loss: 7.6177e-07 - mae_denorm: 7.9981e-07 - val_loss: 4.5414 - val_smape_loss: 1.8324 - val_mae_denorm: 61043678688313344.0000
# Epoch 974/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.5789 - smape_loss: 7.5283e-07 - mae_denorm: 7.9043e-07Tiempo on_epoch_end 2024-10-24 18:19:59
# 21/21 [==============================] - 1s 27ms/step - loss: 0.5776 - smape_loss: 7.5645e-07 - mae_denorm: 7.9423e-07 - val_loss: 4.5251 - val_smape_loss: 1.8264 - val_mae_denorm: 51099244555141120.0000
# Epoch 975/1000
# 20/21 [===========================>..] - ETA: 0s - loss: 0.5697 - smape_loss: 7.5200e-07 - mae_denorm: 7.8955e-07Tiempo on_epoch_end 2024-10-24 18:19:59
# 21/21 [==============================] - 1s 27ms/step - loss: 0.5708 - smape_loss: 7.5663e-07 - mae_denorm: 7.9441e-07 - val_loss: 4.5762 - val_smape_loss: 1.8262 - val_mae_denorm: 71555868843311104.0000
# Epoch 976/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.5761 - smape_loss: 7.6027e-07 - mae_denorm: 7.9823e-07Tiempo on_epoch_end 2024-10-24 18:20:00
# 21/21 [==============================] - 1s 25ms/step - loss: 0.5781 - smape_loss: 7.5922e-07 - mae_denorm: 7.9714e-07 - val_loss: 4.4938 - val_smape_loss: 1.8274 - val_mae_denorm: 28147879923154944.0000
# Epoch 977/1000
# 21/21 [==============================] - ETA: 0s - loss: 0.5827 - smape_loss: 7.6053e-07 - mae_denorm: 7.9851e-07Tiempo on_epoch_end 2024-10-24 18:20:00
# 21/21 [==============================] - 1s 26ms/step - loss: 0.5827 - smape_loss: 7.6053e-07 - mae_denorm: 7.9851e-07 - val_loss: 4.5530 - val_smape_loss: 1.8323 - val_mae_denorm: 48078847458934784.0000
# Epoch 978/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.6076 - smape_loss: 7.6075e-07 - mae_denorm: 7.9874e-07Tiempo on_epoch_end 2024-10-24 18:20:01
# 21/21 [==============================] - 1s 24ms/step - loss: 0.6056 - smape_loss: 7.6249e-07 - mae_denorm: 8.0057e-07 - val_loss: 4.5085 - val_smape_loss: 1.8362 - val_mae_denorm: 30509504198082560.0000
# Epoch 979/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.5642 - smape_loss: 7.5256e-07 - mae_denorm: 7.9014e-07Tiempo on_epoch_end 2024-10-24 18:20:01
# 21/21 [==============================] - 1s 25ms/step - loss: 0.5634 - smape_loss: 7.5477e-07 - mae_denorm: 7.9246e-07 - val_loss: 4.4498 - val_smape_loss: 1.8350 - val_mae_denorm: 21109016935530496.0000
# Epoch 980/1000
# 21/21 [==============================] - ETA: 0s - loss: 0.5626 - smape_loss: 7.5559e-07 - mae_denorm: 7.9332e-07Tiempo on_epoch_end 2024-10-24 18:20:02
# 21/21 [==============================] - 1s 25ms/step - loss: 0.5626 - smape_loss: 7.5559e-07 - mae_denorm: 7.9332e-07 - val_loss: 4.4046 - val_smape_loss: 1.8327 - val_mae_denorm: 12550452784660480.0000
# Epoch 981/1000
# 21/21 [==============================] - ETA: 0s - loss: 0.5753 - smape_loss: 7.5671e-07 - mae_denorm: 7.9450e-07Tiempo on_epoch_end 2024-10-24 18:20:02
# 21/21 [==============================] - 1s 25ms/step - loss: 0.5753 - smape_loss: 7.5671e-07 - mae_denorm: 7.9450e-07 - val_loss: 4.4345 - val_smape_loss: 1.8317 - val_mae_denorm: 13977376211861504.0000
# Epoch 982/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.5708 - smape_loss: 7.5207e-07 - mae_denorm: 7.8962e-07Tiempo on_epoch_end 2024-10-24 18:20:03
# 21/21 [==============================] - 1s 25ms/step - loss: 0.5700 - smape_loss: 7.5501e-07 - mae_denorm: 7.9271e-07 - val_loss: 4.3966 - val_smape_loss: 1.8327 - val_mae_denorm: 8617425603919872.0000
# Epoch 983/1000
# 21/21 [==============================] - ETA: 0s - loss: 0.5731 - smape_loss: 7.5950e-07 - mae_denorm: 7.9743e-07Tiempo on_epoch_end 2024-10-24 18:20:03
# 21/21 [==============================] - 1s 25ms/step - loss: 0.5731 - smape_loss: 7.5950e-07 - mae_denorm: 7.9743e-07 - val_loss: 4.4206 - val_smape_loss: 1.8262 - val_mae_denorm: 9601497100713984.0000
# Epoch 984/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.5759 - smape_loss: 7.4909e-07 - mae_denorm: 7.8650e-07Tiempo on_epoch_end 2024-10-24 18:20:04
# 21/21 [==============================] - 1s 25ms/step - loss: 0.5762 - smape_loss: 7.5928e-07 - mae_denorm: 7.9720e-07 - val_loss: 4.3282 - val_smape_loss: 1.8194 - val_mae_denorm: 5777601817739264.0000
# Epoch 985/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.5615 - smape_loss: 7.5472e-07 - mae_denorm: 7.9241e-07Tiempo on_epoch_end 2024-10-24 18:20:05
# 21/21 [==============================] - 1s 27ms/step - loss: 0.5599 - smape_loss: 7.5608e-07 - mae_denorm: 7.9384e-07 - val_loss: 4.3886 - val_smape_loss: 1.8288 - val_mae_denorm: 6586709768667136.0000
# Epoch 986/1000
# 21/21 [==============================] - ETA: 0s - loss: 0.5680 - smape_loss: 7.5662e-07 - mae_denorm: 7.9441e-07Tiempo on_epoch_end 2024-10-24 18:20:05
# 21/21 [==============================] - 1s 33ms/step - loss: 0.5680 - smape_loss: 7.5662e-07 - mae_denorm: 7.9441e-07 - val_loss: 4.3923 - val_smape_loss: 1.8305 - val_mae_denorm: 11984467363102720.0000
# Epoch 987/1000
# 20/21 [===========================>..] - ETA: 0s - loss: 0.5774 - smape_loss: 7.6319e-07 - mae_denorm: 8.0130e-07Tiempo on_epoch_end 2024-10-24 18:20:06
# 21/21 [==============================] - 1s 33ms/step - loss: 0.5765 - smape_loss: 7.5898e-07 - mae_denorm: 7.9688e-07 - val_loss: 4.4509 - val_smape_loss: 1.8256 - val_mae_denorm: 13645163712741376.0000
# Epoch 988/1000
# 20/21 [===========================>..] - ETA: 0s - loss: 0.5780 - smape_loss: 7.5682e-07 - mae_denorm: 7.9462e-07Tiempo on_epoch_end 2024-10-24 18:20:07
# 21/21 [==============================] - 1s 33ms/step - loss: 0.5783 - smape_loss: 7.6187e-07 - mae_denorm: 7.9992e-07 - val_loss: 4.4110 - val_smape_loss: 1.8242 - val_mae_denorm: 12057133914783744.0000
# Epoch 989/1000
# 20/21 [===========================>..] - ETA: 0s - loss: 0.5804 - smape_loss: 7.6475e-07 - mae_denorm: 8.0294e-07Tiempo on_epoch_end 2024-10-24 18:20:07
# 21/21 [==============================] - 1s 32ms/step - loss: 0.5804 - smape_loss: 7.5977e-07 - mae_denorm: 7.9771e-07 - val_loss: 4.4682 - val_smape_loss: 1.8262 - val_mae_denorm: 27085798935363584.0000
# Epoch 990/1000
# 20/21 [===========================>..] - ETA: 0s - loss: 0.5811 - smape_loss: 7.5736e-07 - mae_denorm: 7.9518e-07Tiempo on_epoch_end 2024-10-24 18:20:08
# 21/21 [==============================] - 1s 30ms/step - loss: 0.5823 - smape_loss: 7.5989e-07 - mae_denorm: 7.9784e-07 - val_loss: 4.3980 - val_smape_loss: 1.8227 - val_mae_denorm: 34403081030467584.0000
# Epoch 991/1000
# 21/21 [==============================] - ETA: 0s - loss: 0.5735 - smape_loss: 7.5624e-07 - mae_denorm: 7.9400e-07Tiempo on_epoch_end 2024-10-24 18:20:09
# 21/21 [==============================] - 1s 33ms/step - loss: 0.5735 - smape_loss: 7.5624e-07 - mae_denorm: 7.9400e-07 - val_loss: 4.3512 - val_smape_loss: 1.8196 - val_mae_denorm: 11067838664015872.0000
# Epoch 992/1000
# 21/21 [==============================] - ETA: 0s - loss: 0.5662 - smape_loss: 7.5643e-07 - mae_denorm: 7.9421e-07Tiempo on_epoch_end 2024-10-24 18:20:09
# 21/21 [==============================] - 1s 34ms/step - loss: 0.5662 - smape_loss: 7.5643e-07 - mae_denorm: 7.9421e-07 - val_loss: 4.3439 - val_smape_loss: 1.8205 - val_mae_denorm: 15960568770854912.0000
# Epoch 993/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.5707 - smape_loss: 7.5766e-07 - mae_denorm: 7.9549e-07Tiempo on_epoch_end 2024-10-24 18:20:10
# 21/21 [==============================] - 1s 32ms/step - loss: 0.5732 - smape_loss: 7.5677e-07 - mae_denorm: 7.9456e-07 - val_loss: 4.4374 - val_smape_loss: 1.8279 - val_mae_denorm: 28139564866469888.0000
# Epoch 994/1000
# 21/21 [==============================] - ETA: 0s - loss: 0.5707 - smape_loss: 7.5775e-07 - mae_denorm: 7.9558e-07Tiempo on_epoch_end 2024-10-24 18:20:11
# 21/21 [==============================] - 1s 28ms/step - loss: 0.5707 - smape_loss: 7.5775e-07 - mae_denorm: 7.9558e-07 - val_loss: 4.5059 - val_smape_loss: 1.8328 - val_mae_denorm: 15828941981876224.0000
# Epoch 995/1000
# 20/21 [===========================>..] - ETA: 0s - loss: 0.5556 - smape_loss: 7.5439e-07 - mae_denorm: 7.9206e-07Tiempo on_epoch_end 2024-10-24 18:20:11
# 21/21 [==============================] - 1s 26ms/step - loss: 0.5567 - smape_loss: 7.5474e-07 - mae_denorm: 7.9242e-07 - val_loss: 4.5884 - val_smape_loss: 1.8327 - val_mae_denorm: 20558784380272640.0000
# Epoch 996/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.5805 - smape_loss: 7.5981e-07 - mae_denorm: 7.9776e-07Tiempo on_epoch_end 2024-10-24 18:20:12
# 21/21 [==============================] - 1s 26ms/step - loss: 0.5803 - smape_loss: 7.6026e-07 - mae_denorm: 7.9822e-07 - val_loss: 4.5425 - val_smape_loss: 1.8291 - val_mae_denorm: 7565466780303360.0000
# Epoch 997/1000
# 20/21 [===========================>..] - ETA: 0s - loss: 0.5767 - smape_loss: 7.5644e-07 - mae_denorm: 7.9422e-07Tiempo on_epoch_end 2024-10-24 18:20:12
# 21/21 [==============================] - 1s 31ms/step - loss: 0.5752 - smape_loss: 7.5938e-07 - mae_denorm: 7.9730e-07 - val_loss: 4.5164 - val_smape_loss: 1.8317 - val_mae_denorm: 8601217471086592.0000
# Epoch 998/1000
# 20/21 [===========================>..] - ETA: 0s - loss: 0.5583 - smape_loss: 7.5987e-07 - mae_denorm: 7.9782e-07Tiempo on_epoch_end 2024-10-24 18:20:13
# 21/21 [==============================] - 1s 30ms/step - loss: 0.5584 - smape_loss: 7.5524e-07 - mae_denorm: 7.9296e-07 - val_loss: 4.5307 - val_smape_loss: 1.8389 - val_mae_denorm: 3811083127095296.0000
# Epoch 999/1000
# 19/21 [==========================>...] - ETA: 0s - loss: 0.5623 - smape_loss: 7.6758e-07 - mae_denorm: 8.0591e-07Tiempo on_epoch_end 2024-10-24 18:20:14
# 21/21 [==============================] - 1s 31ms/step - loss: 0.5627 - smape_loss: 7.5628e-07 - mae_denorm: 7.9404e-07 - val_loss: 4.4905 - val_smape_loss: 1.8445 - val_mae_denorm: 3403439459532800.0000
# Epoch 1000/1000
# 20/21 [===========================>..] - ETA: 0s - loss: 0.5653 - smape_loss: 7.4278e-07 - mae_denorm: 7.7988e-07Tiempo on_epoch_end 2024-10-24 18:20:14
# 21/21 [==============================] - 1s 31ms/step - loss: 0.5653 - smape_loss: 7.5782e-07 - mae_denorm: 7.9567e-07 - val_loss: 4.3765 - val_smape_loss: 1.8329 - val_mae_denorm: 1017652101251072.0000
# Tiempo Final y n_past 2024-10-24 18:21:14   n_past:--> 60

# %%
from matplotlib import pyplot as plt
plt.plot(history_modelo.history['loss'])
plt.plot(history_modelo.history['val_loss'])
#plt.plot(history_modelo.history['val_smape_loss_zscore'])
plt.title('model accuracy')
plt.ylabel('loss')
plt.xlabel('epoch')
#plt.legend(['loss', 'val_loss','val_smape_loss_zscore'], loc='upper left')
plt.legend(['loss', 'val_loss'], loc='upper left')
plt.show()
best_score=min(history_modelo.history['val_loss'])
print('best_score',best_score)
#best_score_smape=min(history_modelo.history['val_smape_loss_zscore'])
#print('best_score smape',best_score_smape)
# Out:
# best_score 2.6862387657165527

# %%
from keras.utils import plot_model

fileplot=pathModelosJson
plot_model(reconstructed_model2, to_file=fileplot+'/model_plot.png', show_shapes=True, show_layer_names=True)

# %%
# %load_ext tensorboard

# %tensorboard --logdir "/content/drive/MyDrive/a Tesis de Grado/Tesis Versiones/tesis2023/Google Analytics 4/Tum Transmedia/modelos/modelos guardados/prueba1-30porciento/logs10divNday21DiasAtras"

# %%
from tensorflow.keras.saving import register_keras_serializable
media_train=train_previo_zscore['Número de vistas de página'].std()
std_train=train_previo_zscore['Número de vistas de página'].mean()
#esta metrica esta en el codigo de github del ganador
@register_keras_serializable()
def smape_loss(y_true, y_pred):
    #revierto zscore
    global media_train
    global std_train
    y_true=(y_true*std_train)+media_train
    y_pred=(y_pred*std_train)+media_train
    #revierto log1p
    y_true=tf.math.expm1(y_true)
    y_pred=tf.math.expm1(y_pred)
    epsilon = 0.1
    y_pred = tf.convert_to_tensor(y_pred)
    y_true = tf.cast(y_true, y_pred.dtype)
    # Calcular el denominador de SMAPE
    summ = tf.maximum(tf.abs(y_true) + tf.abs(y_pred) + epsilon, 0.5 + epsilon)

    # Calcular SMAPE
    smape = tf.abs(y_pred - y_true) / summ * 2.0

    # Retornar la media de SMAPE
    return K.mean(smape, axis=-1)

@register_keras_serializable()
def mae_denorm(y_true, y_pred):
    #revierto zscore
    global media_train
    global std_train
    y_true1=(y_true*std_train)+media_train
    y_pred1=(y_pred*std_train)+media_train
    #revierto log1p
    y_true2=tf.math.expm1(y_true1)
    y_pred2=tf.math.expm1(y_pred1)

    return tf.keras.losses.mean_absolute_error(y_true2, y_pred2)

# %%
#el mejor modelo de verdad
#pathModelosJsonMejor="/content/drive/MyDrive/a Tesis de Grado/Tesis Versiones/tesis 2024/UA/tum transmedia/modelos/modelos resultados/mejores modelos guardados/modelo"
#nombreMejorModeloMejor="/ ndays60hyperband mae 60 zscore.h5"#el mejor modelo es el hyperband de 28 dias y 107 época
pathModelosJsonMejor="/content/drive/MyDrive/a Tesis de Grado/Tesis Versiones/tesis 2024/UA/editorial universitaria/modelos/modelos resultados/prueba2 1000 epocas 1 capas sin early stopping"
nombreMejorModeloMejor="/hyperband056-2.686239-ndays60_1000epochs1capa.h5"#el mejor modelo es el hyperband de 28 dias y 107 época
n_past=60
cambio=datetime.datetime.now(timezone('UTC')) - timedelta(hours=3)
tiempoFinal=f"{cambio:%Y-%m-%d %H:%M:%S }"
print('Tiempo  Inicio y n_past',tiempoFinal , ' n_past:-->',n_past)
n_future = 60
n_features = train.shape[1]
X_train, y_train = split_series(train.values,n_past, n_future)
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1],n_features))
y_train = y_train.reshape((y_train.shape[0], y_train.shape[1], 1)) #no hace falta reshapear
X_test, y_test = split_series(test.values,n_past, n_future)
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1],n_features))
y_test = y_test.reshape((y_test.shape[0], y_test.shape[1], 1)) #no hace falta reshapear

reconstructed_model3 = tf.keras.models.load_model(pathModelosJsonMejor+nombreMejorModeloMejor,custom_objects={'smape_loss':smape_loss,'mae_denorm':mae_denorm})
# Out:
# Tiempo  Inicio y n_past 2024-10-24 18:31:06   n_past:--> 60

# %%
print("Evaluate on test data")
results = reconstructed_model3.evaluate(X_test,y_test, batch_size=64)
print("test loss", results)
# Out:
# Evaluate on test data
# 4/4 [==============================] - 1s 17ms/step - loss: 2.6862 - smape_loss: 1.7318 - mae_denorm: 5208184832.0000
# test loss [2.6862387657165527, 1.7317631244659424, 5208184832.0]

# %%
pred_e1d1=reconstructed_model3.predict(X_test)
pred_e1d1=deepcopy(pred_e1d1)
reshapePred=pred_e1d1.reshape((pred_e1d1.shape[0]*pred_e1d1.shape[2]),pred_e1d1.shape[1])
reshapeY_test=y_test.reshape((y_test.shape[0]*y_test.shape[2]),y_test.shape[1])
print(pred_e1d1.shape,reshapePred.shape)
print('y_test',y_test.shape,reshapeY_test.shape)
print(pred_e1d1)
# Out:
# 8/8 [==============================] - 0s 8ms/step
# (228, 60, 1) (228, 60)
# y_test (228, 60, 1) (228, 60)
# [[[ 0.13405733]
#   [-0.10485971]
#   [-0.11587724]
#   ...
#   [ 0.12007535]
#   [ 0.12170792]
#   [ 0.12329084]]
#
#  [[ 0.05874036]
#   [-0.20824885]
#   [-0.19488086]
#   ...
#   [ 0.1336513 ]
#   [ 0.13586427]
#   [ 0.1380217 ]]
#
#  [[ 0.01915782]
#   [ 0.07128946]
#   [ 0.02053672]
#   ...
#   [ 0.3408648 ]
#   [ 0.34353903]
#   [ 0.34610948]]
#
#  ...
#
#  [[-0.22857368]
#   [-0.27693883]
#   [-0.24053316]
#   ...
#   [ 0.33198687]
#   [ 0.33512256]
#   [ 0.33816913]]
#
#  [[-0.21391219]
#   [-0.2130254 ]
#   [-0.21878019]
#   ...
#   [ 0.34497365]
#   [ 0.3474636 ]
#   [ 0.34985176]]
#
#  [[ 0.14883399]
#   [-0.07219452]
#   [-0.05569784]
#   ...
#   [ 0.18183394]
#   [ 0.18258534]
#   [ 0.18330087]]]

# %%
print(np.expm1(y_test))
# Out:
# [[[ 34.]
#   [  6.]
#   [  4.]
#   ...
#   [ 56.]
#   [ 34.]
#   [ 15.]]
#
#  [[  6.]
#   [  4.]
#   [ 13.]
#   ...
#   [ 34.]
#   [ 15.]
#   [ 16.]]
#
#  [[  4.]
#   [ 13.]
#   [ 94.]
#   ...
#   [ 15.]
#   [ 16.]
#   [  9.]]
#
#  ...
#
#  [[ 20.]
#   [100.]
#   [ 25.]
#   ...
#   [  9.]
#   [ 50.]
#   [ 62.]]
#
#  [[100.]
#   [ 25.]
#   [ 17.]
#   ...
#   [ 50.]
#   [ 62.]
#   [ 34.]]
#
#  [[ 25.]
#   [ 17.]
#   [ 29.]
#   ...
#   [ 62.]
#   [ 34.]
#   [ 81.]]]

# %%
formaFinal=int(dataset.shape[0]*0.80)#80% para train y 20% para test
print(formaFinal)
dataset2=test_previo_log1p
train_df,test_df = dataset2[1:formaFinal], dataset[formaFinal:] #spliteo test/train
for column1 in dataset2.columns:
    std=test[column1].std()
    if std != 0:
        test[column] = (test[column] - test[column].mean()) / std
    else:
        # Si std es 0, puedes optar por no normalizar o asignar un valor específico
        test[column] = 0  # O algún otro valor neutral que prefieras
test_df=test
# Out:
# 1385
# <ipython-input-149-0fce25b5c094>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[column] = (test[column] - test[column].mean()) / std
# <ipython-input-149-0fce25b5c094>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[column] = 0  # O algún otro valor neutral que prefieras

# %%
X_test, y_test2 = split_series(test_df.values,n_past, n_future)
y_test2
# Out:
# array([[3.55534806, 1.94591015, 1.60943791, ..., 4.04305127, 3.55534806,
#         2.77258872],
#        [1.94591015, 1.60943791, 2.63905733, ..., 3.55534806, 2.77258872,
#         2.83321334],
#        [1.60943791, 2.63905733, 4.55387689, ..., 2.77258872, 2.83321334,
#         2.30258509],
#        ...,
#        [3.04452244, 4.61512052, 3.25809654, ..., 2.30258509, 3.93182563,
#         4.14313473],
#        [4.61512052, 3.25809654, 2.89037176, ..., 3.93182563, 4.14313473,
#         3.55534806],
#        [3.25809654, 2.89037176, 3.40119738, ..., 4.14313473, 3.55534806,
#         4.40671925]])

# %%
print(reconstructed_model2.predict(X_test))
# Out:
# 8/8 [==============================] - 0s 14ms/step
# [[[-0.00989227]
#   [-0.30038208]
#   [-0.30038208]
#   ...
#   [-0.30038208]
#   [-0.30038208]
#   [-0.30038208]]
#
#  [[-0.45747334]
#   [-0.31219292]
#   [-0.31219286]
#   ...
#   [-0.31219286]
#   [-0.31219286]
#   [-0.31219286]]
#
#  [[-0.3140918 ]
#   [-0.33975315]
#   [-0.33975315]
#   ...
#   [-0.3397531 ]
#   [-0.3397531 ]
#   [-0.3397531 ]]
#
#  ...
#
#  [[-0.49435169]
#   [-0.23936537]
#   [-0.23936537]
#   ...
#   [-0.23936556]
#   [-0.23936556]
#   [-0.23936555]]
#
#  [[-0.4357564 ]
#   [-0.21697423]
#   [-0.21697421]
#   ...
#   [-0.21697387]
#   [-0.2169738 ]
#   [-0.21697384]]
#
#  [[-0.02893209]
#   [-0.25230914]
#   [-0.25230914]
#   ...
#   [-0.25230914]
#   [-0.25230914]
#   [-0.25230914]]]

# %%
print('MEAN',train_previo_zscore['Número de vistas de página'].mean())
print('STD',train_previo_zscore['Número de vistas de página'].std())
# Out:
# MEAN 34.23988439306358
# STD 46.969185436927425

# %%
pred_e1d1=reconstructed_model3.predict(X_test, batch_size=64)
pred_e1d1=deepcopy(pred_e1d1)
reshapePred=pred_e1d1.reshape((pred_e1d1.shape[0]*pred_e1d1.shape[2]),pred_e1d1.shape[1])
reshapeY_test=y_test.reshape((y_test.shape[0]*y_test.shape[2]),y_test.shape[1])
print(pred_e1d1.shape,reshapePred.shape)
print('y_test',y_test.shape,reshapeY_test.shape)
def smape2(a, f):
    print('len(a)',len(a))

    #std=train_previo_zscore['Predictor Flag'].std()
    #media=train_previo_zscore['Predictor Flag'].mean()
    std=train_previo_zscore['Número de vistas de página'].std()
    media=train_previo_zscore['Número de vistas de página'].mean()
    #revierto zscore
    a=(a*std)+media
    f=(f*std)+media

    a=np.round(np.expm1(a))
    f=np.round(np.expm1(f))
    print('a',a)
    print('f',f)
    return (1/len(a) * np.sum(2 * np.abs(f-a) / (np.abs(a) + np.abs(f))) )

def mae_manual(a, f):
    print('len(a)', len(a))

    # Obtener la desviación estándar y media
    std = train_previo_zscore['Número de vistas de página'].std()
    media = train_previo_zscore['Número de vistas de página'].mean()

    # Revertir z-score
    a = (a * std) + media
    f = (f * std) + media

    a=np.round(np.expm1(a))
    f=np.round(np.expm1(f))
    print('a mae',a)
    print('f mae',f)

    epsilon = 0.1  # Valor para evitar divisiones por cero
    diff =np.abs(a-f)
    return np.mean(diff)#(1 / len(a)) * np.sum(diff)

def rmse_manual(a, f):
    print('len(a)', len(a))

    # Obtener la desviación estándar y media
    std = train_previo_zscore['Número de vistas de página'].std()
    media = train_previo_zscore['Número de vistas de página'].mean()

    # Revertir z-score
    a = (a * std) + media
    f = (f * std) + media

    a=np.round(np.expm1(a))
    f=np.round(np.expm1(f))

    # Calcular el RMSE (Error Cuadrático Medio)
    diff = np.square(a - f)  # Cuadrado de la diferencia
    mse = np.mean(diff)  # Error Cuadrático Medio
    rmse_calculado = np.sqrt(mse)  # Raíz cuadrada del MSE

    return rmse_calculado

auxpred=reshapePred.reshape((y_test.shape[0]*y_test.shape[1]),1)
auxpred2=auxpred.reshape((auxpred.shape[0]),)
auxY_test=reshapeY_test.reshape((y_test.shape[0]*y_test.shape[1]),1)
print(auxpred.shape)
print('smape',smape2(auxY_test,auxpred))
print('mae',mae_manual(auxY_test,auxpred))
print('rmse',rmse_manual(auxY_test,auxpred))
print(auxpred2.shape)
print(np.array([1,2,3]).shape)
print(auxpred2)
# Out:
# 4/4 [==============================] - 1s 13ms/step
# (244, 60, 1) (244, 60)
# y_test (244, 60, 1) (244, 60)
# (14640, 1)
# len(a) 14640
# a [[ 28.]
#  [ 54.]
#  [157.]
#  ...
#  [ 88.]
#  [103.]
#  [148.]]
# f [[ 160.]
#  [ 297.]
#  [ 355.]
#  ...
#  [1356.]
#  [1367.]
#  [1378.]]
# smape 1.3832376102208916
# len(a) 14640
# a mae [[ 28.]
#  [ 54.]
#  [157.]
#  ...
#  [ 88.]
#  [103.]
#  [148.]]
# f mae [[ 160.]
#  [ 297.]
#  [ 355.]
#  ...
#  [1356.]
#  [1367.]
#  [1378.]]
# mae 708.8170765027322
# len(a) 14640
# rmse 1641.6532904228848
# (14640,)
# (3,)
# [0.8975979 1.6067113 1.8129697 ... 3.3585365 3.3677824 3.3768513]

# %%
test_previo_log1p['Número de vistas de página']
X_test5, y_test5 = split_series(test_previo_log1p.values,n_past, n_future)
y_test5
# Out:
# array([[ 28.,  54., 157., ...,  17.,  58.,  61.],
#        [ 54., 157., 265., ...,  58.,  61.,  58.],
#        [157., 265., 202., ...,  61.,  58.,  28.],
#        ...,
#        [ 80.,  63.,  82., ...,  46.,  58.,  88.],
#        [ 63.,  82., 188., ...,  58.,  88., 103.],
#        [ 82., 188., 202., ...,  88., 103., 148.]])

# %%
y_test5.shape
# Out:
# (244, 60)

# %%
auxY_test.shape
# Out:
# (14640, 1)

# %%
# Obtener la desviación estándar y media
import matplotlib.pyplot as plt
std = train_previo_zscore['Número de vistas de página'].std()
media = train_previo_zscore['Número de vistas de página'].mean()

# Revertir z-score
#denorm_actually=(auxY_test*std)+media
#denorm_forecast=(auxpred*std)+media

#denorm_actually = np.array(denorm_actually)
#denorm_forecast = np.array(denorm_forecast)
def denorm_manual(a, f):
    print('len(a)', len(a))

    # Obtener la desviación estándar y media
    std = train_previo_zscore['Número de vistas de página'].std()
    media = train_previo_zscore['Número de vistas de página'].mean()

    # Revertir z-score
    a = (a * std) + media
    f = (f * std) + media

    a=np.round(np.expm1(a))
    f=np.round(np.expm1(f))

    return a,f
denorm_actually,denorm_forecast=  denorm_manual(auxY_test,auxpred)
# Crear un rango de índices para el eje x
x = np.arange(len(denorm_actually))

# Crear el plot
plt.figure(figsize=(10, 6))
#ultimos 60
plt.plot( denorm_actually[-60:], label='Valores de Reales', color='blue')
plt.plot( denorm_forecast[-60:], label='Valores de Pronosticados', color='orange')
#primeros 60
#plt.plot(np.arange(len(denorm_actually[:90])) ,denorm_actually[:90], label='Valores de Reales', color='blue')
#plt.plot(np.arange(len(denorm_actually[:90])) ,denorm_forecast[:90], label='Valores de Pronosticados', color='orange')
print(denorm_actually[:1])
plt.title('Comparación de valores de Actuales y Predichos')
plt.xlabel('-')
plt.ylabel('Vistas')
plt.legend()
plt.grid()
plt.show()
# Out:
# len(a) 14640
# [[28.]]

# %%
mae_manual(auxY_test[:64],auxpred[:64])
# Out:
# len(a) 64
# a mae [[ 34.]
#  [  6.]
#  [  4.]
#  [ 13.]
#  [ 94.]
#  [ 33.]
#  [ 37.]
#  [ 24.]
#  [ 14.]
#  [  6.]
#  [ 20.]
#  [ 14.]
#  [109.]
#  [ 46.]
#  [ 28.]
#  [ 29.]
#  [ 25.]
#  [ 49.]
#  [ 96.]
#  [ 21.]
#  [ 18.]
#  [ 33.]
#  [ 25.]
#  [  7.]
#  [ 27.]
#  [ 46.]
#  [ 45.]
#  [ 72.]
#  [ 26.]
#  [ 34.]
#  [  8.]
#  [ 12.]
#  [ 39.]
#  [ 20.]
#  [ 72.]
#  [ 22.]
#  [ 18.]
#  [  5.]
#  [ 34.]
#  [ 37.]
#  [ 58.]
#  [  8.]
#  [  6.]
#  [  4.]
#  [ 17.]
#  [ 45.]
#  [ 15.]
#  [ 64.]
#  [ 54.]
#  [ 41.]
#  [  5.]
#  [  8.]
#  [ 31.]
#  [ 33.]
#  [ 61.]
#  [ 13.]
#  [  9.]
#  [ 56.]
#  [ 34.]
#  [ 15.]
#  [  6.]
#  [  4.]
#  [ 13.]
#  [ 94.]]
# f mae [[26.]
#  [22.]
#  [19.]
#  [21.]
#  [23.]
#  [45.]
#  [31.]
#  [40.]
#  [37.]
#  [34.]
#  [33.]
#  [31.]
#  [35.]
#  [36.]
#  [40.]
#  [39.]
#  [36.]
#  [34.]
#  [32.]
#  [33.]
#  [37.]
#  [38.]
#  [36.]
#  [33.]
#  [31.]
#  [31.]
#  [33.]
#  [37.]
#  [37.]
#  [34.]
#  [32.]
#  [30.]
#  [31.]
#  [34.]
#  [36.]
#  [34.]
#  [32.]
#  [31.]
#  [30.]
#  [32.]
#  [34.]
#  [34.]
#  [32.]
#  [31.]
#  [31.]
#  [31.]
#  [33.]
#  [34.]
#  [33.]
#  [32.]
#  [31.]
#  [31.]
#  [32.]
#  [33.]
#  [33.]
#  [32.]
#  [32.]
#  [31.]
#  [32.]
#  [33.]
#  [25.]
#  [20.]
#  [23.]
#  [22.]]
# 19.234375
