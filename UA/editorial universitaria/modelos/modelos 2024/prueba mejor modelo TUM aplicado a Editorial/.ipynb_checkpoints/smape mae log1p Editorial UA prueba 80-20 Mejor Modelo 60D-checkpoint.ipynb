# %%
# !pip install keras-tuner==1.4.7
# !pip install pandas==2.1.4
# !pip install numpy==1.26.4
# !pip install tensorflow==2.15.0
# Out:
# Collecting keras-tuner==1.4.7
#   Downloading keras_tuner-1.4.7-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (from keras-tuner==1.4.7) (3.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras-tuner==1.4.7) (24.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from keras-tuner==1.4.7) (2.32.3)
# Collecting kt-legacy (from keras-tuner==1.4.7)
#   Downloading kt_legacy-1.0.5-py3-none-any.whl.metadata (221 bytes)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras->keras-tuner==1.4.7) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras->keras-tuner==1.4.7) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras->keras-tuner==1.4.7) (13.9.3)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras->keras-tuner==1.4.7) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras->keras-tuner==1.4.7) (3.11.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras->keras-tuner==1.4.7) (0.13.0)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.10/dist-packages (from keras->keras-tuner==1.4.7) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner==1.4.7) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner==1.4.7) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner==1.4.7) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner==1.4.7) (2024.8.30)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from optree->keras->keras-tuner==1.4.7) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras->keras-tuner==1.4.7) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras->keras-tuner==1.4.7) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras->keras-tuner==1.4.7) (0.1.2)
# Downloading keras_tuner-1.4.7-py3-none-any.whl (129 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.1/129.1 kB 5.5 MB/s eta 0:00:00
# Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Installing collected packages: kt-legacy, keras-tuner
# Successfully installed keras-tuner-1.4.7 kt-legacy-1.0.5
# Collecting pandas==2.1.4
#   Downloading pandas-2.1.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas==2.1.4) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas==2.1.4) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas==2.1.4) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas==2.1.4) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas==2.1.4) (1.16.0)
# Downloading pandas-2.1.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 25.2 MB/s eta 0:00:00
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.1.4 which is incompatible.
# Successfully installed pandas-2.1.4
# Requirement already satisfied: numpy==1.26.4 in /usr/local/lib/python3.10/dist-packages (1.26.4)
# Collecting tensorflow==2.15.0
#   Downloading tensorflow-2.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.4 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (18.1.1)
# Collecting ml-dtypes~=0.2.0 (from tensorflow==2.15.0)
#   Downloading ml_dtypes-0.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (1.26.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (4.12.2)
# Collecting wrapt<1.15,>=1.11.0 (from tensorflow==2.15.0)
#   Downloading wrapt-1.14.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (0.37.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (1.64.1)
# Collecting tensorboard<2.16,>=2.15 (from tensorflow==2.15.0)
#   Downloading tensorboard-2.15.2-py3-none-any.whl.metadata (1.7 kB)
# Collecting tensorflow-estimator<2.16,>=2.15.0 (from tensorflow==2.15.0)
#   Downloading tensorflow_estimator-2.15.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting keras<2.16,>=2.15.0 (from tensorflow==2.15.0)
#   Downloading keras-2.15.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow==2.15.0) (0.44.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (1.2.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.7)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.0.4)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.0.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.2.2)
# Downloading tensorflow-2.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (475.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 475.2/475.2 MB 3.5 MB/s eta 0:00:00
# Downloading keras-2.15.0-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 12.9 MB/s eta 0:00:00
# Downloading ml_dtypes-0.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 67.3 MB/s eta 0:00:00
# Downloading tensorboard-2.15.2-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 92.3 MB/s eta 0:00:00
# Downloading tensorflow_estimator-2.15.0-py2.py3-none-any.whl (441 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.0/442.0 kB 24.3 MB/s eta 0:00:00
# Downloading wrapt-1.14.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 9.6 MB/s eta 0:00:00
# Installing collected packages: wrapt, tensorflow-estimator, ml-dtypes, keras, tensorboard, tensorflow
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.16.0
#     Uninstalling wrapt-1.16.0:
#       Successfully uninstalled wrapt-1.16.0
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml-dtypes 0.4.1
#     Uninstalling ml-dtypes-0.4.1:
#       Successfully uninstalled ml-dtypes-0.4.1
#   Attempting uninstall: keras
#     Found existing installation: keras 3.4.1
#     Uninstalling keras-3.4.1:
#       Successfully uninstalled keras-3.4.1
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.17.0
#     Uninstalling tensorboard-2.17.0:
#       Successfully uninstalled tensorboard-2.17.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.17.0
#     Uninstalling tensorflow-2.17.0:
#       Successfully uninstalled tensorflow-2.17.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorstore 0.1.66 requires ml-dtypes>=0.3.1, but you have ml-dtypes 0.2.0 which is incompatible.
# tf-keras 2.17.0 requires tensorflow<2.18,>=2.17, but you have tensorflow 2.15.0 which is incompatible.
# Successfully installed keras-2.15.0 ml-dtypes-0.2.0 tensorboard-2.15.2 tensorflow-2.15.0 tensorflow-estimator-2.15.0 wrapt-1.14.1

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras #desde tensorflow 2 se importa keras,  como paquete integrado de tensorflow
import pandas as pd
import numpy as np
from math import sqrt
from numpy import concatenate
from matplotlib import pyplot
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM, GRU
import tensorflow as tf
from datetime import datetime
from keras.models import Sequential
from keras.layers import Dense,Flatten,LSTM,RepeatVector,TimeDistributed#, GRUCellV2
from copy import deepcopy

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Reading the data set, parsing the dates and inferring the date format to date time. We also fill the Nan’s with 0.
#agrego index_col=0 para solucionar Unnamed: 0 porque https://stackoverflow.com/questions/43983622/remove-unnamed-columns-in-pandas-dataframe
dataset = read_csv("/content/drive/MyDrive/a Tesis de Grado/Tesis Versiones/tesis 2024/UA/editorial universitaria/preprocesamiento/outlier/salidaCSV/salidaKNN2024EditorialUniversitariaOctubre.csv", index_col=0)
#dataset.fillna(0, inplace=True)//pasar nans a ceros
#revisar lo que hago en el otro dataset
print(dataset.size)
print(dataset.columns)

print(dataset.shape)
print(dataset)
dataset.head()
# Out:
# 67044
# Index(['Número de vistas de página', 'Usuarios nuevos', 'Usuarios',
#        'Número de sesiones por usuario', 'Sesiones', 'Argentina',
#        'Otros Paises', 'mobile', 'desktop', 'tablet',
#        'Categoría de dispositivo promedio', 'Categoría de dispositivo std',
#        'Windows', 'Android', 'Linux', 'Macintosh',
#        'Sistema operativo (not set)', 'iOS', 'Windows Phone', 'Chrome OS',
#        'Tizen', 'Sistema operativo promedio', 'Sistema operativo std',
#        'Organic Search', 'Social', 'Direct', 'Referral',
#        'Agrupación de canales predeterminada promedio',
#        'Agrupación de canales predeterminada std', 'mediana_de_medianas',
#        'lag_90', 'lag_180', 'lag_270', 'lag_360', 'mediana Dispositivos',
#        'mediana Sistema operativo',
#        'mediana Agrupación de canales predeterminada'],
#       dtype='object')
# (1812, 37)
#       Número de vistas de página  Usuarios nuevos  Usuarios  \
# 0                          541.0             22.0      22.0
# 1                          226.0             23.0      26.0
# 2                          136.0             18.0      24.0
# 3                          229.0             11.0      16.0
# 4                           60.0             10.0      13.0
# ...                          ...              ...       ...
# 1810                        46.0             32.0      39.0
# 1811                        58.0             30.0      35.0
# 1812                        88.0             40.0      48.0
# 1813                       103.0             44.0      58.0
# 1814                       148.0             61.0      73.0
#
#       Número de sesiones por usuario  Sesiones  Argentina  Otros Paises  \
# 0                           1.636364      36.0      540.0           1.0
# 1                           1.346154      35.0      212.0          14.0
# 2                           1.458333      35.0      133.0           3.0
# 3                           1.812500      29.0      224.0           5.0
# 4                           1.461538      19.0       56.0           4.0
# ...                              ...       ...        ...           ...
# 1810                        1.102564      43.0       27.0          19.0
# 1811                        1.028571      36.0       42.0          16.0
# 1812                        1.104167      53.0       65.0          23.0
# 1813                        1.137931      66.0       87.0          16.0
# 1814                        1.123288      82.0      137.0          11.0
#
#       mobile  desktop  tablet  ...  \
# 0       49.0    492.0     0.0  ...
# 1        8.0    211.0     7.0  ...
# 2       17.0    119.0     0.0  ...
# 3       14.0    215.0     0.0  ...
# 4       20.0     40.0     0.0  ...
# ...      ...      ...     ...  ...
# 1810    21.0     25.0     0.0  ...
# 1811    22.0     36.0     0.0  ...
# 1812    40.0     48.0     0.0  ...
# 1813    29.0     74.0     0.0  ...
# 1814    36.0    111.0     1.0  ...
#
#       Agrupación de canales predeterminada promedio  \
# 0                                            135.25
# 1                                             56.50
# 2                                             34.00
# 3                                             57.25
# 4                                             15.00
# ...                                             ...
# 1810                                          11.50
# 1811                                          14.50
# 1812                                          22.00
# 1813                                          25.75
# 1814                                          37.00
#
#       Agrupación de canales predeterminada std  mediana_de_medianas    lag_90  \
# 0                                   202.460340            89.697167  104.5151
# 1                                    84.049095            89.697167  104.5151
# 2                                    39.344630            89.697167  104.5151
# 3                                    94.035570            89.697167  104.5151
# 4                                     9.433981            89.697167  104.5151
# ...                                        ...                  ...       ...
# 1810                                  9.912114           132.000000   46.0000
# 1811                                 17.471405           132.000000  126.0000
# 1812                                 19.836834           127.000000  171.0000
# 1813                                 26.938587           123.000000  104.0000
# 1814                                 35.881752           127.000000  111.0000
#
#          lag_180   lag_270   lag_360  mediana Dispositivos  \
# 0     100.866425  99.52464  100.1708                  49.0
# 1     100.866425  99.52464  100.1708                   8.0
# 2     100.866425  99.52464  100.1708                  17.0
# 3     100.866425  99.52464  100.1708                  14.0
# 4     100.866425  99.52464  100.1708                  20.0
# ...          ...       ...       ...                   ...
# 1810  225.000000  84.00000  251.0000                  21.0
# 1811  214.000000  18.00000  176.0000                  22.0
# 1812  283.000000  38.00000   91.0000                  40.0
# 1813   89.000000  37.00000   54.0000                  29.0
# 1814   52.000000  43.00000   31.0000                  36.0
#
#       mediana Sistema operativo  mediana Agrupación de canales predeterminada
# 0                           1.0                                          28.0
# 1                           0.0                                          12.5
# 2                           0.0                                          20.0
# 3                           0.0                                           4.5
# 4                           0.0                                          18.0
# ...                         ...                                           ...
# 1810                        2.0                                           9.5
# 1811                        0.0                                           6.5
# 1812                        1.0                                          18.5
# 1813                        0.0                                          16.0
# 1814                        1.0                                          22.0
#
# [1812 rows x 37 columns]
#    Número de vistas de página  Usuarios nuevos  Usuarios  \
# 0                       541.0             22.0      22.0
# 1                       226.0             23.0      26.0
# 2                       136.0             18.0      24.0
# 3                       229.0             11.0      16.0
# 4                        60.0             10.0      13.0
#
#    Número de sesiones por usuario  Sesiones  Argentina  Otros Paises  mobile  \
# 0                        1.636364      36.0      540.0           1.0    49.0
# 1                        1.346154      35.0      212.0          14.0     8.0
# 2                        1.458333      35.0      133.0           3.0    17.0
# 3                        1.812500      29.0      224.0           5.0    14.0
# 4                        1.461538      19.0       56.0           4.0    20.0
#
#    desktop  tablet  ...  Agrupación de canales predeterminada promedio  \
# 0    492.0     0.0  ...                                         135.25
# 1    211.0     7.0  ...                                          56.50
# 2    119.0     0.0  ...                                          34.00
# 3    215.0     0.0  ...                                          57.25
# 4     40.0     0.0  ...                                          15.00
#
#    Agrupación de canales predeterminada std  mediana_de_medianas    lag_90  \
# 0                                202.460340            89.697167  104.5151
# 1                                 84.049095            89.697167  104.5151
# 2                                 39.344630            89.697167  104.5151
# 3                                 94.035570            89.697167  104.5151
# 4                                  9.433981            89.697167  104.5151
#
#       lag_180   lag_270   lag_360  mediana Dispositivos  \
# 0  100.866425  99.52464  100.1708                  49.0
# 1  100.866425  99.52464  100.1708                   8.0
# 2  100.866425  99.52464  100.1708                  17.0
# 3  100.866425  99.52464  100.1708                  14.0
# 4  100.866425  99.52464  100.1708                  20.0
#
#    mediana Sistema operativo  mediana Agrupación de canales predeterminada
# 0                        1.0                                          28.0
# 1                        0.0                                          12.5
# 2                        0.0                                          20.0
# 3                        0.0                                           4.5
# 4                        0.0                                          18.0
#
# [5 rows x 37 columns]

# %%
print(dataset.columns)
print(dataset.shape)
print(dataset.head())
# Out:
# Index(['Número de vistas de página', 'Usuarios nuevos', 'Usuarios',
#        'Número de sesiones por usuario', 'Sesiones', 'Argentina',
#        'Otros Paises', 'mobile', 'desktop', 'tablet',
#        'Categoría de dispositivo promedio', 'Categoría de dispositivo std',
#        'Windows', 'Android', 'Linux', 'Macintosh',
#        'Sistema operativo (not set)', 'iOS', 'Windows Phone', 'Chrome OS',
#        'Tizen', 'Sistema operativo promedio', 'Sistema operativo std',
#        'Organic Search', 'Social', 'Direct', 'Referral',
#        'Agrupación de canales predeterminada promedio',
#        'Agrupación de canales predeterminada std', 'mediana_de_medianas',
#        'lag_90', 'lag_180', 'lag_270', 'lag_360', 'mediana Dispositivos',
#        'mediana Sistema operativo',
#        'mediana Agrupación de canales predeterminada'],
#       dtype='object')
# (1812, 37)
#    Número de vistas de página  Usuarios nuevos  Usuarios  \
# 0                       541.0             22.0      22.0
# 1                       226.0             23.0      26.0
# 2                       136.0             18.0      24.0
# 3                       229.0             11.0      16.0
# 4                        60.0             10.0      13.0
#
#    Número de sesiones por usuario  Sesiones  Argentina  Otros Paises  mobile  \
# 0                        1.636364      36.0      540.0           1.0    49.0
# 1                        1.346154      35.0      212.0          14.0     8.0
# 2                        1.458333      35.0      133.0           3.0    17.0
# 3                        1.812500      29.0      224.0           5.0    14.0
# 4                        1.461538      19.0       56.0           4.0    20.0
#
#    desktop  tablet  ...  Agrupación de canales predeterminada promedio  \
# 0    492.0     0.0  ...                                         135.25
# 1    211.0     7.0  ...                                          56.50
# 2    119.0     0.0  ...                                          34.00
# 3    215.0     0.0  ...                                          57.25
# 4     40.0     0.0  ...                                          15.00
#
#    Agrupación de canales predeterminada std  mediana_de_medianas    lag_90  \
# 0                                202.460340            89.697167  104.5151
# 1                                 84.049095            89.697167  104.5151
# 2                                 39.344630            89.697167  104.5151
# 3                                 94.035570            89.697167  104.5151
# 4                                  9.433981            89.697167  104.5151
#
#       lag_180   lag_270   lag_360  mediana Dispositivos  \
# 0  100.866425  99.52464  100.1708                  49.0
# 1  100.866425  99.52464  100.1708                   8.0
# 2  100.866425  99.52464  100.1708                  17.0
# 3  100.866425  99.52464  100.1708                  14.0
# 4  100.866425  99.52464  100.1708                  20.0
#
#    mediana Sistema operativo  mediana Agrupación de canales predeterminada
# 0                        1.0                                          28.0
# 1                        0.0                                          12.5
# 2                        0.0                                          20.0
# 3                        0.0                                           4.5
# 4                        0.0                                          18.0
#
# [5 rows x 37 columns]

# %%
#predictor Flag
from copy import deepcopy
from datetime import datetime as dt

# %%
#-Habia algo aca en el preprocesamiento anterior

# %%
#115*0.75 = 86.25=86
#train_df,test_df = dataset[1:86], dataset[86:]
# parrtir en 80 - 20 segun la profe
# probar sin normalizar los datos, es decir sin escalarlos
#normalizar
#partir datos de entrenamiento y prueba
#dataset.shape[0]=1734 o es 115 en caso del ejemplo
print('dataset.shape[0]',dataset.shape[0],' dataset.shape[1]',dataset.shape[1])
formaFinal=int(dataset.shape[0]*0.80)#80% para train y 20% para test
print(formaFinal)
train_df,test_df = dataset[1:formaFinal], dataset[formaFinal:] #spliteo test/train
train = train_df
test = test_df
# Normalización del conjunto de entrenamiento
train_previo_log1p=deepcopy(train)
for column in train.columns:
    train.loc[:, column] = np.log1p(train[column])
train_previo_zscore = deepcopy(train)
for column in train.columns:
    mean = train[column].mean()  # Media del conjunto de entrenamiento
    std = train[column].std()    # Desviación estándar del conjunto de entrenamiento
    train[column] = (train[column] - mean) / std
    if std != 0:
        train[column] = (train[column] - mean) / std
    else:
        train[column] = 0
test_previo_log1p=deepcopy(test)
for column1 in test.columns:
    test.loc[:, column1] = np.log1p(test[column1])
# Normalización del conjunto de prueba
test_previo_zscore = deepcopy(test)
for column1 in test.columns:
    mean_train = train_previo_zscore[column1].mean()  # Media del conjunto de entrenamiento
    std_train = train_previo_zscore[column1].std()    # Desviación estándar del conjunto de entrenamiento
    if std_train != 0:
        test[column1] = (test[column1] - mean_train) / std_train
    else:
        test[column1] = 0  

print('train_df',train_df.shape)
print('test_df',test_df.shape)
print('test',test.shape,test.values[11])
# Out:
# dataset.shape[0] 1812  dataset.shape[1] 37
# 1449
# train_df (1448, 37)
# test_df (363, 37)
# test (363, 37) [ 0.28415351  1.1688435   1.02416001 -0.13314932  0.98638305  0.29219525
#   0.55355397  0.63233177  0.17913578 -0.31654803  0.27608745  0.03695034
#   0.24148466  0.61676554 -0.57537463  0.14709346 -0.26314637  0.7923334
#  -0.07800006 -0.13480537  0.          0.24945006  0.16704669  0.21340899
#   1.19930762  0.4991939   0.30510696  0.27205578  0.02022211  0.73229229
#  -0.46937797 -0.16210613 -0.62924135  0.51988287  0.75262886 -0.42932858
#   0.57881099]
# <ipython-input-8-f3b70a0d6653>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train[column] = (train[column] - mean) / std
# <ipython-input-8-f3b70a0d6653>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train[column] = (train[column] - mean) / std
# <ipython-input-8-f3b70a0d6653>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train[column] = 0
# <ipython-input-8-f3b70a0d6653>:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[column1] = (test[column1] - mean_train) / std_train
# <ipython-input-8-f3b70a0d6653>:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[column1] = 0  # O algún otro valor neutral que prefieras

# %%
#reshape a entrada

def split_series(series, n_past, n_future):
  #
  # n_past ==> no of past observations
  #
  # n_future ==> no of future observations
  #
  X, y = list(), list()
  for window_start in range(len(series)):
    past_end = window_start + n_past
    future_end = past_end + n_future
    if future_end > len(series):
      break
    # slicing the past and future parts of the window
    #past, future = series[window_start:past_end, :], series[past_end:future_end, :]
    #window_start cuando comienza  past_end es cuando termina y future_endes cuando termina las series a comparar, 0 es porque solo va a tomar la primera columna
    #la cual es la de total de vistas
    past, future = series[window_start:past_end, :], series[past_end:future_end, 0]
    X.append(past)
    y.append(future)
  return np.array(X), np.array(y)
# Out:
# "\nn_past = 50 #va a mirar 10 dias al pasado para predecir x dias a futuro\nn_future = 7 #anterior 5 #probar 7 dias a futuro\nn_features = dataset.shape[1] # Columnas totales del dataset\n\n#Now convert both the train and test data into samples using the split_series function.\n\nX_train, y_train = split_series(train.values,n_past, n_future)\nX_train = X_train.reshape((X_train.shape[0], X_train.shape[1],n_features))\n#y_train = y_train.reshape((y_train.shape[0], y_train.shape[1], n_features))\ny_train = y_train.reshape((y_train.shape[0], y_train.shape[1], 1)) #no hace falta reshapear\nX_test, y_test = split_series(test.values,n_past, n_future)\nX_test = X_test.reshape((X_test.shape[0], X_test.shape[1],n_features))\n#y_test = y_test.reshape((y_test.shape[0], y_test.shape[1], n_features))\ny_test = y_test.reshape((y_test.shape[0], y_test.shape[1], 1)) #no hace falta reshapear\nprint('X_train',X_train.shape,X_train)\nprint('y_train',y_train.shape,y_train)\nprint('X_test',X_test.shape,X_test)\nprint('y_test',y_test.shape,y_test)\n"

# %%
# !pip install keras-tuner -q

# %%
# !df -h
# Out:
# Filesystem      Size  Used Avail Use% Mounted on
# overlay         236G   35G  202G  15% /
# tmpfs            64M     0   64M   0% /dev
# shm             5.7G     0  5.7G   0% /dev/shm
# /dev/root       2.0G  1.2G  820M  59% /usr/sbin/docker-init
# tmpfs           6.4G  496K  6.4G   1% /var/colab
# /dev/sda1       242G   59G  184G  25% /kaggle/input
# tmpfs           6.4G     0  6.4G   0% /proc/acpi
# tmpfs           6.4G     0  6.4G   0% /proc/scsi
# tmpfs           6.4G     0  6.4G   0% /sys/firmware
# drive           100G   61G   40G  61% /content/drive

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0xffffffff
# cpu MHz		: 2199.998
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa mmio_stale_data retbleed bhi
# bogomips	: 4399.99
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 1
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0xffffffff
# cpu MHz		: 2199.998
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 1
# initial apicid	: 1
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa mmio_stale_data retbleed bhi
# bogomips	: 4399.99
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:

# %%
# !cat /proc/meminfo
# Out:
# MemTotal:       13290460 kB
# MemFree:         1632692 kB
# MemAvailable:   11833640 kB
# Buffers:          542856 kB
# Cached:          9573568 kB
# SwapCached:            0 kB
# Active:          1333844 kB
# Inactive:        9683384 kB
# Active(anon):       1776 kB
# Inactive(anon):   901180 kB
# Active(file):    1332068 kB
# Inactive(file):  8782204 kB
# Unevictable:          20 kB
# Mlocked:              20 kB
# SwapTotal:             0 kB
# SwapFree:              0 kB
# Dirty:              7744 kB
# Writeback:             0 kB
# AnonPages:        900888 kB
# Mapped:           721248 kB
# Shmem:              2140 kB
# KReclaimable:     412080 kB
# Slab:             486668 kB
# SReclaimable:     412080 kB
# SUnreclaim:        74588 kB
# KernelStack:        7664 kB
# PageTables:        11852 kB
# SecPageTables:         0 kB
# NFS_Unstable:          0 kB
# Bounce:                0 kB
# WritebackTmp:          0 kB
# CommitLimit:     6645228 kB
# Committed_AS:    3931880 kB
# VmallocTotal:   34359738367 kB
# VmallocUsed:       81804 kB
# VmallocChunk:          0 kB
# Percpu:             1144 kB
# HardwareCorrupted:     0 kB
# AnonHugePages:         0 kB
# ShmemHugePages:        0 kB
# ShmemPmdMapped:        0 kB
# FileHugePages:         0 kB
# FilePmdMapped:         0 kB
# CmaTotal:              0 kB
# CmaFree:               0 kB
# Unaccepted:            0 kB
# HugePages_Total:       0
# HugePages_Free:        0
# HugePages_Rsvd:        0
# HugePages_Surp:        0
# Hugepagesize:       2048 kB
# Hugetlb:               0 kB
# DirectMap4k:      179000 kB
# DirectMap2M:     6109184 kB
# DirectMap1G:     9437184 kB

# %%
# !/usr/local/cuda/bin/nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2023 NVIDIA Corporation
# Built on Tue_Aug_15_22:02:13_PDT_2023
# Cuda compilation tools, release 12.2, V12.2.140
# Build cuda_12.2.r12.2/compiler.33191640_0

# %%
# !which nvidia-smi
# Out:
# /opt/bin/nvidia-smi

# %%
# !nvidia-smi
# Out:
# Mon Oct 28 20:32:05 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
# !python --version
# Out:
# Python 3.10.12

# %%
import keras_tuner as kt
import datetime
from datetime import timedelta
from pytz import timezone
import tensorflow.keras.backend as K
import datetime
from datetime import timedelta
from pytz import timezone
print(tf. __version__)
print(pd. __version__)
print(np. __version__)
print(kt. __version__)
# Out:
# 2.15.0
# 2.1.4
# 1.26.4
# 1.4.7

# %%
# Establecer la semilla
seed_value = 42
import random 
# Establecer semillas
np.random.seed(seed_value)
random.seed(seed_value)
tf.random.set_seed(seed_value)
from tensorflow.keras.saving import register_keras_serializable

# %%
print('std',train_previo_zscore['Número de vistas de página'].std())
print('mean',train_previo_zscore['Número de vistas de página'].mean() )
# Out:
# std 0.8649864124052455
# mean 4.308087962814851

# %%
media_train=train_previo_zscore['Número de vistas de página'].std()
std_train=train_previo_zscore['Número de vistas de página'].mean()
#esta metrica esta en el codigo de github del ganador
@register_keras_serializable()
def smape_loss(y_true, y_pred):
    #revierto zscore
    global media_train
    global std_train
    y_true=(y_true*std_train)+media_train
    y_pred=(y_pred*std_train)+media_train
    #revierto log1p
    y_true=tf.math.expm1(y_true)
    y_pred=tf.math.expm1(y_pred)
    epsilon = 0.1
    y_pred = tf.convert_to_tensor(y_pred)
    y_true = tf.cast(y_true, y_pred.dtype)
    # Calcular el denominador de SMAPE
    summ = tf.maximum(tf.abs(y_true) + tf.abs(y_pred) + epsilon, 0.5 + epsilon)

    # Calcular SMAPE
    smape = tf.abs(y_pred - y_true) / summ * 2.0

    # Retornar la media de SMAPE
    return K.mean(smape, axis=-1)

@register_keras_serializable()
def mae_denorm(y_true, y_pred):
    #revierto zscore
    global media_train
    global std_train
    y_true1=(y_true*std_train)+media_train
    y_pred1=(y_pred*std_train)+media_train
    #revierto log1p
    y_true2=tf.math.expm1(y_true1)
    y_pred2=tf.math.expm1(y_pred1)

    return tf.keras.losses.mean_absolute_error(y_true2, y_pred2)

# %%
pathModelosJsonMejor="/content/drive/MyDrive/a Tesis de Grado/Tesis Versiones/tesis 2024/UA/tum transmedia/modelos/modelos resultados/mejores modelos guardados/modelo"
nombreMejorModeloMejor="/ ndays60hyperband mae 60 zscore.h5"#el mejor modelo es el hyperband de 28 dias y 107 época

reconstructed_model2 = tf.keras.models.load_model(pathModelosJsonMejor+nombreMejorModeloMejor,custom_objects={'smape_loss':smape_loss,'mae_denorm':mae_denorm})

# %%
from tensorflow.keras.callbacks import TensorBoard

# %%
pathModelosJson="/content/drive/MyDrive/a Tesis de Grado/Tesis Versiones/tesis 2024/UA/editorial universitaria/modelos/modelos resultados/prueba 500 epocas 1 capas sin early stopping"
nombreMejorModelo="ndays60_500epochs1capa.h5"
class PrintTimeCallback(tf.keras.callbacks.Callback):#https://www.tensorflow.org/guide/keras/writing_your_own_callbacks
    def on_epoch_end(self, epoch, logs=None):
        cambio=datetime.datetime.now(timezone('UTC')) - timedelta(hours=3)
        salida=f"{cambio:%Y-%m-%d %H:%M:%S }"
        print('Tiempo on_epoch_end',salida)
n_past=60
cambio=datetime.datetime.now(timezone('UTC')) - timedelta(hours=3)
tiempoFinal=f"{cambio:%Y-%m-%d %H:%M:%S }"
print('Tiempo  Inicio y n_past',tiempoFinal , ' n_past:-->',n_past)
n_future = 60
n_features = train.shape[1]
X_train, y_train = split_series(train.values,n_past, n_future)
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1],n_features))
y_train = y_train.reshape((y_train.shape[0], y_train.shape[1], 1)) #no hace falta reshapear
X_test, y_test = split_series(test.values,n_past, n_future)
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1],n_features))
y_test = y_test.reshape((y_test.shape[0], y_test.shape[1], 1)) #no hace falta reshapear
logpaht=pathModelosJson+f"/logsndays60_500epochs1capa"
from tensorflow.keras.callbacks import ReduceLROnPlateau
#reduce_lr = ReduceLROnPlateau(monitor='val_smape_loss_zscore', factor=0.5, patience=5, min_lr=1e-50)
callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=50)#https://pub.towardsai.net/keras-earlystopping-callback-to-train-the-neural-networks-perfectly-2a3f865148f7
mcp_save = tf.keras.callbacks.ModelCheckpoint(pathModelosJson+"/"+'hyperband{epoch:03d}-{val_loss:03f}-'+nombreMejorModelo, save_best_only=True, monitor='val_loss', mode='min')#https://stackoverflow.com/questions/48285129/saving-best-model-in-keras
history_modelo=reconstructed_model2.fit(X_train,y_train,epochs=500,validation_data=(X_test,y_test),batch_size=64,verbose=1,
                                        callbacks=[PrintTimeCallback(),
                                                   mcp_save,#reduce_lr,
                                                   TensorBoard(log_dir=logpaht, write_graph=False, profile_batch=0)
                                                   ])
cambio=datetime.datetime.now(timezone('UTC')) - timedelta(hours=3)
tiempoFinalDespues=f"{cambio:%Y-%m-%d %H:%M:%S }"
print('Tiempo Final y n_past',tiempoFinalDespues , ' n_past:-->',n_past)
#reentreno 70-30
# Out:
# Tiempo  Inicio y n_past 2024-10-28 17:33:33   n_past:--> 60
# Epoch 1/500
# 20/21 [===========================>..] - ETA: 0s - loss: 1.3412 - smape_loss: 0.0603 - mae_denorm: 0.1650Tiempo on_epoch_end 2024-10-28 17:33:43
# 21/21 [==============================] - 8s 85ms/step - loss: 1.3203 - smape_loss: 0.0581 - mae_denorm: 0.1589 - val_loss: 2.2328 - val_smape_loss: 1.6421 - val_mae_denorm: 629397.8125
# Epoch 2/500
# 11/21 [==============>...............] - ETA: 0s - loss: 0.8351 - smape_loss: 7.4488e-07 - mae_denorm: 7.8208e-07
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 21/21 [==============================] - ETA: 0s - loss: 0.8194 - smape_loss: 7.6797e-07 - mae_denorm: 8.0632e-07Tiempo on_epoch_end 2024-10-28 17:33:43
# 21/21 [==============================] - 0s 16ms/step - loss: 0.8194 - smape_loss: 7.6797e-07 - mae_denorm: 8.0632e-07 - val_loss: 2.3258 - val_smape_loss: 1.6477 - val_mae_denorm: 956937.0625
# Epoch 3/500
# 16/21 [=====================>........] - ETA: 0s - loss: 0.7787 - smape_loss: 7.6673e-07 - mae_denorm: 8.0501e-07Tiempo on_epoch_end 2024-10-28 17:33:44
# 21/21 [==============================] - 0s 13ms/step - loss: 0.7759 - smape_loss: 7.6797e-07 - mae_denorm: 8.0632e-07 - val_loss: 2.3104 - val_smape_loss: 1.6474 - val_mae_denorm: 935016.9375
# Epoch 4/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.7525 - smape_loss: 7.7525e-07 - mae_denorm: 8.1396e-07Tiempo on_epoch_end 2024-10-28 17:33:44
# 21/21 [==============================] - 0s 14ms/step - loss: 0.7529 - smape_loss: 7.6830e-07 - mae_denorm: 8.0667e-07 - val_loss: 2.3594 - val_smape_loss: 1.6554 - val_mae_denorm: 1168952.1250
# Epoch 5/500
# 17/21 [=======================>......] - ETA: 0s - loss: 0.7360 - smape_loss: 7.2622e-07 - mae_denorm: 7.6248e-07Tiempo on_epoch_end 2024-10-28 17:33:44
# 21/21 [==============================] - 0s 13ms/step - loss: 0.7330 - smape_loss: 7.6803e-07 - mae_denorm: 8.0639e-07 - val_loss: 2.3454 - val_smape_loss: 1.6570 - val_mae_denorm: 1014989.7500
# Epoch 6/500
# 18/21 [========================>.....] - ETA: 0s - loss: 0.7187 - smape_loss: 7.6604e-07 - mae_denorm: 8.0429e-07Tiempo on_epoch_end 2024-10-28 17:33:45
# 21/21 [==============================] - 0s 15ms/step - loss: 0.7208 - smape_loss: 7.6805e-07 - mae_denorm: 8.0640e-07 - val_loss: 2.3712 - val_smape_loss: 1.6625 - val_mae_denorm: 1149246.7500
# Epoch 7/500
# 18/21 [========================>.....] - ETA: 0s - loss: 0.7147 - smape_loss: 7.8693e-07 - mae_denorm: 8.2623e-07Tiempo on_epoch_end 2024-10-28 17:33:45
# 21/21 [==============================] - 0s 13ms/step - loss: 0.7132 - smape_loss: 7.6807e-07 - mae_denorm: 8.0643e-07 - val_loss: 2.4194 - val_smape_loss: 1.6666 - val_mae_denorm: 1436835.6250
# Epoch 8/500
# 18/21 [========================>.....] - ETA: 0s - loss: 0.7063 - smape_loss: 7.7219e-07 - mae_denorm: 8.1076e-07Tiempo on_epoch_end 2024-10-28 17:33:45
# 21/21 [==============================] - 0s 13ms/step - loss: 0.7060 - smape_loss: 7.6803e-07 - mae_denorm: 8.0638e-07 - val_loss: 2.4349 - val_smape_loss: 1.6706 - val_mae_denorm: 1671981.7500
# Epoch 9/500
# 18/21 [========================>.....] - ETA: 0s - loss: 0.6990 - smape_loss: 7.7285e-07 - mae_denorm: 8.1144e-07Tiempo on_epoch_end 2024-10-28 17:33:45
# 21/21 [==============================] - 0s 13ms/step - loss: 0.7006 - smape_loss: 7.6799e-07 - mae_denorm: 8.0634e-07 - val_loss: 2.4689 - val_smape_loss: 1.6724 - val_mae_denorm: 2059637.2500
# Epoch 10/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.6969 - smape_loss: 7.6497e-07 - mae_denorm: 8.0317e-07Tiempo on_epoch_end 2024-10-28 17:33:46
# 21/21 [==============================] - 0s 13ms/step - loss: 0.6963 - smape_loss: 7.6802e-07 - mae_denorm: 8.0638e-07 - val_loss: 2.4856 - val_smape_loss: 1.6753 - val_mae_denorm: 2312933.0000
# Epoch 11/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.6934 - smape_loss: 7.6231e-07 - mae_denorm: 8.0038e-07Tiempo on_epoch_end 2024-10-28 17:33:46
# 21/21 [==============================] - 0s 13ms/step - loss: 0.6928 - smape_loss: 7.6798e-07 - mae_denorm: 8.0634e-07 - val_loss: 2.4992 - val_smape_loss: 1.6778 - val_mae_denorm: 2584276.2500
# Epoch 12/500
# 17/21 [=======================>......] - ETA: 0s - loss: 0.6898 - smape_loss: 7.6517e-07 - mae_denorm: 8.0338e-07Tiempo on_epoch_end 2024-10-28 17:33:46
# 21/21 [==============================] - 0s 13ms/step - loss: 0.6894 - smape_loss: 7.6793e-07 - mae_denorm: 8.0628e-07 - val_loss: 2.5345 - val_smape_loss: 1.6802 - val_mae_denorm: 3402929.5000
# Epoch 13/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.6867 - smape_loss: 7.6219e-07 - mae_denorm: 8.0025e-07Tiempo on_epoch_end 2024-10-28 17:33:46
# 21/21 [==============================] - 0s 13ms/step - loss: 0.6860 - smape_loss: 7.6789e-07 - mae_denorm: 8.0624e-07 - val_loss: 2.5502 - val_smape_loss: 1.6831 - val_mae_denorm: 3928851.7500
# Epoch 14/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.6851 - smape_loss: 7.6282e-07 - mae_denorm: 8.0091e-07Tiempo on_epoch_end 2024-10-28 17:33:47
# 21/21 [==============================] - 0s 12ms/step - loss: 0.6844 - smape_loss: 7.6781e-07 - mae_denorm: 8.0615e-07 - val_loss: 2.5621 - val_smape_loss: 1.6869 - val_mae_denorm: 4055267.7500
# Epoch 15/500
# 18/21 [========================>.....] - ETA: 0s - loss: 0.6850 - smape_loss: 7.7107e-07 - mae_denorm: 8.0957e-07Tiempo on_epoch_end 2024-10-28 17:33:47
# 21/21 [==============================] - 0s 14ms/step - loss: 0.6832 - smape_loss: 7.6785e-07 - mae_denorm: 8.0619e-07 - val_loss: 2.5701 - val_smape_loss: 1.6864 - val_mae_denorm: 4312516.5000
# Epoch 16/500
# 18/21 [========================>.....] - ETA: 0s - loss: 0.6783 - smape_loss: 7.8404e-07 - mae_denorm: 8.2319e-07Tiempo on_epoch_end 2024-10-28 17:33:47
# 21/21 [==============================] - 0s 14ms/step - loss: 0.6788 - smape_loss: 7.6776e-07 - mae_denorm: 8.0610e-07 - val_loss: 2.5370 - val_smape_loss: 1.6869 - val_mae_denorm: 3768011.5000
# Epoch 17/500
# 18/21 [========================>.....] - ETA: 0s - loss: 0.6757 - smape_loss: 7.7638e-07 - mae_denorm: 8.1515e-07Tiempo on_epoch_end 2024-10-28 17:33:48
# 21/21 [==============================] - 0s 17ms/step - loss: 0.6760 - smape_loss: 7.6772e-07 - mae_denorm: 8.0606e-07 - val_loss: 2.5203 - val_smape_loss: 1.6878 - val_mae_denorm: 3605659.5000
# Epoch 18/500
# 20/21 [===========================>..] - ETA: 0s - loss: 0.6749 - smape_loss: 7.6309e-07 - mae_denorm: 8.0119e-07Tiempo on_epoch_end 2024-10-28 17:33:48
# 21/21 [==============================] - 0s 16ms/step - loss: 0.6744 - smape_loss: 7.6770e-07 - mae_denorm: 8.0604e-07 - val_loss: 2.5602 - val_smape_loss: 1.6928 - val_mae_denorm: 4663370.0000
# Epoch 19/500
# 20/21 [===========================>..] - ETA: 0s - loss: 0.6756 - smape_loss: 7.7684e-07 - mae_denorm: 8.1563e-07Tiempo on_epoch_end 2024-10-28 17:33:48
# 21/21 [==============================] - 0s 17ms/step - loss: 0.6753 - smape_loss: 7.6766e-07 - mae_denorm: 8.0599e-07 - val_loss: 2.5702 - val_smape_loss: 1.6961 - val_mae_denorm: 4898143.5000
# Epoch 20/500
# 17/21 [=======================>......] - ETA: 0s - loss: 0.6748 - smape_loss: 7.9134e-07 - mae_denorm: 8.3085e-07Tiempo on_epoch_end 2024-10-28 17:33:49
# 21/21 [==============================] - 0s 19ms/step - loss: 0.6732 - smape_loss: 7.6764e-07 - mae_denorm: 8.0598e-07 - val_loss: 2.5693 - val_smape_loss: 1.6967 - val_mae_denorm: 4655597.5000
# Epoch 21/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.6697 - smape_loss: 7.6736e-07 - mae_denorm: 8.0568e-07Tiempo on_epoch_end 2024-10-28 17:33:49
# 21/21 [==============================] - 0s 18ms/step - loss: 0.6695 - smape_loss: 7.6765e-07 - mae_denorm: 8.0599e-07 - val_loss: 2.6015 - val_smape_loss: 1.6985 - val_mae_denorm: 5860290.5000
# Epoch 22/500
# 21/21 [==============================] - ETA: 0s - loss: 0.6700 - smape_loss: 7.6762e-07 - mae_denorm: 8.0596e-07Tiempo on_epoch_end 2024-10-28 17:33:50
# 21/21 [==============================] - 0s 18ms/step - loss: 0.6700 - smape_loss: 7.6762e-07 - mae_denorm: 8.0596e-07 - val_loss: 2.5882 - val_smape_loss: 1.6989 - val_mae_denorm: 5369357.0000
# Epoch 23/500
# 21/21 [==============================] - ETA: 0s - loss: 0.6660 - smape_loss: 7.6753e-07 - mae_denorm: 8.0586e-07Tiempo on_epoch_end 2024-10-28 17:33:50
# 21/21 [==============================] - 0s 17ms/step - loss: 0.6660 - smape_loss: 7.6753e-07 - mae_denorm: 8.0586e-07 - val_loss: 2.5804 - val_smape_loss: 1.6999 - val_mae_denorm: 5253198.0000
# Epoch 24/500
# 18/21 [========================>.....] - ETA: 0s - loss: 0.6661 - smape_loss: 7.5402e-07 - mae_denorm: 7.9168e-07Tiempo on_epoch_end 2024-10-28 17:33:50
# 21/21 [==============================] - 0s 18ms/step - loss: 0.6647 - smape_loss: 7.6748e-07 - mae_denorm: 8.0581e-07 - val_loss: 2.5760 - val_smape_loss: 1.7002 - val_mae_denorm: 4707087.5000
# Epoch 25/500
# 21/21 [==============================] - ETA: 0s - loss: 0.6632 - smape_loss: 7.6739e-07 - mae_denorm: 8.0571e-07Tiempo on_epoch_end 2024-10-28 17:33:51
# 21/21 [==============================] - 0s 20ms/step - loss: 0.6632 - smape_loss: 7.6739e-07 - mae_denorm: 8.0571e-07 - val_loss: 2.5894 - val_smape_loss: 1.7009 - val_mae_denorm: 5102013.5000
# Epoch 26/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.6651 - smape_loss: 7.5577e-07 - mae_denorm: 7.9351e-07Tiempo on_epoch_end 2024-10-28 17:33:51
# 21/21 [==============================] - 0s 15ms/step - loss: 0.6661 - smape_loss: 7.6752e-07 - mae_denorm: 8.0585e-07 - val_loss: 2.5433 - val_smape_loss: 1.6988 - val_mae_denorm: 3780576.0000
# Epoch 27/500
# 18/21 [========================>.....] - ETA: 0s - loss: 0.6608 - smape_loss: 7.6774e-07 - mae_denorm: 8.0608e-07Tiempo on_epoch_end 2024-10-28 17:33:51
# 21/21 [==============================] - 0s 13ms/step - loss: 0.6631 - smape_loss: 7.6736e-07 - mae_denorm: 8.0568e-07 - val_loss: 2.5669 - val_smape_loss: 1.7010 - val_mae_denorm: 4181938.0000
# Epoch 28/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.6610 - smape_loss: 7.7616e-07 - mae_denorm: 8.1492e-07Tiempo on_epoch_end 2024-10-28 17:33:52
# 21/21 [==============================] - 0s 14ms/step - loss: 0.6604 - smape_loss: 7.6733e-07 - mae_denorm: 8.0565e-07 - val_loss: 2.5656 - val_smape_loss: 1.7034 - val_mae_denorm: 4136054.7500
# Epoch 29/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.6593 - smape_loss: 7.6182e-07 - mae_denorm: 7.9987e-07Tiempo on_epoch_end 2024-10-28 17:33:52
# 21/21 [==============================] - 0s 13ms/step - loss: 0.6579 - smape_loss: 7.6724e-07 - mae_denorm: 8.0555e-07 - val_loss: 2.5362 - val_smape_loss: 1.7025 - val_mae_denorm: 3432321.0000
# Epoch 30/500
# 17/21 [=======================>......] - ETA: 0s - loss: 0.6578 - smape_loss: 7.6608e-07 - mae_denorm: 8.0434e-07Tiempo on_epoch_end 2024-10-28 17:33:52
# 21/21 [==============================] - 0s 13ms/step - loss: 0.6565 - smape_loss: 7.6720e-07 - mae_denorm: 8.0551e-07 - val_loss: 2.5669 - val_smape_loss: 1.7052 - val_mae_denorm: 4230949.0000
# Epoch 31/500
# 17/21 [=======================>......] - ETA: 0s - loss: 0.6561 - smape_loss: 7.6046e-07 - mae_denorm: 7.9844e-07Tiempo on_epoch_end 2024-10-28 17:33:52
# 21/21 [==============================] - 0s 13ms/step - loss: 0.6544 - smape_loss: 7.6712e-07 - mae_denorm: 8.0543e-07 - val_loss: 2.5362 - val_smape_loss: 1.7010 - val_mae_denorm: 2947277.2500
# Epoch 32/500
# 17/21 [=======================>......] - ETA: 0s - loss: 0.6580 - smape_loss: 7.3880e-07 - mae_denorm: 7.7569e-07Tiempo on_epoch_end 2024-10-28 17:33:53
# 21/21 [==============================] - 0s 13ms/step - loss: 0.6559 - smape_loss: 7.6709e-07 - mae_denorm: 8.0540e-07 - val_loss: 2.5572 - val_smape_loss: 1.7024 - val_mae_denorm: 3519774.5000
# Epoch 33/500
# 18/21 [========================>.....] - ETA: 0s - loss: 0.6535 - smape_loss: 7.5903e-07 - mae_denorm: 7.9693e-07Tiempo on_epoch_end 2024-10-28 17:33:53
# 21/21 [==============================] - 0s 13ms/step - loss: 0.6532 - smape_loss: 7.6704e-07 - mae_denorm: 8.0534e-07 - val_loss: 2.5266 - val_smape_loss: 1.7011 - val_mae_denorm: 2745633.7500
# Epoch 34/500
# 18/21 [========================>.....] - ETA: 0s - loss: 0.6546 - smape_loss: 7.7358e-07 - mae_denorm: 8.1222e-07Tiempo on_epoch_end 2024-10-28 17:33:53
# 21/21 [==============================] - 0s 13ms/step - loss: 0.6531 - smape_loss: 7.6698e-07 - mae_denorm: 8.0528e-07 - val_loss: 2.5377 - val_smape_loss: 1.7016 - val_mae_denorm: 2606490.2500
# Epoch 35/500
# 17/21 [=======================>......] - ETA: 0s - loss: 0.6505 - smape_loss: 7.7308e-07 - mae_denorm: 8.1169e-07Tiempo on_epoch_end 2024-10-28 17:33:54
# 21/21 [==============================] - 0s 13ms/step - loss: 0.6511 - smape_loss: 7.6692e-07 - mae_denorm: 8.0522e-07 - val_loss: 2.5403 - val_smape_loss: 1.7002 - val_mae_denorm: 2482967.7500
# Epoch 36/500
# 18/21 [========================>.....] - ETA: 0s - loss: 0.6526 - smape_loss: 7.7448e-07 - mae_denorm: 8.1315e-07Tiempo on_epoch_end 2024-10-28 17:33:54
# 21/21 [==============================] - 0s 13ms/step - loss: 0.6517 - smape_loss: 7.6696e-07 - mae_denorm: 8.0526e-07 - val_loss: 2.4935 - val_smape_loss: 1.6994 - val_mae_denorm: 2095945.7500
# Epoch 37/500
# 17/21 [=======================>......] - ETA: 0s - loss: 0.6518 - smape_loss: 7.6367e-07 - mae_denorm: 8.0180e-07Tiempo on_epoch_end 2024-10-28 17:33:54
# 21/21 [==============================] - 0s 13ms/step - loss: 0.6509 - smape_loss: 7.6683e-07 - mae_denorm: 8.0512e-07 - val_loss: 2.5459 - val_smape_loss: 1.7027 - val_mae_denorm: 2796209.0000
# Epoch 38/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.6500 - smape_loss: 7.5058e-07 - mae_denorm: 7.8806e-07Tiempo on_epoch_end 2024-10-28 17:33:54
# 21/21 [==============================] - 0s 14ms/step - loss: 0.6487 - smape_loss: 7.6680e-07 - mae_denorm: 8.0509e-07 - val_loss: 2.5230 - val_smape_loss: 1.6999 - val_mae_denorm: 2267205.7500
# Epoch 39/500
# 18/21 [========================>.....] - ETA: 0s - loss: 0.6465 - smape_loss: 7.7911e-07 - mae_denorm: 8.1802e-07Tiempo on_epoch_end 2024-10-28 17:33:55
# 21/21 [==============================] - 0s 13ms/step - loss: 0.6480 - smape_loss: 7.6667e-07 - mae_denorm: 8.0496e-07 - val_loss: 2.5059 - val_smape_loss: 1.6984 - val_mae_denorm: 1970829.0000
# Epoch 40/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.6462 - smape_loss: 7.7632e-07 - mae_denorm: 8.1509e-07Tiempo on_epoch_end 2024-10-28 17:33:55
# 21/21 [==============================] - 0s 14ms/step - loss: 0.6459 - smape_loss: 7.6669e-07 - mae_denorm: 8.0498e-07 - val_loss: 2.5079 - val_smape_loss: 1.6981 - val_mae_denorm: 1960072.5000
# Epoch 41/500
# 18/21 [========================>.....] - ETA: 0s - loss: 0.6493 - smape_loss: 7.7905e-07 - mae_denorm: 8.1796e-07Tiempo on_epoch_end 2024-10-28 17:33:55
# 21/21 [==============================] - 0s 13ms/step - loss: 0.6478 - smape_loss: 7.6679e-07 - mae_denorm: 8.0508e-07 - val_loss: 2.5211 - val_smape_loss: 1.6982 - val_mae_denorm: 2070367.3750
# Epoch 42/500
# 18/21 [========================>.....] - ETA: 0s - loss: 0.6463 - smape_loss: 7.6605e-07 - mae_denorm: 8.0431e-07Tiempo on_epoch_end 2024-10-28 17:33:56
# 21/21 [==============================] - 0s 13ms/step - loss: 0.6458 - smape_loss: 7.6660e-07 - mae_denorm: 8.0488e-07 - val_loss: 2.4858 - val_smape_loss: 1.6970 - val_mae_denorm: 1771930.1250
# Epoch 43/500
# 18/21 [========================>.....] - ETA: 0s - loss: 0.6482 - smape_loss: 7.7647e-07 - mae_denorm: 8.1524e-07Tiempo on_epoch_end 2024-10-28 17:33:56
# 21/21 [==============================] - 0s 13ms/step - loss: 0.6453 - smape_loss: 7.6656e-07 - mae_denorm: 8.0484e-07 - val_loss: 2.5527 - val_smape_loss: 1.7003 - val_mae_denorm: 2377592.7500
# Epoch 44/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.6453 - smape_loss: 7.4889e-07 - mae_denorm: 7.8629e-07Tiempo on_epoch_end 2024-10-28 17:33:56
# 21/21 [==============================] - 0s 13ms/step - loss: 0.6442 - smape_loss: 7.6655e-07 - mae_denorm: 8.0483e-07 - val_loss: 2.5340 - val_smape_loss: 1.6986 - val_mae_denorm: 2136128.7500
# Epoch 45/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.6442 - smape_loss: 7.5709e-07 - mae_denorm: 7.9490e-07Tiempo on_epoch_end 2024-10-28 17:33:56
# 21/21 [==============================] - 0s 12ms/step - loss: 0.6438 - smape_loss: 7.6653e-07 - mae_denorm: 8.0480e-07 - val_loss: 2.5402 - val_smape_loss: 1.6982 - val_mae_denorm: 2111433.0000
# Epoch 46/500
# 17/21 [=======================>......] - ETA: 0s - loss: 0.6411 - smape_loss: 7.6076e-07 - mae_denorm: 7.9875e-07Tiempo on_epoch_end 2024-10-28 17:33:57
# 21/21 [==============================] - 0s 13ms/step - loss: 0.6405 - smape_loss: 7.6627e-07 - mae_denorm: 8.0454e-07 - val_loss: 2.5264 - val_smape_loss: 1.6974 - val_mae_denorm: 1954576.3750
# Epoch 47/500
# 18/21 [========================>.....] - ETA: 0s - loss: 0.6427 - smape_loss: 7.7216e-07 - mae_denorm: 8.1072e-07Tiempo on_epoch_end 2024-10-28 17:33:57
# 21/21 [==============================] - 0s 13ms/step - loss: 0.6449 - smape_loss: 7.6656e-07 - mae_denorm: 8.0484e-07 - val_loss: 2.5577 - val_smape_loss: 1.6979 - val_mae_denorm: 2159704.0000
# Epoch 48/500
# 17/21 [=======================>......] - ETA: 0s - loss: 0.6423 - smape_loss: 7.7836e-07 - mae_denorm: 8.1723e-07Tiempo on_epoch_end 2024-10-28 17:33:57
# 21/21 [==============================] - 0s 15ms/step - loss: 0.6439 - smape_loss: 7.6654e-07 - mae_denorm: 8.0482e-07 - val_loss: 2.5752 - val_smape_loss: 1.7006 - val_mae_denorm: 2587372.2500
# Epoch 49/500
# 18/21 [========================>.....] - ETA: 0s - loss: 0.6408 - smape_loss: 7.3876e-07 - mae_denorm: 7.7565e-07Tiempo on_epoch_end 2024-10-28 17:33:57
# 21/21 [==============================] - 0s 12ms/step - loss: 0.6396 - smape_loss: 7.6614e-07 - mae_denorm: 8.0439e-07 - val_loss: 2.5354 - val_smape_loss: 1.6971 - val_mae_denorm: 1924679.3750
# Epoch 50/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.6382 - smape_loss: 7.7278e-07 - mae_denorm: 8.1137e-07Tiempo on_epoch_end 2024-10-28 17:33:58
# 21/21 [==============================] - 0s 13ms/step - loss: 0.6376 - smape_loss: 7.6613e-07 - mae_denorm: 8.0439e-07 - val_loss: 2.5431 - val_smape_loss: 1.6974 - val_mae_denorm: 1942497.0000
# Epoch 51/500
# 18/21 [========================>.....] - ETA: 0s - loss: 0.6398 - smape_loss: 7.7272e-07 - mae_denorm: 8.1131e-07Tiempo on_epoch_end 2024-10-28 17:33:58
# 21/21 [==============================] - 0s 14ms/step - loss: 0.6407 - smape_loss: 7.6631e-07 - mae_denorm: 8.0457e-07 - val_loss: 2.5482 - val_smape_loss: 1.6979 - val_mae_denorm: 2088040.8750
# Epoch 52/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.6402 - smape_loss: 7.7143e-07 - mae_denorm: 8.0996e-07Tiempo on_epoch_end 2024-10-28 17:33:58
# 21/21 [==============================] - 0s 12ms/step - loss: 0.6394 - smape_loss: 7.6618e-07 - mae_denorm: 8.0444e-07 - val_loss: 2.5632 - val_smape_loss: 1.6986 - val_mae_denorm: 2346777.0000
# Epoch 53/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.6393 - smape_loss: 7.7029e-07 - mae_denorm: 8.0876e-07Tiempo on_epoch_end 2024-10-28 17:33:59
# 21/21 [==============================] - 0s 12ms/step - loss: 0.6398 - smape_loss: 7.6630e-07 - mae_denorm: 8.0457e-07 - val_loss: 2.5317 - val_smape_loss: 1.6952 - val_mae_denorm: 1919581.5000
# Epoch 54/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.6427 - smape_loss: 7.6586e-07 - mae_denorm: 8.0410e-07Tiempo on_epoch_end 2024-10-28 17:33:59
# 21/21 [==============================] - 0s 15ms/step - loss: 0.6424 - smape_loss: 7.6649e-07 - mae_denorm: 8.0477e-07 - val_loss: 2.6182 - val_smape_loss: 1.6970 - val_mae_denorm: 3029088.7500
# Epoch 55/500
# 17/21 [=======================>......] - ETA: 0s - loss: 0.6414 - smape_loss: 7.7934e-07 - mae_denorm: 8.1826e-07Tiempo on_epoch_end 2024-10-28 17:33:59
# 21/21 [==============================] - 0s 13ms/step - loss: 0.6404 - smape_loss: 7.6623e-07 - mae_denorm: 8.0449e-07 - val_loss: 2.5785 - val_smape_loss: 1.6964 - val_mae_denorm: 2566223.5000
# Epoch 56/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.6342 - smape_loss: 7.6459e-07 - mae_denorm: 8.0278e-07Tiempo on_epoch_end 2024-10-28 17:33:59
# 21/21 [==============================] - 0s 12ms/step - loss: 0.6344 - smape_loss: 7.6587e-07 - mae_denorm: 8.0411e-07 - val_loss: 2.5687 - val_smape_loss: 1.6976 - val_mae_denorm: 2350397.2500
# Epoch 57/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.6327 - smape_loss: 7.4502e-07 - mae_denorm: 7.8223e-07Tiempo on_epoch_end 2024-10-28 17:34:00
# 21/21 [==============================] - 0s 12ms/step - loss: 0.6336 - smape_loss: 7.6583e-07 - mae_denorm: 8.0407e-07 - val_loss: 2.5699 - val_smape_loss: 1.6976 - val_mae_denorm: 2490708.5000
# Epoch 58/500
# 17/21 [=======================>......] - ETA: 0s - loss: 0.6353 - smape_loss: 7.5155e-07 - mae_denorm: 7.8908e-07Tiempo on_epoch_end 2024-10-28 17:34:00
# 21/21 [==============================] - 0s 13ms/step - loss: 0.6338 - smape_loss: 7.6589e-07 - mae_denorm: 8.0414e-07 - val_loss: 2.5663 - val_smape_loss: 1.6970 - val_mae_denorm: 2414042.2500
# Epoch 59/500
# 17/21 [=======================>......] - ETA: 0s - loss: 0.6399 - smape_loss: 7.6292e-07 - mae_denorm: 8.0102e-07Tiempo on_epoch_end 2024-10-28 17:34:00
# 21/21 [==============================] - 0s 15ms/step - loss: 0.6397 - smape_loss: 7.6633e-07 - mae_denorm: 8.0460e-07 - val_loss: 2.5520 - val_smape_loss: 1.6968 - val_mae_denorm: 2122620.7500
# Epoch 60/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.6368 - smape_loss: 7.5234e-07 - mae_denorm: 7.8991e-07Tiempo on_epoch_end 2024-10-28 17:34:01
# 21/21 [==============================] - 0s 14ms/step - loss: 0.6366 - smape_loss: 7.6590e-07 - mae_denorm: 8.0415e-07 - val_loss: 2.5611 - val_smape_loss: 1.6976 - val_mae_denorm: 2190622.0000
# Epoch 61/500
# 18/21 [========================>.....] - ETA: 0s - loss: 0.6346 - smape_loss: 7.4528e-07 - mae_denorm: 7.8250e-07Tiempo on_epoch_end 2024-10-28 17:34:01
# 21/21 [==============================] - 0s 14ms/step - loss: 0.6333 - smape_loss: 7.6582e-07 - mae_denorm: 8.0406e-07 - val_loss: 2.5855 - val_smape_loss: 1.6970 - val_mae_denorm: 2671203.5000
# Epoch 62/500
# 18/21 [========================>.....] - ETA: 0s - loss: 0.6294 - smape_loss: 7.5652e-07 - mae_denorm: 7.9429e-07Tiempo on_epoch_end 2024-10-28 17:34:01
# 21/21 [==============================] - 0s 18ms/step - loss: 0.6306 - smape_loss: 7.6563e-07 - mae_denorm: 8.0387e-07 - val_loss: 2.5657 - val_smape_loss: 1.6973 - val_mae_denorm: 2556113.0000
# Epoch 63/500
# 21/21 [==============================] - ETA: 0s - loss: 0.6281 - smape_loss: 7.6540e-07 - mae_denorm: 8.0363e-07Tiempo on_epoch_end 2024-10-28 17:34:02
# 21/21 [==============================] - 0s 16ms/step - loss: 0.6281 - smape_loss: 7.6540e-07 - mae_denorm: 8.0363e-07 - val_loss: 2.5489 - val_smape_loss: 1.6976 - val_mae_denorm: 2175530.7500
# Epoch 64/500
# 21/21 [==============================] - ETA: 0s - loss: 0.6275 - smape_loss: 7.6534e-07 - mae_denorm: 8.0356e-07Tiempo on_epoch_end 2024-10-28 17:34:02
# 21/21 [==============================] - 0s 16ms/step - loss: 0.6275 - smape_loss: 7.6534e-07 - mae_denorm: 8.0356e-07 - val_loss: 2.5395 - val_smape_loss: 1.6984 - val_mae_denorm: 2109319.2500
# Epoch 65/500
# 18/21 [========================>.....] - ETA: 0s - loss: 0.6281 - smape_loss: 7.6701e-07 - mae_denorm: 8.0532e-07Tiempo on_epoch_end 2024-10-28 17:34:02
# 21/21 [==============================] - 0s 18ms/step - loss: 0.6270 - smape_loss: 7.6530e-07 - mae_denorm: 8.0352e-07 - val_loss: 2.5160 - val_smape_loss: 1.6971 - val_mae_denorm: 1966831.2500
# Epoch 66/500
# 21/21 [==============================] - ETA: 0s - loss: 0.6298 - smape_loss: 7.6542e-07 - mae_denorm: 8.0364e-07Tiempo on_epoch_end 2024-10-28 17:34:03
# 21/21 [==============================] - 0s 17ms/step - loss: 0.6298 - smape_loss: 7.6542e-07 - mae_denorm: 8.0364e-07 - val_loss: 2.5440 - val_smape_loss: 1.6974 - val_mae_denorm: 2097383.0000
# Epoch 67/500
# 21/21 [==============================] - ETA: 0s - loss: 0.6268 - smape_loss: 7.6524e-07 - mae_denorm: 8.0346e-07Tiempo on_epoch_end 2024-10-28 17:34:03
# 21/21 [==============================] - 0s 17ms/step - loss: 0.6268 - smape_loss: 7.6524e-07 - mae_denorm: 8.0346e-07 - val_loss: 2.5368 - val_smape_loss: 1.6973 - val_mae_denorm: 1896102.5000
# Epoch 68/500
# 21/21 [==============================] - ETA: 0s - loss: 0.6287 - smape_loss: 7.6536e-07 - mae_denorm: 8.0358e-07Tiempo on_epoch_end 2024-10-28 17:34:03
# 21/21 [==============================] - 0s 17ms/step - loss: 0.6287 - smape_loss: 7.6536e-07 - mae_denorm: 8.0358e-07 - val_loss: 2.5102 - val_smape_loss: 1.6998 - val_mae_denorm: 1663883.2500
# Epoch 69/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.6267 - smape_loss: 7.5587e-07 - mae_denorm: 7.9362e-07Tiempo on_epoch_end 2024-10-28 17:34:04
# 21/21 [==============================] - 0s 16ms/step - loss: 0.6282 - smape_loss: 7.6547e-07 - mae_denorm: 8.0370e-07 - val_loss: 2.4902 - val_smape_loss: 1.6972 - val_mae_denorm: 1250094.5000
# Epoch 70/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.6252 - smape_loss: 7.5689e-07 - mae_denorm: 7.9469e-07Tiempo on_epoch_end 2024-10-28 17:34:04
# 21/21 [==============================] - 0s 18ms/step - loss: 0.6264 - smape_loss: 7.6524e-07 - mae_denorm: 8.0345e-07 - val_loss: 2.5050 - val_smape_loss: 1.6979 - val_mae_denorm: 1419135.2500
# Epoch 71/500
# 21/21 [==============================] - ETA: 0s - loss: 0.6243 - smape_loss: 7.6514e-07 - mae_denorm: 8.0335e-07Tiempo on_epoch_end 2024-10-28 17:34:04
# 21/21 [==============================] - 0s 17ms/step - loss: 0.6243 - smape_loss: 7.6514e-07 - mae_denorm: 8.0335e-07 - val_loss: 2.5222 - val_smape_loss: 1.6993 - val_mae_denorm: 1707771.6250
# Epoch 72/500
# 18/21 [========================>.....] - ETA: 0s - loss: 0.6228 - smape_loss: 7.7692e-07 - mae_denorm: 8.1571e-07Tiempo on_epoch_end 2024-10-28 17:34:05
# 21/21 [==============================] - 0s 17ms/step - loss: 0.6237 - smape_loss: 7.6489e-07 - mae_denorm: 8.0308e-07 - val_loss: 2.5069 - val_smape_loss: 1.6980 - val_mae_denorm: 1455955.2500
# Epoch 73/500
# 21/21 [==============================] - ETA: 0s - loss: 0.6241 - smape_loss: 7.6518e-07 - mae_denorm: 8.0339e-07Tiempo on_epoch_end 2024-10-28 17:34:05
# 21/21 [==============================] - 0s 14ms/step - loss: 0.6241 - smape_loss: 7.6518e-07 - mae_denorm: 8.0339e-07 - val_loss: 2.4842 - val_smape_loss: 1.6958 - val_mae_denorm: 1309633.8750
# Epoch 74/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.6262 - smape_loss: 7.4990e-07 - mae_denorm: 7.8735e-07Tiempo on_epoch_end 2024-10-28 17:34:05
# 21/21 [==============================] - 0s 13ms/step - loss: 0.6254 - smape_loss: 7.6506e-07 - mae_denorm: 8.0326e-07 - val_loss: 2.5082 - val_smape_loss: 1.6959 - val_mae_denorm: 1530055.2500
# Epoch 75/500
# 17/21 [=======================>......] - ETA: 0s - loss: 0.6241 - smape_loss: 7.6788e-07 - mae_denorm: 8.0622e-07Tiempo on_epoch_end 2024-10-28 17:34:06
# 21/21 [==============================] - 0s 13ms/step - loss: 0.6217 - smape_loss: 7.6464e-07 - mae_denorm: 8.0282e-07 - val_loss: 2.5168 - val_smape_loss: 1.6972 - val_mae_denorm: 1437618.2500
# Epoch 76/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.6278 - smape_loss: 7.7510e-07 - mae_denorm: 8.1381e-07Tiempo on_epoch_end 2024-10-28 17:34:06
# 21/21 [==============================] - 0s 14ms/step - loss: 0.6297 - smape_loss: 7.6548e-07 - mae_denorm: 8.0371e-07 - val_loss: 2.5548 - val_smape_loss: 1.6992 - val_mae_denorm: 1701339.8750
# Epoch 77/500
# 21/21 [==============================] - ETA: 0s - loss: 0.6255 - smape_loss: 7.6508e-07 - mae_denorm: 8.0329e-07Tiempo on_epoch_end 2024-10-28 17:34:06
# 21/21 [==============================] - 0s 14ms/step - loss: 0.6255 - smape_loss: 7.6508e-07 - mae_denorm: 8.0329e-07 - val_loss: 2.4970 - val_smape_loss: 1.6950 - val_mae_denorm: 1174967.1250
# Epoch 78/500
# 17/21 [=======================>......] - ETA: 0s - loss: 0.6207 - smape_loss: 7.6215e-07 - mae_denorm: 8.0021e-07Tiempo on_epoch_end 2024-10-28 17:34:07
# 21/21 [==============================] - 0s 13ms/step - loss: 0.6202 - smape_loss: 7.6483e-07 - mae_denorm: 8.0302e-07 - val_loss: 2.4730 - val_smape_loss: 1.6947 - val_mae_denorm: 959084.4375
# Epoch 79/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.6189 - smape_loss: 7.6617e-07 - mae_denorm: 8.0443e-07Tiempo on_epoch_end 2024-10-28 17:34:07
# 21/21 [==============================] - 0s 13ms/step - loss: 0.6188 - smape_loss: 7.6466e-07 - mae_denorm: 8.0285e-07 - val_loss: 2.4756 - val_smape_loss: 1.6956 - val_mae_denorm: 1064799.3750
# Epoch 80/500
# 17/21 [=======================>......] - ETA: 0s - loss: 0.6164 - smape_loss: 7.5315e-07 - mae_denorm: 7.9077e-07Tiempo on_epoch_end 2024-10-28 17:34:07
# 21/21 [==============================] - 0s 13ms/step - loss: 0.6195 - smape_loss: 7.6451e-07 - mae_denorm: 8.0269e-07 - val_loss: 2.4613 - val_smape_loss: 1.6928 - val_mae_denorm: 833564.8125
# Epoch 81/500
# 18/21 [========================>.....] - ETA: 0s - loss: 0.6228 - smape_loss: 7.9076e-07 - mae_denorm: 8.3025e-07Tiempo on_epoch_end 2024-10-28 17:34:07
# 21/21 [==============================] - 0s 14ms/step - loss: 0.6233 - smape_loss: 7.6530e-07 - mae_denorm: 8.0351e-07 - val_loss: 2.4405 - val_smape_loss: 1.6903 - val_mae_denorm: 776541.3125
# Epoch 82/500
# 17/21 [=======================>......] - ETA: 0s - loss: 0.6231 - smape_loss: 7.6946e-07 - mae_denorm: 8.0788e-07Tiempo on_epoch_end 2024-10-28 17:34:08
# 21/21 [==============================] - 0s 13ms/step - loss: 0.6243 - smape_loss: 7.6492e-07 - mae_denorm: 8.0312e-07 - val_loss: 2.4740 - val_smape_loss: 1.6910 - val_mae_denorm: 784646.6875
# Epoch 83/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.6155 - smape_loss: 7.6683e-07 - mae_denorm: 8.0512e-07Tiempo on_epoch_end 2024-10-28 17:34:08
# 21/21 [==============================] - 0s 12ms/step - loss: 0.6147 - smape_loss: 7.6477e-07 - mae_denorm: 8.0296e-07 - val_loss: 2.4292 - val_smape_loss: 1.6897 - val_mae_denorm: 619249.5625
# Epoch 84/500
# 17/21 [=======================>......] - ETA: 0s - loss: 0.6186 - smape_loss: 7.5559e-07 - mae_denorm: 7.9332e-07Tiempo on_epoch_end 2024-10-28 17:34:08
# 21/21 [==============================] - 0s 13ms/step - loss: 0.6172 - smape_loss: 7.6487e-07 - mae_denorm: 8.0307e-07 - val_loss: 2.4639 - val_smape_loss: 1.6932 - val_mae_denorm: 760621.0625
# Epoch 85/500
# 18/21 [========================>.....] - ETA: 0s - loss: 0.6180 - smape_loss: 7.7433e-07 - mae_denorm: 8.1300e-07Tiempo on_epoch_end 2024-10-28 17:34:09
# 21/21 [==============================] - 0s 15ms/step - loss: 0.6192 - smape_loss: 7.6505e-07 - mae_denorm: 8.0326e-07 - val_loss: 2.3911 - val_smape_loss: 1.6865 - val_mae_denorm: 447933.3438
# Epoch 86/500
# 18/21 [========================>.....] - ETA: 0s - loss: 0.6203 - smape_loss: 7.8025e-07 - mae_denorm: 8.1922e-07Tiempo on_epoch_end 2024-10-28 17:34:09
# 21/21 [==============================] - 0s 12ms/step - loss: 0.6193 - smape_loss: 7.6572e-07 - mae_denorm: 8.0396e-07 - val_loss: 2.4411 - val_smape_loss: 1.6884 - val_mae_denorm: 529965.4375
# Epoch 87/500
# 18/21 [========================>.....] - ETA: 0s - loss: 0.6157 - smape_loss: 7.6993e-07 - mae_denorm: 8.0838e-07Tiempo on_epoch_end 2024-10-28 17:34:09
# 21/21 [==============================] - 0s 13ms/step - loss: 0.6138 - smape_loss: 7.6578e-07 - mae_denorm: 8.0402e-07 - val_loss: 2.4512 - val_smape_loss: 1.6925 - val_mae_denorm: 669686.3750
# Epoch 88/500
# 17/21 [=======================>......] - ETA: 0s - loss: 0.6143 - smape_loss: 7.6929e-07 - mae_denorm: 8.0770e-07Tiempo on_epoch_end 2024-10-28 17:34:09
# 21/21 [==============================] - 0s 13ms/step - loss: 0.6138 - smape_loss: 7.6521e-07 - mae_denorm: 8.0342e-07 - val_loss: 2.3833 - val_smape_loss: 1.6841 - val_mae_denorm: 437141.5312
# Epoch 89/500
# 20/21 [===========================>..] - ETA: 0s - loss: 0.6396 - smape_loss: 7.7321e-07 - mae_denorm: 8.1182e-07Tiempo on_epoch_end 2024-10-28 17:34:10
# 21/21 [==============================] - 0s 21ms/step - loss: 0.6385 - smape_loss: 7.6629e-07 - mae_denorm: 8.0456e-07 - val_loss: 2.5779 - val_smape_loss: 1.7024 - val_mae_denorm: 1930335.6250
# Epoch 90/500
# 20/21 [===========================>..] - ETA: 0s - loss: 0.6325 - smape_loss: 7.6520e-07 - mae_denorm: 8.0341e-07Tiempo on_epoch_end 2024-10-28 17:34:10
# 21/21 [==============================] - 0s 24ms/step - loss: 0.6322 - smape_loss: 7.6612e-07 - mae_denorm: 8.0438e-07 - val_loss: 2.5373 - val_smape_loss: 1.6986 - val_mae_denorm: 1279465.7500
# Epoch 91/500
# 18/21 [========================>.....] - ETA: 0s - loss: 0.6200 - smape_loss: 7.8040e-07 - mae_denorm: 8.1937e-07Tiempo on_epoch_end 2024-10-28 17:34:11
# 21/21 [==============================] - 0s 15ms/step - loss: 0.6230 - smape_loss: 7.6512e-07 - mae_denorm: 8.0332e-07 - val_loss: 2.5264 - val_smape_loss: 1.6998 - val_mae_denorm: 1213445.0000
# Epoch 92/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.6200 - smape_loss: 7.6450e-07 - mae_denorm: 8.0268e-07Tiempo on_epoch_end 2024-10-28 17:34:11
# 21/21 [==============================] - 0s 24ms/step - loss: 0.6192 - smape_loss: 7.6467e-07 - mae_denorm: 8.0286e-07 - val_loss: 2.5404 - val_smape_loss: 1.7027 - val_mae_denorm: 1357078.7500
# Epoch 93/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.6147 - smape_loss: 7.6246e-07 - mae_denorm: 8.0054e-07Tiempo on_epoch_end 2024-10-28 17:34:12
# 21/21 [==============================] - 0s 22ms/step - loss: 0.6143 - smape_loss: 7.6439e-07 - mae_denorm: 8.0256e-07 - val_loss: 2.5456 - val_smape_loss: 1.7051 - val_mae_denorm: 1518417.7500
# Epoch 94/500
# 17/21 [=======================>......] - ETA: 0s - loss: 0.6126 - smape_loss: 7.7538e-07 - mae_denorm: 8.1410e-07Tiempo on_epoch_end 2024-10-28 17:34:12
# 21/21 [==============================] - 0s 13ms/step - loss: 0.6142 - smape_loss: 7.6448e-07 - mae_denorm: 8.0266e-07 - val_loss: 2.5514 - val_smape_loss: 1.7056 - val_mae_denorm: 1633082.7500
# Epoch 95/500
# 20/21 [===========================>..] - ETA: 0s - loss: 0.6093 - smape_loss: 7.6953e-07 - mae_denorm: 8.0796e-07Tiempo on_epoch_end 2024-10-28 17:34:12
# 21/21 [==============================] - 1s 25ms/step - loss: 0.6092 - smape_loss: 7.6424e-07 - mae_denorm: 8.0241e-07 - val_loss: 2.5231 - val_smape_loss: 1.7046 - val_mae_denorm: 1344390.3750
# Epoch 96/500
# 18/21 [========================>.....] - ETA: 0s - loss: 0.6177 - smape_loss: 7.7686e-07 - mae_denorm: 8.1566e-07Tiempo on_epoch_end 2024-10-28 17:34:13
# 21/21 [==============================] - 0s 19ms/step - loss: 0.6196 - smape_loss: 7.6526e-07 - mae_denorm: 8.0348e-07 - val_loss: 2.4705 - val_smape_loss: 1.6977 - val_mae_denorm: 1019283.3125
# Epoch 97/500
# 17/21 [=======================>......] - ETA: 0s - loss: 0.6165 - smape_loss: 7.6817e-07 - mae_denorm: 8.0653e-07Tiempo on_epoch_end 2024-10-28 17:34:13
# 21/21 [==============================] - 0s 15ms/step - loss: 0.6168 - smape_loss: 7.6611e-07 - mae_denorm: 8.0437e-07 - val_loss: 2.5049 - val_smape_loss: 1.6999 - val_mae_denorm: 1026403.1250
# Epoch 98/500
# 17/21 [=======================>......] - ETA: 0s - loss: 0.6106 - smape_loss: 7.6695e-07 - mae_denorm: 8.0525e-07Tiempo on_epoch_end 2024-10-28 17:34:13
# 21/21 [==============================] - 0s 13ms/step - loss: 0.6098 - smape_loss: 7.6632e-07 - mae_denorm: 8.0459e-07 - val_loss: 2.4258 - val_smape_loss: 1.6854 - val_mae_denorm: 566037.2500
# Epoch 99/500
# 17/21 [=======================>......] - ETA: 0s - loss: 0.6102 - smape_loss: 7.3925e-07 - mae_denorm: 7.7617e-07Tiempo on_epoch_end 2024-10-28 17:34:14
# 21/21 [==============================] - 0s 15ms/step - loss: 0.6109 - smape_loss: 7.6601e-07 - mae_denorm: 8.0426e-07 - val_loss: 2.4563 - val_smape_loss: 1.6954 - val_mae_denorm: 766967.8750
# Epoch 100/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.6117 - smape_loss: 7.6486e-07 - mae_denorm: 8.0305e-07Tiempo on_epoch_end 2024-10-28 17:34:14
# 21/21 [==============================] - 0s 14ms/step - loss: 0.6117 - smape_loss: 7.6571e-07 - mae_denorm: 8.0395e-07 - val_loss: 2.4503 - val_smape_loss: 1.6943 - val_mae_denorm: 681463.4375
# Epoch 101/500
# 17/21 [=======================>......] - ETA: 0s - loss: 0.6017 - smape_loss: 7.7001e-07 - mae_denorm: 8.0846e-07Tiempo on_epoch_end 2024-10-28 17:34:14
# 21/21 [==============================] - 0s 15ms/step - loss: 0.5968 - smape_loss: 7.6464e-07 - mae_denorm: 8.0282e-07 - val_loss: 2.4441 - val_smape_loss: 1.6947 - val_mae_denorm: 677842.8125
# Epoch 102/500
# 18/21 [========================>.....] - ETA: 0s - loss: 0.5985 - smape_loss: 7.5620e-07 - mae_denorm: 7.9396e-07Tiempo on_epoch_end 2024-10-28 17:34:15
# 21/21 [==============================] - 0s 13ms/step - loss: 0.6001 - smape_loss: 7.6514e-07 - mae_denorm: 8.0334e-07 - val_loss: 2.5208 - val_smape_loss: 1.6995 - val_mae_denorm: 1241737.2500
# Epoch 103/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.5923 - smape_loss: 7.6947e-07 - mae_denorm: 8.0789e-07Tiempo on_epoch_end 2024-10-28 17:34:15
# 21/21 [==============================] - 0s 13ms/step - loss: 0.5936 - smape_loss: 7.6445e-07 - mae_denorm: 8.0263e-07 - val_loss: 2.4865 - val_smape_loss: 1.6933 - val_mae_denorm: 869010.0000
# Epoch 104/500
# 18/21 [========================>.....] - ETA: 0s - loss: 0.5992 - smape_loss: 7.5648e-07 - mae_denorm: 7.9426e-07Tiempo on_epoch_end 2024-10-28 17:34:15
# 21/21 [==============================] - 0s 17ms/step - loss: 0.5986 - smape_loss: 7.6497e-07 - mae_denorm: 8.0318e-07 - val_loss: 2.4947 - val_smape_loss: 1.6988 - val_mae_denorm: 1008794.0000
# Epoch 105/500
# 20/21 [===========================>..] - ETA: 0s - loss: 0.6018 - smape_loss: 7.6239e-07 - mae_denorm: 8.0046e-07Tiempo on_epoch_end 2024-10-28 17:34:16
# 21/21 [==============================] - 0s 17ms/step - loss: 0.6018 - smape_loss: 7.6460e-07 - mae_denorm: 8.0278e-07 - val_loss: 2.5399 - val_smape_loss: 1.7043 - val_mae_denorm: 1189717.0000
# Epoch 106/500
# 20/21 [===========================>..] - ETA: 0s - loss: 0.5951 - smape_loss: 7.6772e-07 - mae_denorm: 8.0606e-07Tiempo on_epoch_end 2024-10-28 17:34:16
# 21/21 [==============================] - 0s 17ms/step - loss: 0.5942 - smape_loss: 7.6447e-07 - mae_denorm: 8.0265e-07 - val_loss: 2.5129 - val_smape_loss: 1.6972 - val_mae_denorm: 834446.4375
# Epoch 107/500
# 21/21 [==============================] - ETA: 0s - loss: 0.5885 - smape_loss: 7.6410e-07 - mae_denorm: 8.0226e-07Tiempo on_epoch_end 2024-10-28 17:34:16
# 21/21 [==============================] - 0s 17ms/step - loss: 0.5885 - smape_loss: 7.6410e-07 - mae_denorm: 8.0226e-07 - val_loss: 2.5671 - val_smape_loss: 1.7041 - val_mae_denorm: 1454540.7500
# Epoch 108/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.5826 - smape_loss: 7.6508e-07 - mae_denorm: 8.0328e-07Tiempo on_epoch_end 2024-10-28 17:34:17
# 21/21 [==============================] - 0s 18ms/step - loss: 0.5837 - smape_loss: 7.6330e-07 - mae_denorm: 8.0141e-07 - val_loss: 2.5823 - val_smape_loss: 1.7063 - val_mae_denorm: 1462380.8750
# Epoch 109/500
# 21/21 [==============================] - ETA: 0s - loss: 0.5730 - smape_loss: 7.6280e-07 - mae_denorm: 8.0089e-07Tiempo on_epoch_end 2024-10-28 17:34:17
# 21/21 [==============================] - 0s 16ms/step - loss: 0.5730 - smape_loss: 7.6280e-07 - mae_denorm: 8.0089e-07 - val_loss: 2.5615 - val_smape_loss: 1.7056 - val_mae_denorm: 1230656.6250
# Epoch 110/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.5865 - smape_loss: 7.7063e-07 - mae_denorm: 8.0911e-07Tiempo on_epoch_end 2024-10-28 17:34:17
# 21/21 [==============================] - 0s 16ms/step - loss: 0.5880 - smape_loss: 7.6381e-07 - mae_denorm: 8.0196e-07 - val_loss: 2.5779 - val_smape_loss: 1.7086 - val_mae_denorm: 1611934.2500
# Epoch 111/500
# 21/21 [==============================] - ETA: 0s - loss: 0.5859 - smape_loss: 7.6378e-07 - mae_denorm: 8.0192e-07Tiempo on_epoch_end 2024-10-28 17:34:18
# 21/21 [==============================] - 0s 19ms/step - loss: 0.5859 - smape_loss: 7.6378e-07 - mae_denorm: 8.0192e-07 - val_loss: 2.6361 - val_smape_loss: 1.7119 - val_mae_denorm: 1781202.3750
# Epoch 112/500
# 20/21 [===========================>..] - ETA: 0s - loss: 0.5743 - smape_loss: 7.5624e-07 - mae_denorm: 7.9401e-07Tiempo on_epoch_end 2024-10-28 17:34:18
# 21/21 [==============================] - 0s 19ms/step - loss: 0.5743 - smape_loss: 7.6320e-07 - mae_denorm: 8.0131e-07 - val_loss: 2.5449 - val_smape_loss: 1.7128 - val_mae_denorm: 1372021.1250
# Epoch 113/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.6150 - smape_loss: 7.7143e-07 - mae_denorm: 8.0995e-07Tiempo on_epoch_end 2024-10-28 17:34:19
# 21/21 [==============================] - 0s 17ms/step - loss: 0.6144 - smape_loss: 7.6583e-07 - mae_denorm: 8.0407e-07 - val_loss: 2.5102 - val_smape_loss: 1.7092 - val_mae_denorm: 935444.0000
# Epoch 114/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.5882 - smape_loss: 7.7066e-07 - mae_denorm: 8.0915e-07Tiempo on_epoch_end 2024-10-28 17:34:19
# 21/21 [==============================] - 0s 16ms/step - loss: 0.5902 - smape_loss: 7.6491e-07 - mae_denorm: 8.0311e-07 - val_loss: 2.6075 - val_smape_loss: 1.7087 - val_mae_denorm: 1220979.7500
# Epoch 115/500
# 17/21 [=======================>......] - ETA: 0s - loss: 0.5859 - smape_loss: 7.5157e-07 - mae_denorm: 7.8910e-07Tiempo on_epoch_end 2024-10-28 17:34:19
# 21/21 [==============================] - 0s 16ms/step - loss: 0.5849 - smape_loss: 7.6408e-07 - mae_denorm: 8.0224e-07 - val_loss: 2.6066 - val_smape_loss: 1.7097 - val_mae_denorm: 1253430.8750
# Epoch 116/500
# 18/21 [========================>.....] - ETA: 0s - loss: 0.5705 - smape_loss: 7.5978e-07 - mae_denorm: 7.9772e-07Tiempo on_epoch_end 2024-10-28 17:34:20
# 21/21 [==============================] - 0s 14ms/step - loss: 0.5713 - smape_loss: 7.6298e-07 - mae_denorm: 8.0108e-07 - val_loss: 2.6004 - val_smape_loss: 1.7126 - val_mae_denorm: 1240655.5000
# Epoch 117/500
# 21/21 [==============================] - ETA: 0s - loss: 0.5720 - smape_loss: 7.6401e-07 - mae_denorm: 8.0217e-07Tiempo on_epoch_end 2024-10-28 17:34:20
# 21/21 [==============================] - 0s 14ms/step - loss: 0.5720 - smape_loss: 7.6401e-07 - mae_denorm: 8.0217e-07 - val_loss: 2.6649 - val_smape_loss: 1.7174 - val_mae_denorm: 2093015.1250
# Epoch 118/500
# 17/21 [=======================>......] - ETA: 0s - loss: 0.5717 - smape_loss: 7.6582e-07 - mae_denorm: 8.0406e-07Tiempo on_epoch_end 2024-10-28 17:34:20
# 21/21 [==============================] - 0s 13ms/step - loss: 0.5729 - smape_loss: 7.6313e-07 - mae_denorm: 8.0124e-07 - val_loss: 2.6770 - val_smape_loss: 1.7256 - val_mae_denorm: 2290500.0000
# Epoch 119/500
# 18/21 [========================>.....] - ETA: 0s - loss: 0.5629 - smape_loss: 7.5735e-07 - mae_denorm: 7.9517e-07Tiempo on_epoch_end 2024-10-28 17:34:20
# 21/21 [==============================] - 0s 13ms/step - loss: 0.5614 - smape_loss: 7.6304e-07 - mae_denorm: 8.0114e-07 - val_loss: 2.6992 - val_smape_loss: 1.7306 - val_mae_denorm: 2571165.7500
# Epoch 120/500
# 18/21 [========================>.....] - ETA: 0s - loss: 0.5482 - smape_loss: 7.4603e-07 - mae_denorm: 7.8328e-07Tiempo on_epoch_end 2024-10-28 17:34:21
# 21/21 [==============================] - 0s 14ms/step - loss: 0.5497 - smape_loss: 7.6177e-07 - mae_denorm: 7.9982e-07 - val_loss: 2.6345 - val_smape_loss: 1.7248 - val_mae_denorm: 1642206.8750
# Epoch 121/500
# 18/21 [========================>.....] - ETA: 0s - loss: 0.5479 - smape_loss: 7.2610e-07 - mae_denorm: 7.6236e-07Tiempo on_epoch_end 2024-10-28 17:34:21
# 21/21 [==============================] - 0s 12ms/step - loss: 0.5482 - smape_loss: 7.6146e-07 - mae_denorm: 7.9949e-07 - val_loss: 2.6591 - val_smape_loss: 1.7255 - val_mae_denorm: 1709781.2500
# Epoch 122/500
# 17/21 [=======================>......] - ETA: 0s - loss: 0.5483 - smape_loss: 7.5352e-07 - mae_denorm: 7.9115e-07Tiempo on_epoch_end 2024-10-28 17:34:21
# 21/21 [==============================] - 0s 13ms/step - loss: 0.5461 - smape_loss: 7.6136e-07 - mae_denorm: 7.9938e-07 - val_loss: 2.6472 - val_smape_loss: 1.7263 - val_mae_denorm: 1764632.5000
# Epoch 123/500
# 16/21 [=====================>........] - ETA: 0s - loss: 0.5565 - smape_loss: 7.8603e-07 - mae_denorm: 8.2528e-07Tiempo on_epoch_end 2024-10-28 17:34:21
# 21/21 [==============================] - 0s 13ms/step - loss: 0.5634 - smape_loss: 7.6166e-07 - mae_denorm: 7.9969e-07 - val_loss: 2.5894 - val_smape_loss: 1.7178 - val_mae_denorm: 1532134.8750
# Epoch 124/500
# 18/21 [========================>.....] - ETA: 0s - loss: 0.5757 - smape_loss: 7.6944e-07 - mae_denorm: 8.0787e-07Tiempo on_epoch_end 2024-10-28 17:34:22
# 21/21 [==============================] - 0s 13ms/step - loss: 0.5761 - smape_loss: 7.6371e-07 - mae_denorm: 8.0185e-07 - val_loss: 2.6194 - val_smape_loss: 1.7157 - val_mae_denorm: 1686252.0000
# Epoch 125/500
# 17/21 [=======================>......] - ETA: 0s - loss: 0.5714 - smape_loss: 7.4424e-07 - mae_denorm: 7.8140e-07Tiempo on_epoch_end 2024-10-28 17:34:22
# 21/21 [==============================] - 0s 15ms/step - loss: 0.5662 - smape_loss: 7.6384e-07 - mae_denorm: 8.0198e-07 - val_loss: 2.7243 - val_smape_loss: 1.7262 - val_mae_denorm: 3146962.5000
# Epoch 126/500
# 18/21 [========================>.....] - ETA: 0s - loss: 0.5646 - smape_loss: 7.8076e-07 - mae_denorm: 8.1975e-07Tiempo on_epoch_end 2024-10-28 17:34:22
# 21/21 [==============================] - 0s 13ms/step - loss: 0.5862 - smape_loss: 7.7430e-07 - mae_denorm: 8.1297e-07 - val_loss: 2.6351 - val_smape_loss: 1.7225 - val_mae_denorm: 2152137.0000
# Epoch 127/500
# 17/21 [=======================>......] - ETA: 0s - loss: 0.7077 - smape_loss: 7.3490e-07 - mae_denorm: 7.7160e-07Tiempo on_epoch_end 2024-10-28 17:34:23
# 21/21 [==============================] - 0s 13ms/step - loss: 0.7063 - smape_loss: 7.7039e-07 - mae_denorm: 8.0887e-07 - val_loss: 2.4814 - val_smape_loss: 1.7010 - val_mae_denorm: 672459.8750
# Epoch 128/500
# 17/21 [=======================>......] - ETA: 0s - loss: 0.6800 - smape_loss: 7.6001e-07 - mae_denorm: 7.9797e-07Tiempo on_epoch_end 2024-10-28 17:34:23
# 21/21 [==============================] - 0s 13ms/step - loss: 0.6781 - smape_loss: 7.6792e-07 - mae_denorm: 8.0627e-07 - val_loss: 2.5556 - val_smape_loss: 1.7101 - val_mae_denorm: 1119452.7500
# Epoch 129/500
# 17/21 [=======================>......] - ETA: 0s - loss: 0.6684 - smape_loss: 7.5766e-07 - mae_denorm: 7.9549e-07Tiempo on_epoch_end 2024-10-28 17:34:23
# 21/21 [==============================] - 0s 13ms/step - loss: 0.6656 - smape_loss: 7.6747e-07 - mae_denorm: 8.0579e-07 - val_loss: 2.5637 - val_smape_loss: 1.7080 - val_mae_denorm: 1104629.7500
# Epoch 130/500
# 18/21 [========================>.....] - ETA: 0s - loss: 0.6576 - smape_loss: 7.6005e-07 - mae_denorm: 7.9801e-07Tiempo on_epoch_end 2024-10-28 17:34:23
# 21/21 [==============================] - 0s 13ms/step - loss: 0.6573 - smape_loss: 7.6708e-07 - mae_denorm: 8.0539e-07 - val_loss: 2.5999 - val_smape_loss: 1.7127 - val_mae_denorm: 1377415.2500
# Epoch 131/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.6512 - smape_loss: 7.5170e-07 - mae_denorm: 7.8924e-07Tiempo on_epoch_end 2024-10-28 17:34:24
# 21/21 [==============================] - 0s 13ms/step - loss: 0.6502 - smape_loss: 7.6666e-07 - mae_denorm: 8.0495e-07 - val_loss: 2.6031 - val_smape_loss: 1.7139 - val_mae_denorm: 1527811.0000
# Epoch 132/500
# 17/21 [=======================>......] - ETA: 0s - loss: 0.6476 - smape_loss: 7.6420e-07 - mae_denorm: 8.0236e-07Tiempo on_epoch_end 2024-10-28 17:34:24
# ...
# Epoch 457/500
# 21/21 [==============================] - ETA: 0s - loss: 0.6259 - smape_loss: 7.6609e-07 - mae_denorm: 8.0435e-07Tiempo on_epoch_end 2024-10-28 17:36:12
# 21/21 [==============================] - 0s 19ms/step - loss: 0.6259 - smape_loss: 7.6609e-07 - mae_denorm: 8.0435e-07 - val_loss: 2.3346 - val_smape_loss: 1.6779 - val_mae_denorm: 451282.2500
# Epoch 458/500
# 18/21 [========================>.....] - ETA: 0s - loss: 0.6161 - smape_loss: 7.6976e-07 - mae_denorm: 8.0820e-07Tiempo on_epoch_end 2024-10-28 17:36:12
# 21/21 [==============================] - 0s 17ms/step - loss: 0.6162 - smape_loss: 7.6566e-07 - mae_denorm: 8.0390e-07 - val_loss: 2.3344 - val_smape_loss: 1.6774 - val_mae_denorm: 441644.7500
# Epoch 459/500
# 21/21 [==============================] - ETA: 0s - loss: 0.6096 - smape_loss: 7.6484e-07 - mae_denorm: 8.0303e-07Tiempo on_epoch_end 2024-10-28 17:36:13
# 21/21 [==============================] - 0s 18ms/step - loss: 0.6096 - smape_loss: 7.6484e-07 - mae_denorm: 8.0303e-07 - val_loss: 2.3244 - val_smape_loss: 1.6793 - val_mae_denorm: 489589.9375
# Epoch 460/500
# 20/21 [===========================>..] - ETA: 0s - loss: 0.6086 - smape_loss: 7.5879e-07 - mae_denorm: 7.9668e-07Tiempo on_epoch_end 2024-10-28 17:36:13
# 21/21 [==============================] - 0s 20ms/step - loss: 0.6087 - smape_loss: 7.6481e-07 - mae_denorm: 8.0301e-07 - val_loss: 2.3020 - val_smape_loss: 1.6761 - val_mae_denorm: 455017.1875
# Epoch 461/500
# 21/21 [==============================] - ETA: 0s - loss: 0.6090 - smape_loss: 7.6468e-07 - mae_denorm: 8.0287e-07Tiempo on_epoch_end 2024-10-28 17:36:14
# 21/21 [==============================] - 0s 20ms/step - loss: 0.6090 - smape_loss: 7.6468e-07 - mae_denorm: 8.0287e-07 - val_loss: 2.3248 - val_smape_loss: 1.6754 - val_mae_denorm: 493692.0000
# Epoch 462/500
# 20/21 [===========================>..] - ETA: 0s - loss: 0.6086 - smape_loss: 7.6591e-07 - mae_denorm: 8.0416e-07Tiempo on_epoch_end 2024-10-28 17:36:14
# 21/21 [==============================] - 0s 20ms/step - loss: 0.6083 - smape_loss: 7.6473e-07 - mae_denorm: 8.0292e-07 - val_loss: 2.3040 - val_smape_loss: 1.6740 - val_mae_denorm: 457087.6250
# Epoch 463/500
# 21/21 [==============================] - ETA: 0s - loss: 0.6100 - smape_loss: 7.6520e-07 - mae_denorm: 8.0341e-07Tiempo on_epoch_end 2024-10-28 17:36:15
# 21/21 [==============================] - 0s 21ms/step - loss: 0.6100 - smape_loss: 7.6520e-07 - mae_denorm: 8.0341e-07 - val_loss: 2.3059 - val_smape_loss: 1.6744 - val_mae_denorm: 497946.6562
# Epoch 464/500
# 18/21 [========================>.....] - ETA: 0s - loss: 0.6126 - smape_loss: 7.4955e-07 - mae_denorm: 7.8698e-07Tiempo on_epoch_end 2024-10-28 17:36:15
# 21/21 [==============================] - 0s 17ms/step - loss: 0.6127 - smape_loss: 7.6520e-07 - mae_denorm: 8.0341e-07 - val_loss: 2.2746 - val_smape_loss: 1.6664 - val_mae_denorm: 386216.5000
# Epoch 465/500
# 20/21 [===========================>..] - ETA: 0s - loss: 0.6089 - smape_loss: 7.6184e-07 - mae_denorm: 7.9989e-07Tiempo on_epoch_end 2024-10-28 17:36:15
# 21/21 [==============================] - 0s 14ms/step - loss: 0.6091 - smape_loss: 7.6482e-07 - mae_denorm: 8.0302e-07 - val_loss: 2.2948 - val_smape_loss: 1.6719 - val_mae_denorm: 420590.6562
# Epoch 466/500
# 20/21 [===========================>..] - ETA: 0s - loss: 0.6064 - smape_loss: 7.6454e-07 - mae_denorm: 8.0272e-07Tiempo on_epoch_end 2024-10-28 17:36:16
# 21/21 [==============================] - 0s 14ms/step - loss: 0.6061 - smape_loss: 7.6479e-07 - mae_denorm: 8.0298e-07 - val_loss: 2.2966 - val_smape_loss: 1.6692 - val_mae_denorm: 423047.9688
# Epoch 467/500
# 21/21 [==============================] - ETA: 0s - loss: 0.6118 - smape_loss: 7.6514e-07 - mae_denorm: 8.0335e-07Tiempo on_epoch_end 2024-10-28 17:36:16
# 21/21 [==============================] - 0s 14ms/step - loss: 0.6118 - smape_loss: 7.6514e-07 - mae_denorm: 8.0335e-07 - val_loss: 2.3222 - val_smape_loss: 1.6736 - val_mae_denorm: 495492.6250
# Epoch 468/500
# 20/21 [===========================>..] - ETA: 0s - loss: 0.6069 - smape_loss: 7.5587e-07 - mae_denorm: 7.9362e-07Tiempo on_epoch_end 2024-10-28 17:36:16
# 21/21 [==============================] - 0s 17ms/step - loss: 0.6079 - smape_loss: 7.6457e-07 - mae_denorm: 8.0275e-07 - val_loss: 2.3183 - val_smape_loss: 1.6841 - val_mae_denorm: 548913.6875
# Epoch 469/500
# 20/21 [===========================>..] - ETA: 0s - loss: 0.6094 - smape_loss: 7.7370e-07 - mae_denorm: 8.1234e-07Tiempo on_epoch_end 2024-10-28 17:36:17
# 21/21 [==============================] - 0s 15ms/step - loss: 0.6087 - smape_loss: 7.6468e-07 - mae_denorm: 8.0286e-07 - val_loss: 2.3040 - val_smape_loss: 1.6804 - val_mae_denorm: 541663.8125
# Epoch 470/500
# 21/21 [==============================] - ETA: 0s - loss: 0.6005 - smape_loss: 7.6416e-07 - mae_denorm: 8.0232e-07Tiempo on_epoch_end 2024-10-28 17:36:17
# 21/21 [==============================] - 0s 14ms/step - loss: 0.6005 - smape_loss: 7.6416e-07 - mae_denorm: 8.0232e-07 - val_loss: 2.2907 - val_smape_loss: 1.6804 - val_mae_denorm: 557082.0625
# Epoch 471/500
# 20/21 [===========================>..] - ETA: 0s - loss: 0.6015 - smape_loss: 7.6886e-07 - mae_denorm: 8.0726e-07Tiempo on_epoch_end 2024-10-28 17:36:17
# 21/21 [==============================] - 0s 16ms/step - loss: 0.6025 - smape_loss: 7.6399e-07 - mae_denorm: 8.0214e-07 - val_loss: 2.2924 - val_smape_loss: 1.6830 - val_mae_denorm: 530804.8125
# Epoch 472/500
# 21/21 [==============================] - ETA: 0s - loss: 0.5987 - smape_loss: 7.6400e-07 - mae_denorm: 8.0215e-07Tiempo on_epoch_end 2024-10-28 17:36:18
# 21/21 [==============================] - 0s 16ms/step - loss: 0.5987 - smape_loss: 7.6400e-07 - mae_denorm: 8.0215e-07 - val_loss: 2.2882 - val_smape_loss: 1.6880 - val_mae_denorm: 507577.3438
# Epoch 473/500
# 21/21 [==============================] - ETA: 0s - loss: 0.5968 - smape_loss: 7.6363e-07 - mae_denorm: 8.0176e-07Tiempo on_epoch_end 2024-10-28 17:36:18
# 21/21 [==============================] - 0s 16ms/step - loss: 0.5968 - smape_loss: 7.6363e-07 - mae_denorm: 8.0176e-07 - val_loss: 2.3077 - val_smape_loss: 1.6915 - val_mae_denorm: 656238.1875
# Epoch 474/500
# 21/21 [==============================] - ETA: 0s - loss: 0.6001 - smape_loss: 7.6402e-07 - mae_denorm: 8.0218e-07Tiempo on_epoch_end 2024-10-28 17:36:18
# 21/21 [==============================] - 0s 15ms/step - loss: 0.6001 - smape_loss: 7.6402e-07 - mae_denorm: 8.0218e-07 - val_loss: 2.3010 - val_smape_loss: 1.6869 - val_mae_denorm: 587153.5625
# Epoch 475/500
# 21/21 [==============================] - ETA: 0s - loss: 0.6003 - smape_loss: 7.6372e-07 - mae_denorm: 8.0186e-07Tiempo on_epoch_end 2024-10-28 17:36:19
# 21/21 [==============================] - 0s 14ms/step - loss: 0.6003 - smape_loss: 7.6372e-07 - mae_denorm: 8.0186e-07 - val_loss: 2.3171 - val_smape_loss: 1.6909 - val_mae_denorm: 649885.2500
# Epoch 476/500
# 21/21 [==============================] - ETA: 0s - loss: 0.5978 - smape_loss: 7.6321e-07 - mae_denorm: 8.0132e-07Tiempo on_epoch_end 2024-10-28 17:36:19
# 21/21 [==============================] - 0s 14ms/step - loss: 0.5978 - smape_loss: 7.6321e-07 - mae_denorm: 8.0132e-07 - val_loss: 2.2733 - val_smape_loss: 1.6849 - val_mae_denorm: 568012.4375
# Epoch 477/500
# 20/21 [===========================>..] - ETA: 0s - loss: 0.5991 - smape_loss: 7.6274e-07 - mae_denorm: 8.0082e-07Tiempo on_epoch_end 2024-10-28 17:36:19
# 21/21 [==============================] - 0s 15ms/step - loss: 0.5990 - smape_loss: 7.6364e-07 - mae_denorm: 8.0177e-07 - val_loss: 2.2701 - val_smape_loss: 1.6833 - val_mae_denorm: 690711.6250
# Epoch 478/500
# 21/21 [==============================] - ETA: 0s - loss: 0.6060 - smape_loss: 7.6456e-07 - mae_denorm: 8.0274e-07Tiempo on_epoch_end 2024-10-28 17:36:19
# 21/21 [==============================] - 0s 14ms/step - loss: 0.6060 - smape_loss: 7.6456e-07 - mae_denorm: 8.0274e-07 - val_loss: 2.2068 - val_smape_loss: 1.6716 - val_mae_denorm: 468252.5312
# Epoch 479/500
# 20/21 [===========================>..] - ETA: 0s - loss: 0.5934 - smape_loss: 7.5868e-07 - mae_denorm: 7.9656e-07Tiempo on_epoch_end 2024-10-28 17:36:20
# 21/21 [==============================] - 0s 14ms/step - loss: 0.5937 - smape_loss: 7.6285e-07 - mae_denorm: 8.0095e-07 - val_loss: 2.2341 - val_smape_loss: 1.6795 - val_mae_denorm: 599096.8125
# Epoch 480/500
# 21/21 [==============================] - ETA: 0s - loss: 0.5904 - smape_loss: 7.6214e-07 - mae_denorm: 8.0020e-07Tiempo on_epoch_end 2024-10-28 17:36:20
# 21/21 [==============================] - 0s 16ms/step - loss: 0.5904 - smape_loss: 7.6214e-07 - mae_denorm: 8.0020e-07 - val_loss: 2.2220 - val_smape_loss: 1.6717 - val_mae_denorm: 547585.0625
# Epoch 481/500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.5999 - smape_loss: 7.5099e-07 - mae_denorm: 7.8849e-07Tiempo on_epoch_end 2024-10-28 17:36:20
# 21/21 [==============================] - 0s 15ms/step - loss: 0.5999 - smape_loss: 7.6389e-07 - mae_denorm: 8.0203e-07 - val_loss: 2.1949 - val_smape_loss: 1.6681 - val_mae_denorm: 468952.3438
# Epoch 482/500
# 18/21 [========================>.....] - ETA: 0s - loss: 0.5991 - smape_loss: 7.4728e-07 - mae_denorm: 7.8460e-07Tiempo on_epoch_end 2024-10-28 17:36:21
# 21/21 [==============================] - 0s 16ms/step - loss: 0.5995 - smape_loss: 7.6361e-07 - mae_denorm: 8.0174e-07 - val_loss: 2.2153 - val_smape_loss: 1.6813 - val_mae_denorm: 485622.9688
# Epoch 483/500
# 21/21 [==============================] - ETA: 0s - loss: 0.6016 - smape_loss: 7.6361e-07 - mae_denorm: 8.0174e-07Tiempo on_epoch_end 2024-10-28 17:36:21
# 21/21 [==============================] - 0s 14ms/step - loss: 0.6016 - smape_loss: 7.6361e-07 - mae_denorm: 8.0174e-07 - val_loss: 2.1878 - val_smape_loss: 1.6685 - val_mae_denorm: 387447.0625
# Epoch 484/500
# 20/21 [===========================>..] - ETA: 0s - loss: 0.5951 - smape_loss: 7.5857e-07 - mae_denorm: 7.9645e-07Tiempo on_epoch_end 2024-10-28 17:36:21
# 21/21 [==============================] - 0s 16ms/step - loss: 0.5936 - smape_loss: 7.6257e-07 - mae_denorm: 8.0065e-07 - val_loss: 2.1896 - val_smape_loss: 1.6684 - val_mae_denorm: 427138.3750
# Epoch 485/500
# 21/21 [==============================] - ETA: 0s - loss: 0.5945 - smape_loss: 7.6274e-07 - mae_denorm: 8.0083e-07Tiempo on_epoch_end 2024-10-28 17:36:22
# 21/21 [==============================] - 0s 16ms/step - loss: 0.5945 - smape_loss: 7.6274e-07 - mae_denorm: 8.0083e-07 - val_loss: 2.2165 - val_smape_loss: 1.6717 - val_mae_denorm: 440166.0938
# Epoch 486/500
# 21/21 [==============================] - ETA: 0s - loss: 0.5923 - smape_loss: 7.6304e-07 - mae_denorm: 8.0114e-07Tiempo on_epoch_end 2024-10-28 17:36:22
# 21/21 [==============================] - 0s 14ms/step - loss: 0.5923 - smape_loss: 7.6304e-07 - mae_denorm: 8.0114e-07 - val_loss: 2.1923 - val_smape_loss: 1.6610 - val_mae_denorm: 404543.3125
# Epoch 487/500
# 20/21 [===========================>..] - ETA: 0s - loss: 0.6077 - smape_loss: 7.5680e-07 - mae_denorm: 7.9459e-07Tiempo on_epoch_end 2024-10-28 17:36:22
# 21/21 [==============================] - 0s 15ms/step - loss: 0.6080 - smape_loss: 7.6512e-07 - mae_denorm: 8.0332e-07 - val_loss: 2.1828 - val_smape_loss: 1.6597 - val_mae_denorm: 412453.9062
# Epoch 488/500
# 21/21 [==============================] - ETA: 0s - loss: 0.5962 - smape_loss: 7.6328e-07 - mae_denorm: 8.0140e-07Tiempo on_epoch_end 2024-10-28 17:36:23
# 21/21 [==============================] - 0s 14ms/step - loss: 0.5962 - smape_loss: 7.6328e-07 - mae_denorm: 8.0140e-07 - val_loss: 2.1791 - val_smape_loss: 1.6621 - val_mae_denorm: 448239.0938
# Epoch 489/500
# 21/21 [==============================] - ETA: 0s - loss: 0.5908 - smape_loss: 7.6272e-07 - mae_denorm: 8.0081e-07Tiempo on_epoch_end 2024-10-28 17:36:23
# 21/21 [==============================] - 0s 14ms/step - loss: 0.5908 - smape_loss: 7.6272e-07 - mae_denorm: 8.0081e-07 - val_loss: 2.1492 - val_smape_loss: 1.6539 - val_mae_denorm: 299124.5938
# Epoch 490/500
# 20/21 [===========================>..] - ETA: 0s - loss: 0.5930 - smape_loss: 7.6400e-07 - mae_denorm: 8.0215e-07Tiempo on_epoch_end 2024-10-28 17:36:23
# 21/21 [==============================] - 0s 15ms/step - loss: 0.5932 - smape_loss: 7.6436e-07 - mae_denorm: 8.0253e-07 - val_loss: 2.2214 - val_smape_loss: 1.6691 - val_mae_denorm: 498530.2188
# Epoch 491/500
# 21/21 [==============================] - ETA: 0s - loss: 0.6002 - smape_loss: 7.6295e-07 - mae_denorm: 8.0105e-07Tiempo on_epoch_end 2024-10-28 17:36:24
# 21/21 [==============================] - 0s 14ms/step - loss: 0.6002 - smape_loss: 7.6295e-07 - mae_denorm: 8.0105e-07 - val_loss: 2.2971 - val_smape_loss: 1.6829 - val_mae_denorm: 866322.4375
# Epoch 492/500
# 21/21 [==============================] - ETA: 0s - loss: 0.6061 - smape_loss: 7.6585e-07 - mae_denorm: 8.0409e-07Tiempo on_epoch_end 2024-10-28 17:36:24
# 21/21 [==============================] - 0s 16ms/step - loss: 0.6061 - smape_loss: 7.6585e-07 - mae_denorm: 8.0409e-07 - val_loss: 2.2142 - val_smape_loss: 1.6622 - val_mae_denorm: 625942.7500
# Epoch 493/500
# 20/21 [===========================>..] - ETA: 0s - loss: 0.6078 - smape_loss: 7.6571e-07 - mae_denorm: 8.0395e-07Tiempo on_epoch_end 2024-10-28 17:36:24
# 21/21 [==============================] - 0s 14ms/step - loss: 0.6081 - smape_loss: 7.6572e-07 - mae_denorm: 8.0396e-07 - val_loss: 2.1975 - val_smape_loss: 1.6744 - val_mae_denorm: 542740.8125
# Epoch 494/500
# 21/21 [==============================] - ETA: 0s - loss: 0.6165 - smape_loss: 7.6626e-07 - mae_denorm: 8.0452e-07Tiempo on_epoch_end 2024-10-28 17:36:24
# 21/21 [==============================] - 0s 16ms/step - loss: 0.6165 - smape_loss: 7.6626e-07 - mae_denorm: 8.0452e-07 - val_loss: 2.1657 - val_smape_loss: 1.6670 - val_mae_denorm: 340313.1250
# Epoch 495/500
# 20/21 [===========================>..] - ETA: 0s - loss: 0.6082 - smape_loss: 7.6810e-07 - mae_denorm: 8.0646e-07Tiempo on_epoch_end 2024-10-28 17:36:25
# 21/21 [==============================] - 0s 17ms/step - loss: 0.6084 - smape_loss: 7.6622e-07 - mae_denorm: 8.0449e-07 - val_loss: 2.1904 - val_smape_loss: 1.6876 - val_mae_denorm: 1152735.2500
# Epoch 496/500
# 21/21 [==============================] - ETA: 0s - loss: 0.5997 - smape_loss: 7.6540e-07 - mae_denorm: 8.0362e-07Tiempo on_epoch_end 2024-10-28 17:36:25
# 21/21 [==============================] - 0s 18ms/step - loss: 0.5997 - smape_loss: 7.6540e-07 - mae_denorm: 8.0362e-07 - val_loss: 2.2411 - val_smape_loss: 1.6998 - val_mae_denorm: 1089149.2500
# Epoch 497/500
# 18/21 [========================>.....] - ETA: 0s - loss: 0.6080 - smape_loss: 7.7609e-07 - mae_denorm: 8.1485e-07Tiempo on_epoch_end 2024-10-28 17:36:26
# 21/21 [==============================] - 0s 19ms/step - loss: 0.6090 - smape_loss: 7.6786e-07 - mae_denorm: 8.0620e-07 - val_loss: 2.1650 - val_smape_loss: 1.6848 - val_mae_denorm: 1057474.8750
# Epoch 498/500
# 21/21 [==============================] - ETA: 0s - loss: 0.6127 - smape_loss: 7.6698e-07 - mae_denorm: 8.0528e-07Tiempo on_epoch_end 2024-10-28 17:36:26
# 21/21 [==============================] - 0s 19ms/step - loss: 0.6127 - smape_loss: 7.6698e-07 - mae_denorm: 8.0528e-07 - val_loss: 2.1428 - val_smape_loss: 1.6684 - val_mae_denorm: 491028.0000
# Epoch 499/500
# 21/21 [==============================] - ETA: 0s - loss: 0.6140 - smape_loss: 7.6602e-07 - mae_denorm: 8.0427e-07Tiempo on_epoch_end 2024-10-28 17:36:26
# 21/21 [==============================] - 0s 19ms/step - loss: 0.6140 - smape_loss: 7.6602e-07 - mae_denorm: 8.0427e-07 - val_loss: 2.1268 - val_smape_loss: 1.6677 - val_mae_denorm: 450816.2812
# Epoch 500/500
# 21/21 [==============================] - ETA: 0s - loss: 0.6006 - smape_loss: 7.6423e-07 - mae_denorm: 8.0239e-07Tiempo on_epoch_end 2024-10-28 17:36:27
# 21/21 [==============================] - 0s 20ms/step - loss: 0.6006 - smape_loss: 7.6423e-07 - mae_denorm: 8.0239e-07 - val_loss: 2.1152 - val_smape_loss: 1.6742 - val_mae_denorm: 428165.9375
# Tiempo Final y n_past 2024-10-28 17:37:02   n_past:--> 60

# %%
from matplotlib import pyplot as plt
plt.plot(history_modelo.history['loss'])
plt.plot(history_modelo.history['val_loss'])
#plt.plot(history_modelo.history['val_smape_loss_zscore'])
plt.title('model accuracy')
plt.ylabel('loss')
plt.xlabel('epoch')
#plt.legend(['loss', 'val_loss','val_smape_loss_zscore'], loc='upper left')
plt.legend(['loss', 'val_loss'], loc='upper left')
plt.show()
best_score=min(history_modelo.history['val_loss'])
print('best_score',best_score)
#best_score_smape=min(history_modelo.history['val_smape_loss_zscore'])
#print('best_score smape',best_score_smape)
# Out:
# best_score 2.070455312728882

# %%
from keras.utils import plot_model

fileplot=pathModelosJson
plot_model(reconstructed_model2, to_file=fileplot+'/model_plot.png', show_shapes=True, show_layer_names=True)

# %%
# %load_ext tensorboard

# %tensorboard --logdir "/content/drive/MyDrive/a Tesis de Grado/Tesis Versiones/tesis2023/Google Analytics 4/Tum Transmedia/modelos/modelos guardados/prueba1-30porciento/logs10divNday21DiasAtras"

# %%
from tensorflow.keras.saving import register_keras_serializable
media_train=train_previo_zscore['Número de vistas de página'].std()
std_train=train_previo_zscore['Número de vistas de página'].mean()
#esta metrica esta en el codigo de github del ganador
@register_keras_serializable()
def smape_loss(y_true, y_pred):
    #revierto zscore
    global media_train
    global std_train
    y_true=(y_true*std_train)+media_train
    y_pred=(y_pred*std_train)+media_train
    #revierto log1p
    y_true=tf.math.expm1(y_true)
    y_pred=tf.math.expm1(y_pred)
    epsilon = 0.1
    y_pred = tf.convert_to_tensor(y_pred)
    y_true = tf.cast(y_true, y_pred.dtype)
    # Calcular el denominador de SMAPE
    summ = tf.maximum(tf.abs(y_true) + tf.abs(y_pred) + epsilon, 0.5 + epsilon)

    # Calcular SMAPE
    smape = tf.abs(y_pred - y_true) / summ * 2.0

    # Retornar la media de SMAPE
    return K.mean(smape, axis=-1)

@register_keras_serializable()
def mae_denorm(y_true, y_pred):
    #revierto zscore
    global media_train
    global std_train
    y_true1=(y_true*std_train)+media_train
    y_pred1=(y_pred*std_train)+media_train
    #revierto log1p
    y_true2=tf.math.expm1(y_true1)
    y_pred2=tf.math.expm1(y_pred1)

    return tf.keras.losses.mean_absolute_error(y_true2, y_pred2)

# %%
#el mejor modelo de verdad
#pathModelosJsonMejor="/content/drive/MyDrive/a Tesis de Grado/Tesis Versiones/tesis 2024/UA/tum transmedia/modelos/modelos resultados/mejores modelos guardados/modelo"
#nombreMejorModeloMejor="/ ndays60hyperband mae 60 zscore.h5"#el mejor modelo es el hyperband de 28 dias y 107 época
pathModelosJsonMejor="/content/drive/MyDrive/a Tesis de Grado/Tesis Versiones/tesis 2024/UA/editorial universitaria/modelos/modelos resultados/prueba 500 epocas 1 capas sin early stopping"
nombreMejorModeloMejor="/hyperband202-2.070455-ndays60_500epochs1capa.h5"#el mejor modelo es el hyperband de 28 dias y 107 época
n_past=60
cambio=datetime.datetime.now(timezone('UTC')) - timedelta(hours=3)
tiempoFinal=f"{cambio:%Y-%m-%d %H:%M:%S }"
print('Tiempo  Inicio y n_past',tiempoFinal , ' n_past:-->',n_past)
n_future = 60
n_features = train.shape[1]
X_train, y_train = split_series(train.values,n_past, n_future)
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1],n_features))
y_train = y_train.reshape((y_train.shape[0], y_train.shape[1], 1)) #no hace falta reshapear
X_test, y_test = split_series(test.values,n_past, n_future)
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1],n_features))
y_test = y_test.reshape((y_test.shape[0], y_test.shape[1], 1)) #no hace falta reshapear

reconstructed_model3 = tf.keras.models.load_model(pathModelosJsonMejor+nombreMejorModeloMejor,custom_objects={'smape_loss':smape_loss,'mae_denorm':mae_denorm})
# Out:
# Tiempo  Inicio y n_past 2024-10-28 17:37:48   n_past:--> 60

# %%
print("Evaluate on test data")
results = reconstructed_model3.evaluate(X_test,y_test, batch_size=64)
print("test loss", results)
# Out:
# Evaluate on test data
# 4/4 [==============================] - 1s 12ms/step - loss: 2.0705 - smape_loss: 1.6390 - mae_denorm: 324527.3438
# test loss [2.070455312728882, 1.6390471458435059, 324527.34375]

# %%
pred_e1d1=reconstructed_model3.predict(X_test, batch_size=64)
pred_e1d1=deepcopy(pred_e1d1)
reshapePred=pred_e1d1.reshape((pred_e1d1.shape[0]*pred_e1d1.shape[2]),pred_e1d1.shape[1])
reshapeY_test=y_test.reshape((y_test.shape[0]*y_test.shape[2]),y_test.shape[1])
print(pred_e1d1.shape,reshapePred.shape)
print('y_test',y_test.shape,reshapeY_test.shape)
def smape2(a, f):
    print('len(a)',len(a))

    #std=train_previo_zscore['Predictor Flag'].std()
    #media=train_previo_zscore['Predictor Flag'].mean()
    std=train_previo_zscore['Número de vistas de página'].std()
    media=train_previo_zscore['Número de vistas de página'].mean()
    #revierto zscore
    a=(a*std)+media
    f=(f*std)+media

    a=np.round(np.expm1(a))
    f=np.round(np.expm1(f))
    print('a',a)
    print('f',f)
    return (1/len(a) * np.sum(2 * np.abs(f-a) / (np.abs(a) + np.abs(f))) )

def mae_manual(a, f):
    print('len(a)', len(a))

    # Obtener la desviación estándar y media
    std = train_previo_zscore['Número de vistas de página'].std()
    media = train_previo_zscore['Número de vistas de página'].mean()

    # Revertir z-score
    a = (a * std) + media
    f = (f * std) + media

    a=np.round(np.expm1(a))
    f=np.round(np.expm1(f))
    print('a mae',a)
    print('f mae',f)

    epsilon = 0.1  # Valor para evitar divisiones por cero
    diff =np.abs(a-f)
    return np.mean(diff)#(1 / len(a)) * np.sum(diff)

def rmse_manual(a, f):
    print('len(a)', len(a))

    # Obtener la desviación estándar y media
    std = train_previo_zscore['Número de vistas de página'].std()
    media = train_previo_zscore['Número de vistas de página'].mean()

    # Revertir z-score
    a = (a * std) + media
    f = (f * std) + media

    a=np.round(np.expm1(a))
    f=np.round(np.expm1(f))

    # Calcular el RMSE (Error Cuadrático Medio)
    diff = np.square(a - f)  # Cuadrado de la diferencia
    mse = np.mean(diff)  # Error Cuadrático Medio
    rmse_calculado = np.sqrt(mse)  # Raíz cuadrada del MSE

    return rmse_calculado

auxpred=reshapePred.reshape((y_test.shape[0]*y_test.shape[1]),1)
auxpred2=auxpred.reshape((auxpred.shape[0]),)
auxY_test=reshapeY_test.reshape((y_test.shape[0]*y_test.shape[1]),1)
print(auxpred.shape)
print('smape',smape2(auxY_test,auxpred))
print('mae',mae_manual(auxY_test,auxpred))
print('rmse',rmse_manual(auxY_test,auxpred))
print(auxpred2.shape)
print(np.array([1,2,3]).shape)
print(auxpred2)
# Out:
# 4/4 [==============================] - 0s 7ms/step
# (244, 60, 1) (244, 60)
# y_test (244, 60, 1) (244, 60)
# (14640, 1)
# len(a) 14640
# a [[ 28.]
#  [ 54.]
#  [157.]
#  ...
#  [ 88.]
#  [103.]
#  [148.]]
# f [[194.]
#  [200.]
#  [210.]
#  ...
#  [448.]
#  [450.]
#  [452.]]
# smape 1.1840436456845502
# len(a) 14640
# a mae [[ 28.]
#  [ 54.]
#  [157.]
#  ...
#  [ 88.]
#  [103.]
#  [148.]]
# f mae [[194.]
#  [200.]
#  [210.]
#  ...
#  [448.]
#  [450.]
#  [452.]]
# mae 258.669262295082
# len(a) 14640
# rmse 364.6410537603133
# (14640,)
# (3,)
# [1.1159161 1.1519629 1.2081755 ... 2.0789726 2.0841532 2.0892227]

# %%
test_previo_log1p['Número de vistas de página']
X_test5, y_test5 = split_series(test_previo_log1p.values,n_past, n_future)
y_test5
# Out:
# array([[ 28.,  54., 157., ...,  17.,  58.,  61.],
#        [ 54., 157., 265., ...,  58.,  61.,  58.],
#        [157., 265., 202., ...,  61.,  58.,  28.],
#        ...,
#        [ 80.,  63.,  82., ...,  46.,  58.,  88.],
#        [ 63.,  82., 188., ...,  58.,  88., 103.],
#        [ 82., 188., 202., ...,  88., 103., 148.]])

# %%
y_test5.shape
# Out:
# (244, 60)

# %%
auxY_test.shape
# Out:
# (14640, 1)

# %%
# Obtener la desviación estándar y media
import matplotlib.pyplot as plt
std = train_previo_zscore['Número de vistas de página'].std()
media = train_previo_zscore['Número de vistas de página'].mean()

# Revertir z-score
#denorm_actually=(auxY_test*std)+media
#denorm_forecast=(auxpred*std)+media

#denorm_actually = np.array(denorm_actually)
#denorm_forecast = np.array(denorm_forecast)
def denorm_manual(a, f):
    print('len(a)', len(a))

    # Obtener la desviación estándar y media
    std = train_previo_zscore['Número de vistas de página'].std()
    media = train_previo_zscore['Número de vistas de página'].mean()

    # Revertir z-score
    a = (a * std) + media
    f = (f * std) + media

    a=np.round(np.expm1(a))
    f=np.round(np.expm1(f))

    return a,f
denorm_actually,denorm_forecast=  denorm_manual(auxY_test,auxpred)
# Crear un rango de índices para el eje x
x = np.arange(len(denorm_actually))

# Crear el plot
plt.figure(figsize=(10, 6))
#ultimos 60
plt.plot( denorm_actually[-60:], label='Valores de Reales', color='blue')
plt.plot( denorm_forecast[-60:], label='Valores de Pronosticados', color='orange')
#primeros 60
#plt.plot(np.arange(len(denorm_actually[:90])) ,denorm_actually[:90], label='Valores de Reales', color='blue')
#plt.plot(np.arange(len(denorm_actually[:90])) ,denorm_forecast[:90], label='Valores de Pronosticados', color='orange')
print(denorm_actually[:1])
plt.title('Comparación de valores de Actuales y Predichos')
plt.xlabel('-')
plt.ylabel('Vistas')
plt.legend()
plt.grid()
plt.show()
# Out:
# len(a) 14640
# [[28.]]

# %%
mae_manual(auxY_test[:60],auxpred[:60])
# Out:
# len(a) 60
# a mae [[ 28.]
#  [ 54.]
#  [157.]
#  [265.]
#  [202.]
#  [ 23.]
#  [ 24.]
#  [ 15.]
#  [ 41.]
#  [386.]
#  [106.]
#  [ 57.]
#  [ 40.]
#  [107.]
#  [ 31.]
#  [ 11.]
#  [112.]
#  [ 80.]
#  [121.]
#  [ 37.]
#  [ 19.]
#  [  6.]
#  [ 29.]
#  [ 60.]
#  [ 19.]
#  [152.]
#  [161.]
#  [ 28.]
#  [ 84.]
#  [ 18.]
#  [ 38.]
#  [ 37.]
#  [ 43.]
#  [ 35.]
#  [ 32.]
#  [ 52.]
#  [ 14.]
#  [ 50.]
#  [ 34.]
#  [ 33.]
#  [ 24.]
#  [ 33.]
#  [ 15.]
#  [ 13.]
#  [ 24.]
#  [ 42.]
#  [ 25.]
#  [ 45.]
#  [ 28.]
#  [ 26.]
#  [ 49.]
#  [ 40.]
#  [ 26.]
#  [ 28.]
#  [ 47.]
#  [ 76.]
#  [ 17.]
#  [ 17.]
#  [ 58.]
#  [ 61.]]
# f mae [[194.]
#  [200.]
#  [210.]
#  [226.]
#  [243.]
#  [259.]
#  [274.]
#  [288.]
#  [302.]
#  [315.]
#  [328.]
#  [339.]
#  [351.]
#  [362.]
#  [372.]
#  [383.]
#  [393.]
#  [402.]
#  [412.]
#  [421.]
#  [429.]
#  [438.]
#  [446.]
#  [454.]
#  [462.]
#  [470.]
#  [478.]
#  [485.]
#  [492.]
#  [499.]
#  [506.]
#  [513.]
#  [520.]
#  [526.]
#  [532.]
#  [539.]
#  [545.]
#  [551.]
#  [556.]
#  [562.]
#  [568.]
#  [573.]
#  [579.]
#  [584.]
#  [589.]
#  [594.]
#  [599.]
#  [604.]
#  [608.]
#  [613.]
#  [618.]
#  [622.]
#  [626.]
#  [631.]
#  [635.]
#  [639.]
#  [643.]
#  [647.]
#  [651.]
#  [655.]]
# 420.6666666666667
